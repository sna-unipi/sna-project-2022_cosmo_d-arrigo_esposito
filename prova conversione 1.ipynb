# %%
import pandas as pd
df = pd.read_json (r'C:\Users\naomi\Documents\GitHub\sna-project-2022_cosmo_d-arrigo_esposito\data_travel_tags.json')
df.to_csv (r'C:\Users\naomi\Documents\GitHub\sna-project-2022_cosmo_d-arrigo_esposito\datafile_new_travel.csv', index = None)

# %%
df
# Out:
#     backoff  has_more  page  quota_max  quota_remaining  total  \
# 0         0     False     1      10000             9999      0
# 1         0     False     1      10000             9999      0
# 2         0     False     1      10000             9999      0
# 3         0     False     1      10000             9999      0
# 4         0     False     1      10000             9999      0
# 5         0     False     1      10000             9999      0
# 6         0     False     1      10000             9999      0
# 7         0     False     1      10000             9999      0
# 8         0     False     1      10000             9999      0
# 9         0     False     1      10000             9999      0
# 10        0     False     1      10000             9999      0
# 11        0     False     1      10000             9999      0
# 12        0     False     1      10000             9999      0
# 13        0     False     1      10000             9999      0
# ...

# %%
df.columns
# Out:
# Index(['backoff', 'has_more', 'page', 'quota_max', 'quota_remaining', 'total',
#        'items'],
#       dtype='object')
