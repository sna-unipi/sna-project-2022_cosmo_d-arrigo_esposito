# %%
import pandas as pd

# %%
path = "../Dataset Super Users/questions_2020_2022.csv"

# %%
df = pd.read_csv(path)

# %%
df['Tags']
# Out:
# 0              macos|-|python|-|zsh|-|compression|-|tar|-|
# 1                                                 crash|-|
# 2              windows-10|-|memory|-|docker|-|resources|-|
# 3                                   windows|-|uninstall|-|
# 4                                           motherboard|-|
#                                ...
# 49995    linux|-|windows|-|windows-subsystem-for-linux|...
# 49996                                   microsoft-excel|-|
# 49997       microsoft-excel|-|worksheet-function|-|time|-|
# 49998    linux|-|ubuntu|-|mount|-|windows-subsystem-for...
# 49999           microsoft-excel|-|spreadsheet|-|vlookup|-|
# Name: Tags, Length: 50000, dtype: object

# %%
df
# Out:
#                                                     Tags  \
# 0            macos|-|python|-|zsh|-|compression|-|tar|-|
# 1                                               crash|-|
# 2            windows-10|-|memory|-|docker|-|resources|-|
# 3                                 windows|-|uninstall|-|
# 4                                         motherboard|-|
# ...                                                  ...
# 49995  linux|-|windows|-|windows-subsystem-for-linux|...
# 49996                                 microsoft-excel|-|
# 49997     microsoft-excel|-|worksheet-function|-|time|-|
# 49998  linux|-|ubuntu|-|mount|-|windows-subsystem-for...
# 49999         microsoft-excel|-|spreadsheet|-|vlookup|-|
#
#                     User_Name  \
# 0      Saaru Lindest&#248;kke
# 1                  Stuntddude
# 2                 CiaranWelsh
# 3                  Anne Maier
# 4                     MechMK1
# ...                       ...
# 49995                    Sean
# ...

# %%
tags = df['Tags']

# %%
tags
# Out:
# 0              macos|-|python|-|zsh|-|compression|-|tar|-|
# 1                                                 crash|-|
# 2              windows-10|-|memory|-|docker|-|resources|-|
# 3                                   windows|-|uninstall|-|
# 4                                           motherboard|-|
#                                ...
# 49995    linux|-|windows|-|windows-subsystem-for-linux|...
# 49996                                   microsoft-excel|-|
# 49997       microsoft-excel|-|worksheet-function|-|time|-|
# 49998    linux|-|ubuntu|-|mount|-|windows-subsystem-for...
# 49999           microsoft-excel|-|spreadsheet|-|vlookup|-|
# Name: Tags, Length: 50000, dtype: object

# %%
tags.to_csv("../Dataset Super Users/tags.csv", index=False)

# %%
apri = pd.read_csv('tags.csv')

# %%
apri
# Out:
#                                                     Tags
# 0            macos|-|python|-|zsh|-|compression|-|tar|-|
# 1                                               crash|-|
# 2            windows-10|-|memory|-|docker|-|resources|-|
# 3                                 windows|-|uninstall|-|
# 4                                         motherboard|-|
# ...                                                  ...
# 49995  linux|-|windows|-|windows-subsystem-for-linux|...
# 49996                                 microsoft-excel|-|
# 49997     microsoft-excel|-|worksheet-function|-|time|-|
# 49998  linux|-|ubuntu|-|mount|-|windows-subsystem-for...
# 49999         microsoft-excel|-|spreadsheet|-|vlookup|-|
#
# [50000 rows x 1 columns]

# %%
ok = pd.read_csv("edges.csv")

# %%
ok
# Out:
#                      Source                Target  Count
# 0                     macos                python     14
# 1                     macos                   zsh     57
# 2                     macos           compression      3
# 3                     macos                   tar      3
# 4                     macos                 crash      3
# ...                     ...                   ...    ...
# 63395          blob-storage                azcopy      1
# 63396             raspberry                   apm      1
# 63397          input-method  chinese-input-method      1
# 63398          input-method             ime-quick      1
# 63399  chinese-input-method             ime-quick      1
#
# [63400 rows x 3 columns]

# %%
ok.head(775)
# Out:
#      Source          Target  Count
# 0     macos          python     14
# 1     macos             zsh     57
# 2     macos     compression      3
# 3     macos             tar      3
# 4     macos           crash      3
# ..      ...             ...    ...
# 770   macos  usb-controller      1
# 771   macos     corestorage      1
# 772   macos       dead-keys      1
# 773   macos        redshift      1
# 774  python             zsh      3
#
# [775 rows x 3 columns]

# %%
ok[ok['Source']=='macos']
# Out:
#     Source          Target  Count
# 0    macos          python     14
# 1    macos             zsh     57
# 2    macos     compression      3
# 3    macos             tar      3
# 4    macos           crash      3
# ..     ...             ...    ...
# 769  macos     system-info      1
# 770  macos  usb-controller      1
# 771  macos     corestorage      1
# 772  macos       dead-keys      1
# 773  macos        redshift      1
#
# [774 rows x 3 columns]

# %%
ok[ok['Source']=='windows-10']
# Out:
#           Source            Target  Count
# 1634  windows-10            memory    144
# 1635  windows-10            docker     14
# 1636  windows-10         resources      1
# 1637  windows-10           windows   1643
# 1638  windows-10         uninstall     33
# ...          ...               ...    ...
# 3525  windows-10           nextdns      1
# 3526  windows-10      preview-pane      1
# 3527  windows-10  case-sensitivity      1
# 3528  windows-10      side-loading      1
# 3529  windows-10        notify-osd      1
#
# [1896 rows x 3 columns]

# %%
ok[ok['Source']=='linux']
# Out:
#       Source        Target  Count
# 9444   linux         audio     82
# 9445   linux     duplicate      1
# 9446   linux           wav      1
# 9447   linux        stereo      1
# 9448   linux           dns     71
# ...      ...           ...    ...
# 11177  linux          nmon      1
# 11178  linux         lando      1
# 11179  linux     dead-keys      1
# 11180  linux  gparted-live      1
# 11181  linux        gunzip      1
#
# [1738 rows x 3 columns]

# %%
ok[ok['Source']=='zoom']
# Out:
#       Source                Target  Count
# 57285   zoom    system-preferences      1
# 57286   zoom        multiple-users      1
# 57287   zoom   fast-user-switching      1
# 57288   zoom        user-switching      1
# 57289   zoom  microsoft-visio-2016      1
# 57290   zoom             magnifier      1
# 57291   zoom                  asio      1
# 57292   zoom   microsoft-surface-3      1
# 57293   zoom               margins      1

# %%
ok[ok['Source']=='skype']
# Out:
#       Source                 Target  Count
# 60017  skype             dictionary      1
# 60018  skype  chrome-remote-desktop      1
# 60019  skype                    bug      1
# 60020  skype     skype-for-business      1
# 60021  skype                    pen      1
# 60022  skype                sharing      1
# 60023  skype                    pin      1
# 60024  skype             teamviewer      1
# 60025  skype                   voip      1
# 60026  skype   skype-for-windows-10      2
# 60027  skype               contacts      1
# 60028  skype          collaboration      1
# 60029  skype      mikrotik-routeros      1
# 60030  skype        citrix-receiver      1
# 60031  skype             voice-chat      1
# 60032  skype             whiteboard      1
# 60033  skype               logitech      1

# %%
ok[ok['Source']=='teams']
# Out:
#       Source     Target  Count
# 59482  teams     column      1
# 59483  teams  microsoft      1

# %%
ok[ok['Source']=='webex']
# Out:
#       Source                            Target  Count
# 62033  webex                              evil      1
# 62034  webex  microsoft-power-automate-desktop      1

# %%
ok[ok['Source']=='chat']
# Out:
#       Source                            Target  Count
# 55986   chat                           restore      1
# 55987   chat                telegram-messenger      1
# 55988   chat                               irc      3
# 55989   chat                         microsoft      1
# 55990   chat                             irssi      1
# 55991   chat  microsoft-power-automate-desktop      1

# %%
ok[ok['Source']=='lessons']
# Out:
# Empty DataFrame
# Columns: [Source, Target, Count]
# Index: []
