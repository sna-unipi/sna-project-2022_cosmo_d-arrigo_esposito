# %%
import networkx as nx
import warnings
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import powerlaw
warnings.filterwarnings('ignore')

# %matplotlib inline

# %%
f = pd.read_csv("..\Dataset Super Users\questions_2020_2022.csv", sep='\t')
g = nx.from_pandas_edgelist(f, source='Tags,User_Name,Title,View_count,Down_vote_count,Up_vote_count,Answer_count,Score,Creation_date,Question_id,Question_link,Is_Answered', target = 'Tags,User_Name,Title,View_count,Down_vote_count,Up_vote_count,Answer_count,Score,Creation_date,Question_id,Question_link,Is_Answered')

# %%
for n in g.nodes():
    # do something
    pass

# %%
for e in g.edges():
    # do something
    pass

# %%
g.number_of_nodes()
# Out:
# 49999

# %%
g.number_of_edges()
# Out:
# 49999

# %%
g.is_directed()
# Out:
# False

# %%
g.degree(1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\networkx\classes\graph.py in bunch_iter(nlist, adj)
#    1895                 try:
# -> 1896                     for n in nlist:
#    1897                         if n in adj:
#
# TypeError: 'int' object is not iterable
#
# The above exception was the direct cause of the following exception:
#
# NetworkXError                             Traceback (most recent call last)
# <ipython-input-30-b6f0afdccbce> in <module>
# ----> 1 g.degree(1)
#
# ~\anaconda3\lib\site-packages\networkx\classes\reportviews.py in __call__(self, nbunch, weight)
#     361         except TypeError:
#     362             pass
# --> 363         return self.__class__(self._graph, nbunch, weight)
#     364
#     365     def __getitem__(self, n):
#
# ...

# %%
sum(dict(g.degree()).values())/float(len(g))
# Out:
# 2.0

# %%
hist = nx.degree_histogram(g)
    
plt.plot(range(0, len(hist)), hist, ".")
plt.title("Degree Distribution")
plt.xlabel("Degree")
plt.ylabel("#Nodes")
plt.loglog()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import math
import numpy as np
import networkx as nx
from operator import itemgetter

# %%
path = "../Dataset Super Users/edges.csv"

# %%
G = nx.read_edgelist(path, comments = "S", delimiter = ",", data=(("Count", int),))
degree_dict = dict(G.degree(G.nodes()))
nx.set_node_attributes(G, degree_dict, 'degree')
sorted_degree = sorted(degree_dict.items(), key = itemgetter(1), reverse = True)

# %%
sorted_degree
# Out:
# [('windows-10', 1901),
#  ('linux', 1762),
#  ('windows', 1686),
#  ('ubuntu', 996),
#  ('networking', 891),
#  ('macos', 774),
#  ('command-line', 687),
#  ('google-chrome', 576),
#  ('windows-7', 569),
#  ('debian', 558),
#  ('powershell', 556),
#  ('hard-drive', 544),
#  ('bash', 522),
#  ('mac', 508),
#  ('usb', 492),
#  ('ssh', 489),
#  ('boot', 479),
#  ('wireless-networking', 474),
#  ('windows-11', 467),
#  ('security', 463),
#  ('microsoft-excel', 448),
#  ('audio', 440),
#  ('firefox', 411),
#  ('drivers', 411),
#  ('laptop', 394),
#  ('ffmpeg', 386),
#  ('virtualbox', 381),
#  ('video', 369),
#  ('python', 361),
#  ('router', 358),
#  ('terminal', 358),
#  ('browser', 356),
#  ('virtual-machine', 356),
#  ('memory', 353),
#  ('ssd', 353),
#  ('keyboard', 348),
#  ('vpn', 342),
#  ('keyboard-shortcuts', 333),
#  ('microsoft-word', 326),
#  ('performance', 323),
#  ('installation', 318),
#  ('display', 318),
#  ('ubuntu-20.04', 317),
#  ('backup', 316),
#  ('dns', 315),
# ...

# %%
ids = []
count = []
named = []
original = []
for i in sorted_degree:
    ids.append(i[0])
    count.append(i[1])
    named.append("unamed")
    original.append(i[0])

# %%
print(count)
# Out:
# [1901, 1762, 1686, 996, 891, 774, 687, 576, 569, 558, 556, 544, 522, 508, 492, 489, 479, 474, 467, 463, 448, 440, 411, 411, 394, 386, 381, 369, 361, 358, 358, 356, 356, 353, 353, 348, 342, 333, 326, 323, 318, 318, 317, 316, 315, 312, 309, 308, 305, 295, 293, 286, 286, 283, 281, 281, 281, 275, 271, 271, 270, 266, 256, 253, 248, 246, 246, 240, 239, 238, 235, 230, 228, 225, 219, 219, 218, 217, 215, 215, 212, 211, 211, 208, 208, 206, 205, 204, 203, 199, 195, 193, 191, 188, 188, 188, 184, 183, 182, 182, 181, 180, 179, 178, 178, 177, 171, 171, 170, 170, 170, 169, 168, 168, 165, 164, 162, 162, 162, 161, 161, 161, 160, 160, 159, 157, 156, 155, 155, 154, 154, 153, 152, 151, 151, 150, 150, 150, 149, 149, 149, 148, 148, 148, 148, 148, 148, 148, 148, 147, 146, 146, 145, 144, 144, 143, 143, 143, 142, 141, 141, 141, 141, 140, 139, 138, 138, 138, 137, 137, 136, 136, 135, 135, 134, 134, 134, 134, 133, 133, 132, 131, 131, 131, 130, 129, 129, 129, 128, 127, 127, 126, 125, 125, 125, 123, 123, 123, 122,
# ...

# %%
original
# Out:
# ['windows-10',
#  'linux',
#  'windows',
#  'ubuntu',
#  'networking',
#  'macos',
#  'command-line',
#  'google-chrome',
#  'windows-7',
#  'debian',
#  'powershell',
#  'hard-drive',
#  'bash',
#  'mac',
#  'usb',
#  'ssh',
#  'boot',
#  'wireless-networking',
#  'windows-11',
#  'security',
#  'microsoft-excel',
#  'audio',
#  'firefox',
#  'drivers',
#  'laptop',
#  'ffmpeg',
#  'virtualbox',
#  'video',
#  'python',
#  'router',
#  'terminal',
#  'browser',
#  'virtual-machine',
#  'memory',
#  'ssd',
#  'keyboard',
#  'vpn',
#  'keyboard-shortcuts',
#  'microsoft-word',
#  'performance',
#  'installation',
#  'display',
#  'ubuntu-20.04',
#  'backup',
#  'dns',
#  'email',
#  'docker',
#  'cmd.exe',
#  'cpu',
#  'bios',
#  'remote-desktop',
#  'filesystems',
#  'permissions',
#  'multiple-monitors',
#  'windows-subsystem-for-linux',
#  'raspberry-pi',
#  'windows-explorer',
#  'partitioning',
#  'batch',
#  'arch-linux',
#  'pdf',
#  'microsoft-outlook',
#  'encryption',
# ...

# %%
path2 = "../Dataset Super Users/nodes.csv"

# %%
df2 = pd.read_csv('nodes.csv')

# %%
df2
# Out:
#                  Id
# 0               bsd
# 1            adware
# 2            cpanel
# 3         usb-modem
# 4            raid-5
# ...             ...
# 4142         jabber
# 4143  tesseract-ocr
# 4144         autofs
# 4145           mode
# 4146         python
#
# [4147 rows x 1 columns]

# %%
df3 = pd.read_csv('questions_2020_2022.csv')

# %%
df3['Title']
# Out:
# 0        Why are tar.xz files 15x smaller when using Py...
# 1         Why does my PC crash only when my cat is nearby?
# 2        How can I reduce the consumption of the `vmmem...
# 3        What is the best way to remove 100% of a softw...
# 4        How do modern motherboards differ from each ot...
#                                ...
# 49995               dual Kali linux instances windows wsl2
# 49996    Add cells then subtract 1 if there is a date i...
# 49997    How to calculate how many days have passed bas...
# 49998         NFS Permission Denied when mounting from WSL
# 49999    Lookup the 1st or nth appearance of value betw...
# Name: Title, Length: 50000, dtype: object

# %%
df3[]
