# %%
import networkx as nx
import warnings
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import powerlaw
warnings.filterwarnings('ignore')

# %%
path = "../Dataset FFF/fff.csv"

# %%
df = pd.read_csv(path)

# %%
df
# Out:
#                                               clean_tags  \
# 0      fossilfuels, wind, solar, green, hydrogen, ene...
# 1                                       fridaysforfuture
# 2                                       fridaysforfuture
# 3                                       fridaysforfuture
# 4                                       fridaysforfuture
# ...                                                  ...
# 28376                                   fridaysforfuture
# 28377  northtynesideclimatestrike, youthstrike4climat...
# 28378                                   exxonknew, klima
# 28379                                   fridaysforfuture
# 28380                                   fridaysforfuture
#
#                                                 hashtags        date  \
# 0      ['fossilfuels', 'wind', 'solar', 'green', 'hyd...  2022-07-10
# 1                                   ['fridaysforfuture']  2022-07-10
# 2                                   ['fridaysforfuture']  2022-07-10
# 3                                   ['fridaysforfuture']  2022-07-10
# 4                                   ['fridaysforfuture']  2022-07-10
# ...                                                  ...         ...
# 28376                               ['fridaysforfuture']  2019-10-25
# 28377  ['northtynesideclimatestrike', 'youthstrike4cl...  2019-10-25
# 28378                             ['exxonknew', 'klima']  2019-10-25
# 28379                               ['fridaysforfuture']  2019-10-25
# 28380                               ['fridaysforfuture']  2019-10-25
#
#                    user_id         username  \
# 0                 59386332         arikring
# 1      1096766566279073792   parents4future
# 2                126978307         kl_stone
# 3      1445119113353994245  tobichrislorenz
# 4                126978307         kl_stone
# ...                    ...              ...
# 28376   891331631436398593   gifsep4climate
# 28377  1186683361722556417  ntclimatestrike
# 28378           4880781801        evastegen
# 28379            712989553       just_aenna
# 28380             68459659        winterbe_
#
#                                         name  \
# 0      Arik Ring - Energy Engineering Expert
# 1         Parents For Future #EndFossilFuels
# 2                          Klaus Steinfelder
# 3                  Tobias Christopher Lorenz
# 4                          Klaus Steinfelder
# ...                                      ...
# 28376                                 GIFSEP
# 28377     North Tyneside Climate Strike LIVE
# 28378                         Dr. Eva Stegen
# 28379                            Anna Hübner
# 28380                               Benjamin
#
#                                                    tweet language  \
# 0      @ProfStrachan @ECOWARRIORSS @ChristineMilne @m...       en
# 1      Eltern wissen, wer hier dumm ist. #FridaysForF...       de
# 2      SERVICETWEET:  Zur aktuellen Hetze der BLÖD-Ze...       de
# 3      #Fridaysforfuture ist eine linksradikale Sekte...       de
# 4      Nettostromerzeugung in D. am gestrigen 09.07.2...       de
# ...                                                  ...      ...
# 28376  The #FridaysForFuture train was at Government ...       en
# 28377  A powerful last chant from the #NorthTynesideC...       en
# 28378  @glouki @VQuaschning @parents4future @HalleVer...       de
# 28379  "Klimaschutz geht auch lokal, am Sonntag haben...       de
# 28380  #FridaysForFuture right now @hannover  https:/...       en
#
#                                                 mentions  \
# 0      [{'screen_name': 'guytaur', 'name': 'scott. tr...
# 1                                                     []
# 2                                                     []
# 3                                                     []
# 4                                                     []
# ...                                                  ...
# 28376                                                 []
# 28377  [{'screen_name': 'strike4youth', 'name': 'yout...
# 28378  [{'screen_name': 'focus', 'name': 'focus', 'id...
# 28379                                                 []
# 28380  [{'screen_name': 'hannover', 'name': 'stadt ha...
#
#                                                     urls  replies_count  \
# 0      ['https://reneweconomy.com.au/integrated-wind-...              2
# 1                                                     []             21
# 2                                                     []              2
# 3                                                     []              1
# 4                                                     []              1
# ...                                                  ...            ...
# 28376                                                 []             10
# 28377                                                 []             26
# 28378          ['https://lobbypedia.de/wiki/Prometheus']              3
# 28379                                                 []              2
# 28380                                                 []             16
#
#        retweets_count  likes_count  \
# 0                  54           59
# 1                  54          595
# 2                   5            8
# 3                   3           12
# 4                   3            6
# ...               ...          ...
# 28376             188         1115
# 28377             231         1673
# 28378              10           14
# 28379               3           14
# 28380             137          910
#
#                                                     link  retweet  \
# 0      https://twitter.com/arikring/status/1546251358...    False
# 1      https://twitter.com/parents4future/status/1546...    False
# 2      https://twitter.com/Kl_Stone/status/1546221657...    False
# 3      https://twitter.com/tobichrislorenz/status/154...    False
# 4      https://twitter.com/Kl_Stone/status/1546154883...    False
# ...                                                  ...      ...
# 28376  https://twitter.com/gifsep4climate/status/1187...    False
# 28377  https://twitter.com/NTClimateStrike/status/118...    False
# 28378  https://twitter.com/EvaStegen/status/118769458...    False
# 28379  https://twitter.com/just_Aenna/status/11876934...    False
# 28380  https://twitter.com/winterbe_/status/118769316...    False
#
#                                                 reply_to
# 0      [{'screen_name': 'ProfStrachan', 'name': 'Prof...
# 1                                                     []
# 2                                                     []
# 3                                                     []
# 4                                                     []
# ...                                                  ...
# 28376                                                 []
# 28377                                                 []
# 28378  [{'screen_name': 'glouki', 'name': 'Gregor Lou...
# 28379                                                 []
# 28380                                                 []
#
# [28381 rows x 16 columns]

# %%
g = nx.read_edgelist(df, delimiter=",", nodetype=int)

# %%
g.is_directed()
# Out:
# False

# %%
g.degree(1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\networkx\classes\graph.py in bunch_iter(nlist, adj)
#    1895                 try:
# -> 1896                     for n in nlist:
#    1897                         if n in adj:
#
# TypeError: 'int' object is not iterable
#
# The above exception was the direct cause of the following exception:
#
# NetworkXError                             Traceback (most recent call last)
# <ipython-input-7-b6f0afdccbce> in <module>
# ----> 1 g.degree(1)
#
# ~\anaconda3\lib\site-packages\networkx\classes\reportviews.py in __call__(self, nbunch, weight)
#     361         except TypeError:
#     362             pass
# --> 363         return self.__class__(self._graph, nbunch, weight)
#     364
#     365     def __getitem__(self, n):
#
# ~\anaconda3\lib\site-packages\networkx\classes\reportviews.py in __init__(self, G, nbunch, weight)
#     346         self._succ = G._succ if hasattr(G, "_succ") else G._adj
#     347         self._pred = G._pred if hasattr(G, "_pred") else G._adj
# --> 348         self._nodes = self._succ if nbunch is None else list(G.nbunch_iter(nbunch))
#     349         self._weight = weight
#     350
#
# ~\anaconda3\lib\site-packages\networkx\classes\graph.py in bunch_iter(nlist, adj)
#    1902                     if "iter" in message:
#    1903                         msg = "nbunch is not a node or a sequence of nodes."
# -> 1904                         raise NetworkXError(msg) from e
#    1905                     # capture error for unhashable node.
#    1906                     elif "hashable" in message:
#
# NetworkXError: nbunch is not a node or a sequence of nodes.
