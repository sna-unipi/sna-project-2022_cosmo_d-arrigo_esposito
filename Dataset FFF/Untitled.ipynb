# %%
import twint

import networkx as nx
import warnings
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import powerlaw
warnings.filterwarnings('ignore')

from wordcloud import WordCloud
import math
from operator import itemgetter

# %matplotlib inline

# %%
df = pd.read_csv('fff.csv')

# %%
df
# Out:
#                                               clean_tags  \
# 0      fossilfuels, wind, solar, green, hydrogen, ene...
# 1                                       fridaysforfuture
# 2                                       fridaysforfuture
# 3                                        fridayforfuture
# 4                  klimakrise, govegan, fridaysforfuture
# ...                                                  ...
# 23499                                   fridaysforfuture
# 23500                    climateaction, fridaysforfuture
# 23501            merkel, allefürsklima, fridaysforfuture
# 23502         klimaatstaking, klimastreik, climatestrike
# 23503  klimastreik, fridaysforfuture, allefuersklima,...
#
#                                                 hashtags        date  \
# 0      ['fossilfuels', 'wind', 'solar', 'green', 'hyd...  2022-07-10
# 1                                   ['fridaysforfuture']  2022-07-10
# 2                                   ['fridaysforfuture']  2022-07-10
# 3                                    ['fridayforfuture']  2022-07-10
# 4          ['klimakrise', 'govegan', 'fridaysforfuture']  2022-07-10
# ...                                                  ...         ...
# 23499                               ['fridaysforfuture']  2019-09-20
# 23500              ['climateaction', 'fridaysforfuture']  2019-09-20
# 23501    ['merkel', 'allefürsklima', 'fridaysforfuture']  2019-09-20
# 23502  ['klimaatstaking', 'klimastreik', 'climatestri...  2019-09-20
# 23503  ['klimastreik', 'fridaysforfuture', 'allefuers...  2019-09-20
#
#                    user_id        username  \
# 0                 59386332        arikring
# 1      1096766566279073792  parents4future
# 2                126978307        kl_stone
# 3                403735368         hahnflo
# 4      1529883123881857031     vegancardio
# ...                    ...             ...
# 23499   957154283002179584      schweizok2
# 23500             33933259          unicef
# 23501              8447362   greenpeace_de
# 23502             25341283            fyeg
# 23503             19811643             lvz
#
#                                              name  \
# 0           Arik Ring - Energy Engineering Expert
# 1              Parents For Future #EndFossilFuels
# 2                               Klaus Steinfelder
# 3                                    Florian Hahn
# 4                           Der vegane Kardiologe
# ...                                           ...
# 23499                                   HansDampf
# 23500                                      UNICEF
# 23501                             Greenpeace e.V.
# 23502  Federation of Young European Greens - FYEG
# 23503                                         LVZ
#
#                                                    tweet language  \
# 0      @ProfStrachan @ECOWARRIORSS @ChristineMilne @m...       en
# 1      Eltern wissen, wer hier dumm ist. #FridaysForF...       de
# 2      SERVICETWEET:  Zur aktuellen Hetze der BLÖD-Ze...       de
# 3      Wer erklärt #FridayForFuture, dass es ohne NAT...       de
# 4      Was sind das eigentlich für Menschen, die sich...       de
# ...                                                  ...      ...
# 23499  Foto von heute aus Berlin !!! #FridaysForFutur...       de
# 23500  The world is listening and the message is clea...       en
# 23501  Beeindruckend, wenn andere auf Wissenschaftler...       de
# 23502  @A2larm @zewlakk_foto @globalgreens @nicohaeri...       en
# 23503  Verkehrschaos in der City: Auf dem Ring ist de...       de
#
#                                                 mentions  replies_count  \
# 0      [{'screen_name': 'guytaur', 'name': 'scott. tr...              2
# 1                                                     []             21
# 2                                                     []              2
# 3                                                     []            127
# 4                                                     []             79
# ...                                                  ...            ...
# 23499                                                 []              3
# 23500                                                 []             25
# 23501                                                 []             15
# 23502  [{'screen_name': 'kimvsparrentak', 'name': 'ki...              2
# 23503                                                 []              2
#
#        retweets_count  likes_count  \
# 0                  54           59
# 1                  54          595
# 2                   5            8
# 3                  65          679
# 4                  25          348
# ...               ...          ...
# 23499               3            8
# 23500             234          695
# 23501              42          161
# 23502               6           28
# 23503               5           17
#
#                                                     link  retweet  \
# 0      https://twitter.com/arikring/status/1546251358...    False
# 1      https://twitter.com/parents4future/status/1546...    False
# 2      https://twitter.com/Kl_Stone/status/1546221657...    False
# 3      https://twitter.com/hahnflo/status/15461339384...    False
# 4      https://twitter.com/VeganCardio/status/1546127...    False
# ...                                                  ...      ...
# 23499  https://twitter.com/schweizok2/status/11750709...    False
# 23500  https://twitter.com/UNICEF/status/117507078447...    False
# 23501  https://twitter.com/greenpeace_de/status/11750...    False
# 23502  https://twitter.com/FYEG/status/11750707449272...    False
# 23503  https://twitter.com/LVZ/status/117507069339176...    False
#
#                                                 reply_to
# 0      [{'screen_name': 'ProfStrachan', 'name': 'Prof...
# 1                                                     []
# 2                                                     []
# 3                                                     []
# 4                                                     []
# ...                                                  ...
# 23499                                                 []
# 23500                                                 []
# 23501                                                 []
# 23502  [{'screen_name': 'A2larm', 'name': 'A2larm', '...
# 23503                                                 []
#
# [23504 rows x 15 columns]

# %%
tags_dict = {}
for i in range(len(df1)):
    ll = df1["clean_tags"][i].split(",")
    for tg in ll:
        tgs=tg.lstrip()
        if tgs not in tags_dict:
            tags_dict[tgs] = [df1["tweet"][i]]
        else:
            tags_dict[tgs].append(df1["tweet"][i])
