# %%
import networkx as nx
from bokeh.io import show, output_notebook
import ndlib.models.ModelConfig as mc
import ndlib.models.epidemics as ep
from ndlib.viz.mpl.DiffusionPrevalence import DiffusionPrevalence
from ndlib.viz.mpl.DiffusionTrend import DiffusionTrend
from ndlib.viz.bokeh.MultiPlot import MultiPlot
import matplotlib
matplotlib.use('Agg')

# %matplotlib inline
# Out:
# no display found. Using non-interactive Agg backend

# %%
path = "../DataSet FFF/"

# %%
path_graph = "../DataSet FFF/Graph_data/"

# %%
saved_path = "../DataSet FFF/"

# %%
G = nx.read_graphml(path_graph+"Real_Network.graphml")

# %%
BA = nx.read_graphml(path_graph+"BA_Network.graphml")
ER = nx.read_graphml(path_graph+"ER_Network.graphml")
CM = nx.read_graphml(path_graph+"CM_Network.graphml")
WS = nx.read_graphml(path_graph+"WS_Network.graphml")

# %% [markdown]
# # ---- SI: Susceptible-Infected

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
beta = 0.001
percentage_infected = 0.05

# %%
def start_SI(G, beta, percentage_infected, it_brunch):
    print(f"Usati beta = {beta}, percentage_infected = {percentage_infected}, it_brunch = {it_brunch}")
    config = mc.Configuration()
    config.add_model_parameter('beta', beta)
    config.add_model_parameter("percentage_infected", percentage_infected)
    model_G = ep.SIModel(G)
    model_G.set_initial_status(config)
    iterations_G = model_G.iteration_bunch(it_brunch, node_status=True)
    trends_G = model_G.build_trends(iterations_G)
    
    vm = MultiPlot()
    
    viz = DiffusionTrend(model_G, trends_G)
    p = viz.plot()

    vm.add_plot(p)
    
    viz2 = DiffusionPrevalence(model_G, trends_G)
    p2 = viz2.plot()

    
    vm.add_plot(p2)
    m = vm.plot()
    show(m)

# %%
start_SI(G, beta, percentage_infected, 400)
# Out:
# Usati beta = 0.001, percentage_infected = 0.05, it_brunch = 400
#   <div class="bk-root" id="ae92d9a1-7c46-4403-9e4a-a03b8488ef58" data-root-id="1005"></div>

# %%
config = mc.Configuration()
config.add_model_parameter('beta', beta)
config.add_model_parameter("percentage_infected", percentage_infected)
model_G = ep.SIModel(G)
model_G.set_initial_status(config)
iterations_G = model_G.iteration_bunch(400, node_status=True, progress_bar = True)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 400/400 [00:37<00:00, 10.70it/s]

# %%
for i in iterations_G:
    print(i["iteration"])
    print(i["node_count"])
# Out:
# 0
# {0: 9843, 1: 518}
# 1
# {0: 9840, 1: 521}
# 2
# {0: 9834, 1: 527}
# 3
# {0: 9827, 1: 534}
# 4
# {0: 9818, 1: 543}
# 5
# {0: 9801, 1: 560}
# 6
# {0: 9782, 1: 579}
# 7
# {0: 9765, 1: 596}
# 8
# {0: 9749, 1: 612}
# 9
# {0: 9731, 1: 630}
# 10
# {0: 9712, 1: 649}
# 11
# {0: 9698, 1: 663}
# 12
# {0: 9676, 1: 685}
# 13
# {0: 9653, 1: 708}
# 14
# {0: 9634, 1: 727}
# 15
# {0: 9614, 1: 747}
# 16
# {0: 9587, 1: 774}
# 17
# {0: 9557, 1: 804}
# 18
# {0: 9541, 1: 820}
# 19
# {0: 9509, 1: 852}
# 20
# {0: 9477, 1: 884}
# 21
# {0: 9444, 1: 917}
# 22
# {0: 9417, 1: 944}
# 23
# {0: 9383, 1: 978}
# 24
# {0: 9360, 1: 1001}
# 25
# {0: 9332, 1: 1029}
# 26
# {0: 9302, 1: 1059}
# 27
# {0: 9271, 1: 1090}
# 28
# {0: 9245, 1: 1116}
# 29
# {0: 9206, 1: 1155}
# 30
# {0: 9176, 1: 1185}
# 31
# {0: 9142, 1: 1219}
# 32
# {0: 9116, 1: 1245}
# 33
# {0: 9096, 1: 1265}
# 34
# {0: 9053, 1: 1308}
# 35
# {0: 9021, 1: 1340}
# 36
# {0: 8992, 1: 1369}
# 37
# {0: 8963, 1: 1398}
# 38
# {0: 8927, 1: 1434}
# 39
# ...

# %%
#175  -  {0: 5177, 1: 5184}

# %%
start_SI(BA, beta, percentage_infected, 400)
# Out:
# Usati beta = 0.001, percentage_infected = 0.05, it_brunch = 400
#   <div class="bk-root" id="0eabc447-cfeb-4db0-ba62-49688e9cb0cc" data-root-id="1009"></div>

# %%
config = mc.Configuration()
config.add_model_parameter('beta', beta)
config.add_model_parameter("percentage_infected", percentage_infected)
model_G = ep.SIModel(BA)
model_G.set_initial_status(config)
iterations_G = model_G.iteration_bunch(400, node_status=True, progress_bar = True)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 400/400 [00:36<00:00, 10.92it/s]

# %%
for i in iterations_G:
    print(i["iteration"])
    print(i["node_count"])
# Out:
# 0
# {0: 9843, 1: 518}
# 1
# {0: 9830, 1: 531}
# 2
# {0: 9823, 1: 538}
# 3
# {0: 9814, 1: 547}
# 4
# {0: 9808, 1: 553}
# 5
# {0: 9799, 1: 562}
# 6
# {0: 9792, 1: 569}
# 7
# {0: 9788, 1: 573}
# 8
# {0: 9777, 1: 584}
# 9
# {0: 9773, 1: 588}
# 10
# {0: 9765, 1: 596}
# 11
# {0: 9759, 1: 602}
# 12
# {0: 9746, 1: 615}
# 13
# {0: 9737, 1: 624}
# 14
# {0: 9725, 1: 636}
# 15
# {0: 9713, 1: 648}
# 16
# {0: 9705, 1: 656}
# 17
# {0: 9691, 1: 670}
# 18
# {0: 9679, 1: 682}
# 19
# {0: 9666, 1: 695}
# 20
# {0: 9655, 1: 706}
# 21
# {0: 9643, 1: 718}
# 22
# {0: 9634, 1: 727}
# 23
# {0: 9625, 1: 736}
# 24
# {0: 9612, 1: 749}
# 25
# {0: 9602, 1: 759}
# 26
# {0: 9584, 1: 777}
# 27
# {0: 9573, 1: 788}
# 28
# {0: 9553, 1: 808}
# 29
# {0: 9540, 1: 821}
# 30
# {0: 9526, 1: 835}
# 31
# {0: 9510, 1: 851}
# 32
# {0: 9487, 1: 874}
# 33
# {0: 9471, 1: 890}
# 34
# {0: 9457, 1: 904}
# 35
# {0: 9443, 1: 918}
# 36
# {0: 9427, 1: 934}
# 37
# {0: 9414, 1: 947}
# 38
# {0: 9402, 1: 959}
# 39
# {0: 9393, 1: 968}
# 40
# ...

# %%
# 180 - {0: 5181, 1: 5180}

# %%
start_SI(ER, beta, percentage_infected, 400)
# Out:
# Usati beta = 0.001, percentage_infected = 0.05, it_brunch = 400
#   <div class="bk-root" id="52a8030f-0572-4379-9078-fdec8707b9c7" data-root-id="1013"></div>

# %%
config = mc.Configuration()
config.add_model_parameter('beta', beta)
config.add_model_parameter("percentage_infected", percentage_infected)
model_G = ep.SIModel(ER)
model_G.set_initial_status(config)
iterations_G = model_G.iteration_bunch(400, node_status=True, progress_bar = True)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 400/400 [00:41<00:00,  9.61it/s]

# %%
for i in iterations_G:
    print(i["iteration"])
    print(i["node_count"])
# Out:
# 0
# {0: 9843, 1: 518}
# 1
# {0: 9836, 1: 525}
# 2
# {0: 9828, 1: 533}
# 3
# {0: 9818, 1: 543}
# 4
# {0: 9814, 1: 547}
# 5
# {0: 9807, 1: 554}
# 6
# {0: 9807, 1: 554}
# 7
# {0: 9800, 1: 561}
# 8
# {0: 9797, 1: 564}
# 9
# {0: 9792, 1: 569}
# 10
# {0: 9786, 1: 575}
# 11
# {0: 9782, 1: 579}
# 12
# {0: 9779, 1: 582}
# 13
# {0: 9773, 1: 588}
# 14
# {0: 9767, 1: 594}
# 15
# {0: 9762, 1: 599}
# 16
# {0: 9756, 1: 605}
# 17
# {0: 9749, 1: 612}
# 18
# {0: 9742, 1: 619}
# 19
# {0: 9739, 1: 622}
# 20
# {0: 9736, 1: 625}
# 21
# {0: 9732, 1: 629}
# 22
# {0: 9727, 1: 634}
# 23
# {0: 9722, 1: 639}
# 24
# {0: 9716, 1: 645}
# 25
# {0: 9710, 1: 651}
# 26
# {0: 9705, 1: 656}
# 27
# {0: 9699, 1: 662}
# 28
# {0: 9695, 1: 666}
# 29
# {0: 9691, 1: 670}
# 30
# {0: 9685, 1: 676}
# 31
# {0: 9679, 1: 682}
# 32
# {0: 9673, 1: 688}
# 33
# {0: 9667, 1: 694}
# 34
# {0: 9663, 1: 698}
# 35
# {0: 9653, 1: 708}
# 36
# {0: 9648, 1: 713}
# 37
# {0: 9643, 1: 718}
# 38
# {0: 9635, 1: 726}
# 39
# {0: 9630, 1: 731}
# 40
# ...

# %%
# 303 - {0: 5177, 1: 5184}

# %%
start_SI(G, beta, percentage_infected, 800)
# Out:
# Usati beta = 0.001, percentage_infected = 0.05, it_brunch = 800
#   <div class="bk-root" id="7297b877-84f4-4b51-8b41-a2938436ace9" data-root-id="1017"></div>

# %%
start_SI(BA, beta, percentage_infected, 800)
# Out:
# Usati beta = 0.001, percentage_infected = 0.05, it_brunch = 800
#   <div class="bk-root" id="dc451d3f-4ae8-4454-b2c8-9749df40d730" data-root-id="1021"></div>

# %%
start_SI(ER, beta, percentage_infected, 800)
# Out:
# Usati beta = 0.001, percentage_infected = 0.05, it_brunch = 800
#   <div class="bk-root" id="3f0c5a68-3e0e-4cc8-b318-a01059908c06" data-root-id="1025"></div>

# %%
start_SI(WS, beta, percentage_infected, 400)
# Out:
# Usati beta = 0.001, percentage_infected = 0.05, it_brunch = 400
#   <div class="bk-root" id="63faafe9-6244-47a2-927d-7a1d15c1445f" data-root-id="1029"></div>

# %%
start_SI(G, 0.01, percentage_infected, 400)
# Out:
# Usati beta = 0.01, percentage_infected = 0.05, it_brunch = 400
#   <div class="bk-root" id="70668ce2-0bad-4c7c-bec5-17b6319b6d5e" data-root-id="1033"></div>

# %%
config = mc.Configuration()
config.add_model_parameter('beta', 0.01)
config.add_model_parameter("percentage_infected", percentage_infected)
model_G = ep.SIModel(G)
model_G.set_initial_status(config)
iterations_G = model_G.iteration_bunch(400, node_status=True)

# %%
for i in iterations_G:
    print(i["iteration"])
    print(i["node_count"])
# Out:
# 0
# {0: 9843, 1: 518}
# 1
# {0: 9811, 1: 550}
# 2
# {0: 9598, 1: 763}
# 3
# {0: 9338, 1: 1023}
# 4
# {0: 9047, 1: 1314}
# 5
# {0: 8765, 1: 1596}
# 6
# {0: 8446, 1: 1915}
# 7
# {0: 8102, 1: 2259}
# 8
# {0: 7755, 1: 2606}
# 9
# {0: 7462, 1: 2899}
# 10
# {0: 7167, 1: 3194}
# 11
# {0: 6863, 1: 3498}
# 12
# {0: 6608, 1: 3753}
# 13
# {0: 6340, 1: 4021}
# 14
# {0: 6105, 1: 4256}
# 15
# {0: 5849, 1: 4512}
# 16
# {0: 5635, 1: 4726}
# 17
# {0: 5425, 1: 4936}
# 18
# {0: 5208, 1: 5153}
# 19
# {0: 5025, 1: 5336}
# 20
# {0: 4846, 1: 5515}
# 21
# {0: 4696, 1: 5665}
# 22
# {0: 4541, 1: 5820}
# 23
# {0: 4387, 1: 5974}
# 24
# {0: 4244, 1: 6117}
# 25
# {0: 4113, 1: 6248}
# 26
# {0: 3970, 1: 6391}
# 27
# {0: 3834, 1: 6527}
# 28
# {0: 3710, 1: 6651}
# 29
# {0: 3596, 1: 6765}
# 30
# {0: 3486, 1: 6875}
# 31
# {0: 3384, 1: 6977}
# 32
# {0: 3288, 1: 7073}
# 33
# {0: 3204, 1: 7157}
# 34
# {0: 3127, 1: 7234}
# 35
# {0: 3037, 1: 7324}
# 36
# {0: 2940, 1: 7421}
# 37
# {0: 2868, 1: 7493}
# 38
# ...

# %%
nx.info(G)
# Out:
# 'Name: \nType: Graph\nNumber of nodes: 10361\nNumber of edges: 63960\nAverage degree:  12.3463'

# %% [markdown]
# # ---- SI senza hub

# %%
from collections import Counter
from operator import itemgetter

# %%
G = nx.read_graphml(path_graph+"Real_Network.graphml")

# %%
degree_dict = dict(G.degree(G.nodes()))
nx.set_node_attributes(G, degree_dict, 'degree')
sorted_degree = sorted(degree_dict.items(), key = itemgetter(1), reverse = True)
nodes = []
for i in sorted_degree:
    nodes.append(i[0])

# %%
G.remove_nodes_from(nodes[:30])

# %%
start_SI(G, beta, percentage_infected, 500)
# Out:
# Usati beta = 0.001, percentage_infected = 0.05, it_brunch = 500
#   <div class="bk-root" id="f83f0d11-9543-4ff8-884b-e05b1f628da8" data-root-id="1009"></div>

# %%
config = mc.Configuration()
config.add_model_parameter('beta', 0.001)
config.add_model_parameter("percentage_infected", percentage_infected)
model_G = ep.SIModel(G)
model_G.set_initial_status(config)
iterations_G = model_G.iteration_bunch(500, node_status=True)

# %%
for i in iterations_G:
    print(i["iteration"])
    print(i["node_count"])
# Out:
# 0
# {0: 9815, 1: 516}
# 1
# {0: 9813, 1: 518}
# 2
# {0: 9810, 1: 521}
# 3
# {0: 9810, 1: 521}
# 4
# {0: 9809, 1: 522}
# 5
# {0: 9802, 1: 529}
# 6
# {0: 9796, 1: 535}
# 7
# {0: 9792, 1: 539}
# 8
# {0: 9782, 1: 549}
# 9
# {0: 9777, 1: 554}
# 10
# {0: 9768, 1: 563}
# 11
# {0: 9761, 1: 570}
# 12
# {0: 9756, 1: 575}
# 13
# {0: 9749, 1: 582}
# 14
# {0: 9744, 1: 587}
# 15
# {0: 9737, 1: 594}
# 16
# {0: 9734, 1: 597}
# 17
# {0: 9724, 1: 607}
# 18
# {0: 9719, 1: 612}
# 19
# {0: 9713, 1: 618}
# 20
# {0: 9707, 1: 624}
# 21
# {0: 9698, 1: 633}
# 22
# {0: 9690, 1: 641}
# 23
# {0: 9688, 1: 643}
# 24
# {0: 9684, 1: 647}
# 25
# {0: 9680, 1: 651}
# 26
# {0: 9674, 1: 657}
# 27
# {0: 9667, 1: 664}
# 28
# {0: 9658, 1: 673}
# 29
# {0: 9651, 1: 680}
# 30
# {0: 9647, 1: 684}
# 31
# {0: 9633, 1: 698}
# 32
# {0: 9623, 1: 708}
# 33
# {0: 9615, 1: 716}
# 34
# {0: 9610, 1: 721}
# 35
# {0: 9598, 1: 733}
# 36
# {0: 9588, 1: 743}
# 37
# {0: 9577, 1: 754}
# 38
# {0: 9568, 1: 763}
# 39
# {0: 9556, 1: 775}
# 40
# ...

# %%
# 405 {0: 5169, 1: 5162}
