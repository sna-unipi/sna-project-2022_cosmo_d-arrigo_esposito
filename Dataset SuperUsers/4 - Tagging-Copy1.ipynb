# %% [markdown]
# ### Renamed tags

# %%
import pandas as pd
import matplotlib.pyplot as plt
import math
import numpy as np
import networkx as nx
from operator import itemgetter

# %%
path = "../Dataset Super Users/questions_2020_2022.csv"
# Out:
# '../Dataset Super Users/questions_2020_2022.csv'

# %%
df = pd.read_csv("../Dataset Super Users/questions_2020_2022.csv")
df
# Out:
#                                                     Tags  \
# 0            macos|-|python|-|zsh|-|compression|-|tar|-|
# 1                                               crash|-|
# 2            windows-10|-|memory|-|docker|-|resources|-|
# 3                                 windows|-|uninstall|-|
# 4                                         motherboard|-|
# ...                                                  ...
# 49995  linux|-|windows|-|windows-subsystem-for-linux|...
# 49996                                 microsoft-excel|-|
# 49997     microsoft-excel|-|worksheet-function|-|time|-|
# 49998  linux|-|ubuntu|-|mount|-|windows-subsystem-for...
# 49999         microsoft-excel|-|spreadsheet|-|vlookup|-|
#
#                     User_Name  \
# 0      Saaru Lindest&#248;kke
# 1                  Stuntddude
# 2                 CiaranWelsh
# 3                  Anne Maier
# 4                     MechMK1
# ...                       ...
# 49995                    Sean
# ...

# %%
G = nx.read_edgelist(path, comments = "S", delimiter = ",", data=(("Count", int),))
degree_dict = dict(G.degree(G.nodes()))
nx.set_node_attributes(G, degree_dict, 'degree')
sorted_degree = sorted(degree_dict.items(), key = itemgetter(1), reverse = True)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-3-cbccd2b39074> in <module>
# ----> 1 G = nx.read_edgelist(path, comments = "S", delimiter = ",", data=(("Count", int),))
#       2 degree_dict = dict(G.degree(G.nodes()))
#       3 nx.set_node_attributes(G, degree_dict, 'degree')
#       4 sorted_degree = sorted(degree_dict.items(), key = itemgetter(1), reverse = True)
#
# ~\anaconda3\lib\site-packages\decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# ~\anaconda3\lib\site-packages\networkx\utils\decorators.py in _open_file(func_to_be_decorated, *args, **kwargs)
# ...

# %%
ids = []                      #tag
count = []                    #quante volte appare
named = []                    #in quale categoria finirà
original = []                 #nome originale
for i in sorted_degree:
    ids.append(i[0])
    count.append(i[1])
    named.append("unamed")
    original.append(i[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-485fc322928a> in <module>
#       3 named = []                    #in quale categoria finirà
#       4 original = []                 #nome originale
# ----> 5 for i in sorted_degree:
#       6     ids.append(i[0])
#       7     count.append(i[1])
#
# NameError: name 'sorted_degree' is not defined

# %%
def select_from_key(key, data, expection):
    al=[]
    for i in data:
        if key in i[0]:
            if len(expection)>0:
                is_except = False
                for ex in expection:
                    if ex in i[0]:
                        is_except = True
                if not is_except:
                    al.append(i[0])
            else:
                al.append(i[0])
    return al

# %%
def replace_name(old_name, new_name, old_dataset, expection):
    for i in range(len(old_dataset)):
        if old_name in old_dataset[i]:
            if len(expection)>0:
                is_except = False
                for ex in expection:
                    if ex in old_dataset[i]:
                        is_except = True
                if not is_except:
                    if "unamed" in named[i]:
                        named[i] = new_name
                        original[i] = new_name
            else:
                if "unamed" in named[i]:
                    named[i] = new_name
                    original[i] = new_name

# %%
set(original)
# Out:
# set()

# %% [markdown]
# Replace tags

# %%
replace_name("microsoft", "Microsoft", ids, "")
replace_name("microsoft-word", "Microsoft", ids, "")
replace_name("microsoft-word-365", "Microsoft", ids, "")
replace_name("microsoft-excel", "Microsoft", ids, "")
replace_name("microsoft-excel-365", "Microsoft", ids, "")
replace_name("microsoft-powerpoint", "Microsoft", ids, "")
replace_name("microsoft-outlook", "Microsoft", ids, "")
replace_name("microsoft-onenote", "Microsoft", ids, "")
replace_name("microsoft-access", "Microsoft", ids, "")
replace_name("sharepoint", "Microsoft", ids, "")
replace_name("onedrive", "Microsoft", ids, "")
replace_name("office365", "Microsoft", ids, "")
replace_name("fonts", "Microsoft", ids, "")

# %%
replace_name("windows-10", "Operating system", ids, "")
replace_name("windows-8", "Operating system", ids, "")
replace_name("windows-7", "Operating system", ids, "")
replace_name("windows-11", "Operating system", ids, "")
replace_name("windows", "Operating system", ids, "")
replace_name("linux", "Operating system", ids, "")
replace_name("linux-mint", "Operating system", ids, "")
replace_name("ubuntu", "Operating system", ids, "")
replace_name("macos", "Operating system", ids, "")
replace_name("debian", "Operating system", ids, "")
replace_name("ubuntu-14.04", "Operating system", ids, "")
replace_name("ubuntu-16.04", "Operating system", ids, "")
replace_name("ubuntu-18.04", "Operating system", ids, "")
replace_name("ubuntu-20.04", "Operating system", ids, "")
replace_name("ubuntu-22.04", "Operating system", ids, "")
replace_name("ios", "Operating system", ids, "")
replace_name("android", "Operating system", ids, "")
replace_name("unix", "Operating system", ids, "")
replace_name("typescript", "Operating system", ids, "")
replace_name("drivers", "Operating system", ids, "")
replace_name("virtualbox", "Operating system", ids, "")
replace_name("fedora", "Operating system", ids, "")
replace_name("operating-systems", "Operating system", ids, "")
replace_name("windows-subsystem-for-linux", "Operating system", ids, "")
replace_name("arch-linux", "Operating system", ids, "")
replace_name("centos", "Operating system", ids, "")
replace_name("linux-mint", "Operating system", ids, "")
replace_name("kali-linux", "Operating system", ids, "")
replace_name("wsl2", "Operating system", ids, "")

# %%
replace_name("r", "Programming Languages", ids, "")
replace_name("php", "Programming Languages", ids, "")
replace_name("dart", "Programming Languages", ids, "")
replace_name("c", "Programming Languages", ids, "")
replace_name("c++", "Programming Languages", ids, "")
replace_name("c#", "Programming Languages", ids, "")
replace_name("matlab", "Programming Languages", ids, "")
replace_name("ruby", "Programming Languages", ids, "")
replace_name("java", "Programming Languages", ids, "")
replace_name("javascript", "Programming Languages", ids, "")
replace_name("scala", "Programming Languages", ids, "")
replace_name("sql", "Programming Languages", ids, "")
replace_name("python", "Programming Languages", ids, "")
replace_name("jenkins", "Programming Languages", ids, "")
replace_name("html", "Programming Languages", ids, "")
replace_name("script", "Programming Languages", ids, "")

# %%
replace_name("google-chrome", "Web & Application Servers", ids, "")
replace_name("gnu", "Web & Application Servers", ids, "")
replace_name("links", "Web & Application Servers", ids, "")
replace_name("web", "Web & Application Servers", ids, "")
replace_name("safari", "Web & Application Servers", ids, "")
replace_name("opera", "Web & Application Servers", ids, "")
replace_name("internet-explorer", "Web & Application Servers", ids, "")
replace_name("vivaldi", "Web & Application Servers", ids, "")
replace_name("chromium", "Web & Application Servers", ids, "")
replace_name("brave", "Web & Application Servers", ids, "")
replace_name("firefox", "Web & Application Servers", ids, "")
replace_name("lynx", "Web & Application Servers", ids, "")
replace_name("elinks", "Web & Application Servers", ids, "")
replace_name("dns", "Web & Application Servers", ids, "")
replace_name("windows-explorer", "Web & Application Servers", ids, "")
replace_name("apache-http-server", "Web & Application Servers", ids, "")
replace_name("github", "Web & Application Servers", ids, "")
replace_name("twitter", "Web & Application Servers", ids, "")

# %%
replace_name("css", "Backup", ids, "")
replace_name("backup", "Backup", ids, "")
replace_name("jar", "Backup", ids, "")
replace_name("tar", "Backup", ids, "")
replace_name("zip", "Backup", ids, "")
replace_name("nas", "Backup", ids, "")
replace_name("rar", "Backup", ids, "")
replace_name("file-system", "Backup", ids, "")
replace_name("memory", "Backup", ids, "")
replace_name("data-recovery", "Backup", ids, "")

# %%
replace_name("external-hard-drive", "Computer Components", ids, "")
replace_name("raspberry-pi", "Computer Components", ids, "")
replace_name("powershell", "Computer Components", ids, "")
replace_name("hard-drive", "Computer Components", ids, "")
replace_name("usb", "Computer Components", ids, "")
replace_name("laptop", "Computer Components", ids, "")
replace_name("video", "Computer Components", ids, "")
replace_name("ssd", "Computer Components", ids, "")
replace_name("keyboard", "Computer Components", ids, "")
replace_name("keyboard-shortcuts", "Computer Components", ids, "")
replace_name("display", "Computer Components", ids, "")
replace_name("cpu", "Computer Components", ids, "")
replace_name("motherboard", "Computer Components", ids, "")
replace_name("graphics-card", "Computer Components", ids, "")
replace_name("bluetooth", "Computer Components", ids, "")
replace_name("cpu", "Computer Components", ids, "")
replace_name("gpu", "Computer Components", ids, "")
replace_name("multiple-monitors", "Computer Components", ids, "")
replace_name("printer", "Computer Components", ids, "")
replace_name("webcam", "Computer Components", ids, "")

# %%
replace_name("audio", "Audio", ids, "")
replace_name("video", "Audio", ids, "")
replace_name("vlc-media-player", "Audio", ids, "")
replace_name("mp3", "Audio", ids, "")
replace_name("mp4", "Audio", ids, "")
replace_name("ffmpeg", "Audio", ids, "")
replace_name("opencv", "Audio", ids, "")
replace_name("git", "Audio", ids, "")
replace_name("audacity", "Audio", ids, "")
replace_name("handbrake", "Audio", ids, "")
replace_name("windows-media-player", "Audio", ids, "")
replace_name("youtube", "Audio", ids, "")
replace_name("obs-studio", "Audio", ids, "")
replace_name("spotify", "Audio", ids, "")
replace_name("gstreamer", "Audio", ids, "")

# %%
replace_name("command-line", "System", ids, "")
replace_name("shell", "System", ids, "")
replace_name("bash", "System", ids, "")
replace_name("kernel", "System", ids, "")
replace_name("docker", "System", ids, "")
replace_name("virtual-machine", "System", ids, "")
replace_name("bios", "System", ids, "")
replace_name("boot", "System", ids, "")
replace_name("terminal", "System", ids, "")
replace_name("cmd.exe", "System", ids, "")
replace_name("installation", "System", ids, "")
replace_name("performance", "System", ids, "")

# %%
replace_name("router", "Internet", ids, "")
replace_name("cookies", "Internet", ids, "")
replace_name("wirless-router", "Internet", ids, "")
replace_name("hotspot", "Internet", ids, "")
replace_name("vpn", "Internet", ids, "")
replace_name("speed", "Internet", ids, "")
replace_name("wirless-hotspot", "Internet", ids, "")
replace_name("lan", "Internet", ids, "")
replace_name("ipv4", "Internet", ids, "")
replace_name("ipv6", "Internet", ids, "")
replace_name("ip", "Internet", ids, "")
replace_name("ip-address", "Internet", ids, "")
replace_name("internet", "Internet", ids, "")
replace_name("internet-connection", "Internet", ids, "")
replace_name("internet-speed", "Internet", ids, "")
replace_name("proxy", "Internet", ids, "")
replace_name("port-forwarding", "Internet", ids, "")
replace_name("wirless-networking", "Internet", ids, "")
replace_name("networking", "Internet", ids, "")
replace_name("email", "Internet", ids, "")
replace_name("remote-desktop", "Internet", ids, "")
replace_name("web", "Internet", ids, "")

# %%
replace_name("ssl", "Security", ids, "")
replace_name("ssh", "Security", ids, "")
replace_name("passwords", "Security", ids, "")
replace_name("firewall", "Security", ids, "")
replace_name("encryption", "Security", ids, "")
replace_name("permission", "Security", ids, "")

# %%
replace_name("batch", "Problems", ids, "")
replace_name("batch-file", "Problems", ids, "")
replace_name("freeze", "Problems", ids, "")
replace_name("batch-rename", "Problems", ids, "")
replace_name("runtime-error", "Problems", ids, "")
replace_name("error-correction", "Problems", ids, "")
replace_name("memory-error", "Problems", ids, "")
replace_name("error-logging", "Problems", ids, "")
replace_name("windows-error-reporting", "Problems", ids, "")
replace_name("help-files", "Problems", ids, "")
replace_name("deep-freeze", "Problems", ids, "")
replace_name("bug", "Problems", ids, "")

# %%
saved_path2 = "../2 - NetworkAnalysis/nodes_tagged_by_language.csv"

new_df = pd.DataFrame({"Id": ids, "Count": count, "Named": named, "Original": original})
new_df.to_csv(saved_path2, index=False)

# %%
for i in set(new_df["Named"]):
    print(f"{i} = ", len(new_df[new_df["Named"]==i]))

# %%
new_df
# Out:
# Empty DataFrame
# Columns: [Id, Count, Named, Original]
# Index: []

# %%
len(set(original))
# Out:
# 10

# %%
select_from_key("bug", sorted_degree, [])
# Out:
# ['bug', 'debug', 'debugger', 'xdebug', 'bug.n']

# %%
set(ids)
# Out:
# {'transcode',
#  'disk-controller',
#  'xbindkeys',
#  'lag',
#  'microsoft-office-2013',
#  'esd',
#  'vectorworks',
#  'vscode-extensions',
#  'intel',
#  'cpu-throttling',
#  'dsl',
#  'grep',
#  'static',
#  'xz',
#  'mutt',
#  'microcontroller',
#  'keybase',
#  'infrastructure',
#  'autoplay',
#  'microsoft-excel-2003',
#  'wsus',
#  'bootloader',
#  'fail2ban',
#  'notifications',
#  'gnu-parallel',
#  'background',
#  'blackberry',
#  'smtp',
#  'ntpd',
#  'css',
#  'proc',
#  'thunar',
#  'timer',
#  'meetings',
#  'hypervisor',
#  'rhythmbox',
#  'gnucash',
#  'scheduling',
#  'vmware-server',
#  'razer-keyboard',
#  'security-center',
#  'react.js',
#  'snmp',
#  'dolphin-file-manager',
#  'hosting',
#  'language',
#  'regex',
#  'bullets',
#  'filesystem-corruption',
#  'isp',
#  'reinstall',
#  'svg',
#  '10gbit',
#  'aac',
#  'audiobook',
#  'acrobat-pro-dc',
#  'gaming',
#  'hp-spectre',
#  'array',
#  'network-traffic',
#  'speakers',
#  'login-script',
# ...

# %%
len(set(ids))
# Out:
# 4147
