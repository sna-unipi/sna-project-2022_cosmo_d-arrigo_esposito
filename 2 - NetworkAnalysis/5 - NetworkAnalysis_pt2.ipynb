# %%
import networkx as nx
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter
from operator import itemgetter
import powerlaw
from networkx.drawing.nx_agraph import graphviz_layout
import pickle
from statistics import mean, stdev
import seaborn as sns
import json

# %%
from cdlib import algorithms
# Out:
# Note: to be able to use all crisp methods, you need to install some additional packages:  {'graph_tool', 'wurlitzer'}
# Note: to be able to use all bipartite methods, you need to install some additional packages:  {'wurlitzer'}

# %%
path_subgraph = "../DataSet FFF/Graph_data/"

# %%
def plot_centralities(first, name_f, second, name_s, third, name_t, n):

    lista = [(k, v) for k, v in first.items()]
    lista.sort(key=lambda x: x[1], reverse = True)
    tops = lista[:n]
    first_ = []
    second_ = []
    third_ = []
    for i in tops:
        first_.append(first[i[0]])
        second_.append(second[i[0]])
        third_.append(third[i[0]])
        
    tops = [i for i,j in tops]
    tops = tops[::-1]
    first_ = first_[::-1]
    second_ = second_[::-1]
    third_ = third_[::-1]
    
    fig = plt.figure(figsize = (25,8), dpi = 300)

    fontsize = 17
    plt.rcParams.update({'font.size': fontsize})
    ax = fig.add_subplot(151)
    plt.barh(tops,first_, color = "#31A894")
    plt.grid(axis = 'both', alpha = .3)
    plt.xlabel(name_f)

    ax2 = fig.add_subplot(152)
    plt.barh(tops,second_, color = "#315FA8")
    plt.grid(axis = 'both', alpha = .3)
    plt.setp(ax2.get_yticklabels(), visible = False)
    plt.xlabel(name_s)

    ax3 = fig.add_subplot(153)
    plt.barh(tops,third_, color = "#5D2FA5")
    plt.grid(axis = 'both', alpha = .3)
    plt.setp(ax3.get_yticklabels(), visible = False)
    plt.xlabel(name_t)
    plt.show()

# %%
path_graph = "../DataSet FFF/Graph_data/"

# %%
G = nx.read_graphml(path_graph+"Real_Network.graphml")

# %%
ba_G = nx.read_graphml(path_graph+"BA_Network.graphml")
er_G = nx.read_graphml(path_graph+"ER_Network.graphml")
ws_G = nx.read_graphml(path_graph+"WS_Network.graphml")
cm_G = nx.read_graphml(path_graph+"CM_Network.graphml")

# %%
models = {
    "Real Network": G,
    "Barabasi Albert": ba_G,
    "Erdos Renyi": er_G,
    "Watts Strogatz": ws_G,
    "Configuration Model": cm_G
}

# %% [markdown]
# # 1 - Degree Centrality

# %%
degree_centrality = nx.degree_centrality(G)

# %%
new_centrality_nodes = [k for k, v in sorted(degree_centrality.items(), key=lambda item: item[1], reverse = True)]
new_df = pd.DataFrame({"Id": new_centrality_nodes})
new_df.to_csv("../DataSet FFF/centrality_degree_nodes.csv", index=False)

# %% [markdown]
# # 2 - Connectivity Based Centrality

# %%
eigenvector_centrality = nx.eigenvector_centrality(G, weight='Count',  max_iter=1000)

# %% [markdown]
# # 3 - PageRank centrality

# %%
pagerank_centrality = nx.pagerank(G, weight='Count', max_iter=1000)

# %%
nx.pagerank??

# %% [markdown]
# # 4 - Geometric Centrality

# %%
closeness_centrality = nx.closeness_centrality(G)

# %%
harmonic_centrality = nx.harmonic_centrality(G)

# %%
betweenness_centrality = nx.betweenness_centrality(G, weight='Count')

# %% [markdown]
# Plot

# %%
plot_centralities(degree_centrality, "Degree", eigenvector_centrality, "Eigenvector", pagerank_centrality, "PageRank", 15)

# %%
plot_centralities(closeness_centrality, "Closeness", betweenness_centrality, "Betweeneess", harmonic_centrality, "Harmonic", 15)

# %%
lista = [(k, v) for k, v in degree_centrality.items()]
lista.sort(key=lambda x: x[1], reverse = True)
tops = lista[:20]
tops = [i for i,j in tops]
H = G.subgraph(tops)
nx.write_gexf(H, path_subgraph+"centrality_subgraph.gexf")

# %% [markdown]
# # Storing central nodes

# %%
betweenness_centrality
# Out:
# {'klimakrise': 0.01845522801233806,
#  ' govegan': 0.0,
#  ' climatestrike': 2.828616088568877e-06,
#  ' fridaysforfuture': 0.00021848593137209154,
#  ' actnow': 4.0376057336438395e-06,
#  ' climatecrisis': 7.951130027101796e-06,
#  ' climateemergency': 7.942103603881426e-06,
#  ' climatejustice': 0.0,
#  ' climatejusticenow': 4.442589578304584e-06,
#  ' climateactionnow': 0.0,
#  ' klimaschutz': 6.627713198397735e-05,
#  ' klimawandel': 0.00010175574479528133,
#  ' atomkraft': 0.00025899507736502545,
#  ' habeck': 0.00010972107088528874,
#  ' klimakrise': 5.208884536765538e-05,
#  ' cdu': 7.753582337436829e-05,
#  ' fff': 0.000155068084796458,
#  ' endegelaende': 1.5991276458206947e-05,
#  ' energiewende': 0.00011192568576883248,
#  ' klimakatastrophe': 0.00025406237711975474,
#  ' neubauer': 6.664389037217709e-05,
#  ' langstreckenluisa': 3.7426368364843955e-05,
#  ' parentsforfuture': 0.0001323899462915227,
#  ' gasstop': 1.1255040115608678e-06,
#  ' tankrabatt': 0.00021961143538365245,
#  ' verkehrswende': 7.470516847173557e-05,
#  ' ipcc': 0.00023765326263556068,
#  ' nordstream2': 0.00019752828867713665,
#  ' niemehrcdu': 0.00036351113515207807,
#  ' earthday': 0.00011738779640432888,
#  ' vegan': 0.0005940606803315902,
#  ' berlin': 0.0005045892112154936,
#  ' fortheanimals': 3.500204429765279e-05,
#  ' hunger': 1.4372733983684628e-06,
#  ' afd': 0.00029985972596680813,
#  ' klimastreik': 0.0011816919322609357,
#  ' klimagerechtigkeit': 8.519922728088355e-05,
#  ' pandemie': 4.088488840074678e-05,
#  ' corona': 0.0007379270463458677,
#  ' covid_19': 0.00014311549330463109,
#  ' covid19': 0.000767999974882657,
#  ' klimaschutzgesetz': 1.0643227419796461e-05,
#  ' grübe': 1.3575283131122993e-05,
#  ' thunberg': 0.00025600816490304,
#  ' grünen': 0.00012692250978683415,
#  ' klimaproteste': 3.981496485703602e-06,
#  ' kohleausstieg': 0.0002392472864951321,
#  ' tellthetruth': 0.0001916586857490318,
#  ' scientists4future': 0.00052720707033917,
#  ' klimagebet': 3.944874482408753e-05,
#  ' klimapolitik': 0.0002050253029017316,
#  ' erderwärmung': 2.4681328774844287e-05,
#  ' datteln4': 0.0007079110882822732,
#  ' klimafrage': 0.0,
#  ' dürre': 5.25739681555175e-05,
#  ' klimanotstand': 0.0008617139977533383,
#  ' wdr': 4.714670196833044e-05,
#  ' linkebpt': 0.00022306752927284438,
#  ' kurzstreckenflüge': 7.994868226514756e-05,
#  ' keingradweiter': 0.0005378726325129928,
#  ' klimaarschlöcher': 1.3082746753693715e-05,
#  ' windkraft': 0.00018926180938846316,
#  ' tazlab2021': 1.467124822663321e-06,
#  ' endegelände': 0.00015810310402603205,
#  ' doppelmoral': 0.000497023696985402,
#  ' niemehrcsu': 3.6501109303710155e-05,
#  ' fighteverycrisis': 0.0001798049147865252,
#  ' waldstattasphalt': 0.000191993073522286,
#  ' fliegold': 8.047897418080934e-05,
#  ' coronakrise': 0.00017466726645745898,
#  ' hambibleibt': 0.0005976874469659772,
#  ' erneuerbareenergien': 0.00015162993019212883,
#  ' keepcoalintheground': 0.0001746277226275757,
#  ' nrwe': 0.0002810036138192549,
#  ' klimapaket': 0.0009260862019894109,
#  ' endcoalnow': 7.442147714514285e-05,
#  ' lexgarzweiler': 7.1516073627440825e-06,
#  ' trump': 0.00028199653192990655,
#  ' protest': 7.795631025587204e-06,
#  ' garzweiler': 5.657092346209744e-05,
#  ' kreuzfahrtschiffe': 0.00011809412556975839,
#  ' klimabewusstsein': 3.944874482408753e-05,
#  ' groko': 0.00017326944762381118,
#  ' kanzlerin': 7.636316518353046e-06,
#  ' cop25': 0.00028115744555769315,
#  ' klimahysterie': 0.0005679544022379751,
#  ' howdareyou': 0.0004974121160626108,
#  ' netzstreikfürsklima': 0.0001178792717569966,
#  ' trinkwasser': 0.0,
#  ' resilienz': 4.3532907908165514e-05,
#  ' togetherforfuture': 0.0002620188392802578,
#  ' windräder': 6.475163862182795e-05,
#  ' eautofabriken': 8.027884116238853e-06,
#  ' stopadani': 0.0004372247322751859,
#  ' menschenrechte': 4.7312241273699855e-05,
#  ' klimaleugner': 0.0003392164160299019,
#  ' klimawandelleugner': 0.0,
#  ' unwortdesjahres': 2.4075950006784206e-05,
#  ' whendowewantit': 5.7799183330980246e-05,
#  ' hitzewellen': 3.944874482408753e-05,
#  ' todesfälle': 0.0002579346761961795,
#  ' massenaussterben': 0.0,
#  ' netzhetze': 3.944874482408753e-05,
#  ' klimaschutzes': 3.944874482408753e-05,
#  ' flugscham': 0.00014072916776642724,
#  ' suvs': 0.00015461231603581575,
#  ' victoria': 3.944874482408753e-05,
#  ' zeitzuhandeln': 5.3480583805053635e-06,
#  ' unserespd': 0.0006342322588431673,
#  ' quaschning2go': 1.3540966295733539e-05,
#  ' 5jahreskandal': 1.809565578249175e-06,
#  ' bmw': 0.00028777223899552015,
#  ' reclaimthehouse': 0.0,
#  ' carisover': 3.944874482408753e-05,
#  ' endcars': 0.00025793467619617954,
#  'govegan': 0.002072415025582932,
#  'fridaysforfuture': 0.6297536796054617,
#  ' climateaction': 0.0,
#  ' climatechange': 0.00037014118569688435,
#  ' fridayfeeling': 6.096788095081921e-05,
#  ' fridaymotivation': 6.67286477555231e-05,
#  ' fightfor1point5': 9.44537294444459e-05,
#  ' weekend': 1.1566692824328798e-06,
#  ' globalwarming': 0.00019218252282526778,
#  ' fridayforfuture': 0.0011635974892514089,
#  'vegan': 0.0015936184305754568,
#  ' plantbased': 0.00023757874381032454,
#  ' toronto': 0.00025915060607196636,
#  ' fridaythoughts': 0.00026051770522859626,
#  ' umwelt': 0.0003622827490811725,
#  ' vegansforfuture': 0.0004284741010505793,
#  ' digitalstrike': 0.0001540197501056283,
#  'eilmeldung': 0.00022547504868839557,
#  ' pflanzenmilch': 0.00022546640946611912,
#  ' changeiscoming': 0.00044395234083820364,
#  ' weekendvibes': 0.00031012843956138453,
#  'factoryfarming': 7.425333968714729e-05,
#  ' veganfortheplanet': 7.424686027043992e-05,
#  ' aacc': 0.00029273279164252934,
#  'wtf': 0.00021415311385065386,
#  ' marchaporelclima': 9.370669014546573e-05,
#  ' friyay': 3.516753199733468e-05,
#  ' climatestrikecanada': 8.169484531494183e-05,
#  ' fffsantiago': 0.0001924843541392444,
#  ' vegano': 0.0004109702855113368,
#  ' animalcruelty': 0.0001824304243359309,
#  ' switzerland': 0.00029164747235514737,
#  ' zurich': 0.000510133403727239,
#  ' weightloss': 0.00010196792464692718,
#  ' climate': 0.0,
#  ' mapa': 2.1081691608703013e-06,
#  ' peoplenotprofit': 1.2285420924416241e-06,
#  ' byebyebojo': 2.54167174392911e-05,
#  ' climatebrawl': 3.9717221487260433e-07,
#  ' uprootthesystem': 3.914340703910296e-06,
#  ' schoolstrikeforclimate': 2.2273945596389122e-05,
#  ' schoolstrike': 0.0003263074523945025,
#  ' standwithukraine️': 0.0,
#  ' scholz': 0.0,
#  ' fossilfuels': 1.4462447787077881e-05,
#  ' future': 5.706923418455918e-06,
#  ' sustainability': 6.84212383952602e-06,
#  ' zivilerungehorsam': 0.0,
#  ' renewables': 3.0447920151075084e-05,
#  ' gas': 0.0002073763045848861,
#  ' luisaneubauer': 0.00043266984295811634,
#  ' standwithukraine': 0.0001048581635521169,
#  ' klima': 5.356711582136619e-05,
#  ' öko': 0.0,
#  ' systemchange': 3.1722246486373423e-06,
#  ' facetheclimateemergency': 1.4271202777763266e-05,
#  ' riseupmovement': 7.815016136525068e-06,
#  ' life': 8.646839255957479e-07,
#  ' g7': 2.365017428351089e-06,
#  ' noemptypromises': 0.0,
#  ' stopfundingfossilfuel': 0.0,
#  ' endfossilfuels': 0.00027729661820144306,
#  ' environment': 5.198347692841997e-05,
#  ' climatestrikeonline': 3.388833768308592e-06,
#  ' nature': 2.387806103237553e-05,
#  ' globalgoals': 0.0002535935181349784,
#  ' ff': 0.00011105056617674449,
#  ' stopeacop': 7.527706506102531e-06,
#  ' nuclearbanweek': 0.0,
#  ' science': 1.220764992169021e-05,
#  ' klimaneutral': 0.00010532674814570691,
#  ' pollution': 7.156233769578147e-05,
#  ' fdp': 4.10906912797334e-06,
#  ' heatwave': 4.587929375822906e-05,
#  ' spd': 5.470467107214973e-05,
#  ' union': 0.0001415228640694619,
#  ' ampel': 3.5628640064304015e-06,
#  ' stopcambo': 1.4527719822494096e-05,
#  ' communityawareness': 5.103702998801334e-05,
#  ' humanrights': 8.233608063952699e-06,
#  ' environmentalracism': 6.350621937329654e-05,
#  ' fridays4future': 0.00011828866410302397,
#  ' lossanddamage': 4.929867608374511e-05,
#  ' india': 2.0352611033825887e-05,
#  ' fridaymorning': 0.00017013901847608184,
#  ' fridayvibes': 3.159730175320026e-05,
#  ' demokratie': 8.114069100696665e-05,
#  ' radikalisierung': 2.7093317756622653e-05,
#  ' boomer': 0.00022434724161121103,
#  ' oldgrowth': 0.0,
#  ' ancientforest': 0.00021848593137209146,
#  ' savecongorainforest': 2.2937391267945527e-05,
#  ' educategirlsforclimatejustice': 2.170024735463976e-05,
#  ' dublin': 2.54167174392911e-05,
#  ' fridaysforfuturehamburg': 3.2030246756343e-06,
#  ' hamburg': 0.0,
#  ' ambiente': 0.00026177709006739304,
#  ' onlyoneearth': 0.00010376083106054668,
#  ' actonclimate': 4.929641891284294e-05,
#  ' f1': 0.00014560545224772957,
#  ' extinctionrebellion': 0.0002840695736513766,
#  ' stockholm50': 9.548625304843524e-06,
#  ' bangladesh': 6.911165499954764e-05,
#  ' gruene': 3.0156273565433043e-05,
#  ' onpoli': 0.00010457984475818824,
#  ' emissions': 8.474558846612783e-05,
#  ' schoolstrike4climate': 0.00022698654448547901,
#  ' scientistsforfuture': 0.00025173354616049766,
#  ' helsinki': 8.675615306176826e-05,
#  ' ilmasto': 0.0,
#  ' ilmastolakko': 1.5650209070184644e-05,
#  ' riseup': 1.0748426340744937e-05,
#  ' ilmastokriisi': 4.6719268552210564e-05,
#  ' finland': 1.6632108457432103e-06,
#  ' ilmastonmuutos': 0.0,
#  ' gazprom': 0.0,
#  ' pace': 0.00017146321053081208,
#  ' russia': 0.00029416075657827373,
#  ' klimawahl': 0.00014249850931818243,
#  ' menschen': 0.0,
#  ' umweltzerstörung': 0.0,
#  ' krieg': 4.9864136932365616e-05,
#  ' astronaut': 0.00011478160004328004,
#  ' maurer': 0.00033326753141536104,
#  ' nationalbikeweek': 1.4791103133432664e-05,
#  ' worldbeeday2022': 0.00023327703450553018,
#  ' climatefinance': 7.918757686514287e-05,
#  ' renewableenergy': 4.125569319310554e-05,
#  ' tempolimit': 0.0,
#  ' cleanenergy': 5.742043936370605e-05,
#  ' everydayforfuture': 1.0364030994055407e-05,
#  ' leuven': 0.00022884996236613922,
#  ' embargoforpeace': 0.0,
#  ' globalcrisis': 2.6660593632098965e-05,
#  ' sweden': 0.0,
#  ' ukraine': 0.0002303009476637713,
#  ' keepitintheground': 0.0001718421913225108,
#  ' planetnotprofit': 0.0,
#  ' lismorefloods': 2.54167174392911e-05,
#  ' auspol': 2.54167174392911e-05,
#  ' ausvotes': 5.676283864629596e-05,
#  ' cliamteemergency': 0.00027245314657994157,
#  ' diegrünen': 5.072800877969609e-05,
#  ' dielinke': 0.00017548517054105043,
#  ' kokumsforclimate': 0.0,
#  ' endallfossilfuels': 3.5559927143744756e-05,
#  ' dutyofcare': 3.847654555336374e-05,
#  ' codered': 0.00037666085410151907,
#  ' ukraine️': 0.00024325783302749343,
#  ' noplanetb': 0.00017321902902583787,
#  ' climatechangeisreal': 0.0010003031999033661,
#  ' covid': 7.342198627047063e-05,
#  ' climatebreakdown': 7.906443112517869e-05,
#  ' nomoreemptypromises': 0.00043717418042772454,
#  ' youth': 1.6527667084015308e-05,
#  ' goodfriday': 3.569865876927412e-05,
#  ' stopfuellingwar': 6.78048833069632e-05,
#  ' human': 0.0009809457888823832,
#  ' climatecantwait': 1.3438819087955708e-05,
#  ' russland': 0.0004253686166176417,
#  ' cambiamentoclimatico': 7.029713885770984e-05,
#  ' hongkong': 7.471061293285831e-06,
#  ' cloppenburg': 0.0,
#  ' weilburg': 0.0,
#  ' dreadlocks': 4.075578003313017e-05,
#  ' ronjamaltzahn': 0.00028633068542597857,
#  ' aachen': 3.3150366870066484e-05,
#  ' kommunismus': 0.00012071628548532235,
#  ' pessoasnãolucro': 1.5849095708916578e-05,
#  ' orlando': 0.0,
#  ' brescia': 0.0,
#  ' kiruna': 0.0,
#  ' ukraina': 0.0,
#  ' klimatet': 0.00021848593137209184,
#  ' globalclimatestrike': 0.0005178636868033294,
#  ' guerra': 0.0,
#  ' kiel': 0.0,
#  ' rastalocken': 0.0,
#  ' alledörferbleiben': 3.097103657059663e-05,
#  ' strom': 0.0,
#  ' sprit': 0.0,
#  ' globalstrike': 0.0002357928186179051,
#  ' cgil': 0.0,
#  ' münchen': 2.9164265779786814e-05,
#  ' allefürsklima': 0.00016791882808707753,
#  ' ac2503': 0.0,
#  ' usa': 0.00022509448568947481,
#  ' arctic': 3.7173080437275016e-05,
#  ' brandenburg': 2.834726382705532e-05,
#  ' polizei': 4.639765020557606e-05,
#  ' hannover': 4.829361625249477e-06,
#  ' maltzahn': 4.197324566784947e-05,
#  ' carolarackete': 0.0,
#  ' piraten': 0.00010376487004047652,
#  ' kulturelleaneignung': 2.706402405608655e-05,
#  ' globalerklimastreik': 6.7445460502538e-05,
#  ' salzburg': 0.00023427633485898814,
#  ' fridaysforforests': 4.33320551357969e-05,
#  ' votethemout': 0.00026181798650788695,
#  ' padredalloglio': 0.0,
#  ' ahmedsamirsantawy': 2.4580325076959144e-05,
#  ' patrickzaki': 5.306941465144298e-05,
#  ' veritapergiulioregeni': 8.695712104001712e-05,
#  ' mariopaciolla': 0.00012879847853967803,
#  ' freepalestine': 0.0002551973031225808,
#  ' freeassange': 0.00020666093384581855,
#  ' nowar': 0.00031587798186503426,
#  ' 18marzo': 0.00053436391323712,
#  ' greenpeace': 9.812530751528236e-05,
#  ' ambientalismo': 0.0,
#  ' sostenibilità': 0.00022711590313276831,
#  ' volt': 0.0003139555946909432,
#  ' petrolio': 0.00020507439903638404,
#  ' carbone': 0.0001275798003337405,
#  ' stopputinswar': 0.0,
#  ' climatereport': 0.00034710224434203544,
#  ' love': 6.008772595894488e-07,
#  ' fridayfitness': 0.0,
#  ' standingwithukraine': 0.0005566914816311665,
#  ' peace': 7.18247562946731e-05,
#  ' siochain': 0.00012948177916584922,
#  ' shanti': 0.00034796771053795413,
#  ' racialjustice': 2.2953528313785378e-05,
#  ' stormeunice': 1.0748426340744937e-05,
#  ' stormdudley': 0.00011996547435996012,
#  ' stormfff': 0.000338451405732052,
#  ' diesel': 0.00019976290434949788,
#  ' greennewdeal': 0.0005441141899747261,
#  ' gretathunberg': 0.0027781970216052146,
#  ' cop26': 0.0007904624729851617,
#  ' nomineingállok': 1.5849095708916578e-05,
#  ' maischberger': 1.9232277684616676e-05,
#  ' action': 0.00012819928898172083,
#  ' klimarevolution': 0.0,
#  ' fridaysforfutureindia': 4.24689608410432e-06,
#  ' okainkitui': 9.931135205277448e-06,
#  ' magdeburg': 2.834726382705532e-05,
#  ' remarqabl': 5.6500963889259266e-05,
#  ' nomusiconadeadplanet': 5.303586342629008e-05,
#  ' musicdeclares': 0.00016225291144550662,
#  ' earthpercent': 0.00038073884281759885,
#  ' israel': 0.00045958514793035155,
#  ' stopthesoot': 0.0,
#  ' stopthebalcksoot': 0.0,
#  ' saveourlives': 0.00021848593137209146,
#  ' 2021end': 0.0,
#  ' vancouver': 5.628791277925598e-05,
#  ' antifa': 0.00047751143026749586,
#  ' climatestrikes': 2.113100671647959e-05,
#  ' biripi': 1.8100753399571356e-05,
#  ' fundourfuturenotgas': 0.00032623891320524224,
#  ' parisagreement': 0.00023720881193916665,
#  ' winteriscoming': 0.0,
#  ' schnee': 0.00021848593137209146,
#  ' blackfriday': 0.0006973047914128979,
#  ' ampelkoalition': 0.00031215280731280336,
#  ' untergang': 0.0,
#  ' youth4climate': 0.000600111972833378,
#  ' koalitionsverhandlungen': 0.0,
#  ' inspirationalquote': 0.0,
#  ' knittingnannas': 6.692648147384604e-05,
#  ' climatecriminals': 0.0002854124128459385,
#  ' torino': 0.000129218112461161,
#  ' realzero': 0.0,
#  ' glasgow': 0.00020613618068112245,
#  ' greta': 0.001114688934061866,
#  ' uprootthecop': 3.4682888985109685e-05,
#  ' defundclimatechaos': 0.0002971968349204236,
#  ' movement': 6.932729902969553e-05,
#  ' klimagipfel': 4.2363886858916905e-05,
#  ' klimakonferenz': 0.00019553702341276678,
#  ' nomoreblahblahblah': 8.502060279737373e-05,
#  ' noadominga': 0.0,
#  ' elaguanosevende': 0.0002184340960384326,
#  ' justiciaclimáticaya': 0.00021848593137209146,
#  ' divest': 4.87022430118823e-05,
#  ' cleanupstandardchartered': 1.836320043812623e-05,
#  ' abo': 5.79983116488313e-05,
#  ' deutschland': 0.00011391797178686439,
#  ' blm': 1.6452067873629776e-05,
#  ' cambioclimático': 0.0006656893617254114,
#  ' dierichtigenfragen': 3.917920201498793e-05,
#  ' diegruenen': 4.177976814130613e-05,
#  ' gender': 7.794425917677706e-05,
#  ' allefuersklima': 0.000878539003782954,
#  ' plasticpollution': 0.00038520344759041187,
#  ' 1o5c': 6.974184942557841e-05,
#  ' ihrlasstunskeinewahl': 0.0,
#  ' klimaprotest': 0.0002097577652915699,
#  ' demo': 0.0005122251186725981,
#  ' grün': 0.00011613010921277992,
#  ' ecosystem': 0.0008004801631271089,
#  ' köln': 5.0349680779131014e-05,
#  ' spahn': 8.021417928739719e-05,
#  ' wildlife': 0.0002294308606616606,
#  ' karlsruhe': 0.0005219669945756959,
#  ' svpol': 5.333048200977293e-06,
#  ' nytonpakko': 2.2825562470626725e-05,
#  ' ilmastoisovanhemmat': 2.0014979401350316e-05,
#  ' gdp': 8.02769320551775e-05,
#  ' gretino': 0.0,
#  ' giocattoli': 0.00021848593137209146,
#  ' btw21': 0.0003282858104648335,
#  ' mindthegap': 0.00017537587332738325,
#  ' austria': 8.233608063952699e-06,
#  ' antisemitismus': 2.595165062482429e-05,
#  ' scotland': 0.0003536800667374493,
#  ' fairshare': 4.776829392083154e-05,
#  ' momoreemptyconferences': 0.00028997078367443146,
#  ' cambioclimatico': 0.00028617089094404855,
#  ' bundestagswahl21': 0.00021165603550801364,
#  ' talkimhangar7': 0.00013941712375033466,
#  ' stoptmx': 5.1121827196116265e-05,
#  ' laschet': 0.0002962512405560492,
#  ' timetoact': 5.750776008708012e-05,
#  ' bundestagswahl': 0.00029535902851956136,
#  ' clima': 0.00025600352869166736,
#  ' gehtwaehlen': 0.0,
#  ' allesfürsklima': 8.214998397766725e-05,
#  ' huelgamundialporelclima': 4.6404634583511035e-05,
#  ' greatersudbury': 1.8132413625851888e-06,
#  ' schlussrunde': 0.00027802860829037785,
#  ' systemchangenotclimatechange': 0.00013489240232458923,
#  ' ard': 0.0,
#  ' laschetlügt': 5.289703790966568e-05,
#  ' protestzug': 0.00010518282174669517,
#  ' bayern': 0.0003921063015262236,
#  ' ecologia': 0.0,
#  ' feminismo': 3.9944107036887806e-05,
#  ' migration': 0.00020551227231273696,
#  ' crisisclimatica': 0.00019419941637390371,
#  ' climateweek': 4.5201752461679475e-05,
#  ' scioperoglobaleperilclima': 0.0,
#  ' germanelection2021': 7.30777398560752e-05,
#  ' nomoreexcuses': 9.714461076386016e-05,
#  ' greenparty': 0.00020077534740746316,
#  ' bundestagswahl2021': 0.0004608581741593231,
#  ' sachsen': 0.00017087425057075604,
#  ' stuttgart': 3.5148974956310128e-06,
#  ' frühstart': 2.834726382705532e-05,
#  ' climatestikeonline': 3.703845784964472e-05,
#  ' fridaysforfuturemilano': 0.0,
#  ' triell': 7.640389152648372e-05,
#  ' scioperoperilclima': 8.53368395021862e-05,
#  ' bild': 9.453649022890848e-05,
#  ' braunerlaschet': 0.0,
#  ' ngo': 0.00013377885260838036,
#  ' elxn44': 6.0022889224687254e-05,
#  ' wahlkandidat': 3.6779241080646836e-08,
#  ' wahl': 0.000198279518421715,
#  ' enkelbriefen': 4.027088064669681e-05,
#  ' cdurausausderregierung': 0.0,
#  ' klimakriseistjetzt': 3.733515539459188e-05,
#  ' kliimastreik': 8.355308608246622e-06,
#  ' belem': 0.0,
#  ' carbondioxide': 1.5663296529462367e-05,
#  ' animalagriculture': 0.00012488034454867836,
#  ' methane': 0.0003433662759207678,
#  ' laschetverhindern': 0.0003262177401001079,
#  ' voteclimate': 7.794579535079565e-05,
#  ' respekt': 0.0002355305268533962,
#  ' tiredearth': 0.000670516156069919,
#  ' bcpoli': 5.274810511527841e-05,
#  ' cdnpoli': 0.00022869739451119615,
#  ' düsseldorf': 5.876312520126345e-06,
#  ' nichtwienrw': 0.0,
#  ' allesistdrin': 5.6494367898310806e-05,
#  ' 24settembre': 0.0,
#  ' riverbankprotection': 0.0,
#  ' rt': 0.00042089166957053265,
#  ' greenwashing': 0.00016942460332696626,
#  ' socialjustice': 0.0001899803864423803,
#  ' cancelculture': 0.00014024770359965472,
#  ' lgbtq': 0.00016303939539155332,
#  ' mercalli': 0.0,
#  ' frankfurt': 1.4601650479642841e-05,
#  ' demonstrationen': 0.0,
#  ' injustice': 0.0002276000150717529,
#  ' justtransitionmossmorran': 0.00044608594644384147,
#  ' streikmituns': 1.6973499097707256e-05,
#  ' africaisnotadumpster': 0.0,
#  ' netzstreikfuersklima': 1.0082961065204832e-05,
#  ' globalstrikeforfuture': 9.273431149852527e-05,
#  ' klimaziele': 0.00034811697049502325,
#  ' gulfstreamcollapse': 4.798458397849109e-05,
#  ' klimat': 0.00038313905316575143,
#  ' saveourkoalas': 9.830114137743083e-05,
#  ' fridaysforforest': 0.00032572772614775374,
#  ' youthforclimate': 0.0001696282595873101,
#  ' factoryfarming': 1.5663296529462367e-05,
#  ' comicsforclimate': 8.72572862506028e-05,
#  ' overshoot': 0.00011452267175516378,
#  ' basketball': 0.00014569051737946313,
#  ' notevengonnatry': 0.00018206164316343025,
#  ' lazygovernment': 0.00022571736117091791,
#  ' wehavethedata': 0.00028029996751369115,
#  ' wehavethetechnology': 0.00035309405441530633,
#  ' humanchangenotclimatechange': 0.00046231110243452286,
#  ' comics': 0.0006807970338066153,
#  ' flattenthecurve': 1.8814015002953276e-05,
#  ' gruenen': 6.279252783570738e-05,
#  ' hochwassergebieten': 0.0,
#  ' bonn': 4.880149141024927e-05,
#  ' hochwasser': 6.224439147078525e-06,
#  ' laschetwusstees': 0.0,
#  ' laschetlacht': 0.0002369821489741161,
#  ' cducsu': 0.0002468331951991452,
#  ' wahlprogramm': 0.0,
#  ' cancellej': 2.560978119832054e-05,
#  ' reemtsma': 0.00034387448644587553,
#  ' lyttonbc': 2.293058738242661e-05,
#  ' blogging': 6.719276555647091e-05,
#  ' europawahl': 6.667280663169186e-05,
#  ' ps126': 1.4995962627769666e-05,
#  ' withdrawthecap': 9.700179220589587e-06,
#  ' saveourplanet': 0.00025571055113556175,
#  ' emergenzaclimatica': 0.0001533227696202806,
#  ' dunfermline': 0.00014560859392806038,
#  ' fightfor1point': 0.0003640945253001515,
#  ' strikeforclimate': 5.493927179963805e-05,
#  ' emcke': 0.0,
#  ' buildbackbetter': 4.549751685343383e-06,
#  ' g7cornwall': 3.199370386554926e-05,
#  ' falmouth': 0.0,
#  ' uganda': 3.134948198524427e-05,
#  ' ilmastotekoja': 0.00019839501319475868,
#  ' ilmastovaalit': 0.0004168809445668471,
#  ' zukunft': 0.0005345422285439499,
#  ' youth2030': 7.535003758108827e-05,
#  ' justtransition': 0.0003412960928040924,
#  ' rebellionextension': 7.428144106674594e-05,
#  ' antifaterrorist': 0.0002926098448073551,
#  ' politcalcorrectness': 0.00021865860702767457,
#  ' bundestag': 0.0003340947397812389,
#  ' nannas': 6.749513333787301e-05,
#  ' worimi': 0.0001462396991653117,
#  ' forster': 7.263390082844375e-05,
#  ' nsw': 0.00015089767590167687,
#  ' australia': 0.0002773209312825752,
#  ' climatestrikeforster': 0.0001746457763012327,
#  ' bds': 0.0002306950291870456,
#  ' settlercolonialism': 0.0,
#  ' stopmisinformation': 0.00021848593137209165,
#  ' merkel': 0.00016915360071019213,
#  ' keinekohlefuerdiekohle': 1.9549750913208318e-05,
#  ' climateactionbill': 4.3243968578161095e-05,
#  ' colombiasos': 2.5021379503666878e-05,
#  ' paronacionalcolombia': 0.0001342384275228832,
#  ' peaceforpalestineandisrael': 0.0003527243588949733,
#  ' polarstern': 3.655678547480517e-05,
#  ' hamas': 0.0,
#  ' israelunderfire': 8.634102593591714e-05,
#  ' hass': 0.000295690163487816,
#  ' sozialismus': 1.6744029029183016e-06,
#  ' blacklivesmatter': 4.256771140058129e-05,
#  ' fridaysforfutureottawa': 0.0,
#  ' actonyourpromises': 0.00021848593137209146,
#  ' sudbury': 8.664492572005201e-06,
#  ' canada': 8.978851875494007e-05,
#  ' fundlu': 1.2944638104654257e-05,
#  ' bundesregierung': 0.0002446644725837371,
#  ' coronavirus': 0.000519075659882509,
#  ' defendthedefenders': 0.0003331504284336158,
#  ' savetheoceans': 7.563742013482029e-05,
#  ' lockdown': 0.00010143223489408036,
#  ' unteilbar': 0.0,
#  ' kabila4sdgs': 0.00011802535585780684,
#  ' saveourforests': 0.0002511013659137164,
#  ' oekoterror': 2.7937269363039378e-05,
#  ' agrarindustrie': 0.0,
#  ' agrarwende': 0.00021848593137209146,
#  ' genz': 0.00021848593137209146,
#  ' ddr': 0.0005448744449882473,
#  ' vraieloiclimat': 0.0,
#  ' stopeumercosur': 2.9130795504300285e-05,
#  ' göttingen': 1.3261524464472562e-07,
#  ' ac1903': 0.0,
#  ' oberbaumbrücke': 6.662190739427772e-05,
#  ' prien': 9.548625304843524e-06,
#  ' allefuer1komma5': 0.0002402384142676268,
#  ' globalclimatejustice': 0.00017277482811635538,
#  ' climatepoli': 5.4492593052228304e-05,
#  ' 私たちの未来を手放さない': 7.734451837527773e-05,
#  ' taketheknee': 1.9549750913208318e-05,
#  ' onlineclimatestrike': 0.0002307014633397908,
#  ' internationalwomensday': 5.030823539292222e-05,
#  ' nomoreemptywords': 6.868161017362299e-05,
#  ' steinibleibt': 0.0,
#  ' storckerweiterung': 0.00021848593137209146,
#  ' climat': 0.0003495407336965457,
#  ' koala': 8.467817749054775e-05,
#  ' tigerquoll': 0.0001574722643921414,
#  ' powerfulowl': 0.0002666893124113572,
#  ' greaterglider': 0.00048517524378346256,
#  ' autoindustrie': 0.00022594414308709616,
#  ' undemokratisch': 2.8674773437861927e-05,
#  ' disharavi': 1.3014724683379907e-05,
#  ' march': 1.2944638104654257e-05,
#  ' augsburg': 1.5588488196126554e-05,
#  ' globalstrikeonline': 0.0,
#  ' strike4climate': 0.00016780662082992517,
#  ' teamcows': 1.786041784570986e-05,
#  ' bidenadministration': 0.0,
#  ' l277': 1.2268680245007343e-05,
#  ' dannibleibt': 0.0003318806192666714,
#  ' keinea49': 0.00012441842550436465,
#  ' dannenroederforst': 0.00041013686317371026,
#  ' alledoerferbleiben': 0.0006198788320615255,
#  ' happynewyear2021': 0.0001153565752194274,
#  ' 2021year': 0.00010838326617827037,
#  ' bye2020': 0.00017530375412430204,
#  ' pollutersout': 0.00013769624369230774,
#  ' fightclimateinjustice': 0.00017781623193523625,
#  ' banplasticug': 7.196107175267701e-05,
#  ' erklärung': 6.938711785622935e-05,
#  ' sonnenfinsternis': 0.00017860416587544536,
#  ' südamerika': 0.000397090097247536,
#  ' lockdownjetzt': 3.774162324897999e-05,
#  ' bildungabersicher': 0.0002562275546210724,
#  ' querdenken211': 0.0,
#  ' wirtschaft': 0.0008321602033338021,
#  ' covidー19': 0.00010077468728797261,
#  ' papua': 9.352133713314474e-05,
#  ' plasticfree': 0.000591392354941121,
#  ' skolstrejkförklimatet': 0.00013553955803384665,
#  ' climateaccountability': 1.2944638104654257e-05,
#  ' 地球温暖化': 1.9549750913208318e-05,
#  ' rodungsstoppjetzt': 0.0,
#  ' savethano': 0.0002253300058218393,
#  ' dbdk2020': 4.539113415436095e-07,
#  ' mumbai': 3.3784411135113107e-06,
#  ' kinder': 0.000599709823270827,
#  ' ardmediathek': 4.860216891970719e-06,
#  ' 気候変動': 0.001092040891858016,
#  ' wieleben': 0.0004383885330236869,
#  ' climatejusticeisracialjustice': 9.514993412806735e-06,
#  ' wearestillhere': 2.8696398042417133e-05,
#  ' unitebehindthescience': 0.0007232229769664498,
#  ' klimakiller': 0.0,
#  ' nomorepillepalle': 0.00010346890250183114,
#  ' climatestrickonline': 3.129548591581038e-05,
#  ' savethanoforest': 0.00024978141728790315,
#  ' xr': 0.0003002756387751843,
#  ' eyesopencanada': 0.0,
#  ' buildbackbetterscot': 0.0,
#  ' seebrücke': 1.4627047367409127e-05,
#  ' fridays': 5.2348214730376687e-08,
#  ' sosamazonia': 0.00045050270704389785,
#  ' linke': 0.0013652688664316521,
#  ' covid19de': 0.00020317997632878114,
#  ' warnstreik': 0.0,
#  ' leavenoonebehind': 2.99479899144183e-05,
#  ' 25s': 0.00016993124188247237,
#  ' sosamazonía': 0.00017032333915636334,
#  ' climatestrikestjohns': 2.54167174392911e-05,
#  ' globalclimateaction2020': 4.4481762648292856e-05,
#  ' вместезаклимат': 0.00012079223313307691,
#  ' thüringen': 1.6388283290177252e-05,
#  ' jena': 4.768287185969326e-05,
#  ' klimareligion': 0.0,
#  ' justiciaclimática': 0.0,
#  ' trabajoyclima': 0.0,
#  ' vw': 0.0,
#  ' riseupforchange': 0.0,
#  ' 1komma5': 0.0,
#  ' escolacompromesa': 0.0,
#  ' intensament': 0.0001092170480192163,
#  ' ravaleducacio': 0.0003277029793913078,
#  ' niemehrspd': 7.373937741662872e-05,
#  ' onlinepetitionen': 0.00014351198256954615,
#  ' digichat': 0.00036199791394162444,
#  ' wahlalter16': 0.0,
#  ' nrwähltklima': 0.0,
#  ' dortmund': 0.0,
#  ' nocruiseday': 0.00028031394842930907,
#  ' heuchler': 0.0,
#  ' plantfortheplanet': 8.63050970101006e-06,
#  ' greenrecoveryni': 0.000301338755395094,
#  ' escazuahora': 7.097775752774598e-05,
#  ' digitalprotest': 0.0001801948055469617,
#  ' climateprotestonline': 0.0003986807369190517,
#  ' sexismus': 3.944874482408753e-05,
#  ' nohate': 0.00019389838877802544,
#  ' strukturwandel': 9.21267042878612e-05,
#  ' co2steuer': 0.00010322115860388375,
#  ' klimawahl2021': 0.0,
#  ' sciencematters': 0.00010492127746904365,
#  ' fossilfree': 0.00033199874994148073,
#  ' escazuya': 4.7902212504657964e-05,
#  ' digitalstrikeonline': 0.0,
#  ' bundesblockierliga': 0.0,
#  ' covidioten': 0.0,
#  ' eltville': 7.83781319191378e-06,
#  ' noforestnofuture': 7.265364026918046e-05,
#  ' savecongoforest_flora_fauna': 0.00021848593137209165,
#  ' mentalhealthmatters': 0.0003708970759866096,
#  ' mentalhealthforfuture': 1.3528736530557467e-05,
#  ' kohleeinstiegsgesetz': 3.960334885125565e-05,
#  ' nextlevel4future': 0.00013142737341794453,
#  ' youthstrike4climate': 6.669755020543307e-05,
#  ' stophs2': 0.0001416721855997478,
#  ' shutthesites': 0.0,
#  ' nhsnoths2': 1.758390276915707e-07,
#  ' covidsafe': 0.0,
#  ' savenorilsk': 1.9712116487660233e-05,
#  ' junkterrorlawnow': 2.8019421267763854e-05,
#  ' savethesahel': 0.0005776426976889531,
#  ' nachhaltigkeit': 0.0002097431877249029,
#  ' ltw21': 0.0,
#  ' grossekohlekoalition': 0.00045596167981510623,
#  ' berlin4future': 0.00030472536358548783,
#  ' grevedigital': 7.108143165083982e-06,
#  ' acriseclimáticamata': 0.00022559407453717528,
#  ' savecongoforestflora_fauna': 4.182261660814652e-05,
#  ' savennp': 0.00015103966462736337,
#  ' junkterrorbill': 0.00015209629099610203,
#  ' allegegenrwe': 0.0002053870575827655,
#  ' nürnberg': 0.0002953679443530911,
#  ' занацпарки': 7.108143165083982e-06,
#  ' palmer': 0.00024039173269725344,
#  ' wirsindantifa': 0.0,
#  ' solaroffensive': 0.0,
#  ' abfckpraemie': 0.0001241501591266352,
#  ' schildermeerfürsklima': 3.944874482408753e-05,
#  ' datteln4stoppen': 0.00017709990155936347,
#  ' hungerstreik': 0.0,
#  ' fahrraddemo': 0.0,
#  ' covid__19': 0.0,
#  ' flughafen': 0.0,
#  ' africaday2020': 0.0,
#  ' africaday': 0.00021848593137209146,
#  ' climatefriday': 0.00016627781276421657,
#  ' potsdam': 0.0,
#  ' whatthefork': 0.0,
#  ' kurz': 7.825523146498359e-05,
#  ' savedibangvalley': 3.977791911061465e-05,
#  ' protectwildlife': 8.794160262063187e-05,
#  ' neueswirtschaftswunder': 0.0,
#  ' klimagerechtigkeitsbewegung': 0.00021848593137209108,
#  ' villagers': 0.0,
#  ' freerangers': 0.00021848593137209146,
#  ' patriarchat': 8.44362127787911e-09,
#  ' standwithworkers': 0.00023817169422317403,
#  ' istandwithworkers': 3.8629013625807445e-05,
#  ' allesgesagt': 2.0126457013457643e-05,
#  ' foodblog': 0.00020248081288101448,
#  ' yummy': 9.810044116857685e-06,
#  ' earthstrike': 0.00012708885664840887,
#  ' nyc': 0.0004810241143777083,
#  ' coronacrisis': 0.00010953470976872997,
#  ' foodie': 3.2688331436652906e-06,
#  ' netzstreik': 6.904400809257e-05,
#  ' mission1point5': 0.00034980842417361123,
#  ' unccdlandheroes': 0.00015943779761743777,
#  ' togetherathome': 3.2756284869155855e-05,
#  ' treateverycrisis': 0.0002512422162412491,
#  ' climatetwitter': 0.00027836941506696907,
#  ' schulboykottde': 0.0,
#  ' agenda2030': 0.000339103403814282,
#  ' moria': 0.00012345440949160537,
#  ' alankurdî': 0.00034194034086369995,
#  ' coronaviruscanada': 3.929112283267823e-05,
#  ' policestate': 8.294684084016871e-05,
#  ' policebrutality': 0.00013752944718294769,
#  ' martiallaw': 0.00021032353408454246,
#  ' agenda21': 0.000319540582103752,
#  ' contacttracing': 0.0005380265134758442,
#  ' flüchtlinge': 5.78850554325693e-05,
#  ' teamtrees': 0.00029088223185525175,
#  ' strikewithus': 0.00011530295625398859,
#  ' fckafd': 0.00012351823462321585,
#  ' nopegida': 2.8057881553263956e-05,
#  ' 立憲フェス2020': 0.0,
#  ' seattle': 3.149008421330542e-05,
#  ' covid19seattle': 4.972116662251974e-05,
#  ' earthcomesfirst': 2.973954339360435e-05,
#  ' catsofthequarantine': 0.00024822547476569554,
#  ' now': 1.417132218651842e-05,
#  ' nolympia': 4.9695878416837415e-05,
#  ' ökorassismus': 0.00048315376452239293,
#  ' naidoo': 0.0,
#  ' savecongobasin': 0.0002337410883480406,
#  ' unternehmen': 0.0,
#  ' handelsregister': 0.00021848593137209146,
#  ' forestfriday': 5.6541846466108814e-05,
#  ' amazonrainforest': 2.8435834653840945e-06,
#  ' savewolflake': 4.683467235152532e-05,
#  ' nonunadimeno': 5.5902524103959765e-06,
#  ' ticktock': 0.0,
#  ' euclimatelaw': 0.0,
#  ' school': 1.836320043812623e-05,
#  ' lgbtqpower': 0.00024381108053713726,
#  ' by2020weriseup': 0.0002219067284498448,
#  ' thinktank': 8.972632895883657e-06,
#  ' kantonsrat': 5.5902524103959765e-06,
#  ' krzh': 0.00022407618378249096,
#  ' vanessa': 8.8734856629111e-05,
#  ' alexnote': 2.238009046149901e-05,
#  ' stormjorge': 2.54167174392911e-05,
#  ' fridaysforfuturehealth': 1.0748426340744937e-05,
#  ' seedballs': 0.0,
#  ' bristolys4c': 2.54167174392911e-05,
#  ' citicbs': 1.390277736018963e-05,
#  ' parenting': 1.0125358708601644e-05,
#  ' hamburgwahl': 2.6683779397813462e-06,
#  ' hhwahl2020': 0.0,
#  ' flensburg': 7.024047010358298e-05,
#  ' hvv': 0.0,
#  ' feministsforfuture': 0.0,
#  ' equality': 0.00021848593137209146,
#  ' birthdaytrees': 0.0,
#  ' belfast': 0.00017510705703302837,
#  ' youthstrike': 0.00011312475468351048,
#  ' valentinesday2020': 3.766064062183608e-05,
#  ' bushfirerebellion': 3.8902134215938535e-05,
#  ' earthcleanup': 0.0,
#  ' backasápmi': 4.710813330359956e-05,
#  ' decoalonize': 5.8206397718615255e-05,
#  ' limerick': 0.0,
#  ' oneplanet': 0.0,
#  ' onefuture': 0.00015410151859218088,
#  ' stormciara': 0.00030825438643538623,
#  ' waterford': 2.54167174392911e-05,
#  ' klimatstrejk': 0.0002758314933971658,
#  ' siemens': 0.00017442374252294582,
#  ' adani': 1.18664877425077e-05,
#  ' cop': 0.0,
#  ' publikationen': 0.0002903380203006203,
#  ' youthquake': 0.0,
#  ' climatjustice': 3.180714394617862e-05,
#  ' kaeser': 0.0002861841276726568,
#  ' fridaysforhubraum': 0.0006751067048471202,
#  ' mlpd': 0.0,
#  ' vonderleyen': 0.0002307364253838727,
#  ' cannabisverbot': 7.677065421359466e-05,
#  ' rente': 0.0007764078818973537,
#  ' erwerbsminderungsrente': 0.00032122045543058077,
#  ' retweeetplease': 0.0007174753982464449,
#  ' help': 0.000583806792896185,
#  ' deadlineday': 0.0007713979519941333,
#  ' antarctica2020': 0.00041933586682743753,
#  ' generalelection2020': 0.0,
#  ' tomradtke': 0.0,
#  ' contaminación': 0.00025770739252756186,
#  ' emergenciaclimatica': 0.00031385172553088,
#  ' climateemegency': 0.0003386171575328172,
#  ' fffhalle': 6.7415229720442495e-06,
#  ' amazonia': 0.0002368491318102162,
#  ' davos': 0.0003365835641558925,
#  ' eliten': 1.2973264866689427e-05,
#  ' australiaday': 2.4169568001245178e-05,
#  ' youthled': 5.089398520548163e-05,
#  ' wef20': 0.0003830747270050795,
#  ' arbeitsplätze': 6.218577796717733e-05,
#  ' wef': 4.343485446378987e-05,
#  ' klimaklage': 3.111028966192536e-05,
#  ' hassimnetz': 0.0,
#  ' ableg': 0.00013118656989765661,
#  ' abpoli': 1.5016141216581672e-05,
#  ' interview': 5.9141658634624794e-05,
#  ' dieuhrtickt': 2.6570145200997643e-05,
#  ' bauernproteste': 0.00014668284562547131,
#  ' urgenceclimatique': 0.0001561517121899074,
#  ' werefusecoalmine': 0.0,
#  ' perjantaitgretankanssa': 0.00010260818300516086,
#  ' grandparentsforfuture': 9.686030326004973e-05,
#  ' climategrandma': 0.00047433266799108573,
#  ' treckerdemo': 4.894049267411696e-05,
#  ' bauersuchtfrau': 4.964614185465826e-05,
#  ' agrarextremisten': 0.00014652621056002684,
#  ' nitratsau': 0.0003343208181076909,
#  ' umweltsau': 0.0003030332164961746,
#  ' australiafires': 0.00015406693176514712,
#  ' eni': 0.00026365992516379737,
#  ' total': 0.0005083653649070489,
#  ' gehtdoch': 0.0,
#  ' australiaisonfire': 0.0,
#  ' bushfirecrisisaustralia': 0.00010042537678024789,
#  ' australianbushfire': 5.555373495337458e-05,
#  ' granniesforfuture': 0.0,
#  ' omaumweltsau': 0.00010921704801921649,
#  ' k0301': 0.0003277029793913083,
#  ' werteunion': 4.6373833817544935e-05,
#  ' neujahr': 0.0001433525463473759,
#  ' kohlekommission': 7.626760895077218e-05,
#  ' ffffordert': 0.0001076438191358327,
#  ' ac2106': 0.00016667016621640715,
#  ' sokofuture': 0.0002731448287414754,
#  ' notmyklimapaket': 0.0005292352737598888,
#  ' neustartklima': 0.0018620738893194752,
#  ' campeonesdelatierra': 0.0,
#  ' nuhr': 0.00024719897137816515,
#  ' savethecongorainforest': 7.108143165083982e-06,
#  ' weihnachten': 0.00045201237813751924,
#  ' weihnachtenundklimakrise': 0.0004591329506028295,
#  ' linksfaschismus': 0.000136310365775838,
#  ' altersdiskriminierung': 0.00035479629714793115,
#  ' fridaysforfurture': 0.0008944275776533411,
#  ' dieerdebrennt': 2.834726382705532e-05,
#  ' klimarettung': 0.0002140289896461693,
#  ' sardine': 0.0007416490924441432,
#  ' cop25madrid': 0.0004001095674650255,
#  ' klimaathysterie': 0.00021477390194967386,
#  ' unitedbehindthesceince': 3.424436910372282e-05,
#  ' fixarticle6': 0.00010703845600531207,
#  ' wearemad': 0.00021625550402452773,
#  ' getrid': 0.00043474143539664066,
#  ' timepoy': 5.614426594558056e-05,
#  ' copforfuture': 3.789869804982606e-05,
#  ' genderday': 5.0315891441837816e-05,
#  ' actonthegap': 0.00026880182281392836,
#  ' childrensrights': 4.56780850064868e-05,
#  ' spdbt19': 0.00012074734656970292,
#  ' verantwortung': 0.00021346832044586597,
#  ' nichtmeinklimapaket': 0.0004966029855176519,
#  ' timeforaction': 0.00012074850408669219,
#  ' generalelection': 8.233608063952699e-06,
#  ' climateelection': 0.00014163451871679005,
#  ' vote': 0.0002868020135093779,
#  ' racist': 7.280268186033725e-05,
#  ' islamaphobic': 0.00014559676876192758,
#  ' sexist': 0.00025481381678114354,
#  ' homophobic': 0.00047329974815324313,
#  ' rinkeby': 9.130927488879902e-05,
#  ' makepolluterspay': 0.0,
#  ' fahrverbote': 3.007717236439695e-06,
#  ' ingeniería': 0.00018046499718732146,
#  ' jänschwalde': 0.0,
#  ' lausitz': 0.000339499788765339,
#  ' nopalm': 0.0,
#  ' dresden': 0.0004268212351733515,
#  ' duohnec': 0.0,
#  ' streikenstattfeiern': 2.834726382705532e-05,
#  ' blackfridaysale': 1.390277736018963e-05,
#  ' aktivistimummot': 0.00013761713039202715,
#  ' sittingwithgreta': 0.00035610306176411723,
#  ' ggultras': 1.8317125128948623e-05,
#  ' justiciasocial': 0.0,
#  ' bringafriendfriday': 9.725756014610269e-05,
#  ' lehrer': 0.0003157434915181959,
#  ' squali': 2.3833424159067705e-05,
#  ' santori': 0.0002990759041872337,
#  ' leader': 0.000180070717344276,
#  ' nov15th2019': 4.395211071266511e-05,
#  ' nov15': 0.00026243804208475765,
#  ' 15novembre': 0.00010908561262188096,
#  ' bolloré': 0.00013088755395879786,
#  ' criminelsécologistes': 0.00015511769270355334,
#  ' esclavagistes': 0.00018238307820811394,
#  ' lrem': 0.00021355092383242057,
#  ' modem': 0.0002499220496163852,
#  ' lr': 0.0002935777676238793,
#  ' huiledepalme': 0.00034816037396665785,
#  ' 1for25': 0.00042095446086824604,
#  ' 1pour25': 0.0005301715088874622,
#  ' carbonrationtickets': 0.0007486574402595513,
#  ' studiom': 0.0001719291512447752,
#  ' spdvorsitz': 0.00033503308115389354,
#  ' kleineaktivistin': 0.0,
#  ' würzburg': 0.00010565040626396379,
#  ' niederlande': 0.0001238685543019319,
#  ' roma': 0.0011843635890854227,
#  ' actonlakechad': 5.9155170333328915e-05,
#  ' saskatoon': 0.0001900905681153338,
#  ' youtube': 4.6346786051352975e-05,
#  ' tuesdaymotivation': 5.490761482898298e-05,
#  ' tuesdaythoughts': 0.00012770170173057925,
#  ' zerohunger': 0.00023691874974979577,
#  ' cupofuji': 0.00045540468112188726,
#  ' kurden': 0.0,
#  ' syrien': 0.00021848593137209108,
#  ' maynooth': 4.743281786360329e-05,
#  ' otromundoesposible': 0.0,
#  ' climatestrikevancouver': 6.686447027597021e-05,
#  ' indigenous': 0.00013061514991786398,
#  ' nomoreuicoal': 0.0,
#  ' dhanteras': 2.551858183125005e-05,
#  ' diwali': 0.00013472267101705265,
#  ' religions': 0.0005716426984275742,
#  ' goettingen': 0.0,
#  ' demaiziere': 0.00010288795390881577,
#  ' aareyforest': 0.0002939993418068729,
#  ' mitmenschenwürde': 0.0,
#  ' nopegidadd': 0.0,
#  ' pegidaistscheisse': 0.0,
#  ...}

# %%
new_centrality = {k: v for k, v in sorted(betweenness_centrality.items(), key=lambda item: item[1], reverse = True)}
new_centrality_nodes = [k for k, v in sorted(betweenness_centrality.items(), key=lambda item: item[1], reverse = True)]

# %% [markdown]
# # 5 - Assortativity

# %% [markdown]
# Weighted graph

# %%
d_weighted = nx.degree_assortativity_coefficient(G, weight = "Count")

# %%
d_weighted
# Out:
# -0.10390100274509496

# %%
# Calcolo avg nearest neigh
## Compute the average degree connectivity of graph.
"""
The average degree connectivity is the average nearest neighbor degree of
    nodes with degree k. For weighted graphs, an analogous measure can
    be computed using the weighted average neighbors degree defined in
    [1]_, for a node `i`, as
"""
avg=nx.k_nearest_neighbors(G, weight = "Count")
y=list(avg.values())

# Calcolo vettore dei gradi
k=G.degree()
x=[]
for item in k:
    x.append(item[1])
    
output = []
for b in x:
       if b not in output:
            output.append(b)

# Plot
plt.plot(output,y,'b.')   
plt.xlabel('Degree k')
plt.ylabel('KNN(k)')
# Out:
# Text(0, 0.5, 'KNN(k)')

# %%
d=nx.degree_assortativity_coefficient(G)

# %%
d
# Out:
# -0.117539092564233

# %%
# Calcolo avg nearest neigh
avg=nx.k_nearest_neighbors(G)
y=list(avg.values())

# Calcolo vettore dei gradi
k=G.degree()
x=[]
for item in k:
    x.append(item[1])
    
output = []
for b in x:
       if b not in output:
            output.append(b)

# Plot
plt.plot(output,y,'b.')   
plt.xlabel('Degree k')
plt.ylabel('KNN(k)')
# Out:
# Text(0, 0.5, 'KNN(k)')
