# %%
import pandas as pd
import matplotlib.pyplot as plt
import math
import numpy as np
import networkx as nx
from operator import itemgetter

# %%
path = "../Dataset FFF/edges.csv"

# %%
df = pd.read_csv(path)
df
# Out:
#              Source           Target  Count
# 0       fossilfuels             wind      1
# 1       fossilfuels            solar      1
# 2       fossilfuels            green      2
# 3       fossilfuels         hydrogen      1
# 4       fossilfuels           energy      2
# ...             ...              ...    ...
# 423985   agitaction   amiensforyouth      1
# 423986  i̇klimgrevi     sıfırgelecek      1
# 423987      amazing             ddop      1
# 423988      amazing             hips      1
# 423989         ddop             hips      1
#
# [423990 rows x 3 columns]

# %%
G = nx.read_edgelist(path, comments = "S", delimiter = ",", data=(("Count", int),))
degree_dict = dict(G.degree(G.nodes()))
nx.set_node_attributes(G, degree_dict, 'degree')
sorted_degree = sorted(degree_dict.items(), key = itemgetter(1), reverse = True)

# %%
ids = []                      #tag
count = []                    #quante volte appare
named = []                    #in quale categoria finirà
original = []                 #nome originale
for i in sorted_degree:
    ids.append(i[0])
    count.append(i[1])
    named.append("unamed")
    original.append(i[0])

# %%
len(ids)
# Out:
# 18887

# %%
count
# Out:
# [11712,
#  5194,
#  3894,
#  3804,
#  3379,
#  2914,
#  2856,
#  2625,
#  2622,
#  2569,
#  2530,
#  2371,
#  2284,
#  2239,
#  2160,
#  2104,
#  2091,
#  1991,
#  1986,
#  1954,
#  1906,
#  1898,
#  1891,
#  1850,
#  1838,
#  1760,
#  1749,
#  1615,
#  1597,
#  1475,
#  1406,
#  1303,
#  1224,
#  1215,
#  1179,
#  1168,
#  1158,
#  1143,
#  1121,
#  1117,
#  1067,
#  1047,
#  1033,
#  1030,
#  1028,
#  1017,
#  1014,
#  1007,
#  1005,
#  1000,
#  993,
#  990,
#  969,
#  938,
#  929,
#  925,
#  919,
#  902,
#  901,
#  894,
#  875,
#  869,
#  864,
#  852,
#  836,
#  817,
#  816,
#  811,
#  811,
#  807,
#  796,
#  790,
#  783,
#  769,
#  761,
#  756,
#  751,
#  739,
#  737,
#  727,
#  726,
#  723,
#  719,
#  718,
#  715,
#  710,
#  709,
#  700,
#  697,
#  696,
#  695,
#  689,
#  685,
#  681,
#  677,
#  671,
#  668,
#  664,
#  661,
#  657,
#  656,
#  641,
#  639,
#  639,
#  639,
#  636,
#  634,
#  624,
#  619,
#  617,
#  617,
#  615,
#  614,
#  611,
#  595,
#  594,
#  591,
#  579,
#  577,
#  576,
#  573,
#  570,
#  561,
#  559,
#  556,
#  555,
#  552,
#  546,
#  530,
#  528,
#  527,
#  526,
#  524,
#  524,
#  523,
#  523,
#  521,
#  514,
#  513,
#  511,
#  507,
#  506,
#  502,
#  502,
#  500,
#  496,
#  493,
#  491,
#  490,
#  488,
#  488,
#  486,
#  486,
#  485,
#  479,
#  475,
#  474,
#  473,
#  471,
#  466,
#  466,
#  464,
#  461,
#  460,
#  457,
#  456,
#  455,
#  454,
#  447,
#  442,
#  442,
#  440,
#  440,
#  439,
#  437,
#  434,
#  432,
#  431,
#  427,
#  426,
#  424,
#  421,
#  420,
#  420,
#  419,
#  419,
#  417,
#  416,
#  415,
#  413,
#  413,
#  406,
#  406,
#  405,
#  405,
#  403,
#  402,
#  398,
#  398,
#  397,
#  395,
#  393,
#  392,
#  392,
#  392,
#  392,
#  390,
#  389,
#  386,
#  385,
#  384,
#  384,
#  380,
#  378,
#  375,
#  374,
#  371,
#  370,
#  368,
#  365,
#  364,
#  363,
#  363,
#  361,
#  361,
#  361,
#  361,
#  359,
#  358,
#  357,
#  357,
#  357,
#  356,
#  356,
#  356,
#  356,
#  355,
#  355,
#  352,
#  351,
#  351,
#  347,
#  346,
#  346,
#  346,
#  346,
#  342,
#  341,
#  338,
#  338,
#  335,
#  335,
#  334,
#  334,
#  332,
#  332,
#  331,
#  330,
#  330,
#  329,
#  329,
#  328,
#  327,
#  327,
#  327,
#  327,
#  323,
#  322,
#  321,
#  320,
#  319,
#  319,
#  319,
#  319,
#  315,
#  315,
#  314,
#  314,
#  313,
#  313,
#  313,
#  312,
#  311,
#  310,
#  309,
#  307,
#  304,
#  304,
#  304,
#  301,
#  301,
#  300,
#  298,
#  298,
#  298,
#  297,
#  297,
#  297,
#  297,
#  296,
#  296,
#  296,
#  296,
#  294,
#  293,
#  292,
#  292,
#  290,
#  288,
#  286,
#  284,
#  283,
#  283,
#  282,
#  281,
#  280,
#  280,
#  279,
#  279,
#  279,
#  278,
#  278,
#  275,
#  275,
#  275,
#  274,
#  273,
#  273,
#  272,
#  272,
#  272,
#  271,
#  271,
#  270,
#  270,
#  270,
#  269,
#  268,
#  268,
#  268,
#  267,
#  267,
#  265,
#  265,
#  265,
#  265,
#  265,
#  265,
#  264,
#  264,
#  264,
#  264,
#  263,
#  262,
#  262,
#  261,
#  260,
#  260,
#  260,
#  260,
#  260,
#  258,
#  258,
#  258,
#  257,
#  257,
#  256,
#  256,
#  256,
#  255,
#  255,
#  254,
#  254,
#  253,
#  252,
#  252,
#  252,
#  251,
#  251,
#  251,
#  251,
#  251,
#  251,
#  250,
#  250,
#  249,
#  249,
#  249,
#  247,
#  246,
#  245,
#  245,
#  244,
#  244,
#  244,
#  244,
#  243,
#  243,
#  243,
#  243,
#  243,
#  243,
#  243,
#  243,
#  242,
#  241,
#  241,
#  241,
#  241,
#  241,
#  241,
#  241,
#  240,
#  240,
#  240,
#  240,
#  240,
#  240,
#  238,
#  238,
#  238,
#  238,
#  238,
#  238,
#  238,
#  238,
#  237,
#  237,
#  237,
#  237,
#  237,
#  237,
#  237,
#  237,
#  237,
#  237,
#  237,
#  237,
#  237,
#  237,
#  237,
#  237,
#  237,
#  237,
#  236,
#  236,
#  236,
#  236,
#  236,
#  236,
#  236,
#  236,
#  236,
#  236,
#  236,
#  236,
#  236,
#  236,
#  236,
#  236,
#  236,
#  236,
#  236,
#  236,
#  236,
#  236,
#  236,
#  236,
#  235,
#  235,
#  235,
#  235,
#  235,
#  235,
#  235,
#  234,
#  234,
#  234,
#  234,
#  234,
#  233,
#  233,
#  233,
#  232,
#  232,
#  231,
#  231,
#  230,
#  230,
#  230,
#  229,
#  229,
#  228,
#  227,
#  227,
#  227,
#  226,
#  226,
#  226,
#  226,
#  225,
#  225,
#  224,
#  224,
#  224,
#  224,
#  223,
#  222,
#  222,
#  221,
#  221,
#  221,
#  220,
#  220,
#  219,
#  219,
#  219,
#  218,
#  218,
#  218,
#  218,
#  218,
#  217,
#  216,
#  216,
#  215,
#  214,
#  214,
#  213,
#  213,
#  213,
#  213,
#  213,
#  211,
#  211,
#  211,
#  211,
#  211,
#  210,
#  210,
#  210,
#  209,
#  209,
#  209,
#  207,
#  207,
#  207,
#  207,
#  206,
#  206,
#  205,
#  205,
#  205,
#  205,
#  204,
#  204,
#  204,
#  204,
#  204,
#  204,
#  203,
#  203,
#  202,
#  201,
#  201,
#  201,
#  201,
#  201,
#  201,
#  201,
#  201,
#  200,
#  200,
#  200,
#  200,
#  199,
#  199,
#  198,
#  198,
#  198,
#  198,
#  198,
#  198,
#  198,
#  197,
#  197,
#  196,
#  196,
#  196,
#  196,
#  195,
#  195,
#  195,
#  195,
#  195,
#  194,
#  194,
#  194,
#  194,
#  194,
#  194,
#  193,
#  193,
#  192,
#  192,
#  192,
#  192,
#  192,
#  190,
#  190,
#  190,
#  189,
#  189,
#  189,
#  189,
#  189,
#  188,
#  187,
#  187,
#  187,
#  187,
#  187,
#  186,
#  186,
#  186,
#  186,
#  186,
#  186,
#  185,
#  185,
#  185,
#  185,
#  185,
#  185,
#  184,
#  183,
#  183,
#  183,
#  182,
#  182,
#  182,
#  182,
#  182,
#  182,
#  182,
#  181,
#  181,
#  181,
#  181,
#  181,
#  181,
#  181,
#  181,
#  181,
#  180,
#  180,
#  179,
#  179,
#  179,
#  178,
#  177,
#  177,
#  175,
#  175,
#  175,
#  175,
#  175,
#  174,
#  174,
#  174,
#  174,
#  173,
#  173,
#  173,
#  173,
#  172,
#  172,
#  172,
#  172,
#  172,
#  172,
#  171,
#  171,
#  171,
#  171,
#  170,
#  169,
#  169,
#  169,
#  169,
#  169,
#  168,
#  168,
#  168,
#  168,
#  168,
#  168,
#  167,
#  167,
#  167,
#  167,
#  166,
#  166,
#  166,
#  166,
#  166,
#  166,
#  166,
#  166,
#  166,
#  166,
#  166,
#  165,
#  165,
#  165,
#  165,
#  165,
#  165,
#  164,
#  164,
#  164,
#  164,
#  164,
#  164,
#  164,
#  164,
#  164,
#  164,
#  163,
#  163,
#  163,
#  162,
#  162,
#  162,
#  162,
#  162,
#  162,
#  162,
#  162,
#  162,
#  161,
#  161,
#  161,
#  161,
#  160,
#  160,
#  160,
#  160,
#  160,
#  160,
#  160,
#  160,
#  159,
#  159,
#  159,
#  159,
#  159,
#  159,
#  159,
#  158,
#  158,
#  158,
#  158,
#  158,
#  158,
#  158,
#  157,
#  157,
#  157,
#  156,
#  156,
#  156,
#  155,
#  155,
#  155,
#  155,
#  155,
#  155,
#  154,
#  154,
#  154,
#  154,
#  154,
#  153,
#  153,
#  153,
#  153,
#  153,
#  153,
#  153,
#  153,
#  153,
#  153,
#  153,
#  153,
#  152,
#  152,
#  152,
#  152,
#  152,
#  152,
#  151,
#  151,
#  151,
#  151,
#  151,
#  151,
#  151,
#  151,
#  151,
#  151,
#  150,
#  150,
#  150,
#  150,
#  150,
#  149,
#  149,
#  149,
#  149,
#  149,
#  149,
#  149,
#  149,
#  149,
#  149,
#  148,
#  148,
#  148,
#  148,
#  148,
#  148,
#  148,
#  147,
#  147,
#  147,
#  147,
#  147,
#  147,
#  147,
#  147,
#  147,
#  147,
#  146,
#  146,
#  146,
#  146,
#  146,
#  145,
#  145,
#  145,
#  145,
#  145,
#  145,
#  145,
#  144,
#  144,
#  144,
#  144,
#  144,
#  144,
#  144,
#  144,
#  144,
#  144,
#  144,
#  144,
#  143,
#  143,
#  143,
#  142,
#  142,
#  142,
#  142,
#  142,
#  142,
#  142,
#  142,
#  142,
#  142,
#  141,
#  141,
#  141,
#  141,
#  141,
#  141,
#  141,
#  140,
#  140,
#  140,
#  140,
#  140,
#  140,
#  139,
#  139,
#  139,
#  139,
#  139,
#  139,
#  139,
#  139,
#  138,
#  138,
#  138,
#  138,
#  138,
#  137,
#  137,
#  137,
#  137,
#  137,
#  137,
#  137,
#  137,
#  136,
#  136,
#  136,
#  136,
#  136,
#  136,
#  135,
#  135,
#  135,
#  135,
#  135,
#  135,
#  135,
#  135,
#  135,
#  135,
#  134,
#  134,
#  134,
#  134,
#  134,
#  134,
#  134,
#  134,
#  134,
#  134,
#  134,
#  133,
#  133,
#  133,
#  133,
#  133,
#  133,
#  133,
#  133,
#  133,
#  133,
#  132,
#  132,
#  132,
#  132,
#  132,
#  132,
#  132,
#  131,
#  131,
#  131,
#  131,
#  131,
#  131,
#  131,
#  131,
#  131,
#  131,
#  131,
#  130,
#  130,
#  130,
#  130,
#  130,
#  130,
#  130,
#  130,
#  130,
#  130,
#  130,
#  130,
#  130,
#  130,
#  130,
#  130,
#  130,
#  130,
#  130,
#  130,
#  130,
#  130,
#  130,
#  130,
#  130,
#  129,
#  129,
#  129,
#  129,
#  129,
#  129,
#  ...]

# %%
degree_dict = dict(G.degree(G.nodes()))
nx.set_node_attributes(G, degree_dict, 'degree')
sorted_degree = sorted(degree_dict.items(), key = itemgetter(1), reverse = True)
print(" ---- Top 100 nodes by degree ----")
for d in sorted_degree[:150]:
    print("\t" + str(d))
# Out:
#  ---- Top 100 nodes by degree ----
# 	('fridaysforfuture', 11712)
# 	('climatestrike', 5194)
# 	('climateaction', 3894)
# 	('climatecrisis', 3804)
# 	('climateemergency', 3379)
# 	('climatechange', 2914)
# 	('climatejustice', 2856)
# 	('climatestrikeonline', 2625)
# 	('klimastreik', 2622)
# 	('fridayforfuture', 2569)
# 	('klimaschutz', 2530)
# 	('klimakrise', 2371)
# 	('gretathunberg', 2284)
# 	('climateactionnow', 2239)
# 	('peoplenotprofit', 2160)
# 	('nomoreemptypromises', 2104)
# 	('fff', 2091)
# 	('uprootthesystem', 1991)
# 	('climate', 1986)
# 	('extinctionrebellion', 1954)
# 	('cop26', 1906)
# 	('globalclimatestrike', 1898)
# 	('klimawandel', 1891)
# 	('schoolstrike4climate', 1850)
# 	('fightfor1point5', 1838)
# 	('actnow', 1760)
# 	('facetheclimateemergency', 1749)
# 	('covid19', 1615)
# 	('digitalstrike', 1597)
# 	('cop25', 1475)
# 	('klima', 1406)
# 	('co2', 1303)
# 	('verkehrswende', 1224)
# 	('berlin', 1215)
# 	('neustartklima', 1179)
# 	('covid_19', 1168)
# 	('kohleausstieg', 1158)
# 	('corona', 1143)
# 	('earthday', 1121)
# 	('keingradweiter', 1117)
# 	('datteln4', 1067)
# 	('klimapaket', 1047)
# 	('spd', 1033)
# 	('allefürsklima', 1030)
# 	('actonclimate', 1028)
# 	('parisagreement', 1017)
# 	('merkel', 1014)
# 	('fridayfeeling', 1007)
# 	('gas', 1005)
# 	('energiewende', 1000)
# 	('fightclimateinjustice', 993)
# 	('klimagerechtigkeit', 990)
# 	('groko', 969)
# 	('fighteverycrisis', 938)
# 	('greta', 929)
# 	('coronavirus', 925)
# 	('mindthegap', 919)
# 	('fossilfuels', 902)
# 	('klimakatastrophe', 901)
# 	('allefuersklima', 894)
# 	('grünen', 875)
# 	('klimanotstand', 869)
# 	('laschet', 864)
# 	('klimawahl', 852)
# 	('afd', 836)
# 	('environment', 817)
# 	('cdu', 816)
# 	('globalstrike', 811)
# 	('greennewdeal', 811)
# 	('globalwarming', 807)
# 	('siemens', 796)
# 	('klimapolitik', 790)
# 	('endegelände', 783)
# 	('savecongorainforest', 769)
# 	('klimaziele', 761)
# 	('fridaymotivation', 756)
# 	('earth', 751)
# 	('antifa', 739)
# 	('sustainability', 737)
# 	('parentsforfuture', 727)
# 	('rwe', 726)
# 	('deutschland', 723)
# 	('bundestag', 719)
# 	('flattenthecurve', 718)
# 	('ipcc', 715)
# 	('ampel', 710)
# 	('dannibleibt', 709)
# 	('eu', 700)
# 	('noafd', 697)
# 	('klimaschutzgesetz', 696)
# 	('stopadani', 695)
# 	('lützerath', 689)
# 	('bundesregierung', 685)
# 	('climatejusticenow', 681)
# 	('endegelaende', 677)
# 	('alledörferbleiben', 671)
# 	('biodiversity', 668)
# 	('climatechangeisreal', 664)
# 	('netzstreikfürsklima', 661)
# 	('windkraft', 657)
# 	('blackfriday', 656)
# 	('atomkraft', 641)
# 	('tempolimit', 639)
# 	('defendthedefenders', 639)
# 	('scholz', 639)
# 	('hambacherforst', 636)
# 	('schoolstrike', 634)
# 	('fridaythoughts', 624)
# 	('notmyklimapaket', 619)
# 	('renewableenergy', 617)
# 	('trump', 617)
# 	('coronakrise', 615)
# 	('systemchangenotclimatechange', 614)
# 	('howdareyou', 611)
# 	(' cop25', 595)
# 	('nature', 594)
# 	('greendeal', 591)
# 	('blacklivesmatter', 579)
# 	('umweltsau', 577)
# 	('floods', 576)
# 	('renewables', 573)
# 	('climatebreakdown', 570)
# 	('nordstream2', 561)
# 	('endcoal', 559)
# 	('india', 556)
# 	('climatestrikes', 555)
# 	('thunberg', 552)
# 	('hamburg', 546)
# 	('withdrawthecap', 530)
# 	('klimahysterie', 528)
# 	('pollution', 527)
# 	('habeck', 526)
# 	(' notmyklimapaket', 524)
# 	('klimazielstattlobbydeal', 524)
# 	('science', 523)
# 	('unitebehindthescience', 523)
# 	('fridays4future', 521)
# 	('netzstreikfuersklima', 514)
# 	('klimaklage', 513)
# 	('neubauer', 511)
# 	('hambibleibt', 507)
# 	('ihrlasstunskeinewahl', 506)
# 	('systemchange', 502)
# 	('g7', 502)
# 	('australia', 500)
# 	('vegan', 496)
# 	('fossilfuel', 493)
# 	('btw21', 491)
# 	('kohleeinstiegsgesetz', 490)
# 	('sdgs', 488)

# %%
def select_from_key(key, data, expection):
    al=[]
    for i in data:
        if key in i[0]:
            if len(expection)>0:
                is_except = False
                for ex in expection:
                    if ex in i[0]:
                        is_except = True
                if not is_except:
                    al.append(i[0])
            else:
                al.append(i[0])
    return al

# %%
def replace_name(old_name, new_name, old_dataset, expection):
    for i in range(len(old_dataset)):
        if old_name in old_dataset[i]:
            if len(expection)>0:
                is_except = False
                for ex in expection:
                    if ex in old_dataset[i]:
                        is_except = True
                if not is_except:
                    if "unamed" in named[i]:
                        named[i] = new_name
                        original[i] = new_name
            else:
                if "unamed" in named[i]:
                    named[i] = new_name
                    original[i] = old_name

# %%
set(original)
# Out:
# {'bikelife',
#  ' eegreparatur',
#  'festivals',
#  'canyouhearusyet',
#  ' walmartblackfriday',
#  ' buxwaha',
#  'satyagrahaagainsteia2020',
#  ' bs2911',
#  ' peoplelovemoneymore',
#  'campusforfuture',
#  ' cdnpoli',
#  'climat',
#  'commissionspeciale',
#  'climatedisaster',
#  'nextlevel4future',
#  'makelovenotco2',
#  ' hartzundherzlich',
#  'maskup',
#  ' bundjugend',
#  'klimabilanz',
#  'motivation',
#  'lovemayo',
#  'nwa',
#  'plastic',
#  'tantacazz',
#  'endfossilfuelsubsidies',
#  ' triell',
#  ' robin_wood',
#  'kommunalwahlen',
#  ' klimastreik',
#  ' youthled',
#  'stopdatteln4',
#  ' ldk22nrw',
#  ' syrien',
#  ' artists',
#  ' hitzewellen',
#  ' nocarsundays',
#  'klimagate',
#  'klimaaktivistin',
#  ' march25',
#  'nooilinvirunga',
#  'microplastics',
#  ' lobbyland',
#  ' mentalhealthforfuture',
#  'ralphcaspers',
#  'fridaysforfutureindia',
#  'ggi',
#  ' snp',
#  ' climatesolution',
#  ' indiegame',
#  ' north',
#  ' i̇klimiçinhareketegeç',
#  'virus',
#  ' decoalonizeeurope',
#  ' 日テレ',
#  '否认气候危机者是人类公敌',
#  'endangeredspecies',
#  'antifaterrorists',
#  'herne',
#  ' öko',
#  'winner',
#  'la7',
#  ' ddop',
#  'actionnotwords',
#  ' migrante',
#  ' barbaraalberti',
#  ' ressourcen',
#  ' ispeakupfortheplanet',
#  'freedom',
#  'lovenothate',
#  'rubiesallies',
#  ' niemehrcducsu',
#  ' nomisma',
#  ' stoppadani',
#  'finestresu',
#  'powerfulowl',
#  ' yerlihakları',
#  'ulm',
#  ' exposicióahg',
#  'climatelive2021',
#  'fossilfreefuture',
#  'pflegestreik',
#  'banopenpitmining',
#  ' fratellitutti',
#  ' teamkinderschutz',
#  ' dolphinday',
#  ' carpitalism',
#  'manidelucesysombras',
#  'sundaymotivation',
#  ' treesforfuture',
#  ' globalclimateweek',
#  ' intensament',
#  ' youthvote',
#  'fahrraddemo',
#  ' ungeimpfte',
#  'earthhourwales',
#  'nutella',
#  ' foodies',
#  ' nofracking',
#  'trumpisnotadoctor',
#  ' onefight',
#  ' allefür1komma5grad',
#  ' meettherebels',
#  'agrarpolitik',
#  ' parisagreement',
#  ' runtervomgas',
#  'drehbuch',
#  'washingtondc',
#  'global',
#  ' westdale',
#  ' oberursel',
#  ' plasticintoxication',
#  ' itcouldbedifferent',
#  ' horden',
#  'naturelovers',
#  'keepmamaafricagreen',
#  ' schulstreik',
#  'niveau',
#  'savana',
#  ' extremismus',
#  'kraftwerk',
#  'jmun',
#  'hlt',
#  'glauber',
#  ' tag',
#  ' ideasforfuture',
#  ' wohlstand',
#  's04',
#  'sbt',
#  'staygrounded',
#  ' menschenkette',
#  'boxingday2019',
#  'onlyoneearth',
#  ' coachella',
#  ' nowayout',
#  'womensart',
#  'avellino',
#  'sauna',
#  ' grace',
#  ' sittingwithgreta',
#  ' fck2038',
#  ' wearewatching',
#  ' anarchisten',
#  ' fossilförbud',
#  ' 5thofnovember',
#  ' fridaysforfuturesiegen',
#  ' internationalwomansday',
#  'cap',
#  ' fife',
#  ' futuroesahora',
#  'bus',
#  'fightclimateinjustice',
#  'area51storm',
#  ' hitzewelle',
#  'beegees',
#  'huracanlorenzo',
#  ' luft',
#  '4dattelnessen',
#  'philosophie',
#  ' nuclear',
#  ' fightforourfutures',
#  'delhipollution',
#  'gretl',
#  ' groundhogday',
#  'faceclimateemergeny',
#  'week85',
#  'cycloneamphan',
#  ' tantacazz',
#  ' juventudporelclima',
#  'cduwahlprogramm',
#  '気候正義',
#  'muensterplatz',
#  ' fire',
#  'frontal21',
#  'leggebilancio',
#  'biodiversidad',
#  'freising',
#  ' actonfaso',
#  'wales',
#  ' guerillapv',
#  'banprivatecars',
#  ' parlamente',
#  ' narcogobierno',
#  ' mint',
#  ' eniecocida',
#  'ministerpräsident',
#  ' luisaschweigt',
#  'balcony4climate',
#  ' coruña',
#  ' aachen',
#  'wahlprogramme',
#  'meeresspiegel',
#  ' trees4peace',
#  'wirtschaftsrat',
#  'climatebanners',
#  'furaleón',
#  ' spö',
#  ' leadonclimate',
#  ' riseupmovt',
#  ' klimawissenschaft',
#  'dontgiveup',
#  'br',
#  'hupdolen',
#  'profilepic',
#  'bundesverfassungsgericht',
#  ' supportergegennazis',
#  'emissionfree',
#  ' actlikeit',
#  'uniper',
#  'healthcareworkers',
#  'stopwarinukraine',
#  ' bigschoolsbirdwatch',
#  'pyarkiiyeekkahani',
#  ' travelblogger',
#  'altmaierknick',
#  'muenchen',
#  ' berlinblockieren',
#  'chile',
#  ' belfast',
#  'iammadagascar',
#  'kesselbambule',
#  'uniontent',
#  ' deforestation',
#  'ceipausiàsmarchalboraia',
#  'wahrheit',
#  ' wuppertal',
#  'wednesdaythoughts',
#  ' yyjtraffic',
#  ' welcometoarabia',
#  ' sterbehilfe',
#  'technologien',
#  ' bushfiresaustralia',
#  ' stopthebalcksoot',
#  'rackete',
#  'itsourtime',
#  'dbdk20',
#  'marvelaudition',
#  'soli',
#  ' kapitalismus',
#  ' gazprom',
#  'treemendous',
#  'verzicht',
#  'extremismi',
#  'manifestazione',
#  ' workinprogress',
#  'jaén',
#  ' greenwave',
#  ' konzert',
#  'flood',
#  ' allesfürsklima',
#  ' togetherfor100re',
#  'klimaschutzvertrages',
#  'gruendeppen',
#  ' ntv',
#  ' niewiedersozialismus',
#  ' photooftheday',
#  'digitalstrikeoxford',
#  ' ilmasto',
#  '2019in5words',
#  ' ammattiliitto',
#  'indianeedsoxygen',
#  'wärmesektor',
#  'carbonfriendly',
#  'machtsendlich',
#  ' svgreen',
#  'dayoftheforest',
#  ' zugstreik',
#  'listentothescientists',
#  ' lostchildren',
#  ' verona',
#  'flatnotboring',
#  ' lsa',
#  ' pilgerstatthetze',
#  ' investitionen',
#  ' culturalheritage',
#  ' mainz1701',
#  'livestreammomente',
#  ' meetoo',
#  ' nationalrescuedogday',
#  'easyrecipes',
#  ' nobleeconomists',
#  ' nyalesund',
#  ' youngpeople',
#  'salestips',
#  ' actnow',
#  ' farm4climate',
#  ' attivismo',
#  'abstorm',
#  'afdgehörtnichtzudeutschland',
#  ' savebuxwahaforest',
#  'kurzstreckenflüge',
#  ' poisonisreal',
#  'icoalert',
#  ' newgovernment',
#  ' skincareroutine',
#  'cumbredelclima',
#  ' marchaclimática',
#  'dunfermline',
#  'strong',
#  ' himnonacional',
#  ' kincadefire',
#  ' canadaelection2019',
#  'uno',
#  'climatestrike2404',
#  'landschafftverbindung',
#  ' redsij',
#  ' greenwashing',
#  ' covid19de',
#  'bundeswehr',
#  'ostseeskandal',
#  ' withdawthecap',
#  ' lush',
#  ' writingcommmunity',
#  'newgovernment',
#  'b1606',
#  'hirschhausen',
#  'day9',
#  '大豆ミート',
#  ' helpateacher',
#  ' youthforclimate',
#  'dannenröderforst',
#  'heldinnen',
#  'friday13th',
#  'wisskomm',
#  'inyourmemory',
#  ' ecuador',
#  'thyssenkrupp',
#  'gewalt',
#  'climatecult',
#  ' fridaysforfutureantarctica',
#  'rmdetodos',
#  'humankind',
#  'flugscham',
#  ' behindthescenes',
#  'gerusalemme',
#  'amazonrainforest',
#  ' motivational',
#  ' crises',
#  'klima',
#  ' activismisnotacrime',
#  ' stopadani',
#  'week5',
#  ' sustainableleadership',
#  ' funnyvegacademy',
#  ' stopthemoneypipeline',
#  'politikverbrecher',
#  'alldaysforfuture',
#  ' alifeonourplanet',
#  ' abindieschule',
#  'ceoquotes',
#  ' erdüberlastungstag',
#  ' agenda2030',
#  'fridayquotes',
#  ' letloverule',
#  ' hessen',
#  'radikalisierung',
#  ' wienliebe',
#  ' klimaneutral',
#  ' planttreesaveearth',
#  'rappcoop21',
#  ' zeitzumumdenken',
#  'monibleibt',
#  'aufstandoderaussterben',
#  ' condordown',
#  ' noplasticosdeunsolouso',
#  ' iklimacil',
#  'wohnen',
#  'unwort',
#  ' uprootthecop',
#  'netzstreikfuersklima',
#  ' circular',
#  ' bernie2020',
#  ' nachhaltigkeit',
#  ' veneto',
#  ' savegreen',
#  ' onealbuquerque',
#  ' globalstrikefornature',
#  ' connected',
#  ' plasticstreaty',
#  'endwhitesupremacy',
#  ' workout',
#  ' lifegivingforests',
#  ' esreicht',
#  ' sunrisemovement',
#  ' ki',
#  'tàrrega',
#  'mostpollutingbrands',
#  ' verursacherprinzip',
#  'klimaschutzlähmung',
#  ' dannenroderforst',
#  ' tippingpoint',
#  'ココイチ',
#  ' bäume',
#  ' connewitz',
#  'europa',
#  ' staytuned',
#  'ndc',
#  'salviamovenezia',
#  ' respectanimals',
#  ' ge2020',
#  ' kurz',
#  ' veganadvocacy',
#  'bauleni',
#  'raggi',
#  'resisters',
#  'transrightsarehumanrights',
#  ' nov15',
#  'startup',
#  'joinin247',
#  ' iwantyoutopanic',
#  ' positivetwitterπ',
#  'ss4c',
#  'co2idioten',
#  ' covid19seattle',
#  'plakataktion',
#  ' keepoilintheground',
#  ' boomersforclimatejustice',
#  'escazúya',
#  ' climatered',
#  'ilmastotekoja',
#  ' stopclearcuts',
#  'tod',
#  ' aufklärung',
#  'enteignung',
#  ' united4climatejustice',
#  ' flatnotboring',
#  ' iamgreta',
#  'kohlecommerzbank',
#  'obiezionecoscienza',
#  ' worldpeaceday',
#  'stalbert',
#  'worsethanthanos',
#  'shutdown',
#  ' bepartofthesolution_notthepollution',
#  ' twitch',
#  'preisverleihungen',
#  'greatgreenwall',
#  'bernieblackout',
#  'digitalstrikeforclimate',
#  'gainesville',
#  ' semesterfrage',
#  ' fahrrad',
#  'europawahl',
#  ' wearestillhere',
#  ' witchcraft',
#  ' rovaniemi',
#  ' andieeigenenasefassen',
#  ' haan',
#  ' oedp',
#  ' kindern',
#  '3dtours',
#  'manmohansingh',
#  ' huether',
#  'atomanlagen',
#  'amazoniaislife',
#  'movimento',
#  'globalwarming',
#  'extinguirnosorebelarnos',
#  ' wirbleibenzuhause',
#  ' milano',
#  'sostenibilidad',
#  ' liberty',
#  'breonnataylor',
#  ' recoveryfunds',
#  ' eutaxonomy',
#  ' bpt',
#  ' denmark',
#  ' stopaeroportomontijo',
#  'dbdk22',
#  ' chafrica',
#  ' mettmann',
#  ' climatestrikephx',
#  'wohlstandfüralle',
#  'privatjet',
#  'unitedforclimate',
#  'pupsfortheplanet',
#  'istayontheground',
#  ' scioperoperilclima',
#  'neindanke',
#  'maltempo',
#  'ynetartcontest2022',
#  'böller',
#  ' emergenciaclimática',
#  'gardening',
#  'wirtschaft',
#  ' wärmegesetz',
#  'schulen',
#  ' wellfarenotwarfare',
#  'bischof',
#  'contentmarketing',
#  'klimaliste',
#  ' chef',
#  ' taskforceklimakrise',
#  ' stem',
#  ' sustentavel',
#  ' hurricane',
#  'giornatamondialedellambiente',
#  ' future',
#  'technologyupdates',
#  ' doctorsforfuture',
#  'yyc',
#  ' norway',
#  'सकारात्मक_संदेश',
#  ' halifax',
#  'kleinaberfein',
#  ' wirbleibenalle',
#  ' stopcambo',
#  ' wirtschaftssabotage',
#  ' jeunes',
#  ' hevrinkhalaf',
#  ' genderday',
#  'solobutnotalone',
#  ' spreadawareness',
#  ' worldvegetarianday',
#  ' 1komma5grad',
#  'brotstattboeller',
#  ' noect',
#  ' maybritillner',
#  'rajayoga',
#  'プラントベース',
#  ' olympiastadion',
#  ' boliviano',
#  ' verkehrstote',
#  'winnipeg',
#  ' acciónclimática',
#  ' food',
#  ' teachsdgs',
#  'nrwaehltklima',
#  'tukslaw',
#  ' climatemarchkarachi',
#  'misinformation',
#  'santurbán',
#  ' wirfahrenzusammen',
#  ' listentothescience',
#  'neve',
#  'rebuildbetter',
#  'ausgelutzt',
#  'symces',
#  ' corgicrew',
#  'bauersuchtfrau',
#  'plantónporelclima',
#  ' fffsolidaritywithsudan',
#  'warumnuhr',
#  'fff_osterholz',
#  ' jbsollerpelclima',
#  ' co2020',
#  ' stopisds',
#  'artenvielfalt',
#  ' gehtdoch',
#  '1for25',
#  'bcelection2020',
#  'wirsindfriedlichwasseidihr',
#  ' rodent',
#  'topgun',
#  'friedrichshafen',
#  'cat',
#  ' energiewenderocken',
#  'stopfakerenewables',
#  ' endegelaende',
#  ' ecologicalcollapse',
#  ' followerpower',
#  ' seltensovielschwachsinngehört',
#  'klimaklage',
#  ' exportüberschuss',
#  'breg',
#  ' afdverbot',
#  ' maltzan',
#  ' niederösterreich',
#  'ゼロウェイスト',
#  'bsfwarrior',
#  'extinctionrebellion',
#  ' violin',
#  'entérate',
#  ' audi',
#  'migrante',
#  'congorainforest',
#  'traveltips',
#  'newprofilepic',
#  ' kündigung',
#  ' peking',
#  'buildourfuture',
#  ' veganfood',
#  'wo0606',
#  'peoplearedying',
#  ' poewatcheseu',
#  ' ffffordert',
#  ' zorasarahblogs',
#  ' 化石賞',
#  ' manifencours',
#  ' pkw',
#  'subventionen',
#  'notstromaggregate',
#  'abrüsten',
#  ' 2020ends',
#  'noexistevacunaparalacrisisclimatica',
#  ' danni',
#  ' meatloaf',
#  ' matura2020',
#  'endfossilfuels',
#  ' 気候危機に特効薬なし',
#  ' policebrutality',
#  ' solarpflicht',
#  'proverbe',
#  ' kriege',
#  'netzero2030',
#  ' stockholm',
#  ' asha',
#  'acquaalta',
#  ' tongosv',
#  'copout26',
#  ' cduwahlprogramm',
#  'igmetall',
#  ' mohring',
#  ' generalelection2019',
#  ' climatejusticeissocialjustice',
#  'systemversagen',
#  ' nichtsnutze',
#  ' foodie',
#  'kielahoi',
#  'speciesism',
#  'feuerwehr',
#  ' environmentday',
#  'writingcommmunity',
#  'draghi',
#  'rentner',
#  'hanfkalk',
#  'dashandwerk',
#  ' anakkayam',
#  ' eni',
#  'strikeeverywhere',
#  'peaceuponyemen',
#  ' ong',
#  ' thisiszerohour',
#  ' mixedmedia',
#  'hambacherwald',
#  ' climatesummit',
#  'covid2019',
#  'biodiversity',
#  'メリークリスマス',
#  'digitalstrikescotland',
#  'flashbackfriday',
#  ' cdublockiert',
#  'divestfromfossilfuels',
#  ' climatepeace',
#  ' ilmastoaktivismi',
#  'ecocidelaw',
#  'iskpassion',
#  ' tpl',
#  ' demo',
#  'digitalstrikesapporo',
#  'ernähren',
#  'bayern',
#  'vicentelopez',
#  ' klimagipfel',
#  ' aktien',
#  'eat',
#  ' emergenciaclimaticabcn',
#  'tgv',
#  'konjunkturpaketes',
#  ' k0301',
#  'nuhr',
#  'strikeforfuture',
#  'climatestrikenyc',
#  ' berlin4future',
#  ' georgeflyod',
#  'bernieorbust',
#  ' planttree',
#  'london',
#  ' covid19',
#  ' ビリー・アイリッシュ',
#  ' timefornature',
#  'oildrilling',
#  ' kliamschutz',
#  'matera',
#  'dreadlocks',
#  ' amazonecho',
#  ' kinder',
#  'fashion',
#  ' lovetrumpshate',
#  ' biofuels',
#  ' wölki',
#  ' garrotxa',
#  ' autumnpeltier',
#  '28000porelclima',
#  ' itshappening',
#  'wodarg',
#  'tdi',
#  ' manitoba',
#  'climatesign',
#  ' bcstorm',
#  'lasagne',
#  'notstromaggregat',
#  'nachhaltigkeit',
#  ' unitedbehindthescience',
#  ' climateheroines',
#  'iloveza',
#  'palermo',
#  'farmersforfuture',
#  'fridaysvstechnology',
#  'queensferrycrossing',
#  'wevsclimatecrisis',
#  ' vernunft',
#  'leag',
#  ' oberbaumbrücke',
#  ' help',
#  ' b1606',
#  ' phheidelberg',
#  'العدالة_المناخية',
#  'euw19',
#  ' demokratisch',
#  ' thirdpole',
#  'waldrodung',
#  'oceanandclimateemergency',
#  ' christmas2020',
#  ' stayinghome',
#  'musicdeclares',
#  ' bremerhaven',
#  ' siemenshv2020',
#  ' bced',
#  'eka',
#  'interiordesign',
#  'fridaysforfuturejhansi',
#  'mayday2025',
#  ' saanslenedo',
#  'antelaemergencia',
#  ' proudlyyou',
#  ' uselection',
#  'shoeprotest',
#  ' verdrängung',
#  'plasticwaste',
#  ' k3010',
#  ' actonsahel',
#  'demvoice1',
#  'fluechtlinge',
#  ' klimaathysterie',
#  ' cartoon',
#  ' flycats',
#  ' quetzaltenango',
#  'sharmelsheikh',
#  'besteuert',
#  'cliamtestrike',
#  ' fridayreads',
#  ' stadtfürmenschen',
#  ' mittel',
#  'equidaddegenero',
#  'belugagrads',
#  ' 買い物は投票',
#  'genz',
#  'vanclimateemergency',
#  'tumbaco',
#  ' farmersprotesthijacked',
#  'help',
#  'chalukyadynasty',
#  'climatestrikecr',
#  'jugendgegenrassismus731',
#  'flüchlingskrise',
#  ' fantasy',
#  'greenhousegases',
#  '27sep',
#  'scientistrebellion',
#  'togethefor100re',
#  'kippraconference2022',
#  'bmwk',
#  'leibnizmuseen',
#  'koeln',
#  'palebluedot',
#  'thoughtfortheday',
#  'lausitz',
#  ' zukunftsrisikocsu',
#  ' school',
#  ' fungus',
#  'scottishindependence13',
#  ' felizfindesemana',
#  'selfiequeen',
#  ' webinar',
#  'farpol',
#  ' ausgelutzt',
#  'pressefreiheit',
#  'schwurbel',
#  'efficiency',
#  ' marketingstrategy',
#  'wahlalter',
#  'lossanddamage',
#  ' salud',
#  'movies',
#  'day14',
#  ' storck',
#  'riscaldamentoglobale',
#  'mühlrose',
#  'berniecutishs',
#  ' naturalis_sci',
#  ' siemenslügt',
#  ' climateactionclub',
#  'sunset',
#  'justtransitionnow',
#  'climatestrikeaz',
#  ' konjunkturpaket',
#  ' oilchange',
#  'sovereignty',
#  ' web3',
#  'keinea66',
#  ' thephotohour',
#  'welt',
#  'internationalwomensday2022',
#  ' moria',
#  ' cycloneapmhan',
#  'votehimout',
#  'vivaespaña',
#  ' campingas',
#  ' extreme',
#  'stopttip',
#  'abo',
#  ' skincaretips',
#  ' pratsdelluçanès',
#  ' smoke',
#  ' timetoact',
#  ' hanau',
#  ' thursdaymorning',
#  'klimaproteste',
#  'politicians',
#  'climatedeedsnotwords',
#  ' someat',
#  'savesoilsavelife',
#  'fahrverbote',
#  'horrornights',
#  ' countdowntothefuture',
#  ' brookline',
#  ' ac2911',
#  ' teamlaura',
#  'climatechanges',
#  'huelgaclimatica',
#  'climateemergencyph',
#  ' bundesverfassungsgericht',
#  ' lsv',
#  'day821',
#  'carolsforclimate',
#  'listenlearnact',
#  'प्\\u200dयाज',
#  'diadetodoslossantos',
#  ' singlelife',
#  ' hindulynched',
#  ' finanstwitter',
#  'ambientalismo',
#  ' 17punkteplan',
#  'bath',
#  'physiotherapistsforfuture',
#  ' batti',
#  ' drawdown',
#  ' finnland',
#  ' environnement',
#  'glyphosat',
#  'sanders',
#  ' plasticban',
#  '大学生協',
#  ' greveglobalpeloclima',
#  'thanksgiving',
#  'weltklimatag',
#  'mauritiusoilspill',
#  ' niemehrcdu',
#  'lebanon',
#  'dresdenfüralle',
#  ' speranza',
#  ' istandwithblm',
#  ' protectantarctica',
#  ' readingismagicfest',
#  ' 金曜日アクション',
#  ' kenia',
#  ' crueltyfree',
#  'schuetztunseremeere',
#  ' science',
#  ' habitat',
#  'stockholmuniversity',
#  ' nolympia',
#  'picktherightbattle',
#  ' peace4climate',
#  ' globaldayofclimateaction',
#  ' bicycleschangelives',
#  '1pour25',
#  'save_farmer_save_country',
#  'abstandsregel',
#  ' saveenvironment',
#  ' osstf',
#  ' solidarieta',
#  'klimamomente2019',
#  'gegen1000kreuze',
#  'ecojogging',
#  'münsterkannmehr',
#  'dürrejahr',
#  'fundourfuturenotgas',
#  ' climatecriminals',
#  ' satire',
#  ' a100',
#  'unserezukunftdeinewahl',
#  ' bgija',
#  ' gibrassismuskeinechance',
#  'solidarischnichtalleine',
#  'waste',
#  'stream',
#  'nextgencityaction',
#  ' erfurt',
#  ' socialdistancing',
#  'strikefromhome',
#  'nazis',
#  'pmblessinglu',
#  ' amthor',
#  ' wirsindmehr',
#  'elycathedral',
#  ' electric',
#  'worldeggday',
#  ' perversesubventionen',
#  '2020werdenwir',
#  ' believe',
#  ' ilmastoteko',
#  ' nomorewars',
#  'europeanhomeparliaments',
#  'dreckwegtag',
#  ' siemensboykott',
#  'noeasy_iscoming',
#  'giletsjaunes',
#  ' sky',
#  ' gamerforfuture',
#  ' facetheclimateemergency',
#  'wessel',
#  'saveportharcourt',
#  'fdi',
#  'fahrräder',
#  'vermittlungsausschuss',
#  ' acciónclimáticaya',
#  'bangladesch',
#  ' bus',
#  ' awareness',
#  'klimamahnwache',
#  ' biden',
#  'updateklimaenergie',
#  'unterlaufen',
#  ' lebensgrundlage',
#  'south_vally_university',
#  ' nofuturenodancefloor',
#  'noplasticosdeunsolouso',
#  ' pokélife',
#  ' nuhr',
#  '15feb2020',
#  ' kraftwerk',
#  'genclimateaction',
#  ' sustentabilidad',
#  'buxwaha',
#  'いいにくいことを言う日',
#  'untilwearedone',
#  ' 5300climate',
#  'fridayvibe',
#  'rehabilitatekhori',
#  ' youthlead',
#  ' philippines',
#  ' durchseuchungstoppen',
#  ' vonderleyen',
#  ' climatestrikenow',
#  ' airdrops',
#  'bluecarbon',
#  'normal',
#  ' greenfinanceeu',
#  'amazing',
#  ' doučování',
#  ' baumhaus',
#  'fckracism',
#  'fossilfuelnonproliferationtreaty',
#  'faktenfinder',
#  'energyefficiency',
#  ' giveaway',
#  ' ravensburg',
#  'bergbauindustrie',
#  'knittingscience',
#  ' fehmarnbelttunnel',
#  'feuerdenscheuer',
#  ' gullmarsplan',
#  'stopputinnow',
#  ' neujahr',
#  'gutso',
#  'earthovershotday',
#  ' klimaentscheid',
#  ' energieeffizienz',
#  'menschlichkeit',
#  'iamgreta',
#  ' romeisus',
#  'mainkai',
#  ' cambioclimático',
#  'grevedigital',
#  'waldsterben',
#  'climatescience',
#  ' steinkohlekraftwerk',
#  'georgeflyod',
#  'macrophotography',
#  'tierrecht',
#  ' escolaverda',
#  ' lbv',
#  'adventadvocacy',
#  ' nothingaboutuswithoutus',
#  ' orangeaktiv',
#  ' aegreenivory',
#  ' cialtrone',
#  'masks',
#  ...}

# %%
print(nx.info(G))
# Out:
# Name:
# Type: Graph
# Number of nodes: 18887
# Number of edges: 363452
# Average degree:  38.4870

# %%
replace_name("gretathunberg", "Greta Thunberg", ids, [])
replace_name("greta", "Greta Thunberg", ids, [])
replace_name("gretathurnberg", "Greta Thunberg", ids, [])
replace_name("gretaeffect", "Greta Thunberg", ids, [])
replace_name("iamgreta", "Greta Thunberg", ids, [])
replace_name("gretaultras", "Greta Thunberg", ids, [])
replace_name("istandwithgreta", "Greta Thunberg", ids, [])
replace_name("istandwithgreta", "Greta Thunberg", ids, [])
replace_name("iamgreta", "Greta Thunberg", ids, [])
replace_name("gretathunberg", "Greta Thunberg", ids, [])
replace_name("makeamericagretaagain", "Greta Thunberg", ids, [])
replace_name("gretathumberg", "Greta Thunberg", ids, [])
replace_name("gretathurnberg", "Greta Thunberg", ids, [])
replace_name("generationgreta", "Greta Thunberg", ids, [])
replace_name("gretastyle", "Greta Thunberg", ids, [])
replace_name("thegretaeffect", "Greta Thunberg", ids, [])
replace_name("sittingwithgreta", "Greta Thunberg", ids, [])
replace_name("greta4nobelprize", "Greta Thunberg", ids, [])
replace_name("teamgreta", "Greta Thunberg", ids, [])

# %%
replace_name("climatestrike", "Action", ids, "")
replace_name("climateaction", "Action", ids, "")
replace_name("klimastreik", "Action", ids, "")
replace_name("climatestrikeonline", "Action", ids, "")
replace_name("climateactionnow", "Action", ids, "")
replace_name("climatestrikeonline", "Action", ids, "")
replace_name("peoplenotprofit", "Action", ids, "")
replace_name("climateactionnow", "Action", ids, "")
replace_name("nomoreemptypromises", "Action", ids, "")
replace_name("globalclimatestrike", "Action", ids, "")
replace_name("schoolstrike4climate", "Action", ids, "")
replace_name("actnow", "Action", ids, "")
replace_name("digitalstrike", "Action", ids, "")
replace_name("fridays4futureonline", "Action", ids, "")
replace_name("fridaysforfutureonline", "Action", ids, "")
replace_name("youngactivists", "Action", ids, "")
replace_name("youngpeoplemarching", "Action", ids, "")
replace_name("youngpeopleforchange", "Action", ids, "")
replace_name("youngactivists", "Action", ids, "")
replace_name("activists", "Action", ids, "")

# %%
replace_name("fridaysforfuture", "#FridayForFuture", ids, "")
replace_name("climatecrisis", "#FridayForFuture", ids, "")
replace_name("climateemergency", "#FridayForFuture", ids, "")
replace_name("climatechange", "#FridayForFuture", ids, "")
replace_name("climatejustice", "#FridayForFuture", ids, "")
replace_name("fridayforfuture", "#FridayForFuture", ids, "")
replace_name("fff", "#FridayForFuture", ids, "")
replace_name("uprootthesystem", "#FridayForFuture", ids, "")
replace_name("climate", "#FridayForFuture", ids, "")
replace_name("extinctionrebellion", "#FridayForFuture", ids, "")
replace_name("fightfor1point5", "#FridayForFuture", ids, "")
replace_name("facetheclimateemergency", "#FridayForFuture", ids, "")
replace_name("earthday", "#FridayForFuture", ids, "")
replace_name("fridayfeeling", "#FridayForFuture", ids, "")
replace_name("fightclimateinjustice", "#FridayForFuture", ids, "")
replace_name("fighteverycrisis", "#FridayForFuture", ids, "")
replace_name("globalwarming", "#FridayForFuture", ids, "")
replace_name("fridaymotivation", "#FridayForFuture", ids, "")
replace_name("f4f", "#FridayForFuture", ids, "")
replace_name("fridaythoughts", "#FridayForFuture", ids, "")
replace_name("fridays4future", "#FridayForFuture", ids, "")
replace_name("friday", "#FridayForFuture", ids, "")
replace_name("fridays4futureonline", "#FridayForFuture", ids, "")
replace_name("fffdigitalstrike", "#FridayForFuture", ids, "")
replace_name("fff_digital'", "#FridayForFuture", ids, "")
replace_name("fridays", "#FridayForFuture", ids, "")
replace_name("youngpeopleforclimateaction", "#FridayForFuture", ids, "")
replace_name("younggreens", "#FridayForFuture", ids, "")

# %%
replace_name("klimastreik", "FFF DE", ids, "")
replace_name("klimaschutz", "FFF DE", ids, "")
replace_name("klimakrise", "FFF DE", ids, "")
replace_name("klimawandel", "FFF DE", ids, "")
replace_name("verkehrswende", "FFF DE", ids, "")
replace_name("klima", "FFF DE", ids, "")
replace_name("verkehrswende", "FFF DE", ids, "")
replace_name("berlin", "FFF DE", ids, "")
replace_name("neustartklima", "FFF DE", ids, "")
replace_name("kohleausstieg", "FFF DE", ids, "")
replace_name("keingradweiter", "FFF DE", ids, "")
replace_name("datteln4", "FFF DE", ids, "")
replace_name("klimapaket", "FFF DE", ids, "")
replace_name("allefürsklima", "FFF DE", ids, "")
replace_name("klimagerechtigkeit", "FFF DE", ids, "")
replace_name("klimakatastrophe", "FFF DE", ids, "")
replace_name("allefuersklima", "FFF DE", ids, "")
replace_name("klimanotstand", "FFF DE", ids, "")
replace_name("klimawahl", "FFF DE", ids, "")
replace_name("klimaziele", "FFF DE", ids, "")
replace_name("deutschland", "FFF DE", ids, "")
replace_name("klimaschutzgesetz", "FFF DE", ids, "")
replace_name("endegelaende", "FFF DE", ids, "")
replace_name("windkraft", "FFF DE", ids, "")
replace_name("energiewende", "FFF DE", ids, "")

# %%
replace_name("covid19", "Covid", ids, "")
replace_name("covid_19", "Covid", ids, "")
replace_name("corona", "Covid", ids, "")
replace_name("covidー19", "Covid", ids, "")
replace_name("covid", "Covid", ids, "")
replace_name("coronavirus", "Covid", ids, "")
replace_name("covid2019", "Covid", ids, "")
replace_name("covidsafe", "Covid", ids, "")
replace_name(" covidsafe", "Covid", ids, "")
replace_name(" covid__19", "Covid", ids, "")
replace_name("covidcrisis", "Covid", ids, "")
replace_name("stopcovid", "Covid", ids, "")

# %%
replace_name("gas", "Material", ids, "")
replace_name("fossilfuels", "Material", ids, "")
replace_name("co2", "Material", ids, "")
replace_name("windkraft", "Material", ids, "")

# %%
replace_name("spd", "German politics", ids, "")
replace_name("merkel", "German politics", ids, "")
replace_name("groko", "German politics", ids, "")
replace_name("grünen", "German politics", ids, "")
replace_name("laschet", "German politics", ids, "")
replace_name("afd", "German politics", ids, "")
replace_name("cdu", "German politics", ids, "")
replace_name("klimapolitik", "German politics", ids, "")
replace_name("rwe", "German politics", ids, "")
replace_name("bundestag", "German politics", ids, "")
replace_name("bundesregierung", "German politics", ids, "")
replace_name("energiepolitik", "German politics", ids, "")
replace_name("politik", "German politics", ids, "")
replace_name("politikern", "German politics", ids, "")
replace_name("klimaschutzpolitik", "German politics", ids, "")

# %%
replace_name("parisagreement", "Agreement", ids, "")
replace_name("cop26", "Agreement", ids, "")
replace_name("cop25", "Agreement", ids, "")
replace_name(" cop25", "Agreement", ids, "")
replace_name("ipcc", "Agreement", ids, "")
replace_name("mindthegap", "Agreement", ids, "")
replace_name("greennewdeal", "Agreement", ids, "")
replace_name("greendeal", "Agreement", ids, "")

# %%
replace_name("dannibleibt", "DE Actions", ids, "")
replace_name("noafd", "DE Actions", ids, "")
replace_name("ampel", "DE Actions", ids, "")
replace_name("endegelände", "DE Actions", ids, "")
replace_name("lützerath", "DE Actions", ids, "")
replace_name("endegelaende", "DE Actions", ids, "")
replace_name("alledörferbleiben", "DE Actions", ids, "")
replace_name("netzstreikfürsklima", "DE Actions", ids, "")

# %% [markdown]
# ### Creazione file CSV

# %%
saved_path2 = "../Dataset FFF/nodes_tagged.csv"

new_df = pd.DataFrame({"Id": ids, "Count": count, "Named": named, "Original": original})
new_df.to_csv(saved_path2, index=False)
new_df
# Out:
#                      Id  Count             Named          Original
# 0      fridaysforfuture  11712  #FridayForFuture  fridaysforfuture
# 1         climatestrike   5194            Action     climatestrike
# 2         climateaction   3894            Action     climateaction
# 3         climatecrisis   3804  #FridayForFuture     climatecrisis
# 4      climateemergency   3379  #FridayForFuture  climateemergency
# ...                 ...    ...               ...               ...
# 18882             برلين      1            unamed             برلين
# 18883    التغير_المناخي      1            unamed    التغير_المناخي
# 18884       omställning      1            unamed       omställning
# 18885      omstkonf2019      1            unamed      omstkonf2019
# 18886              ddop      1            unamed              ddop
#
# [18887 rows x 4 columns]

# %%
for i in set(new_df["Named"]):
    print(f"{i} = ", len(new_df[new_df["Named"]==i]))
# Out:
# Greta Thunberg =  57
# German politics =  198
# #FridayForFuture =  979
# FFF DE =  558
# Agreement =  49
# unamed =  16549
# DE Actions =  19
# Covid =  86
# Material =  130
# Action =  262

# %% [markdown]
# ###### Controllo dei tag all'interno del dataset

# %%
select_from_key("", sorted_degree, [])
# Out:
# []

# %%
select_from_key("klimat", sorted_degree, [])
# Out:
# ['klimatstrejk',
#  'klimat',
#  ' klimatram',
#  'klimatkris',
#  'klimatnödläge',
#  ' klimatnödläge',
#  ' skolstrejkförklimatet',
#  ' allaförklimatet',
#  'skolstrejkförklimatet',
#  ' klimatstrejk',
#  ' klimat',
#  ' klimatkris',
#  ' klimatstreik',
#  'klimatickakrize',
#  ' klimatnötläge',
#  'strajkklimatyczny',
#  'weltklimatag',
#  'klimatram',
#  ' klimatet',
#  'klimathandlingsplanen',
#  ' klimatnedbrytning',
#  ' klimatickakrize',
#  ' skostrejkförklimatet',
#  ' strajkklimatyczny',
#  ' mlodziezowystrajkklimatyczny',
#  'larrialdiklimatikoa',
#  ' strajkdlaklimatu',
#  ' młodzieżowystrajkklimatyczny',
#  ' weltklimatag',
#  'młodzieżowystrajkklimatyczny',
#  'klimatstreik',
#  'klimatagājiens',
#  'strajkdlaklimatu']

# %%
df['language'].value_counts()
# Out:
# de     15951
# en     13860
# it      1553
# es      1023
# qme      431
# sv       322
# ja       305
# fr       232
# und      168
# fi       163
# ca       131
# pt       100
# hi        83
# qht       76
# nl        67
# tr        65
# in        54
# da        21
# pl        20
# qam       20
# ru        20
# zh        18
# tl        14
# cs        14
# no        13
# ne        12
# et        11
# eu        10
# ro         9
# ta         8
# ar         8
# uk         8
# zxx        8
# cy         5
# sl         5
# el         4
# th         4
# lt         4
# bg         3
# ht         3
# bn         3
# sr         3
# ko         3
# fa         2
# lv         2
# te         2
# is         1
# iw         1
# art        1
# hu         1
# mr         1
# ur         1
# vi         1
# Name: language, dtype: int64

# %% [markdown]
# #### Codici bianchi

# %% [markdown]
# select_from_key("", sorted_degree, [])

# %% [markdown]
# replace_name("", "", ids, "")
