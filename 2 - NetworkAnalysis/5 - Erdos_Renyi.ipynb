# %%
import networkx as nx
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter
from operator import itemgetter
import powerlaw
from networkx.drawing.nx_agraph import graphviz_layout
import pickle
from statistics import mean, stdev
import seaborn as sns

# %%
from net_analysis import *

# %%
path = "../Dataset FFF/edges.csv"
path1 = "../Dataset FFF/edges_3K.csv"

# %%
path_graph = "../Dataset FFF/Graph_data/"

# %%
G = nx.read_edgelist(path, comments = "S", delimiter = ",", data=(("Count", int),))

# %%
print(nx.info(G))
# Out:
# Name:
# Type: Graph
# Number of nodes: 4147
# Number of edges: 63400
# Average degree:  30.5763

# %%
er_G = nx.erdos_renyi_graph(G.number_of_nodes(), p=0.001033 , directed = False, seed = 42)
print("Nodes:", er_G.number_of_nodes())
print("Edges:", er_G.number_of_edges())
# Out:
# Nodes: 4147
# Edges: 8684

# %%
nx.write_graphml(er_G, path_graph+"ER_Network.graphml")

# %% [markdown]
# # 1 - Degree Distribution1

# %%
degree_dist(er_G, "Erdos_Renyi", "ER")

# %%
plot_dist(er_G, "Erdos_Renyi", "ER")
# Out:
# Calculating best minimal value for power law fit
# **** Degree Distribution for Erdos_Renyi graph ****
# alpha=2.3221778579318095 sigma=0.08935606050709938

# %%
info_degree(er_G , "Erdos_Renyi")
# Out:
# ***** Degree info for Erdos_Renyi graph ***
# Maximum degree: (12, 3949)
# Minimum degree: (0, 188)

# %% [markdown]
# # 2 - Connected Components

# %%
components = n_connected_components(er_G , "Erdos_Renyi")
# Out:
# **** Connected components for Erdos_Renyi graph ****
# Number of Connected Components for Erdos_Renyi: 61
# 	 component len = 4084
# 	 component len = 1
# 	 component len = 2

# %% [markdown]
# # 3 - Path Analysis

# %%
path_analysis(er_G , "Erdos_Renyi", components)
# Out:
# ***** Path analysis for Erdos_Renyi graph
# Diameter for components 0 network Erdos_Renyi: 13
# Average shortest path for components 0 network Erdos_Renyi: 5.966634666612934

# %% [markdown]
# # 4 - Clustering Coefficient

# %%
name, values = c_coefficient_analysis(er_G , "Erdos_Renyi")
# Out:
# *** Clustering coefficient analyssi for Erdos_Renyi graph ***
# Min: 0
# Max: 0.3333333333333333
# Mean: 0.0004583539066297687
# Stdev: 0.00880530768875402

# %%
degree_clustering(er_G , "Erdos_Renyi", "ER")
# Out:
# **** Distribution degree/clustering for Erdos_Renyi graph ***

# %% [markdown]
# # 5 - Density Analysis

# %%
density_analysis(er_G , "Erdos_Renyi")
# Out:
# Density for Erdos_Renyi graph: 0.0010101514168583384
