# %%
import networkx as nx
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter
from operator import itemgetter
import powerlaw
from networkx.drawing.nx_agraph import graphviz_layout
import pickle
from statistics import mean, stdev
import seaborn as sns

# %%
from net_analysis import *

# %%
path = "../Dataset FFF/edges.csv"
path1 = "../Dataset FFF/edges_3K.csv"

# %%
path_graph = "../Dataset FFF/Graph_data/"

# %%
G = nx.read_edgelist(path, comments = "S", delimiter = ",", data=(("Count", int),))

# %%
print(nx.info(G))
# Out:
# Name:
# Type: Graph
# Number of nodes: 15169
# Number of edges: 300987
# Average degree:  39.6845

# %%
er_G = nx.erdos_renyi_graph(G.number_of_nodes(), p=0.001033 , directed = False, seed = 42)
print("Nodes:", er_G.number_of_nodes())
print("Edges:", er_G.number_of_edges())
# Out:
# Nodes: 15169
# Edges: 118677

# %%
nx.write_graphml(er_G, path_graph+"ER_Network.graphml")

# %% [markdown]
# # 1 - Degree Distribution1

# %%
degree_dist(er_G, "Erdos_Renyi", "ER")

# %%
plot_dist(er_G, "Erdos_Renyi", "ER")
# Out:
# Calculating best minimal value for power law fit
# **** Degree Distribution for Erdos_Renyi graph ****
# C:\Users\marco\Documents\sna-project-2022_cosmo_d-arrigo_esposito\2 - NetworkAnalysis\net_analysis.py:40: UserWarning: Attempted to set non-positive left xlim on a log-scaled axis.
# Invalid limit will be ignored.
#   plt.xlim((min(degree), max(degree)))
# alpha=94.8088191837405 sigma=53.58319673890388

# %%
info_degree(er_G , "Erdos_Renyi")
# Out:
# ***** Degree info for Erdos_Renyi graph ***
# Maximum degree: (35, 2025)
# Minimum degree: (3, 5398)

# %% [markdown]
# # 2 - Connected Components

# %%
components = n_connected_components(er_G , "Erdos_Renyi")
# Out:
# **** Connected components for Erdos_Renyi graph ****
# Number of Connected Components for Erdos_Renyi: 1
# 	 component len = 15169

# %% [markdown]
# # 3 - Path Analysis

# %%
path_analysis(er_G , "Erdos_Renyi", components)
# Out:
# ***** Path analysis for Erdos_Renyi graph
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-d5bb158867d1> in <module>
# ----> 1 path_analysis(er_G , "Erdos_Renyi", components)
#
# ~\Documents\sna-project-2022_cosmo_d-arrigo_esposito\2 - NetworkAnalysis\net_analysis.py in path_analysis(G, name, components)
#     119 def path_analysis(G, name, components):
#     120     print(f"***** Path analysis for {name} graph")
# --> 121     print(f"Diameter for components 0 network {name}: {nx.diameter(G.subgraph(components[0]))}")
#     122     print(f"Average shortest path for components 0 network {name}: {nx.average_shortest_path_length(G.subgraph(components[0]))}")
#     123
#
# ~\anaconda3\lib\site-packages\networkx\algorithms\distance_measures.py in diameter(G, e, usebounds)
#     297         return extrema_bounding(G, compute="diameter")
#     298     if e is None:
# --> 299         e = eccentricity(G)
#     300     return max(e.values())
#     301
#
# ~\anaconda3\lib\site-packages\networkx\algorithms\distance_measures.py in eccentricity(G, v, sp)
#     246     for n in G.nbunch_iter(v):
#     247         if sp is None:
# --> 248             length = nx.single_source_shortest_path_length(G, n)
#     249             L = len(length)
#     250         else:
#
# ~\anaconda3\lib\site-packages\networkx\algorithms\shortest_paths\unweighted.py in single_source_shortest_path_length(G, source, cutoff)
#      57         cutoff = float("inf")
#      58     nextlevel = {source: 1}
# ---> 59     return dict(_single_shortest_path_length(G.adj, nextlevel, cutoff))
#      60
#      61
#
# ~\anaconda3\lib\site-packages\networkx\algorithms\shortest_paths\unweighted.py in _single_shortest_path_length(adj, firstlevel, cutoff)
#      89             return
#      90         for v in found:
# ---> 91             nextlevel.update(adj[v])
#      92         level += 1
#      93     del seen
#
# ~\anaconda3\lib\site-packages\networkx\classes\coreviews.py in <genexpr>(.0)
#     277         if node_ok_shorter:
#     278             return (n for n in self.NODE_OK.nodes if n in self._atlas)
# --> 279         return (n for n in self._atlas if self.NODE_OK(n))
#     280
#     281     def __getitem__(self, key):
#
# ~\anaconda3\lib\site-packages\networkx\classes\coreviews.py in new_node_ok(nbr)
#     322
#     323             def new_node_ok(nbr):
# --> 324                 return self.NODE_OK(nbr) and self.EDGE_OK(node, nbr)
#     325
#     326             return FilterAtlas(self._atlas[node], new_node_ok)
#
# KeyboardInterrupt:

# %% [markdown]
# # 4 - Clustering Coefficient

# %%
name, values = c_coefficient_analysis(er_G , "Erdos_Renyi")

# %%
degree_clustering(er_G , "Erdos_Renyi", "ER")

# %% [markdown]
# # 5 - Density Analysis

# %%
density_analysis(er_G , "Erdos_Renyi")
