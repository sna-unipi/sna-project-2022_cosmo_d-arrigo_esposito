# %%
import networkx as nx
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter
from operator import itemgetter
import powerlaw
from networkx.drawing.nx_agraph import graphviz_layout
import pickle
from statistics import mean, stdev
import seaborn as sns

# %%
from net_analysis import *

# %%
path_edges = "../Dataset SuperUsers/edges.csv"
path_nodes = "../Dataset SuperUsers/nodes.csv"
path_all = "../Dataset SuperUsers/questions_2020_2022.csv"
edges = "../Dataset SuperUsers/edges_10K.csv"

# %%
G = nx.read_edgelist(edges, comments = "S", delimiter = ",", data=(("Count", int),))

# %%
G.number_of_nodes()
# Out:
# 4147

# %%
print(nx.info(G))
# Out:
# Name:
# Type: Graph
# Number of nodes: 4147
# Number of edges: 63400
# Average degree:  30.5763

# %%
df_all
# Out:
#                                                     Tags  \
# 0            macos|-|python|-|zsh|-|compression|-|tar|-|
# 1                                               crash|-|
# 2            windows-10|-|memory|-|docker|-|resources|-|
# 3                                 windows|-|uninstall|-|
# 4                                         motherboard|-|
# ...                                                  ...
# 49995  linux|-|windows|-|windows-subsystem-for-linux|...
# 49996                                 microsoft-excel|-|
# 49997     microsoft-excel|-|worksheet-function|-|time|-|
# 49998  linux|-|ubuntu|-|mount|-|windows-subsystem-for...
# 49999         microsoft-excel|-|spreadsheet|-|vlookup|-|
#
#                     User_Name  \
# 0      Saaru Lindest&#248;kke
# 1                  Stuntddude
# 2                 CiaranWelsh
# 3                  Anne Maier
# 4                     MechMK1
# ...                       ...
# 49995                    Sean
# ...

# %%
df_nodes
# Out:
#                        Id
# 0                 corsair
# 1             playstation
# 2         total-commander
# 3         process-monitor
# 4             gtk-windows
# ...                   ...
# 4142          android-x86
# 4143   desktop-management
# 4144  microsoft-word-2016
# 4145               handle
# 4146     wireless-headset
#
# [4147 rows x 1 columns]

# %%
df_edges
# Out:
#                      Source                Target  Count
# 0                     macos                python     14
# 1                     macos                   zsh     57
# 2                     macos           compression      3
# 3                     macos                   tar      3
# 4                     macos                 crash      3
# ...                     ...                   ...    ...
# 63395          blob-storage                azcopy      1
# 63396             raspberry                   apm      1
# 63397          input-method  chinese-input-method      1
# 63398          input-method             ime-quick      1
# 63399  chinese-input-method             ime-quick      1
#
# [63400 rows x 3 columns]

# %%
df_edges.value_counts()
# Out:
# Source     Target               Count
# .net-core  api                  1        1
# router     cisco-packet-tracer  1        1
#            clone                1        1
#            cluster              1        1
#            coaxial              2        1
#                                         ..
# html       script               2        1
#            search-engines       1        1
#            sendmail             1        1
#            sftp                 1        1
# zsh        xquartz              1        1
# Length: 63400, dtype: int64

# %%
df_edges['Source'].unique()
# Out:
# array(['macos', 'python', 'zsh', ..., 'raspberry', 'input-method',
#        'chinese-input-method'], dtype=object)
