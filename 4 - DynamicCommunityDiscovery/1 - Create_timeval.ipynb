# %%
import pandas as pd
import time as _time
import datetime
import numpy as np

# %%
path = "../Dataset FFF/fff.csv"

# %%
df = pd.read_csv(path)
df.columns
# Out:
# Index(['clean_tags', 'hashtags', 'date', 'user_id', 'username', 'name',
#        'tweet', 'language', 'mentions', 'replies_count', 'retweets_count',
#        'likes_count', 'link', 'retweet', 'reply_to'],
#       dtype='object')

# %%
df = df.sort_values(by=['date'])

# %%
df
# Out:
#                                               clean_tags  \
# 23503  klimastreik, fridaysforfuture, allefuersklima,...
# 23161  climatestrike, youthclimatestrike, fridaysforf...
# 23162   climatestrikedc, climatestrike, fridaysforfuture
# 23163  fridaysforfuture, 20septiembre, climatecrisis,...
# 23164           uganda, fridaysforfuture, climatestrikes
# ...                                                  ...
# 4                  klimakrise, govegan, fridaysforfuture
# 3                                        fridayforfuture
# 2                                       fridaysforfuture
# 1                                       fridaysforfuture
# 0      fossilfuels, wind, solar, green, hydrogen, ene...
#
#                                                 hashtags        date  \
# 23503  ['klimastreik', 'fridaysforfuture', 'allefuers...  2019-09-20
# 23161  ['climatestrike', 'youthclimatestrike', 'frida...  2019-09-20
# 23162  ['climatestrikedc', 'climatestrike', 'fridaysf...  2019-09-20
# 23163  ['fridaysforfuture', '20septiembre', 'climatec...  2019-09-20
# 23164   ['uganda', 'fridaysforfuture', 'climatestrikes']  2019-09-20
# ...                                                  ...         ...
# 4          ['klimakrise', 'govegan', 'fridaysforfuture']  2022-07-10
# 3                                    ['fridayforfuture']  2022-07-10
# 2                                   ['fridaysforfuture']  2022-07-10
# 1                                   ['fridaysforfuture']  2022-07-10
# 0      ['fossilfuels', 'wind', 'solar', 'green', 'hyd...  2022-07-10
#
#                    user_id         username  \
# 23503             19811643              lvz
# 23161            457653720      jakewoodier
# 23162             16583846              rei
# 23163             14586333     greenpeacecl
# 23164            561608197  earthquakestime
# ...                    ...              ...
# 4      1529883123881857031      vegancardio
# 3                403735368          hahnflo
# 2                126978307         kl_stone
# 1      1096766566279073792   parents4future
# 0                 59386332         arikring
#
#                                         name  \
# 23503                                    LVZ
# 23161                           Jake Woodier
# 23162                                    REI
# 23163                       Greenpeace Chile
# 23164                        EarthQuakesTime
# ...                                      ...
# 4                      Der vegane Kardiologe
# 3                               Florian Hahn
# 2                          Klaus Steinfelder
# 1         Parents For Future #EndFossilFuels
# 0      Arik Ring - Energy Engineering Expert
#
#                                                    tweet language  \
# 23503  Verkehrschaos in der City: Auf dem Ring ist de...       de
# 23161  Wow, provisional estimate in for the UK #Clima...       en
# 23162  These are the powerful voices at #ClimateStrik...       en
# 23163  Marchamos por el futuro del planeta ! ✊🏽#Frida...       es
# 23164  🌍 #Uganda 🇺🇬 Presente en la manifestación mund...       es
# ...                                                  ...      ...
# 4      Was sind das eigentlich für Menschen, die sich...       de
# 3      Wer erklärt #FridayForFuture, dass es ohne NAT...       de
# 2      SERVICETWEET:  Zur aktuellen Hetze der BLÖD-Ze...       de
# 1      Eltern wissen, wer hier dumm ist. #FridaysForF...       de
# 0      @ProfStrachan @ECOWARRIORSS @ChristineMilne @m...       en
#
#                                                 mentions  replies_count  \
# 23503                                                 []              2
# 23161  [{'screen_name': 'strike4youth', 'name': 'yout...             15
# 23162                                                 []             36
# 23163  [{'screen_name': 'fffsantiago', 'name': 'frida...              2
# 23164  [{'screen_name': 'zaynrahm', 'name': 'zayn rah...              2
# ...                                                  ...            ...
# 4                                                     []             79
# 3                                                     []            127
# 2                                                     []              2
# 1                                                     []             21
# 0      [{'screen_name': 'guytaur', 'name': 'scott. tr...              2
#
#        retweets_count  likes_count  \
# 23503               5           17
# 23161             287         1341
# 23162              34          182
# 23163              49          130
# 23164              12           27
# ...               ...          ...
# 4                  25          348
# 3                  65          679
# 2                   5            8
# 1                  54          595
# 0                  54           59
#
#                                                     link  retweet  \
# 23503  https://twitter.com/LVZ/status/117507069339176...    False
# 23161  https://twitter.com/JakeWoodier/status/1175125...    False
# 23162  https://twitter.com/REI/status/117512536431976...    False
# 23163  https://twitter.com/GreenpeaceCL/status/117512...    False
# 23164  https://twitter.com/EarthQuakesTime/status/117...    False
# ...                                                  ...      ...
# 4      https://twitter.com/VeganCardio/status/1546127...    False
# 3      https://twitter.com/hahnflo/status/15461339384...    False
# 2      https://twitter.com/Kl_Stone/status/1546221657...    False
# 1      https://twitter.com/parents4future/status/1546...    False
# 0      https://twitter.com/arikring/status/1546251358...    False
#
#                                                 reply_to
# 23503                                                 []
# 23161                                                 []
# 23162                                                 []
# 23163                                                 []
# 23164                                                 []
# ...                                                  ...
# 4                                                     []
# 3                                                     []
# 2                                                     []
# 1                                                     []
# 0      [{'screen_name': 'ProfStrachan', 'name': 'Prof...
#
# [23504 rows x 15 columns]

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df['Year'] = df['date'].dt.year 
df['Month'] = df['date'].dt.month 
df['Day'] = df['date'].dt.day

# %%
df
# Out:
#                                               clean_tags  \
# 23503  klimastreik, fridaysforfuture, allefuersklima,...
# 23161  climatestrike, youthclimatestrike, fridaysforf...
# 23162   climatestrikedc, climatestrike, fridaysforfuture
# 23163  fridaysforfuture, 20septiembre, climatecrisis,...
# 23164           uganda, fridaysforfuture, climatestrikes
# ...                                                  ...
# 4                  klimakrise, govegan, fridaysforfuture
# 3                                        fridayforfuture
# 2                                       fridaysforfuture
# 1                                       fridaysforfuture
# 0      fossilfuels, wind, solar, green, hydrogen, ene...
#
#                                                 hashtags       date  \
# 23503  ['klimastreik', 'fridaysforfuture', 'allefuers... 2019-09-20
# 23161  ['climatestrike', 'youthclimatestrike', 'frida... 2019-09-20
# 23162  ['climatestrikedc', 'climatestrike', 'fridaysf... 2019-09-20
# 23163  ['fridaysforfuture', '20septiembre', 'climatec... 2019-09-20
# 23164   ['uganda', 'fridaysforfuture', 'climatestrikes'] 2019-09-20
# ...                                                  ...        ...
# 4          ['klimakrise', 'govegan', 'fridaysforfuture'] 2022-07-10
# 3                                    ['fridayforfuture'] 2022-07-10
# 2                                   ['fridaysforfuture'] 2022-07-10
# 1                                   ['fridaysforfuture'] 2022-07-10
# 0      ['fossilfuels', 'wind', 'solar', 'green', 'hyd... 2022-07-10
#
#                    user_id         username  \
# 23503             19811643              lvz
# 23161            457653720      jakewoodier
# 23162             16583846              rei
# 23163             14586333     greenpeacecl
# 23164            561608197  earthquakestime
# ...                    ...              ...
# 4      1529883123881857031      vegancardio
# 3                403735368          hahnflo
# 2                126978307         kl_stone
# 1      1096766566279073792   parents4future
# 0                 59386332         arikring
#
#                                         name  \
# 23503                                    LVZ
# 23161                           Jake Woodier
# 23162                                    REI
# 23163                       Greenpeace Chile
# 23164                        EarthQuakesTime
# ...                                      ...
# 4                      Der vegane Kardiologe
# 3                               Florian Hahn
# 2                          Klaus Steinfelder
# 1         Parents For Future #EndFossilFuels
# 0      Arik Ring - Energy Engineering Expert
#
#                                                    tweet language  \
# 23503  Verkehrschaos in der City: Auf dem Ring ist de...       de
# 23161  Wow, provisional estimate in for the UK #Clima...       en
# 23162  These are the powerful voices at #ClimateStrik...       en
# 23163  Marchamos por el futuro del planeta ! ✊🏽#Frida...       es
# 23164  🌍 #Uganda 🇺🇬 Presente en la manifestación mund...       es
# ...                                                  ...      ...
# 4      Was sind das eigentlich für Menschen, die sich...       de
# 3      Wer erklärt #FridayForFuture, dass es ohne NAT...       de
# 2      SERVICETWEET:  Zur aktuellen Hetze der BLÖD-Ze...       de
# 1      Eltern wissen, wer hier dumm ist. #FridaysForF...       de
# 0      @ProfStrachan @ECOWARRIORSS @ChristineMilne @m...       en
#
#                                                 mentions  replies_count  \
# 23503                                                 []              2
# 23161  [{'screen_name': 'strike4youth', 'name': 'yout...             15
# 23162                                                 []             36
# 23163  [{'screen_name': 'fffsantiago', 'name': 'frida...              2
# 23164  [{'screen_name': 'zaynrahm', 'name': 'zayn rah...              2
# ...                                                  ...            ...
# 4                                                     []             79
# 3                                                     []            127
# 2                                                     []              2
# 1                                                     []             21
# 0      [{'screen_name': 'guytaur', 'name': 'scott. tr...              2
#
#        retweets_count  likes_count  \
# 23503               5           17
# 23161             287         1341
# 23162              34          182
# 23163              49          130
# 23164              12           27
# ...               ...          ...
# 4                  25          348
# 3                  65          679
# 2                   5            8
# 1                  54          595
# 0                  54           59
#
#                                                     link  retweet  \
# 23503  https://twitter.com/LVZ/status/117507069339176...    False
# 23161  https://twitter.com/JakeWoodier/status/1175125...    False
# 23162  https://twitter.com/REI/status/117512536431976...    False
# 23163  https://twitter.com/GreenpeaceCL/status/117512...    False
# 23164  https://twitter.com/EarthQuakesTime/status/117...    False
# ...                                                  ...      ...
# 4      https://twitter.com/VeganCardio/status/1546127...    False
# 3      https://twitter.com/hahnflo/status/15461339384...    False
# 2      https://twitter.com/Kl_Stone/status/1546221657...    False
# 1      https://twitter.com/parents4future/status/1546...    False
# 0      https://twitter.com/arikring/status/1546251358...    False
#
#                                                 reply_to  Year  Month  Day
# 23503                                                 []  2019      9   20
# 23161                                                 []  2019      9   20
# 23162                                                 []  2019      9   20
# 23163                                                 []  2019      9   20
# 23164                                                 []  2019      9   20
# ...                                                  ...   ...    ...  ...
# 4                                                     []  2022      7   10
# 3                                                     []  2022      7   10
# 2                                                     []  2022      7   10
# 1                                                     []  2022      7   10
# 0      [{'screen_name': 'ProfStrachan', 'name': 'Prof...  2022      7   10
#
# [23504 rows x 18 columns]

# %%
df.insert(3, 'Year', df.pop('Year'))

# %%
df.insert(4, 'Month', df.pop('Month'))

# %%
df.insert(5, 'Day', df.pop('Day'))

# %%
df
# Out:
#                                               clean_tags  \
# 23503  klimastreik, fridaysforfuture, allefuersklima,...
# 23161  climatestrike, youthclimatestrike, fridaysforf...
# 23162   climatestrikedc, climatestrike, fridaysforfuture
# 23163  fridaysforfuture, 20septiembre, climatecrisis,...
# 23164           uganda, fridaysforfuture, climatestrikes
# ...                                                  ...
# 4                  klimakrise, govegan, fridaysforfuture
# 3                                        fridayforfuture
# 2                                       fridaysforfuture
# 1                                       fridaysforfuture
# 0      fossilfuels, wind, solar, green, hydrogen, ene...
#
#                                                 hashtags       date  Year  \
# 23503  ['klimastreik', 'fridaysforfuture', 'allefuers... 2019-09-20  2019
# 23161  ['climatestrike', 'youthclimatestrike', 'frida... 2019-09-20  2019
# 23162  ['climatestrikedc', 'climatestrike', 'fridaysf... 2019-09-20  2019
# 23163  ['fridaysforfuture', '20septiembre', 'climatec... 2019-09-20  2019
# 23164   ['uganda', 'fridaysforfuture', 'climatestrikes'] 2019-09-20  2019
# ...                                                  ...        ...   ...
# 4          ['klimakrise', 'govegan', 'fridaysforfuture'] 2022-07-10  2022
# 3                                    ['fridayforfuture'] 2022-07-10  2022
# 2                                   ['fridaysforfuture'] 2022-07-10  2022
# 1                                   ['fridaysforfuture'] 2022-07-10  2022
# 0      ['fossilfuels', 'wind', 'solar', 'green', 'hyd... 2022-07-10  2022
#
#        Month  Day              user_id         username  \
# 23503      9   20             19811643              lvz
# 23161      9   20            457653720      jakewoodier
# 23162      9   20             16583846              rei
# 23163      9   20             14586333     greenpeacecl
# 23164      9   20            561608197  earthquakestime
# ...      ...  ...                  ...              ...
# 4          7   10  1529883123881857031      vegancardio
# 3          7   10            403735368          hahnflo
# 2          7   10            126978307         kl_stone
# 1          7   10  1096766566279073792   parents4future
# 0          7   10             59386332         arikring
#
#                                         name  \
# 23503                                    LVZ
# 23161                           Jake Woodier
# 23162                                    REI
# 23163                       Greenpeace Chile
# 23164                        EarthQuakesTime
# ...                                      ...
# 4                      Der vegane Kardiologe
# 3                               Florian Hahn
# 2                          Klaus Steinfelder
# 1         Parents For Future #EndFossilFuels
# 0      Arik Ring - Energy Engineering Expert
#
#                                                    tweet language  \
# 23503  Verkehrschaos in der City: Auf dem Ring ist de...       de
# 23161  Wow, provisional estimate in for the UK #Clima...       en
# 23162  These are the powerful voices at #ClimateStrik...       en
# 23163  Marchamos por el futuro del planeta ! ✊🏽#Frida...       es
# 23164  🌍 #Uganda 🇺🇬 Presente en la manifestación mund...       es
# ...                                                  ...      ...
# 4      Was sind das eigentlich für Menschen, die sich...       de
# 3      Wer erklärt #FridayForFuture, dass es ohne NAT...       de
# 2      SERVICETWEET:  Zur aktuellen Hetze der BLÖD-Ze...       de
# 1      Eltern wissen, wer hier dumm ist. #FridaysForF...       de
# 0      @ProfStrachan @ECOWARRIORSS @ChristineMilne @m...       en
#
#                                                 mentions  replies_count  \
# 23503                                                 []              2
# 23161  [{'screen_name': 'strike4youth', 'name': 'yout...             15
# 23162                                                 []             36
# 23163  [{'screen_name': 'fffsantiago', 'name': 'frida...              2
# 23164  [{'screen_name': 'zaynrahm', 'name': 'zayn rah...              2
# ...                                                  ...            ...
# 4                                                     []             79
# 3                                                     []            127
# 2                                                     []              2
# 1                                                     []             21
# 0      [{'screen_name': 'guytaur', 'name': 'scott. tr...              2
#
#        retweets_count  likes_count  \
# 23503               5           17
# 23161             287         1341
# 23162              34          182
# 23163              49          130
# 23164              12           27
# ...               ...          ...
# 4                  25          348
# 3                  65          679
# 2                   5            8
# 1                  54          595
# 0                  54           59
#
#                                                     link  retweet  \
# 23503  https://twitter.com/LVZ/status/117507069339176...    False
# 23161  https://twitter.com/JakeWoodier/status/1175125...    False
# 23162  https://twitter.com/REI/status/117512536431976...    False
# 23163  https://twitter.com/GreenpeaceCL/status/117512...    False
# 23164  https://twitter.com/EarthQuakesTime/status/117...    False
# ...                                                  ...      ...
# 4      https://twitter.com/VeganCardio/status/1546127...    False
# 3      https://twitter.com/hahnflo/status/15461339384...    False
# 2      https://twitter.com/Kl_Stone/status/1546221657...    False
# 1      https://twitter.com/parents4future/status/1546...    False
# 0      https://twitter.com/arikring/status/1546251358...    False
#
#                                                 reply_to
# 23503                                                 []
# 23161                                                 []
# 23162                                                 []
# 23163                                                 []
# 23164                                                 []
# ...                                                  ...
# 4                                                     []
# 3                                                     []
# 2                                                     []
# 1                                                     []
# 0      [{'screen_name': 'ProfStrachan', 'name': 'Prof...
#
# [23504 rows x 18 columns]

# %%
from datetime import tzinfo, timedelta, datetime, time

# %%
len(df['date'])
# Out:
# 23504

# %%
for i in df.values:
    tagsss = i[0].split(",")
    for t in range(len(tagsss)):
        tags.append(tagsss[t])
        for d in df.values:
            time = i[2]
            for d in range(len(str(time))):
                time_tags.append(time[d])
                for j in tagsss[t+1:]:
                    couple_tags.append((tagsss[t], j))  
                    time_couple.append(time[d])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-7b78ddb3039f> in <module>
#       6             time = i[2]
#       7             for d in range(len(str(time))):
# ----> 8                 time_tags.append(time[d])
#       9                 for j in tagsss[t+1:]:
#      10                     couple_tags.append((tagsss[t], j))
#
# TypeError: 'Timestamp' object is not subscriptable

# %%
tags
# Out:
# []

# %%
date.fromisoformat

# %%
tags = []
time_tags = []

# %%
couple_tags = []
time_couple = []

# %%
for i in df.values:
    tagsss = i[0].split(",")
    for t in range(len(tagsss)):
        tags.append(tagsss[t])
        data = i[2]
        for d in range(len(str(data))):
            time_tags.append(i[2])
            for j in tagsss[t+1:]:
                couple_tags.append((tagsss[t], j))  
                for f in data[d+1:]:
                    time_couple.append((data[d], f))

# %%
for i in df.values:
    tagsss = i[0].split(",")
    for t in range(len(tagsss)):
        tags.append(tagsss[t])

# %%
data = []

# %%
for i in df.values:
    data = i[2]
    for d in range(len(str((data))):
        data.append(data[d])
# Out:
#   File "<ipython-input-92-fbbd271adc86>", line 3
#     for d in range(len(str((data))):
#                                    ^
# SyntaxError: invalid syntax

# %%
tags
# Out:
# ['klimastreik',
#  'klimastreik',
#  'klimastreik',
#  ' fridaysforfuture',
#  ' allefuersklima',
#  ' allefürsklima',
#  ' le2009',
#  'climatestrike',
#  ' youthclimatestrike',
#  ' fridaysforfuture',
#  'climatestrikedc',
#  ' climatestrike',
#  ' fridaysforfuture',
#  'fridaysforfuture',
#  ' 20septiembre',
#  ' climatecrisis',
#  ' crisisclimatica',
#  ' viernesporelfuturo',
#  'uganda',
#  ' fridaysforfuture',
#  ' climatestrikes',
#  'climatestrike',
#  ' fridayforfuture',
#  'halifax',
#  ' fridaysforfuture',
#  ' climateaction',
#  'climatestrike',
#  ' fridaysforfuture',
#  'svpol',
#  ' fridaysforfuture',
#  'fridaysforfuture',
#  ' climatestrike',
#  ' climatestrikenyc',
#  'climatestrike',
#  ' fridaysforfuture',
#  ' allefuersklima',
#  ' globalclimatestrike',
#  ' klimakabinett',
#  ' klimapakt',
#  'fridaysforfuture',
#  'climatestrike',
#  ' fridaysforfuture',
#  'fridaysforfuture',
#  'fridaysforfuture',
#  'fridaysforfuture',
#  ' allefuersklima',
#  'faz',
#  ' fridaysforfuture',
#  ' cdu',
#  ' csu',
#  ' spd',
#  ' fdp',
#  ' linke',
#  ' grüne',
#  ' afd',
#  '20settembre',
#  ' fridaysforfuture',
#  ' climatestrike',
#  'fridaysforfuture',
#  ' climatestrike',
#  'fridaysforfuture',
#  ' bayreuth',
#  'fridaysforfuture',
#  ' newgreendeal',
#  ' climatestrike',
#  'climatestrike',
#  ' globalclimatestrike',
#  ' globalclimatestrikeindia',
#  ' globalclimatestrikesindia',
#  ' fridaysforfuture',
#  ' schoolstrike4climate',
#  ' youthclimatestrike',
#  'climatestrike',
#  ' climatechange',
#  ' climateaction',
#  ' fridaysforfuture',
#  'fridaysforfuture',
#  ' groko',
#  ' klimapaket',
#  'climatestrike',
#  ' fridaysforfuture',
#  'climatestrike',
#  ' fridaysforfuture',
#  'cdu',
#  ' spd',
#  ' fridaysforfuture',
#  'klimastreik',
#  ' globalstrike',
#  ' fridaysforfuture',
#  'fridaysforfuture',
#  ' klimastreik',
#  ' globalstrike',
#  ' fridaysforfuture',
#  ' b2009',
#  ' climatestrike',
#  'climatecrisis',
#  ' climatestrike',
#  ' climatechange',
#  ' fridayforfuture',
#  'lorax',
#  ' kinderbuchliebe',
#  ' drseuss',
#  ' klimakrise',
#  ' allefuersklima',
#  ' fridaysforfuture',
#  ' weltklimastreik',
#  'वत्स',
#  ' fridaysforfuture',
#  'allefuersklima',
#  ' fridaysforfuture',
#  'fridaysforfuture',
#  ' climateaction',
#  ' العمل_لأجل_المناخ',
#  'climatestrike',
#  ' fridaysforfuture',
#  'climatestrike',
#  ' fridaysforfuture',
#  ' dubmayor350',
#  ' beclimatebrave',
#  'strikeforclimate',
#  ' fridaysforfuture',
#  ' ambassadorofconscience',
#  'bancomer',
#  ' felizfindesemana',
#  ' felizviernesatodos',
#  ' iphone11',
#  ' area51storm',
#  ' fridaysforfuture',
#  ' vocalkingchenday',
#  'fridaysforfuture',
#  ' ilmastonmuutos',
#  'bundesregierung',
#  ' allefuersklima',
#  ' fridaysforfuture',
#  ' extinctionrebellion',
#  ' scientists4future',
#  'berlín',
#  ' cambioclimático',
#  ' protestas',
#  ' alemania',
#  ' climatestrike',
#  ' dwnoticias',
#  'fridaysforfuture',
#  'fridaysforfuture',
#  ' climatestrike',
#  'fridaysforfuture',
#  ' klimakabinett',
#  'bernie2020',
#  ' berniesanders2020',
#  ' climatestrike',
#  ' climateaction',
#  ' fridaymorning',
#  ' fridaymorning',
#  ' fridaysforfuture',
#  's04',
#  ' klimastreik',
#  ' globalclimatestrike',
#  ' fridaysforfuture',
#  ' allefuersklima',
#  ' s04',
#  ' s04m05',
#  'fridaysforfuture',
#  ' bernie2020',
#  ' tulsi2020',
#  ' greennewdeal',
#  ' offact',
#  'klimaschutzpaket',
#  ' klimapaket',
#  ' klimakabinett',
#  ' fridaysforfuture',
#  'polizei',
#  ' wendt',
#  ' fridaysforfuture',
#  'fridaysforfuture',
#  ' climatestrike',
#  'fridaysforfuture',
#  ' cdmx',
#  ' cambioclimatico',
#  ' méxico',
#  ' gretathunberg',
#  'climatestrike',
#  ' fridaysforfuture',
#  ' inspiration',
#  ' youth',
#  ' earth',
#  ' savetheworld',
#  ' peace',
#  ' climatecrisis',
#  'fridaysforfuture',
#  'fridaysforfuture',
#  ' climatestrike',
#  'fridaysforfuture',
#  ' climatestrike',
#  'klimastreiks',
#  ' fridaysforfuture',
#  'burundi',
#  ' keepmamaafricagreen',
#  ' fridaysforfuture',
#  ' climatestrike',
#  'allefürsklima',
#  ' fridaysforfuture',
#  'climatestrike',
#  ' fridaysforfuture',
#  'fridaysforfuture',
#  ' climatestrike',
#  'climatestrike',
#  ' fridaysforfuture',
#  'fridaysforfuture',
#  'fridaysforfuture',
#  ' climatestrike',
#  'hoy',
#  ' fridaysforfuture',
#  'fridaysforfuture',
#  ' climatestrike',
#  'fridaysforfuture',
#  ' klimaschutzpaket',
#  'globalclimatestrike',
#  ' fridaysforfuture',
#  ' portlandclimatestrike',
#  'climatestrike',
#  ' fridaysforfuture',
#  'fridaysforfuture',
#  'fridaysforfuture',
#  'klimastreik',
#  ' berlin',
#  ' fridaysforfuture',
#  ' allefuersklima',
#  ' klimapaket',
#  ' klimawahn',
#  ' diewelle',
#  'greveglobalpeloclima',
#  ' aquecimentoglobal',
#  ' criseclimática',
#  ' climatestrike',
#  ' fridaysforfuture',
#  ' senadordetodosnós',
#  'fridaysforfuture',
#  'kabul',
#  ' climatestrike',
#  ' fridaysforfuture',
#  'leipzig',
#  ' fridaysforfuture',
#  ' allefuersklima',
#  ' notmyklimapaket',
#  ' klimapaket',
#  'guns',
#  ' climatechange',
#  ' climatestrike',
#  ' fridaysforfuture',
#  'nichtmeinklimapaket',
#  ' fridaysforfuture',
#  ' climatestrike',
#  'climatestrike',
#  ' fridaysforfuture',
#  'fridaysforfuture',
#  ' svpol',
#  'climatestrike',
#  ' fridaysforfuture',
#  'climatestrike',
#  ' fridaysforfuture',
#  'ff',
#  'climatestrike',
#  ' fridaysforfuture',
#  'wirtschaft',
#  ' klimaschutz',
#  ' berlin',
#  ' fridaysforfuture',
#  'fridaysforfuture',
#  ' klimastreik',
#  'fridaysforfuture',
#  'klimapaket',
#  ' niemehrspd',
#  ' fridaysforfuture',
#  ' allefuersklima',
#  'schoolstrikes4climate',
#  ' climatestrikelondon',
#  ' climatestrike',
#  ' fridaysforfuture',
#  ' climatechange',
#  ' globalwarming',
#  ' millbank',
#  ' parliament',
#  'fridayforfuture',
#  'climatestrike',
#  ' fridaysforfuture',
#  ' faithsforfuture',
#  'climatestrike',
#  ' fridaysforfuture',
#  ' santiago',
#  ' chile',
#  'climateaction',
#  ' fridaysforfuture',
#  ' climatestrike',
#  'fridaysforfuture',
#  ' climatestrike',
#  ' tippingpoint',
#  ' unstoppable',
#  'fridaysforfuture',
#  ' climatestrike',
#  'youporn',
#  ' fridaysforfuture',
#  ' climatestrike',
#  'climatestrike',
#  ' actonclimate',
#  ' fridaysforfuture',
#  ' yourparksyourturn',
#  'fridaysforfuture',
#  ' parentsforfuture',
#  ' allefuersklima',
#  'fridaysforfuture',
#  'klimastreik',
#  ' fridayforfuture',
#  ' globalclimatestrike',
#  ' sketchnotes',
#  'allefürsklima',
#  ' klimakabinett',
#  'climatestrike',
#  ' environmentaljustice',
#  ' fridaysforfuture',
#  ' equity',
#  'climatestrike',
#  ' fridaysforfuture',
#  'mlpd',
#  ' fridaysforfuture',
#  ' fff',
#  'fridaysforfuture',
#  ' klimatstrejk',
#  'climatestrike',
#  ' climateaction',
#  ' fridaysforfuture',
#  'klimastreik',
#  ' besetzen',
#  ' tumalwat',
#  ' mietenwahnsinn',
#  ' stadtvonunten',
#  ' fridaysforfuture',
#  ' besetzen4future',
#  ' climatestrike',
#  ' diesela',
#  'climatestrike',
#  ' fridaysforfuture',
#  'gretathunberg',
#  ' fridayforfuture',
#  ' newyork',
#  'globalclimatestrike',
#  ' youthstrike4climate',
#  ' youthforclimate',
#  ' fridaysforfuture',
#  ' liverpool',
#  'fridaysforfuture',
#  ' multikulti',
#  'climatestrike',
#  ' fridaysforfuture',
#  'jeunesse',
#  ' strikeforclimatechange',
#  ' fridaysforfuture',
#  'fridaysforfuture',
#  ' klimapaket',
#  'sanfrancisco',
#  ' climatestrike',
#  ' fridaysforfuture',
#  ' globalclimatestrike',
#  'fridaysforfuture',
#  'amazon',
#  ' seattle',
#  ' climatechange',
#  ' climatestrike',
#  ' fridaysforfuture',
#  ' networkofnow',
#  'fridaysforfuture',
#  'climatestrike',
#  ' fridaysforfuture',
#  'climatestrike',
#  ' fridaysforfuture',
#  'cambioclimatico',
#  ' fridaysforfuture',
#  'climatestrike',
#  ' climatestrikeindia',
#  ' fridaysforfuture',
#  'forourfuturegenerations',
#  ' fridaysforfuture',
#  ' yyj',
#  ' climatestrike',
#  'fridaysforfuture',
#  ' climatestrike',
#  'climatestrikeseattle',
#  ' climatestrike',
#  ' fridaysforfuture',
#  'climatestrikes',
#  ' schoolstrike4climate',
#  ' fridaysforfuture',
#  'climatejustice',
#  ' climatestrike',
#  ' fridaysforfuture',
#  ' climateaction',
#  'fridaysforfuture',
#  ' strikeforclimate',
#  ' greennewdeal',
#  ' trumpresign',
#  'fridaysforfuture',
#  'globalclimatestrike',
#  ' youthclimatestrike',
#  ' climateaction',
#  ' fridaysforfuture',
#  ' cdnpoli',
#  ' greenaf',
#  'fridaysforfuture',
#  ' globalclimatestrike',
#  ' globalclimatestrikes',
#  'fridaysforfuture',
#  'fridaysforfuture',
#  ' klimakabinett',
#  ' groko',
#  ' notmyklimapaket',
#  ' allefürsklima',
#  'fridaysforfuture',
#  ' fff',
#  ' marxismus',
#  'climatestrikenyc',
#  ' fridaysforfuture',
#  ' globalclimatestrike',
#  ' climatejustice',
#  'globalclimatestrike',
#  ' climatechange',
#  ' nyc',
#  ' cdmx',
#  ' climatestrike',
#  ' fridaysforfuture',
#  'klimapaket',
#  ' pendlerpauschale',
#  ' fridaysforfuture',
#  ' allefürsklima',
#  'climatestrike',
#  ' fridaysforfuture',
#  'climatestrike',
#  ' fridaysforfuture',
#  ' video',
#  'fridaysforfuture',
#  'climatestrike',
#  ' fridaysforfuture',
#  ' climateactionnow',
#  'climatestrike',
#  ' fridaysforfuture',
#  ' berladangbukankejahatan',
#  ' area51storm',
#  'fridaysforfuture',
#  'fridaysforfuture',
#  'klimastreik',
#  ' fridaysforfuture',
#  ' allefuersklima',
#  'amazon',
#  ' fridaysforfuture',
#  ' sosbolivia',
#  ' actfortheamazon',
#  'fridaysforfuture',
#  'katowice',
#  ' mlodziezowystrajkklimatyczny',
#  ' fridaysforfuture',
#  ' climatestrike',
#  'globalclimatestrike',
#  ' climatestrike',
#  ' fridaysforfuture',
#  ' climateemergency',
#  ' fffdelhi',
#  'climatestrike',
#  ' fridaysforfuture',
#  ' climatejusticenow',
#  'klimastreik',
#  ' f4f',
#  ' fridaysforfuture',
#  ' allefuersklima',
#  'fridaysforfuture',
#  'zdf',
#  ' fridaysforfuture',
#  'fridaysforfuture',
#  ' climatestrike',
#  'fridaysforfuture',
#  'huelgaclimáticaglobal',
#  ' fridaysforfuture',
#  'cdmx',
#  ' fridaysforfuture',
#  'area51storm',
#  ' stormingarea51',
#  ' 6ix9ine',
#  ' fridaysforfuture',
#  'fridaysforfuture',
#  ' wachstumszwang',
#  ' wachstumswahn',
#  ' klimapaket',
#  ' fridaysforfuture',
#  ' klimastreik',
#  'fridaysforfuture',
#  ' klimastreik',
#  ' allefuersklima',
#  'climatestrike',
#  ' fridaysforfuture',
#  'fridaysforfuture',
#  'fridaysforfuture',
#  ' climatestrike',
#  'fridaysforfuture',
#  'fridaysforfuture',
#  ' climatestrike',
#  'fridaysforfuture',
#  ' qroorgullodemx',
#  'klimastreik',
#  ' münchen',
#  ' climatestrike',
#  ' werbietetmehr',
#  'fridaysforfuture',
#  ' globalclimatestrike',
#  'climatestrike',
#  ' amznclimate',
#  ' fridaysforfuture',
#  'climatestrikedc',
#  ' climatestrike',
#  ' fridaysforfuture',
#  'fridaysforfuture',
#  'climateaction',
#  ' climatestrikes',
#  ' climateactionnow',
#  ' climatestrikesf',
#  ' climatestrikenyc',
#  ' climatejustice',
#  ' fridaysforfuture',
#  'fridaysforfuture',
#  'globalclimatestrike',
#  ' climatestrike',
#  ' grevepeloclima',
#  ' greveglobalpeloclima',
#  ' climatechange',
#  ' meioambiente',
#  ' fightforamazonia',
#  ' actforamazonia',
#  ' fridaysforfuture',
#  'último',
#  ' fridaysforfuture',
#  ' bolivia',
#  ' anf',
#  'climatestrike',
#  ' fridaysforfuture',
#  ' emergenciaclimatica',
#  'ahoraesnoticia',
#  ' perúemergenciaclimática',
#  ' fridaysforfuture',
#  ' climatestrike',
#  ' viernesporelfuturo',
#  ' cambioclimático',
#  'fridaysforfuture',
#  ' climateaction',
#  ' onealbuquerque',
#  ' globalclimatestrike',
#  'globalclimatestrike',
#  ' fridaysforfuture',
#  ' climateaction',
#  ' onealbuquerque',
#  'climatestrike',
#  ' fridaysforfuture',
#  ' strikewithus',
#  'climatestrike',
#  ' fridaysforfuture',
#  'fridaysforfuture',
#  ' klimapaket',
#  'cediainforma',
#  ' ahora',
#  ' lima',
#  ' fridaysforfuture',
#  ' climatestrike',
#  ' climatehope',
#  'chile',
#  ' fridaysforfuture',
#  ' osorno',
#  'nyc',
#  ' batterypark',
#  ' climatestrike',
#  ' united4climatejustice',
#  ' fridaysforfuture',
#  'marchaporelclima',
#  ' fridaysforfuture',
#  ' climatestrike',
#  'fridayvibes',
#  ' fridaythoughts',
#  ' fridaysforfuture',
#  'climatestrike',
#  ' fridaysforfuture',
#  'freitags_kindern',
#  ' doppelmoral',
#  ' fridaysforfuture',
#  'fridaysforfuture',
#  'climatestrike',
#  ' fridaysforfuture',
#  'huelgamundialporelclima',
#  ' fridaysforfuture',
#  ' zócalo',
#  ' notimex',
#  'fridaysforfuture',
#  'climatestrike',
#  ' huelgaclimáticaglobal',
#  ' fridaysforfuture',
#  'fridaysforfuture',
#  'fridaysforfuture',
#  'werteunion',
#  ' afd',
#  ' lehrerdenunzianten',
#  ' klimawandel',
#  ' fridaysforfuture',
#  'climatestrike',
#  ' cleanbc',
#  ' fridaysforfuture',
#  'entérate',
#  ' fridaysforfuture',
#  'fridaysforfuture',
#  ' climatestrike',
#  ' climateaction',
#  ' puertooctaysinagua',
#  'fridaysforfuture',
#  ' emergenciaclimatica',
#  'delhi',
#  ' globalstrike',
#  ' climatecrisis',
#  'fridaysforfuture',
#  ' allesfuersklima',
#  'klimaatstaking',
#  ' fridaysforfuture',
#  'trees',
#  ' keepitwild',
#  ' climateaction',
#  ' fridaysforfuture',
#  ' climatestrike',
#  'climatestrike',
#  ' fridaysforfuture',
#  ' climatestrikenyc',
#  'fridaysforfuture',
#  ' climatestrike',
#  'fridaysforfuture',
#  ' climatestrike',
#  ' greveglobalpeloclima',
#  'thread',
#  ' fridaysforfuture',
#  ' climatestrike',
#  ' greveglobalpeloclima',
#  'fridaysforfuture',
#  'fridaysforfuture',
#  ' globalclimatestrike',
#  'climatestrike',
#  ' fridaysforfuture',
#  'fridaysforfuture',
#  ' allefürsklima',
#  'klimapaket',
#  ' fridaysforfuture',
#  ' notmyklimapaket',
#  'fridaysforfuture',
#  ' strike4climate',
#  ' climatestrike',
#  ' climateaction',
#  'klimastreik',
#  ' klimawandel',
#  ' fridaysforfuture',
#  'fridaysforfuture',
#  'climatestrike',
#  ' fridaysforfuture',
#  ' actnow',
#  'fridaysforfuture',
#  'allefürsklima',
#  ' fridaysforfuture',
#  'bostonclimatestrike',
#  ' climatestrike',
#  ' fridaysforfuture',
#  'globalclimatestrike',
#  ' fridaysforfuture',
#  ' climatejustice',
#  ' strike4climate',
#  'gretathunberg',
#  ' globalclimatestrike',
#  ' fridaysforfuture',
#  ' actnowforfuture',
#  'afd',
#  ' noafd',
#  ' fridaysforfuture',
#  ' allefuersklima',
#  ' klimastreik',
#  ' klimaschutz',
#  'climatestrike',
#  ' climateaction',
#  ' fridaysforfuture',
#  ' cop25chile',
#  'dentonclimatestrike',
#  ' strikewithus',
#  ' fridaysforfuture',
#  'fridaysforfuture',
#  ' klimapaket',
#  'fridaysforfuture',
#  ' klimakabinett',
#  ' groko',
#  ' notmyklimapaket',
#  ' allefürsklima',
#  'fridaysforfuture',
#  'gretathunberg',
#  ' fridaysforfuture',
#  'fridaysforfuture',
#  ' climatestrike',
#  ' live',
#  ' love',
#  ' care',
#  ' ourplanet',
#  ' ourfuture',
#  ' nextgeneration',
#  'climatestrike',
#  ' fridaysforfuture',
#  ' mexicocity',
#  'nyc',
#  ' climate',
#  ' fridaysforfuture',
#  ' globalclimatestrike',
#  ' fridayfeeling',
#  ' wallstreet',
#  'fridaysforfuture',
#  ' emergenciaclimatica',
#  ' calentamientoglobal',
#  'klimastreik',
#  ' sebnitz',
#  ' sachsen',
#  ' fridaysforfuture',
#  'climateaction',
#  ' العمل_لأجل_المناخ',
#  ' fridaysforfuture',
#  'washingtondc',
#  ' climatestrike',
#  ' frontline',
#  ' environmentaljustice',
#  ' climateaction',
#  ' justtransition',
#  ' fossilfuels',
#  ' planetb',
#  ' vote',
#  ' win',
#  ' fridaysforfuture',
#  'schoolstrike4climate',
#  ' fridaysforfuture',
#  'huelgaclimaticaglobal',
#  ' climatestrike',
#  ' dwnoticias',
#  'peoplepower',
#  ' climatestrike',
#  ' fridaysforfuture',
#  'fridaysforfuture',
#  ' climatestrike',
#  ' climateaction',
#  ' climatetruth',
#  'sacramento',
#  ' globalclimatestrike',
#  ' fridaysforfuture',
#  'climatestrike',
#  ' fridaysforfuture',
#  'fridaysforfuture',
#  'fridaysforfuture',
#  ' neuwahlen',
#  ' klimastreik',
#  ' climatestrike',
#  'fridaysforfuture',
#  ' climatestrike',
#  ' nyc',
#  ' climateaction',
#  ' girlsgetequal',
#  'climatestrike',
#  ' fridaysforfuture',
#  'fridaysforfuture',
#  'climatestrikenyc',
#  ' climatestrike',
#  ' fridaysforfuture',
#  ' strikewithus',
#  'climatestrike',
#  ' fridaysforfuture',
#  ' youthstrike4climate',
#  ' climateaction',
#  ' savetheplanet',
#  'klimaatstaking',
#  ' klimastreik',
#  ' climatestrike',
#  'climateaction',
#  ' fridaysforfuture',
#  'notmyklimapaket',
#  'climatestrike',
#  ' fridaysforfuture',
#  'climatestrike',
#  ' fridaysforfuture',
#  'climatestrike',
#  ' fridaysforfuture',
#  'fridaysforfuture',
#  ' climatestrike',
#  'climatestrike',
#  ' fridaysforfuture',
#  'fridaysforfuture',
#  ' climateaction',
#  'whistleblowergate',
#  ' fridaymotivation',
#  ' fridayfeeling',
#  ' fridaysforfuture',
#  ' arresttrump',
#  ' indicttrump',
#  ' prison',
#  'climatestike',
#  ' neumayer',
#  ' antarctica',
#  ' awis4future',
#  ' allefuersklima',
#  ' nomorepillepalle',
#  ' klimastreik',
#  'climatestrike',
#  ' fridaysforfuture',
#  ' climatestrikes',
#  'fridaysforfuture',
#  ' frankfurt',
#  ' fff',
#  'climatestrike',
#  ' fridaysforfuture',
#  ' onpse',
#  ' cfsfcee',
#  'fridaysforfuture',
#  'برلين',
#  ' التغير_المناخي',
#  ' fridaysforfuture',
#  'energíasrenovables',
#  ' crisisclimática',
#  ' fridaysforfuture',
#  'klimastreik',
#  'fridaysforfuture',
#  ' climateaction',
#  'fridaysforfuture',
#  ' climatestrike',
#  ' huelgamundialporelclima',
#  'klimapaket',
#  ' fridaysforfuture',
#  ' unserespd',
#  'fridaysforfuture',
#  ' climatestrike',
#  'fridaysforfuture',
#  ' climatestrike',
#  ' gretathunberg',
#  'climateaction',
#  ' climateactionnow',
#  ' climatestrike',
#  ' fridaysforfuture',
#  ' climatemarch',
#  'russland',
#  ' klima',
#  ' fridaysforfuture',
#  ' klimastreik',
#  ' allefuersklima',
#  ' climatestrike',
#  'jeunesse',
#  ' jeunes',
#  ' agitaction',
#  ' fridaysforfuture',
#  'climatestrike',
#  ' fridaysforfuture',
#  'augustsplatz',
#  ' leipzig',
#  ' globalstrike',
#  ' allefürsklima',
#  ' klimastreik',
#  ' fridaysforfuture',
#  ' climatestrike',
#  ' klimapaket',
#  'fridaysforfuture',
#  ' climatestrike',
#  'fridaysforfuture',
#  ' climat',
#  'fridaysforfuture',
#  ' climatestrike',
#  'schoolstrike4climate',
#  ' fridaysforfuture',
#  ' climatestrike',
#  'fridaysforfuture',
#  'fridaysforfuture',
#  'fridaysforfuture',
#  ' climatestrike',
#  'fridaysforfuture',
#  'globalclimatestrike',
#  ' fridays4future',
#  ' fridaysforfuture',
#  'frankfurt',
#  ' weilheim',
#  ' köln',
#  ' kiel',
#  ' klimastreik',
#  ' allefuersklima',
#  ' fridaysforfuture',
#  'fridaysforfuture',
#  ' fff',
#  'fridaysforfuture',
#  ' allefuersklima',
#  ' b2009',
#  ' climatestrike',
#  ' klimapaket',
#  'fridaysforfuture',
#  'fridaysforfuture',
#  ' thekidsareallright',
#  'groko',
#  ' climatestrike',
#  ' fridaysforfuture',
#  ' notmyklimapaket',
#  'fridaysforfuture',
#  'fridaysforfuture',
#  ' climatestrike',
#  'fridaysforfuture',
#  ' svpol',
#  'fridaysforfuture',
#  'climateactionweek',
#  ' fridaysforfuture',
#  ' climatestrike',
#  ' climateemergency',
#  ' bangladesh',
#  'fridaysforfuture',
#  'fridaysforfuture',
#  'climatestrike',
#  ' fridaysforfuture',
#  'fridaysforfuture',
#  'youthstrike4climatehuddersfield',
#  ' climateaction',
#  ' fridaysforfuture',
#  'fridaysforfuture',
#  'fridaysforfuture',
#  ' cambioclimatico',
#  'fridaysforfuture',
#  ' climatecrisis',
#  'symbolpolitik',
#  ' fridaysforfuture',
#  ' fridays4future',
#  ' klimapaket',
#  ' allefuersklima',
#  ' merkel',
#  'fridaysforfuture',
#  ' istanbul',
#  ' kohlendioxid',
#  ' klimastreik',
#  ' climatestrike',
#  'fridaysforfuture',
#  ' climatestrike',
#  'climatestrike',
#  ' fridaysforfuture',
#  ' marchwithus',
#  'climatejustice',
#  ' brussels',
#  ' fridaysforfuture',
#  ' climateaction',
#  ' climatechange',
#  ' teach4climate',
#  'notmyklimapaket',
#  ' allefuersklima',
#  ' fridaysforfuture',
#  'fridaysforfuture',
#  'goodnighttwitterworld',
#  ' fridaysforfuture',
#  'fridaysforfuture',
#  ' latvijavar',
#  'fridaysforfuture',
#  ' marcheclimat',
#  ' ecologieparis',
#  'amazing',
#  ' demonstration',
#  ' climatechange',
#  ' saarbrücken',
#  ' saarland',
#  ' scientists',
#  ' scientists4future',
#  ' ddop',
#  ' hips',
#  ' climatestrike',
#  ' fridaysforfuture',
#  'klimapaket',
#  ' klimakrise',
#  ' klimastreik',
#  ' klimakabinett',
#  ' fridaysforfuture',
#  'fridaysforfuture',
#  ' climatestrike',
#  ' globalclimatestrike',
#  'fridaysforfuture',
#  ' allefürsklima',
#  'climatestrike',
#  ' klimastreik',
#  ' fridaysforfuture',
#  ' klimakrise',
#  ' parentsforfuture',
#  'fridaysforfuture',
#  'fridaysforfuture',
#  ' climatestrike',
#  'fridaysforfuture',
#  ' allefuersklima',
#  ' chemnitz',
#  ' climatestrike',
#  'fridaysforfuture',
#  ' climatestrike',
#  'fridaysforfuture',
#  'fridaysforfuture',
#  'climatestrike',
#  ' climateaction',
#  ' fridaysforfuture',
#  ' washingtondc',
#  'klimastreik',
#  ...]

# %%
for i in df.values:
    tagsss = i[0].split(",")
    for t in range(len(tagsss)):
        tags.append(tagsss[t])
        time_tags.append(i[2])
        for j in tagsss[t+1:]:
            couple_tags.append((tagsss[t], j))  
            time_couple.append(i[2])

# %%
couple_tags
# Out:
# [('klimastreik', ' fridaysforfuture'),
#  ('klimastreik', ' allefuersklima'),
#  ('klimastreik', ' allefürsklima'),
#  ('klimastreik', ' le2009'),
#  (' fridaysforfuture', ' allefuersklima'),
#  (' fridaysforfuture', ' allefürsklima'),
#  (' fridaysforfuture', ' le2009'),
#  (' allefuersklima', ' allefürsklima'),
#  (' allefuersklima', ' le2009'),
#  (' allefürsklima', ' le2009'),
#  ('climatestrike', ' youthclimatestrike'),
#  ('climatestrike', ' fridaysforfuture'),
#  (' youthclimatestrike', ' fridaysforfuture'),
#  ('climatestrikedc', ' climatestrike'),
#  ('climatestrikedc', ' fridaysforfuture'),
#  (' climatestrike', ' fridaysforfuture'),
#  ('fridaysforfuture', ' 20septiembre'),
#  ('fridaysforfuture', ' climatecrisis'),
#  ('fridaysforfuture', ' crisisclimatica'),
#  ('fridaysforfuture', ' viernesporelfuturo'),
#  (' 20septiembre', ' climatecrisis'),
#  (' 20septiembre', ' crisisclimatica'),
#  (' 20septiembre', ' viernesporelfuturo'),
#  (' climatecrisis', ' crisisclimatica'),
#  (' climatecrisis', ' viernesporelfuturo'),
#  (' crisisclimatica', ' viernesporelfuturo'),
#  ('uganda', ' fridaysforfuture'),
#  ('uganda', ' climatestrikes'),
#  (' fridaysforfuture', ' climatestrikes'),
#  ('climatestrike', ' fridayforfuture'),
#  ('halifax', ' fridaysforfuture'),
#  ('halifax', ' climateaction'),
#  (' fridaysforfuture', ' climateaction'),
#  ('climatestrike', ' fridaysforfuture'),
#  ('svpol', ' fridaysforfuture'),
#  ('fridaysforfuture', ' climatestrike'),
#  ('fridaysforfuture', ' climatestrikenyc'),
#  (' climatestrike', ' climatestrikenyc'),
#  ('climatestrike', ' fridaysforfuture'),
#  ('climatestrike', ' allefuersklima'),
#  ('climatestrike', ' globalclimatestrike'),
#  ('climatestrike', ' klimakabinett'),
#  ('climatestrike', ' klimapakt'),
#  (' fridaysforfuture', ' allefuersklima'),
#  (' fridaysforfuture', ' globalclimatestrike'),
#  (' fridaysforfuture', ' klimakabinett'),
#  (' fridaysforfuture', ' klimapakt'),
#  (' allefuersklima', ' globalclimatestrike'),
#  (' allefuersklima', ' klimakabinett'),
#  (' allefuersklima', ' klimapakt'),
#  (' globalclimatestrike', ' klimakabinett'),
#  (' globalclimatestrike', ' klimapakt'),
#  (' klimakabinett', ' klimapakt'),
#  ('climatestrike', ' fridaysforfuture'),
#  ('fridaysforfuture', ' allefuersklima'),
#  ('faz', ' fridaysforfuture'),
#  ('faz', ' cdu'),
#  ('faz', ' csu'),
#  ('faz', ' spd'),
#  ('faz', ' fdp'),
#  ('faz', ' linke'),
#  ('faz', ' grüne'),
#  ('faz', ' afd'),
#  (' fridaysforfuture', ' cdu'),
#  (' fridaysforfuture', ' csu'),
#  (' fridaysforfuture', ' spd'),
#  (' fridaysforfuture', ' fdp'),
#  (' fridaysforfuture', ' linke'),
#  (' fridaysforfuture', ' grüne'),
#  (' fridaysforfuture', ' afd'),
#  (' cdu', ' csu'),
#  (' cdu', ' spd'),
#  (' cdu', ' fdp'),
#  (' cdu', ' linke'),
#  (' cdu', ' grüne'),
#  (' cdu', ' afd'),
#  (' csu', ' spd'),
#  (' csu', ' fdp'),
#  (' csu', ' linke'),
#  (' csu', ' grüne'),
#  (' csu', ' afd'),
#  (' spd', ' fdp'),
#  (' spd', ' linke'),
#  (' spd', ' grüne'),
#  (' spd', ' afd'),
#  (' fdp', ' linke'),
#  (' fdp', ' grüne'),
#  (' fdp', ' afd'),
#  (' linke', ' grüne'),
#  (' linke', ' afd'),
#  (' grüne', ' afd'),
#  ('20settembre', ' fridaysforfuture'),
#  ('20settembre', ' climatestrike'),
#  (' fridaysforfuture', ' climatestrike'),
#  ('fridaysforfuture', ' climatestrike'),
#  ('fridaysforfuture', ' bayreuth'),
#  ('fridaysforfuture', ' newgreendeal'),
#  ('fridaysforfuture', ' climatestrike'),
#  (' newgreendeal', ' climatestrike'),
#  ('climatestrike', ' globalclimatestrike'),
#  ('climatestrike', ' globalclimatestrikeindia'),
#  ('climatestrike', ' globalclimatestrikesindia'),
#  ('climatestrike', ' fridaysforfuture'),
#  ('climatestrike', ' schoolstrike4climate'),
#  ('climatestrike', ' youthclimatestrike'),
#  (' globalclimatestrike', ' globalclimatestrikeindia'),
#  (' globalclimatestrike', ' globalclimatestrikesindia'),
#  (' globalclimatestrike', ' fridaysforfuture'),
#  (' globalclimatestrike', ' schoolstrike4climate'),
#  (' globalclimatestrike', ' youthclimatestrike'),
#  (' globalclimatestrikeindia', ' globalclimatestrikesindia'),
#  (' globalclimatestrikeindia', ' fridaysforfuture'),
#  (' globalclimatestrikeindia', ' schoolstrike4climate'),
#  (' globalclimatestrikeindia', ' youthclimatestrike'),
#  (' globalclimatestrikesindia', ' fridaysforfuture'),
#  (' globalclimatestrikesindia', ' schoolstrike4climate'),
#  (' globalclimatestrikesindia', ' youthclimatestrike'),
#  (' fridaysforfuture', ' schoolstrike4climate'),
#  (' fridaysforfuture', ' youthclimatestrike'),
#  (' schoolstrike4climate', ' youthclimatestrike'),
#  ('climatestrike', ' climatechange'),
#  ('climatestrike', ' climateaction'),
#  ('climatestrike', ' fridaysforfuture'),
#  (' climatechange', ' climateaction'),
#  (' climatechange', ' fridaysforfuture'),
#  (' climateaction', ' fridaysforfuture'),
#  ('fridaysforfuture', ' groko'),
#  ('fridaysforfuture', ' klimapaket'),
#  (' groko', ' klimapaket'),
#  ('climatestrike', ' fridaysforfuture'),
#  ('climatestrike', ' fridaysforfuture'),
#  ('cdu', ' spd'),
#  ('cdu', ' fridaysforfuture'),
#  (' spd', ' fridaysforfuture'),
#  ('klimastreik', ' globalstrike'),
#  ('klimastreik', ' fridaysforfuture'),
#  (' globalstrike', ' fridaysforfuture'),
#  ('fridaysforfuture', ' klimastreik'),
#  ('fridaysforfuture', ' globalstrike'),
#  ('fridaysforfuture', ' fridaysforfuture'),
#  ('fridaysforfuture', ' b2009'),
#  ('fridaysforfuture', ' climatestrike'),
#  (' klimastreik', ' globalstrike'),
#  (' klimastreik', ' fridaysforfuture'),
#  (' klimastreik', ' b2009'),
#  (' klimastreik', ' climatestrike'),
#  (' globalstrike', ' fridaysforfuture'),
#  (' globalstrike', ' b2009'),
#  (' globalstrike', ' climatestrike'),
#  (' fridaysforfuture', ' b2009'),
#  (' fridaysforfuture', ' climatestrike'),
#  (' b2009', ' climatestrike'),
#  ('climatecrisis', ' climatestrike'),
#  ('climatecrisis', ' climatechange'),
#  ('climatecrisis', ' fridayforfuture'),
#  (' climatestrike', ' climatechange'),
#  (' climatestrike', ' fridayforfuture'),
#  (' climatechange', ' fridayforfuture'),
#  ('lorax', ' kinderbuchliebe'),
#  ('lorax', ' drseuss'),
#  ('lorax', ' klimakrise'),
#  ('lorax', ' allefuersklima'),
#  ('lorax', ' fridaysforfuture'),
#  ('lorax', ' weltklimastreik'),
#  (' kinderbuchliebe', ' drseuss'),
#  (' kinderbuchliebe', ' klimakrise'),
#  (' kinderbuchliebe', ' allefuersklima'),
#  (' kinderbuchliebe', ' fridaysforfuture'),
#  (' kinderbuchliebe', ' weltklimastreik'),
#  (' drseuss', ' klimakrise'),
#  (' drseuss', ' allefuersklima'),
#  (' drseuss', ' fridaysforfuture'),
#  (' drseuss', ' weltklimastreik'),
#  (' klimakrise', ' allefuersklima'),
#  (' klimakrise', ' fridaysforfuture'),
#  (' klimakrise', ' weltklimastreik'),
#  (' allefuersklima', ' fridaysforfuture'),
#  (' allefuersklima', ' weltklimastreik'),
#  (' fridaysforfuture', ' weltklimastreik'),
#  ('वत्स', ' fridaysforfuture'),
#  ('allefuersklima', ' fridaysforfuture'),
#  ('fridaysforfuture', ' climateaction'),
#  ('fridaysforfuture', ' العمل_لأجل_المناخ'),
#  (' climateaction', ' العمل_لأجل_المناخ'),
#  ('climatestrike', ' fridaysforfuture'),
#  ('climatestrike', ' fridaysforfuture'),
#  ('climatestrike', ' dubmayor350'),
#  ('climatestrike', ' beclimatebrave'),
#  (' fridaysforfuture', ' dubmayor350'),
#  (' fridaysforfuture', ' beclimatebrave'),
#  (' dubmayor350', ' beclimatebrave'),
#  ('strikeforclimate', ' fridaysforfuture'),
#  ('strikeforclimate', ' ambassadorofconscience'),
#  (' fridaysforfuture', ' ambassadorofconscience'),
#  ('bancomer', ' felizfindesemana'),
#  ('bancomer', ' felizviernesatodos'),
#  ('bancomer', ' iphone11'),
#  ('bancomer', ' area51storm'),
#  ('bancomer', ' fridaysforfuture'),
#  ('bancomer', ' vocalkingchenday'),
#  (' felizfindesemana', ' felizviernesatodos'),
#  (' felizfindesemana', ' iphone11'),
#  (' felizfindesemana', ' area51storm'),
#  (' felizfindesemana', ' fridaysforfuture'),
#  (' felizfindesemana', ' vocalkingchenday'),
#  (' felizviernesatodos', ' iphone11'),
#  (' felizviernesatodos', ' area51storm'),
#  (' felizviernesatodos', ' fridaysforfuture'),
#  (' felizviernesatodos', ' vocalkingchenday'),
#  (' iphone11', ' area51storm'),
#  (' iphone11', ' fridaysforfuture'),
#  (' iphone11', ' vocalkingchenday'),
#  (' area51storm', ' fridaysforfuture'),
#  (' area51storm', ' vocalkingchenday'),
#  (' fridaysforfuture', ' vocalkingchenday'),
#  ('fridaysforfuture', ' ilmastonmuutos'),
#  ('bundesregierung', ' allefuersklima'),
#  ('bundesregierung', ' fridaysforfuture'),
#  ('bundesregierung', ' extinctionrebellion'),
#  ('bundesregierung', ' scientists4future'),
#  (' allefuersklima', ' fridaysforfuture'),
#  (' allefuersklima', ' extinctionrebellion'),
#  (' allefuersklima', ' scientists4future'),
#  (' fridaysforfuture', ' extinctionrebellion'),
#  (' fridaysforfuture', ' scientists4future'),
#  (' extinctionrebellion', ' scientists4future'),
#  ('berlín', ' cambioclimático'),
#  ('berlín', ' protestas'),
#  ('berlín', ' alemania'),
#  ('berlín', ' climatestrike'),
#  ('berlín', ' dwnoticias'),
#  (' cambioclimático', ' protestas'),
#  (' cambioclimático', ' alemania'),
#  (' cambioclimático', ' climatestrike'),
#  (' cambioclimático', ' dwnoticias'),
#  (' protestas', ' alemania'),
#  (' protestas', ' climatestrike'),
#  (' protestas', ' dwnoticias'),
#  (' alemania', ' climatestrike'),
#  (' alemania', ' dwnoticias'),
#  (' climatestrike', ' dwnoticias'),
#  ('fridaysforfuture', ' climatestrike'),
#  ('fridaysforfuture', ' klimakabinett'),
#  ('bernie2020', ' berniesanders2020'),
#  ('bernie2020', ' climatestrike'),
#  ('bernie2020', ' climateaction'),
#  ('bernie2020', ' fridaymorning'),
#  ('bernie2020', ' fridaymorning'),
#  ('bernie2020', ' fridaysforfuture'),
#  (' berniesanders2020', ' climatestrike'),
#  (' berniesanders2020', ' climateaction'),
#  (' berniesanders2020', ' fridaymorning'),
#  (' berniesanders2020', ' fridaymorning'),
#  (' berniesanders2020', ' fridaysforfuture'),
#  (' climatestrike', ' climateaction'),
#  (' climatestrike', ' fridaymorning'),
#  (' climatestrike', ' fridaymorning'),
#  (' climatestrike', ' fridaysforfuture'),
#  (' climateaction', ' fridaymorning'),
#  (' climateaction', ' fridaymorning'),
#  (' climateaction', ' fridaysforfuture'),
#  (' fridaymorning', ' fridaymorning'),
#  (' fridaymorning', ' fridaysforfuture'),
#  (' fridaymorning', ' fridaysforfuture'),
#  ('s04', ' klimastreik'),
#  ('s04', ' globalclimatestrike'),
#  ('s04', ' fridaysforfuture'),
#  ('s04', ' allefuersklima'),
#  ('s04', ' s04'),
#  ('s04', ' s04m05'),
#  (' klimastreik', ' globalclimatestrike'),
#  (' klimastreik', ' fridaysforfuture'),
#  (' klimastreik', ' allefuersklima'),
#  (' klimastreik', ' s04'),
#  (' klimastreik', ' s04m05'),
#  (' globalclimatestrike', ' fridaysforfuture'),
#  (' globalclimatestrike', ' allefuersklima'),
#  (' globalclimatestrike', ' s04'),
#  (' globalclimatestrike', ' s04m05'),
#  (' fridaysforfuture', ' allefuersklima'),
#  (' fridaysforfuture', ' s04'),
#  (' fridaysforfuture', ' s04m05'),
#  (' allefuersklima', ' s04'),
#  (' allefuersklima', ' s04m05'),
#  (' s04', ' s04m05'),
#  ('fridaysforfuture', ' bernie2020'),
#  ('fridaysforfuture', ' tulsi2020'),
#  ('fridaysforfuture', ' greennewdeal'),
#  ('fridaysforfuture', ' offact'),
#  (' bernie2020', ' tulsi2020'),
#  (' bernie2020', ' greennewdeal'),
#  (' bernie2020', ' offact'),
#  (' tulsi2020', ' greennewdeal'),
#  (' tulsi2020', ' offact'),
#  (' greennewdeal', ' offact'),
#  ('klimaschutzpaket', ' klimapaket'),
#  ('klimaschutzpaket', ' klimakabinett'),
#  ('klimaschutzpaket', ' fridaysforfuture'),
#  (' klimapaket', ' klimakabinett'),
#  (' klimapaket', ' fridaysforfuture'),
#  (' klimakabinett', ' fridaysforfuture'),
#  ('polizei', ' wendt'),
#  ('polizei', ' fridaysforfuture'),
#  (' wendt', ' fridaysforfuture'),
#  ('fridaysforfuture', ' climatestrike'),
#  ('fridaysforfuture', ' cdmx'),
#  ('fridaysforfuture', ' cambioclimatico'),
#  ('fridaysforfuture', ' méxico'),
#  ('fridaysforfuture', ' gretathunberg'),
#  (' cdmx', ' cambioclimatico'),
#  (' cdmx', ' méxico'),
#  (' cdmx', ' gretathunberg'),
#  (' cambioclimatico', ' méxico'),
#  (' cambioclimatico', ' gretathunberg'),
#  (' méxico', ' gretathunberg'),
#  ('climatestrike', ' fridaysforfuture'),
#  ('climatestrike', ' inspiration'),
#  ('climatestrike', ' youth'),
#  ('climatestrike', ' earth'),
#  ('climatestrike', ' savetheworld'),
#  ('climatestrike', ' peace'),
#  ('climatestrike', ' climatecrisis'),
#  (' fridaysforfuture', ' inspiration'),
#  (' fridaysforfuture', ' youth'),
#  (' fridaysforfuture', ' earth'),
#  (' fridaysforfuture', ' savetheworld'),
#  (' fridaysforfuture', ' peace'),
#  (' fridaysforfuture', ' climatecrisis'),
#  (' inspiration', ' youth'),
#  (' inspiration', ' earth'),
#  (' inspiration', ' savetheworld'),
#  (' inspiration', ' peace'),
#  (' inspiration', ' climatecrisis'),
#  (' youth', ' earth'),
#  (' youth', ' savetheworld'),
#  (' youth', ' peace'),
#  (' youth', ' climatecrisis'),
#  (' earth', ' savetheworld'),
#  (' earth', ' peace'),
#  (' earth', ' climatecrisis'),
#  (' savetheworld', ' peace'),
#  (' savetheworld', ' climatecrisis'),
#  (' peace', ' climatecrisis'),
#  ('fridaysforfuture', ' climatestrike'),
#  ('fridaysforfuture', ' climatestrike'),
#  ('klimastreiks', ' fridaysforfuture'),
#  ('burundi', ' keepmamaafricagreen'),
#  ('burundi', ' fridaysforfuture'),
#  ('burundi', ' climatestrike'),
#  (' keepmamaafricagreen', ' fridaysforfuture'),
#  (' keepmamaafricagreen', ' climatestrike'),
#  (' fridaysforfuture', ' climatestrike'),
#  ('allefürsklima', ' fridaysforfuture'),
#  ('climatestrike', ' fridaysforfuture'),
#  ('fridaysforfuture', ' climatestrike'),
#  ('climatestrike', ' fridaysforfuture'),
#  ('fridaysforfuture', ' climatestrike'),
#  ('hoy', ' fridaysforfuture'),
#  ('fridaysforfuture', ' climatestrike'),
#  ('fridaysforfuture', ' klimaschutzpaket'),
#  ('globalclimatestrike', ' fridaysforfuture'),
#  ('globalclimatestrike', ' portlandclimatestrike'),
#  (' fridaysforfuture', ' portlandclimatestrike'),
#  ('climatestrike', ' fridaysforfuture'),
#  ('klimastreik', ' berlin'),
#  ('klimastreik', ' fridaysforfuture'),
#  ('klimastreik', ' allefuersklima'),
#  ('klimastreik', ' klimapaket'),
#  ('klimastreik', ' klimawahn'),
#  ('klimastreik', ' diewelle'),
#  (' berlin', ' fridaysforfuture'),
#  (' berlin', ' allefuersklima'),
#  (' berlin', ' klimapaket'),
#  (' berlin', ' klimawahn'),
#  (' berlin', ' diewelle'),
#  (' fridaysforfuture', ' allefuersklima'),
#  (' fridaysforfuture', ' klimapaket'),
#  (' fridaysforfuture', ' klimawahn'),
#  (' fridaysforfuture', ' diewelle'),
#  (' allefuersklima', ' klimapaket'),
#  (' allefuersklima', ' klimawahn'),
#  (' allefuersklima', ' diewelle'),
#  (' klimapaket', ' klimawahn'),
#  (' klimapaket', ' diewelle'),
#  (' klimawahn', ' diewelle'),
#  ('greveglobalpeloclima', ' aquecimentoglobal'),
#  ('greveglobalpeloclima', ' criseclimática'),
#  ('greveglobalpeloclima', ' climatestrike'),
#  ('greveglobalpeloclima', ' fridaysforfuture'),
#  ('greveglobalpeloclima', ' senadordetodosnós'),
#  (' aquecimentoglobal', ' criseclimática'),
#  (' aquecimentoglobal', ' climatestrike'),
#  (' aquecimentoglobal', ' fridaysforfuture'),
#  (' aquecimentoglobal', ' senadordetodosnós'),
#  (' criseclimática', ' climatestrike'),
#  (' criseclimática', ' fridaysforfuture'),
#  (' criseclimática', ' senadordetodosnós'),
#  (' climatestrike', ' fridaysforfuture'),
#  (' climatestrike', ' senadordetodosnós'),
#  (' fridaysforfuture', ' senadordetodosnós'),
#  ('kabul', ' climatestrike'),
#  ('kabul', ' fridaysforfuture'),
#  (' climatestrike', ' fridaysforfuture'),
#  ('leipzig', ' fridaysforfuture'),
#  ('leipzig', ' allefuersklima'),
#  ('leipzig', ' notmyklimapaket'),
#  ('leipzig', ' klimapaket'),
#  (' fridaysforfuture', ' allefuersklima'),
#  (' fridaysforfuture', ' notmyklimapaket'),
#  (' fridaysforfuture', ' klimapaket'),
#  (' allefuersklima', ' notmyklimapaket'),
#  (' allefuersklima', ' klimapaket'),
#  (' notmyklimapaket', ' klimapaket'),
#  ('guns', ' climatechange'),
#  ('guns', ' climatestrike'),
#  ('guns', ' fridaysforfuture'),
#  (' climatechange', ' climatestrike'),
#  (' climatechange', ' fridaysforfuture'),
#  (' climatestrike', ' fridaysforfuture'),
#  ('nichtmeinklimapaket', ' fridaysforfuture'),
#  ('nichtmeinklimapaket', ' climatestrike'),
#  (' fridaysforfuture', ' climatestrike'),
#  ('climatestrike', ' fridaysforfuture'),
#  ('fridaysforfuture', ' svpol'),
#  ('climatestrike', ' fridaysforfuture'),
#  ('climatestrike', ' fridaysforfuture'),
#  ('climatestrike', ' fridaysforfuture'),
#  ('wirtschaft', ' klimaschutz'),
#  ('wirtschaft', ' berlin'),
#  ('wirtschaft', ' fridaysforfuture'),
#  (' klimaschutz', ' berlin'),
#  (' klimaschutz', ' fridaysforfuture'),
#  (' berlin', ' fridaysforfuture'),
#  ('fridaysforfuture', ' klimastreik'),
#  ('klimapaket', ' niemehrspd'),
#  ('klimapaket', ' fridaysforfuture'),
#  ('klimapaket', ' allefuersklima'),
#  (' niemehrspd', ' fridaysforfuture'),
#  (' niemehrspd', ' allefuersklima'),
#  (' fridaysforfuture', ' allefuersklima'),
#  ('schoolstrikes4climate', ' climatestrikelondon'),
#  ('schoolstrikes4climate', ' climatestrike'),
#  ('schoolstrikes4climate', ' fridaysforfuture'),
#  ('schoolstrikes4climate', ' climatechange'),
#  ('schoolstrikes4climate', ' globalwarming'),
#  ('schoolstrikes4climate', ' millbank'),
#  ('schoolstrikes4climate', ' parliament'),
#  (' climatestrikelondon', ' climatestrike'),
#  (' climatestrikelondon', ' fridaysforfuture'),
#  (' climatestrikelondon', ' climatechange'),
#  (' climatestrikelondon', ' globalwarming'),
#  (' climatestrikelondon', ' millbank'),
#  (' climatestrikelondon', ' parliament'),
#  (' climatestrike', ' fridaysforfuture'),
#  (' climatestrike', ' climatechange'),
#  (' climatestrike', ' globalwarming'),
#  (' climatestrike', ' millbank'),
#  (' climatestrike', ' parliament'),
#  (' fridaysforfuture', ' climatechange'),
#  (' fridaysforfuture', ' globalwarming'),
#  (' fridaysforfuture', ' millbank'),
#  (' fridaysforfuture', ' parliament'),
#  (' climatechange', ' globalwarming'),
#  (' climatechange', ' millbank'),
#  (' climatechange', ' parliament'),
#  (' globalwarming', ' millbank'),
#  (' globalwarming', ' parliament'),
#  (' millbank', ' parliament'),
#  ('climatestrike', ' fridaysforfuture'),
#  ('climatestrike', ' faithsforfuture'),
#  (' fridaysforfuture', ' faithsforfuture'),
#  ('climatestrike', ' fridaysforfuture'),
#  ('climatestrike', ' santiago'),
#  ('climatestrike', ' chile'),
#  (' fridaysforfuture', ' santiago'),
#  (' fridaysforfuture', ' chile'),
#  (' santiago', ' chile'),
#  ('climateaction', ' fridaysforfuture'),
#  ('climateaction', ' climatestrike'),
#  (' fridaysforfuture', ' climatestrike'),
#  ('fridaysforfuture', ' climatestrike'),
#  ('fridaysforfuture', ' tippingpoint'),
#  ('fridaysforfuture', ' unstoppable'),
#  (' climatestrike', ' tippingpoint'),
#  (' climatestrike', ' unstoppable'),
#  (' tippingpoint', ' unstoppable'),
#  ('fridaysforfuture', ' climatestrike'),
#  ('youporn', ' fridaysforfuture'),
#  ('youporn', ' climatestrike'),
#  (' fridaysforfuture', ' climatestrike'),
#  ('climatestrike', ' actonclimate'),
#  ('climatestrike', ' fridaysforfuture'),
#  ('climatestrike', ' yourparksyourturn'),
#  (' actonclimate', ' fridaysforfuture'),
#  (' actonclimate', ' yourparksyourturn'),
#  (' fridaysforfuture', ' yourparksyourturn'),
#  ('fridaysforfuture', ' parentsforfuture'),
#  ('fridaysforfuture', ' allefuersklima'),
#  (' parentsforfuture', ' allefuersklima'),
#  ('klimastreik', ' fridayforfuture'),
#  ('klimastreik', ' globalclimatestrike'),
#  ('klimastreik', ' sketchnotes'),
#  (' fridayforfuture', ' globalclimatestrike'),
#  (' fridayforfuture', ' sketchnotes'),
#  (' globalclimatestrike', ' sketchnotes'),
#  ('allefürsklima', ' klimakabinett'),
#  ('climatestrike', ' environmentaljustice'),
#  ('climatestrike', ' fridaysforfuture'),
#  ('climatestrike', ' equity'),
#  (' environmentaljustice', ' fridaysforfuture'),
#  (' environmentaljustice', ' equity'),
#  (' fridaysforfuture', ' equity'),
#  ('climatestrike', ' fridaysforfuture'),
#  ('mlpd', ' fridaysforfuture'),
#  ('mlpd', ' fff'),
#  (' fridaysforfuture', ' fff'),
#  ('fridaysforfuture', ' klimatstrejk'),
#  ('climatestrike', ' climateaction'),
#  ('climatestrike', ' fridaysforfuture'),
#  (' climateaction', ' fridaysforfuture'),
#  ('klimastreik', ' besetzen'),
#  ('klimastreik', ' tumalwat'),
#  ('klimastreik', ' mietenwahnsinn'),
#  ('klimastreik', ' stadtvonunten'),
#  ('klimastreik', ' fridaysforfuture'),
#  ('klimastreik', ' besetzen4future'),
#  ('klimastreik', ' climatestrike'),
#  ('klimastreik', ' diesela'),
#  (' besetzen', ' tumalwat'),
#  (' besetzen', ' mietenwahnsinn'),
#  (' besetzen', ' stadtvonunten'),
#  (' besetzen', ' fridaysforfuture'),
#  (' besetzen', ' besetzen4future'),
#  (' besetzen', ' climatestrike'),
#  (' besetzen', ' diesela'),
#  (' tumalwat', ' mietenwahnsinn'),
#  (' tumalwat', ' stadtvonunten'),
#  (' tumalwat', ' fridaysforfuture'),
#  (' tumalwat', ' besetzen4future'),
#  (' tumalwat', ' climatestrike'),
#  (' tumalwat', ' diesela'),
#  (' mietenwahnsinn', ' stadtvonunten'),
#  (' mietenwahnsinn', ' fridaysforfuture'),
#  (' mietenwahnsinn', ' besetzen4future'),
#  (' mietenwahnsinn', ' climatestrike'),
#  (' mietenwahnsinn', ' diesela'),
#  (' stadtvonunten', ' fridaysforfuture'),
#  (' stadtvonunten', ' besetzen4future'),
#  (' stadtvonunten', ' climatestrike'),
#  (' stadtvonunten', ' diesela'),
#  (' fridaysforfuture', ' besetzen4future'),
#  (' fridaysforfuture', ' climatestrike'),
#  (' fridaysforfuture', ' diesela'),
#  (' besetzen4future', ' climatestrike'),
#  (' besetzen4future', ' diesela'),
#  (' climatestrike', ' diesela'),
#  ('climatestrike', ' fridaysforfuture'),
#  ('gretathunberg', ' fridayforfuture'),
#  ('gretathunberg', ' newyork'),
#  (' fridayforfuture', ' newyork'),
#  ('globalclimatestrike', ' youthstrike4climate'),
#  ('globalclimatestrike', ' youthforclimate'),
#  ('globalclimatestrike', ' fridaysforfuture'),
#  ('globalclimatestrike', ' liverpool'),
#  (' youthstrike4climate', ' youthforclimate'),
#  (' youthstrike4climate', ' fridaysforfuture'),
#  (' youthstrike4climate', ' liverpool'),
#  (' youthforclimate', ' fridaysforfuture'),
#  (' youthforclimate', ' liverpool'),
#  (' fridaysforfuture', ' liverpool'),
#  ('fridaysforfuture', ' multikulti'),
#  ('climatestrike', ' fridaysforfuture'),
#  ('jeunesse', ' strikeforclimatechange'),
#  ('jeunesse', ' fridaysforfuture'),
#  (' strikeforclimatechange', ' fridaysforfuture'),
#  ('fridaysforfuture', ' klimapaket'),
#  ('sanfrancisco', ' climatestrike'),
#  ('sanfrancisco', ' fridaysforfuture'),
#  ('sanfrancisco', ' globalclimatestrike'),
#  (' climatestrike', ' fridaysforfuture'),
#  (' climatestrike', ' globalclimatestrike'),
#  (' fridaysforfuture', ' globalclimatestrike'),
#  ('amazon', ' seattle'),
#  ('amazon', ' climatechange'),
#  ('amazon', ' climatestrike'),
#  ('amazon', ' fridaysforfuture'),
#  ('amazon', ' networkofnow'),
#  (' seattle', ' climatechange'),
#  (' seattle', ' climatestrike'),
#  (' seattle', ' fridaysforfuture'),
#  (' seattle', ' networkofnow'),
#  (' climatechange', ' climatestrike'),
#  (' climatechange', ' fridaysforfuture'),
#  (' climatechange', ' networkofnow'),
#  (' climatestrike', ' fridaysforfuture'),
#  (' climatestrike', ' networkofnow'),
#  (' fridaysforfuture', ' networkofnow'),
#  ('climatestrike', ' fridaysforfuture'),
#  ('climatestrike', ' fridaysforfuture'),
#  ('cambioclimatico', ' fridaysforfuture'),
#  ('climatestrike', ' climatestrikeindia'),
#  ('climatestrike', ' fridaysforfuture'),
#  (' climatestrikeindia', ' fridaysforfuture'),
#  ('forourfuturegenerations', ' fridaysforfuture'),
#  ('forourfuturegenerations', ' yyj'),
#  ('forourfuturegenerations', ' climatestrike'),
#  (' fridaysforfuture', ' yyj'),
#  (' fridaysforfuture', ' climatestrike'),
#  (' yyj', ' climatestrike'),
#  ('fridaysforfuture', ' climatestrike'),
#  ('climatestrikeseattle', ' climatestrike'),
#  ('climatestrikeseattle', ' fridaysforfuture'),
#  (' climatestrike', ' fridaysforfuture'),
#  ('climatestrikes', ' schoolstrike4climate'),
#  ('climatestrikes', ' fridaysforfuture'),
#  (' schoolstrike4climate', ' fridaysforfuture'),
#  ('climatejustice', ' climatestrike'),
#  ('climatejustice', ' fridaysforfuture'),
#  ('climatejustice', ' climateaction'),
#  (' climatestrike', ' fridaysforfuture'),
#  (' climatestrike', ' climateaction'),
#  (' fridaysforfuture', ' climateaction'),
#  ('fridaysforfuture', ' strikeforclimate'),
#  ('fridaysforfuture', ' greennewdeal'),
#  ('fridaysforfuture', ' trumpresign'),
#  (' strikeforclimate', ' greennewdeal'),
#  (' strikeforclimate', ' trumpresign'),
#  (' greennewdeal', ' trumpresign'),
#  ('globalclimatestrike', ' youthclimatestrike'),
#  ('globalclimatestrike', ' climateaction'),
#  ('globalclimatestrike', ' fridaysforfuture'),
#  ('globalclimatestrike', ' cdnpoli'),
#  ('globalclimatestrike', ' greenaf'),
#  (' youthclimatestrike', ' climateaction'),
#  (' youthclimatestrike', ' fridaysforfuture'),
#  (' youthclimatestrike', ' cdnpoli'),
#  (' youthclimatestrike', ' greenaf'),
#  (' climateaction', ' fridaysforfuture'),
#  (' climateaction', ' cdnpoli'),
#  (' climateaction', ' greenaf'),
#  (' fridaysforfuture', ' cdnpoli'),
#  (' fridaysforfuture', ' greenaf'),
#  (' cdnpoli', ' greenaf'),
#  ('fridaysforfuture', ' globalclimatestrike'),
#  ('fridaysforfuture', ' globalclimatestrikes'),
#  (' globalclimatestrike', ' globalclimatestrikes'),
#  ('fridaysforfuture', ' klimakabinett'),
#  ('fridaysforfuture', ' groko'),
#  ('fridaysforfuture', ' notmyklimapaket'),
#  ('fridaysforfuture', ' allefürsklima'),
#  (' klimakabinett', ' groko'),
#  (' klimakabinett', ' notmyklimapaket'),
#  (' klimakabinett', ' allefürsklima'),
#  (' groko', ' notmyklimapaket'),
#  (' groko', ' allefürsklima'),
#  (' notmyklimapaket', ' allefürsklima'),
#  ('fridaysforfuture', ' fff'),
#  ('fridaysforfuture', ' marxismus'),
#  (' fff', ' marxismus'),
#  ('climatestrikenyc', ' fridaysforfuture'),
#  ('climatestrikenyc', ' globalclimatestrike'),
#  ('climatestrikenyc', ' climatejustice'),
#  (' fridaysforfuture', ' globalclimatestrike'),
#  (' fridaysforfuture', ' climatejustice'),
#  (' globalclimatestrike', ' climatejustice'),
#  ('globalclimatestrike', ' climatechange'),
#  ('globalclimatestrike', ' nyc'),
#  ('globalclimatestrike', ' cdmx'),
#  ('globalclimatestrike', ' climatestrike'),
#  ('globalclimatestrike', ' fridaysforfuture'),
#  (' climatechange', ' nyc'),
#  (' climatechange', ' cdmx'),
#  (' climatechange', ' climatestrike'),
#  (' climatechange', ' fridaysforfuture'),
#  (' nyc', ' cdmx'),
#  (' nyc', ' climatestrike'),
#  (' nyc', ' fridaysforfuture'),
#  (' cdmx', ' climatestrike'),
#  (' cdmx', ' fridaysforfuture'),
#  (' climatestrike', ' fridaysforfuture'),
#  ('klimapaket', ' pendlerpauschale'),
#  ('klimapaket', ' fridaysforfuture'),
#  ('klimapaket', ' allefürsklima'),
#  (' pendlerpauschale', ' fridaysforfuture'),
#  (' pendlerpauschale', ' allefürsklima'),
#  (' fridaysforfuture', ' allefürsklima'),
#  ('climatestrike', ' fridaysforfuture'),
#  ('climatestrike', ' fridaysforfuture'),
#  ('climatestrike', ' video'),
#  (' fridaysforfuture', ' video'),
#  ('climatestrike', ' fridaysforfuture'),
#  ('climatestrike', ' climateactionnow'),
#  (' fridaysforfuture', ' climateactionnow'),
#  ('climatestrike', ' fridaysforfuture'),
#  ('climatestrike', ' berladangbukankejahatan'),
#  ('climatestrike', ' area51storm'),
#  (' fridaysforfuture', ' berladangbukankejahatan'),
#  (' fridaysforfuture', ' area51storm'),
#  (' berladangbukankejahatan', ' area51storm'),
#  ('klimastreik', ' fridaysforfuture'),
#  ('klimastreik', ' allefuersklima'),
#  (' fridaysforfuture', ' allefuersklima'),
#  ('amazon', ' fridaysforfuture'),
#  ('amazon', ' sosbolivia'),
#  ('amazon', ' actfortheamazon'),
#  (' fridaysforfuture', ' sosbolivia'),
#  (' fridaysforfuture', ' actfortheamazon'),
#  (' sosbolivia', ' actfortheamazon'),
#  ('katowice', ' mlodziezowystrajkklimatyczny'),
#  ('katowice', ' fridaysforfuture'),
#  ('katowice', ' climatestrike'),
#  (' mlodziezowystrajkklimatyczny', ' fridaysforfuture'),
#  (' mlodziezowystrajkklimatyczny', ' climatestrike'),
#  (' fridaysforfuture', ' climatestrike'),
#  ('globalclimatestrike', ' climatestrike'),
#  ('globalclimatestrike', ' fridaysforfuture'),
#  ('globalclimatestrike', ' climateemergency'),
#  ('globalclimatestrike', ' fffdelhi'),
#  (' climatestrike', ' fridaysforfuture'),
#  (' climatestrike', ' climateemergency'),
#  (' climatestrike', ' fffdelhi'),
#  (' fridaysforfuture', ' climateemergency'),
#  (' fridaysforfuture', ' fffdelhi'),
#  (' climateemergency', ' fffdelhi'),
#  ('climatestrike', ' fridaysforfuture'),
#  ('climatestrike', ' climatejusticenow'),
#  (' fridaysforfuture', ' climatejusticenow'),
#  ('klimastreik', ' f4f'),
#  ('klimastreik', ' fridaysforfuture'),
#  ('klimastreik', ' allefuersklima'),
#  (' f4f', ' fridaysforfuture'),
#  (' f4f', ' allefuersklima'),
#  (' fridaysforfuture', ' allefuersklima'),
#  ('zdf', ' fridaysforfuture'),
#  ('fridaysforfuture', ' climatestrike'),
#  ('huelgaclimáticaglobal', ' fridaysforfuture'),
#  ('cdmx', ' fridaysforfuture'),
#  ('area51storm', ' stormingarea51'),
#  ('area51storm', ' 6ix9ine'),
#  ('area51storm', ' fridaysforfuture'),
#  (' stormingarea51', ' 6ix9ine'),
#  (' stormingarea51', ' fridaysforfuture'),
#  (' 6ix9ine', ' fridaysforfuture'),
#  ('fridaysforfuture', ' wachstumszwang'),
#  ('fridaysforfuture', ' wachstumswahn'),
#  ('fridaysforfuture', ' klimapaket'),
#  ('fridaysforfuture', ' fridaysforfuture'),
#  ('fridaysforfuture', ' klimastreik'),
#  (' wachstumszwang', ' wachstumswahn'),
#  (' wachstumszwang', ' klimapaket'),
#  (' wachstumszwang', ' fridaysforfuture'),
#  (' wachstumszwang', ' klimastreik'),
#  (' wachstumswahn', ' klimapaket'),
#  (' wachstumswahn', ' fridaysforfuture'),
#  (' wachstumswahn', ' klimastreik'),
#  (' klimapaket', ' fridaysforfuture'),
#  (' klimapaket', ' klimastreik'),
#  (' fridaysforfuture', ' klimastreik'),
#  ('fridaysforfuture', ' klimastreik'),
#  ('fridaysforfuture', ' allefuersklima'),
#  (' klimastreik', ' allefuersklima'),
#  ('climatestrike', ' fridaysforfuture'),
#  ('fridaysforfuture', ' climatestrike'),
#  ('fridaysforfuture', ' climatestrike'),
#  ('fridaysforfuture', ' qroorgullodemx'),
#  ('klimastreik', ' münchen'),
#  ('klimastreik', ' climatestrike'),
#  ('klimastreik', ' werbietetmehr'),
#  (' münchen', ' climatestrike'),
#  (' münchen', ' werbietetmehr'),
#  (' climatestrike', ' werbietetmehr'),
#  ('fridaysforfuture', ' globalclimatestrike'),
#  ('climatestrike', ' amznclimate'),
#  ('climatestrike', ' fridaysforfuture'),
#  (' amznclimate', ' fridaysforfuture'),
#  ('climatestrikedc', ' climatestrike'),
#  ('climatestrikedc', ' fridaysforfuture'),
#  (' climatestrike', ' fridaysforfuture'),
#  ('climateaction', ' climatestrikes'),
#  ('climateaction', ' climateactionnow'),
#  ('climateaction', ' climatestrikesf'),
#  ('climateaction', ' climatestrikenyc'),
#  ('climateaction', ' climatejustice'),
#  ('climateaction', ' fridaysforfuture'),
#  (' climatestrikes', ' climateactionnow'),
#  (' climatestrikes', ' climatestrikesf'),
#  (' climatestrikes', ' climatestrikenyc'),
#  (' climatestrikes', ' climatejustice'),
#  (' climatestrikes', ' fridaysforfuture'),
#  (' climateactionnow', ' climatestrikesf'),
#  (' climateactionnow', ' climatestrikenyc'),
#  (' climateactionnow', ' climatejustice'),
#  (' climateactionnow', ' fridaysforfuture'),
#  (' climatestrikesf', ' climatestrikenyc'),
#  (' climatestrikesf', ' climatejustice'),
#  (' climatestrikesf', ' fridaysforfuture'),
#  (' climatestrikenyc', ' climatejustice'),
#  (' climatestrikenyc', ' fridaysforfuture'),
#  (' climatejustice', ' fridaysforfuture'),
#  ('globalclimatestrike', ' climatestrike'),
#  ('globalclimatestrike', ' grevepeloclima'),
#  ('globalclimatestrike', ' greveglobalpeloclima'),
#  ('globalclimatestrike', ' climatechange'),
#  ('globalclimatestrike', ' meioambiente'),
#  ('globalclimatestrike', ' fightforamazonia'),
#  ('globalclimatestrike', ' actforamazonia'),
#  ('globalclimatestrike', ' fridaysforfuture'),
#  (' climatestrike', ' grevepeloclima'),
#  (' climatestrike', ' greveglobalpeloclima'),
#  (' climatestrike', ' climatechange'),
#  (' climatestrike', ' meioambiente'),
#  (' climatestrike', ' fightforamazonia'),
#  (' climatestrike', ' actforamazonia'),
#  (' climatestrike', ' fridaysforfuture'),
#  (' grevepeloclima', ' greveglobalpeloclima'),
#  (' grevepeloclima', ' climatechange'),
#  (' grevepeloclima', ' meioambiente'),
#  (' grevepeloclima', ' fightforamazonia'),
#  (' grevepeloclima', ' actforamazonia'),
#  (' grevepeloclima', ' fridaysforfuture'),
#  (' greveglobalpeloclima', ' climatechange'),
#  (' greveglobalpeloclima', ' meioambiente'),
#  (' greveglobalpeloclima', ' fightforamazonia'),
#  (' greveglobalpeloclima', ' actforamazonia'),
#  (' greveglobalpeloclima', ' fridaysforfuture'),
#  (' climatechange', ' meioambiente'),
#  (' climatechange', ' fightforamazonia'),
#  (' climatechange', ' actforamazonia'),
#  (' climatechange', ' fridaysforfuture'),
#  (' meioambiente', ' fightforamazonia'),
#  (' meioambiente', ' actforamazonia'),
#  (' meioambiente', ' fridaysforfuture'),
#  (' fightforamazonia', ' actforamazonia'),
#  (' fightforamazonia', ' fridaysforfuture'),
#  (' actforamazonia', ' fridaysforfuture'),
#  ('último', ' fridaysforfuture'),
#  ('último', ' bolivia'),
#  ('último', ' anf'),
#  (' fridaysforfuture', ' bolivia'),
#  (' fridaysforfuture', ' anf'),
#  (' bolivia', ' anf'),
#  ('climatestrike', ' fridaysforfuture'),
#  ('climatestrike', ' emergenciaclimatica'),
#  (' fridaysforfuture', ' emergenciaclimatica'),
#  ('ahoraesnoticia', ' perúemergenciaclimática'),
#  ('ahoraesnoticia', ' fridaysforfuture'),
#  ('ahoraesnoticia', ' climatestrike'),
#  ('ahoraesnoticia', ' viernesporelfuturo'),
#  ('ahoraesnoticia', ' cambioclimático'),
#  (' perúemergenciaclimática', ' fridaysforfuture'),
#  (' perúemergenciaclimática', ' climatestrike'),
#  (' perúemergenciaclimática', ' viernesporelfuturo'),
#  (' perúemergenciaclimática', ' cambioclimático'),
#  (' fridaysforfuture', ' climatestrike'),
#  (' fridaysforfuture', ' viernesporelfuturo'),
#  (' fridaysforfuture', ' cambioclimático'),
#  (' climatestrike', ' viernesporelfuturo'),
#  (' climatestrike', ' cambioclimático'),
#  (' viernesporelfuturo', ' cambioclimático'),
#  ('fridaysforfuture', ' climateaction'),
#  ('fridaysforfuture', ' onealbuquerque'),
#  ('fridaysforfuture', ' globalclimatestrike'),
#  (' climateaction', ' onealbuquerque'),
#  (' climateaction', ' globalclimatestrike'),
#  (' onealbuquerque', ' globalclimatestrike'),
#  ('globalclimatestrike', ' fridaysforfuture'),
#  ('globalclimatestrike', ' climateaction'),
#  ('globalclimatestrike', ' onealbuquerque'),
#  (' fridaysforfuture', ' climateaction'),
#  (' fridaysforfuture', ' onealbuquerque'),
#  (' climateaction', ' onealbuquerque'),
#  ('climatestrike', ' fridaysforfuture'),
#  ('climatestrike', ' strikewithus'),
#  (' fridaysforfuture', ' strikewithus'),
#  ('climatestrike', ' fridaysforfuture'),
#  ('fridaysforfuture', ' klimapaket'),
#  ('cediainforma', ' ahora'),
#  ('cediainforma', ' lima'),
#  ('cediainforma', ' fridaysforfuture'),
#  ('cediainforma', ' climatestrike'),
#  ('cediainforma', ' climatehope'),
#  (' ahora', ' lima'),
#  (' ahora', ' fridaysforfuture'),
#  (' ahora', ' climatestrike'),
#  (' ahora', ' climatehope'),
#  (' lima', ' fridaysforfuture'),
#  (' lima', ' climatestrike'),
#  (' lima', ' climatehope'),
#  (' fridaysforfuture', ' climatestrike'),
#  (' fridaysforfuture', ' climatehope'),
#  (' climatestrike', ' climatehope'),
#  ('chile', ' fridaysforfuture'),
#  ('chile', ' osorno'),
#  (' fridaysforfuture', ' osorno'),
#  ('nyc', ' batterypark'),
#  ('nyc', ' climatestrike'),
#  ('nyc', ' united4climatejustice'),
#  ('nyc', ' fridaysforfuture'),
#  (' batterypark', ' climatestrike'),
#  (' batterypark', ' united4climatejustice'),
#  (' batterypark', ' fridaysforfuture'),
#  (' climatestrike', ' united4climatejustice'),
#  (' climatestrike', ' fridaysforfuture'),
#  (' united4climatejustice', ' fridaysforfuture'),
#  ('marchaporelclima', ' fridaysforfuture'),
#  ('marchaporelclima', ' climatestrike'),
#  (' fridaysforfuture', ' climatestrike'),
#  ('fridayvibes', ' fridaythoughts'),
#  ('fridayvibes', ' fridaysforfuture'),
#  (' fridaythoughts', ' fridaysforfuture'),
#  ('climatestrike', ' fridaysforfuture'),
#  ('freitags_kindern', ' doppelmoral'),
#  ('freitags_kindern', ' fridaysforfuture'),
#  (' doppelmoral', ' fridaysforfuture'),
#  ('climatestrike', ' fridaysforfuture'),
#  ('huelgamundialporelclima', ' fridaysforfuture'),
#  ('huelgamundialporelclima', ' zócalo'),
#  ('huelgamundialporelclima', ' notimex'),
#  (' fridaysforfuture', ' zócalo'),
#  (' fridaysforfuture', ' notimex'),
#  (' zócalo', ' notimex'),
#  ('climatestrike', ' huelgaclimáticaglobal'),
#  ('climatestrike', ' fridaysforfuture'),
#  (' huelgaclimáticaglobal', ' fridaysforfuture'),
#  ('werteunion', ' afd'),
#  ('werteunion', ' lehrerdenunzianten'),
#  ('werteunion', ' klimawandel'),
#  ('werteunion', ' fridaysforfuture'),
#  (' afd', ' lehrerdenunzianten'),
#  (' afd', ' klimawandel'),
#  (' afd', ' fridaysforfuture'),
#  (' lehrerdenunzianten', ' klimawandel'),
#  (' lehrerdenunzianten', ' fridaysforfuture'),
#  (' klimawandel', ' fridaysforfuture'),
#  ('climatestrike', ' cleanbc'),
#  ('climatestrike', ' fridaysforfuture'),
#  (' cleanbc', ' fridaysforfuture'),
#  ('entérate', ' fridaysforfuture'),
#  ('fridaysforfuture', ' climatestrike'),
#  ('fridaysforfuture', ' climateaction'),
#  ('fridaysforfuture', ' puertooctaysinagua'),
#  (' climatestrike', ' climateaction'),
#  (' climatestrike', ' puertooctaysinagua'),
#  (' climateaction', ' puertooctaysinagua'),
#  ('fridaysforfuture', ' emergenciaclimatica'),
#  ('delhi', ' globalstrike'),
#  ('delhi', ' climatecrisis'),
#  (' globalstrike', ' climatecrisis'),
#  ('fridaysforfuture', ' allesfuersklima'),
#  ('klimaatstaking', ' fridaysforfuture'),
#  ('trees', ' keepitwild'),
#  ('trees', ' climateaction'),
#  ('trees', ' fridaysforfuture'),
#  ('trees', ' climatestrike'),
#  (' keepitwild', ' climateaction'),
#  (' keepitwild', ' fridaysforfuture'),
#  (' keepitwild', ' climatestrike'),
#  (' climateaction', ' fridaysforfuture'),
#  (' climateaction', ' climatestrike'),
#  (' fridaysforfuture', ' climatestrike'),
#  ('climatestrike', ' fridaysforfuture'),
#  ('climatestrike', ' climatestrikenyc'),
#  (' fridaysforfuture', ' climatestrikenyc'),
#  ('fridaysforfuture', ' climatestrike'),
#  ('fridaysforfuture', ' climatestrike'),
#  ('fridaysforfuture', ' greveglobalpeloclima'),
#  (' climatestrike', ' greveglobalpeloclima'),
#  ('thread', ' fridaysforfuture'),
#  ('thread', ' climatestrike'),
#  ('thread', ' greveglobalpeloclima'),
#  (' fridaysforfuture', ' climatestrike'),
#  (' fridaysforfuture', ' greveglobalpeloclima'),
#  (' climatestrike', ' greveglobalpeloclima'),
#  ('fridaysforfuture', ' globalclimatestrike'),
#  ('climatestrike', ' fridaysforfuture'),
#  ('fridaysforfuture', ' allefürsklima'),
#  ('klimapaket', ' fridaysforfuture'),
#  ('klimapaket', ' notmyklimapaket'),
#  (' fridaysforfuture', ' notmyklimapaket'),
#  ('fridaysforfuture', ' strike4climate'),
#  ('fridaysforfuture', ' climatestrike'),
#  ('fridaysforfuture', ' climateaction'),
#  (' strike4climate', ' climatestrike'),
#  (' strike4climate', ' climateaction'),
#  (' climatestrike', ' climateaction'),
#  ('klimastreik', ' klimawandel'),
#  ('klimastreik', ' fridaysforfuture'),
#  (' klimawandel', ' fridaysforfuture'),
#  ('climatestrike', ' fridaysforfuture'),
#  ('climatestrike', ' actnow'),
#  (' fridaysforfuture', ' actnow'),
#  ('allefürsklima', ' fridaysforfuture'),
#  ('bostonclimatestrike', ' climatestrike'),
#  ('bostonclimatestrike', ' fridaysforfuture'),
#  (' climatestrike', ' fridaysforfuture'),
#  ('globalclimatestrike', ' fridaysforfuture'),
#  ('globalclimatestrike', ' climatejustice'),
#  ('globalclimatestrike', ' strike4climate'),
#  (' fridaysforfuture', ' climatejustice'),
#  (' fridaysforfuture', ' strike4climate'),
#  ...]

# %%
time_tags
# Out:
# [23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
# ...
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  23503   2019-09-20
#  23161   2019-09-20
#  23162   2019-09-20
#  23163   2019-09-20
#  23164   2019-09-20
#             ...
#  4       2022-07-10
#  3       2022-07-10
#  2       2022-07-10
#  1       2022-07-10
#  0       2022-07-10
#  Name: date, Length: 23504, dtype: datetime64[ns],
#  ...]

# %%
new_df = pd.DataFrame({"Title": df["tweet"], "Month": time_tags })
new_df.to_csv("../4 - DynamicCommunityDiscovery/tweet_with_time.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-58-c6d8d98356da> in <module>
# ----> 1 new_df = pd.DataFrame({"Title": df["tweet"], "Month": time_tags })
#       2 new_df.to_csv("../4 - DynamicCommunityDiscovery/tweet_with_time.csv", index=False)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     527
#     528         elif isinstance(data, dict):
# --> 529             mgr = init_dict(data, index, columns, dtype=dtype)
#     530         elif isinstance(data, ma.MaskedArray):
#     531             import numpy.ma.mrecords as mrecords
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     285             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     286         ]
# --> 287     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     288
#     289
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype, verify_integrity)
#      78         # figure out the index, if necessary
#      79         if index is None:
# ---> 80             index = extract_index(arrays)
#      81         else:
#      82             index = ensure_index(index)
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in extract_index(data)
#     413                         f"length {len(index)}"
#     414                     )
# --> 415                     raise ValueError(msg)
#     416             else:
#     417                 index = ibase.default_index(lengths[0])
#
# ValueError: array length 406585 does not match index length 23504

# %%
source = []
target = []
for i in couple_tags:
    source.append(i[0])
    target.append(i[1])

# %%
month = []
for i in time_tags:
    month.append(months)

# %%
len(month)
# Out:
# 81317

# %%
new_df = pd.DataFrame({"Id": tags, "Ok": time_tags, "Month": month})
new_df.to_csv("../4 - DynamicCommunityDiscovery/tags_with_time.csv", index=False)

# %%
dd = pd.read_csv("../4 - DynamicCommunityDiscovery/tags_with_time.csv")

# %%
dd
# Out:
#                       Id                                                 Ok  \
# 0            klimastreik  23503    9\n23161    9\n23162    9\n23163    9...
# 1       fridaysforfuture  23503    9\n23161    9\n23162    9\n23163    9...
# 2         allefuersklima  23503    9\n23161    9\n23162    9\n23163    9...
# 3          allefürsklima  23503    9\n23161    9\n23162    9\n23163    9...
# 4                 le2009  23503    9\n23161    9\n23162    9\n23163    9...
# ...                  ...                                                ...
# 81312             carbon  23503    9\n23161    9\n23162    9\n23163    9...
# 81313          demvoice1  23503    9\n23161    9\n23162    9\n23163    9...
# 81314               sdgs  23503    9\n23161    9\n23162    9\n23163    9...
# 81315      climatecrisis  23503    9\n23161    9\n23162    9\n23163    9...
# 81316   fridaysforfuture  23503    9\n23161    9\n23162    9\n23163    9...
#
#        Month
# 0          7
# 1          7
# 2          7
# 3          7
# 4          7
# ...      ...
# 81312      7
# 81313      7
# 81314      7
# 81315      7
# 81316      7
#
# [81317 rows x 3 columns]

# %%
dd['Month'].value_counts()
# Out:
# 7    81317
# Name: Month, dtype: int64

# %%
df['Month'].value_counts()
# Out:
# 9     5182
# 10    2450
# 11    2196
# 3     2006
# 1     1924
# 12    1827
# 2     1599
# 4     1461
# 5     1457
# 6     1259
# 7     1238
# 8      905
# Name: Month, dtype: int64

# %%
tags_dict = {}
for i in range(len(df)):
    ll = df["clean_tags"][i].split(",")
    for tg in ll:
        tgs=tg.lstrip()
        if tgs not in tags_dict:
            tags_dict[tgs] = [df["tweet"][i]]
        else:
            tags_dict[tgs].append(df["tweet"][i])

# %%
tags = list(tags_dict.keys())
#crea una lista costituita da coppie di tags
couple_tags = []
for i in range(len(tags)):
    for j in tags[i+1:]:
        couple_tags.append((tags[i], j))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-f18780e0c4ec> in <module>
#       4 for i in range(len(tags)):
#       5     for j in tags[i+1:]:
# ----> 6         couple_tags.append((tags[i], j))
#
# KeyboardInterrupt:

# %%
source = []
target = []
count = []
nodes = []
month = []
for i in couple_tags:
    ll = list(set(tags_dict[i[0]]) & set(tags_dict[i[1]]))
    if len(ll)>0:
        source.append(i[0])
        target.append(i[1])
        count.append(len(ll))
        nodes.append(i[0])
        nodes.append(i[1])
        month.append(months)

# %%
mesi = list(set(str(month)))

# %%
len(mesi)

# %%
new_df

# %%
source = []
target = []
count = []
nodes = []
for i in couple_tags:
    ll = list(set(tags_dict[i[0]]) & set(tags_dict[i[1]]))
    if len(ll)>0:
        source.append(i[0])
        target.append(i[1])
        count.append(len(ll))
        nodes.append(i[0])
        nodes.append(i[1])

# %%
len(count)

# %%
len(month)

# %%
len(year)

# %%
len(nodes)

# %%
new_df = pd.DataFrame({"Title": df["Title"], "Timeval": new_date, "Month": month})
new_df.to_csv("../Dataset FFF/tweet_with_time.csv", index=False)

# %%
source = []
target = []
for i in couple_tags:
    source.append(i[0])
    target.append(i[1])

# %%
month = []
for i in time_tags:
    month.append(i[5:7])

# %%
new_df = pd.DataFrame({"Id": tags, "Timeval": time_tags, "Month": month})
new_df.to_csv("../Dataset FFF/hashtags_with_time.csv", index=False)

# %%
month = []
for i in time_couple:
    month.append(i[5:7])

# %%
new_df = pd.DataFrame({"Source": source,
                       "Target": target,
                      "Timeval": time_couple, "Month": month})
new_df.to_csv("../Dataset FFF/hashtags_edges_with_time.csv", index=False)
