# %%
import pandas as pd
import time as _time
import datetime
import numpy as np

# %%
path = "../Dataset FFF/fff.csv"

# %%
df = pd.read_csv(path)
df.columns
# Out:
# Index(['clean_tags', 'hashtags', 'date', 'user_id', 'username', 'name',
#        'tweet', 'language', 'mentions', 'replies_count', 'retweets_count',
#        'likes_count', 'link', 'retweet', 'reply_to'],
#       dtype='object')

# %%
df = df.sort_values(by=['date'])

# %%
df
# Out:
#                                               clean_tags  \
# 23503  klimastreik, fridaysforfuture, allefuersklima,...
# 23161  climatestrike, youthclimatestrike, fridaysforf...
# 23162   climatestrikedc, climatestrike, fridaysforfuture
# 23163  fridaysforfuture, 20septiembre, climatecrisis,...
# 23164           uganda, fridaysforfuture, climatestrikes
# ...                                                  ...
# 4                  klimakrise, govegan, fridaysforfuture
# 3                                        fridayforfuture
# 2                                       fridaysforfuture
# 1                                       fridaysforfuture
# 0      fossilfuels, wind, solar, green, hydrogen, ene...
#
#                                                 hashtags        date  \
# 23503  ['klimastreik', 'fridaysforfuture', 'allefuers...  2019-09-20
# 23161  ['climatestrike', 'youthclimatestrike', 'frida...  2019-09-20
# 23162  ['climatestrikedc', 'climatestrike', 'fridaysf...  2019-09-20
# ...

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df['Year'] = df['date'].dt.year 
df['Month'] = df['date'].dt.month 
df['Day'] = df['date'].dt.day

# %%
df
# Out:
#                                               clean_tags  \
# 23503  klimastreik, fridaysforfuture, allefuersklima,...
# 23161  climatestrike, youthclimatestrike, fridaysforf...
# 23162   climatestrikedc, climatestrike, fridaysforfuture
# 23163  fridaysforfuture, 20septiembre, climatecrisis,...
# 23164           uganda, fridaysforfuture, climatestrikes
# ...                                                  ...
# 4                  klimakrise, govegan, fridaysforfuture
# 3                                        fridayforfuture
# 2                                       fridaysforfuture
# 1                                       fridaysforfuture
# 0      fossilfuels, wind, solar, green, hydrogen, ene...
#
#                                                 hashtags       date  \
# 23503  ['klimastreik', 'fridaysforfuture', 'allefuers... 2019-09-20
# 23161  ['climatestrike', 'youthclimatestrike', 'frida... 2019-09-20
# 23162  ['climatestrikedc', 'climatestrike', 'fridaysf... 2019-09-20
# ...

# %%
df.insert(3, 'Year', df.pop('Year'))

# %%
df.insert(4, 'Month', df.pop('Month'))

# %%
df.insert(5, 'Day', df.pop('Day'))

# %%
df
# Out:
#                                               clean_tags  \
# 23503  klimastreik, fridaysforfuture, allefuersklima,...
# 23161  climatestrike, youthclimatestrike, fridaysforf...
# 23162   climatestrikedc, climatestrike, fridaysforfuture
# 23163  fridaysforfuture, 20septiembre, climatecrisis,...
# 23164           uganda, fridaysforfuture, climatestrikes
# ...                                                  ...
# 4                  klimakrise, govegan, fridaysforfuture
# 3                                        fridayforfuture
# 2                                       fridaysforfuture
# 1                                       fridaysforfuture
# 0      fossilfuels, wind, solar, green, hydrogen, ene...
#
#                                                 hashtags       date  Year  \
# 23503  ['klimastreik', 'fridaysforfuture', 'allefuers... 2019-09-20  2019
# 23161  ['climatestrike', 'youthclimatestrike', 'frida... 2019-09-20  2019
# ...

# %%
len(df['date'])
# Out:
# 23504

# %% [markdown]
# for i in df.values:
#     tagsss = i[0].split(",")
#     for t in range(len(tagsss)):
#         tags.append(tagsss[t])
#         for d in df.values:
#             time = i[2]
#             for d in range(len(str(time))):
#                 time_tags.append(time[d])
#                 for j in tagsss[t+1:]:
#                     couple_tags.append((tagsss[t], j))
#                     time_couple.append(time[d])

# %% [markdown]
# for i in df.values:
#     tagsss = i[0].split(",")
#     for t in range(len(tagsss)):
#         tags.append(tagsss[t])
#         data = i[2]
#         for d in range(len(str(data))):
#             time_tags.append(i[2])
#             for j in tagsss[t+1:]:
#                 couple_tags.append((tagsss[t], j))
#                 for f in data[d+1:]:
#                     time_couple.append((data[d], f))

# %% [markdown]
# tags

# %% [markdown]
# for i in df.values:
#     data = i[2]
#     for d in range(len(str((data))):
#         data.append(data[d])

# %% [markdown]
# for i in df.values:
#     tagsss = i[0].split(",")
#     for t in range(len(tagsss)):
#         tags.append(tagsss[t])

# %%
tags = []
time_tags = []

# %%
couple_tags = []
time_couple = []

# %%
for i in df.values:
    tagsss = i[0].split("|-|")[:-1]
    for t in range(len(tagsss)):
        tags.append(tagsss[t])
        time_tags.append(datetime.utcfromtimestamp(i[8]).strftime('%Y-%m-%d %H:%M:%S'))
        for j in tagsss[t+1:]:
            couple_tags.append((tagsss[t], j))  
            time_couple.append(datetime.utcfromtimestamp(i[8]).strftime('%Y-%m-%d %H:%M:%S'))

# %%
for i in df.values:
    tagsss = i[0].split(",")
    for t in range(len(tagsss)):
        tags.append(tagsss[t])
        time_tags.append(i[2])
        for j in tagsss[t+1:]:
            couple_tags.append((tagsss[t], j))  
            time_couple.append(i[2])

# %%
new_date = []
month = []
for i in df["date"]:
    new_date.append(i)
    for j in df['Month']:
        month.append(j)
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "C:\Users\naomi\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3437, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-19-0648c934574e>", line 6, in <module>
#     month.append(j)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\naomi\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2061, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\naomi\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
# ...

# %%
new_df = pd.DataFrame({"Title": df["tweet"], "Date": df['date']})
new_df.to_csv("../Dataset fff/tweet_with_time.csv", index=False)

# %%
source = []
target = []
for i in couple_tags:
    source.append(i[0])
    target.append(i[1])

# %%
new_df = pd.DataFrame({"Id": tags, "Timeval": time_tags, "Month": df['date']})
new_df.to_csv("../Dataset fff/tags_with_time.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-48df3993fffc> in <module>
# ----> 1 new_df = pd.DataFrame({"Id": tags, "Timeval": time_tags, "Month": df['date']})
#       2 new_df.to_csv("../Dataset fff/tags_with_time.csv", index=False)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     527
#     528         elif isinstance(data, dict):
# --> 529             mgr = init_dict(data, index, columns, dtype=dtype)
#     530         elif isinstance(data, ma.MaskedArray):
#     531             import numpy.ma.mrecords as mrecords
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     285             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     286         ]
# ...

# %%
month = []
for i in time_tags:
    month.append(months)

# %%
len(month)
# Out:
# 81317

# %%
new_df = pd.DataFrame({"Id": tags, "Ok": time_tags, "Month": month})
new_df.to_csv("../4 - DynamicCommunityDiscovery/tags_with_time.csv", index=False)

# %%
dd = pd.read_csv("../4 - DynamicCommunityDiscovery/tags_with_time.csv")

# %%
dd
# Out:
#                       Id                                                 Ok  \
# 0            klimastreik  23503    9\n23161    9\n23162    9\n23163    9...
# 1       fridaysforfuture  23503    9\n23161    9\n23162    9\n23163    9...
# 2         allefuersklima  23503    9\n23161    9\n23162    9\n23163    9...
# 3          allefürsklima  23503    9\n23161    9\n23162    9\n23163    9...
# 4                 le2009  23503    9\n23161    9\n23162    9\n23163    9...
# ...                  ...                                                ...
# 81312             carbon  23503    9\n23161    9\n23162    9\n23163    9...
# 81313          demvoice1  23503    9\n23161    9\n23162    9\n23163    9...
# 81314               sdgs  23503    9\n23161    9\n23162    9\n23163    9...
# 81315      climatecrisis  23503    9\n23161    9\n23162    9\n23163    9...
# 81316   fridaysforfuture  23503    9\n23161    9\n23162    9\n23163    9...
#
#        Month
# 0          7
# 1          7
# ...

# %%
dd['Month'].value_counts()
# Out:
# 7    81317
# Name: Month, dtype: int64

# %%
df['Month'].value_counts()
# Out:
# 9     5182
# 10    2450
# 11    2196
# 3     2006
# 1     1924
# 12    1827
# 2     1599
# 4     1461
# 5     1457
# 6     1259
# 7     1238
# 8      905
# Name: Month, dtype: int64

# %%
tags_dict = {}
for i in range(len(df)):
    ll = df["clean_tags"][i].split(",")
    for tg in ll:
        tgs=tg.lstrip()
        if tgs not in tags_dict:
            tags_dict[tgs] = [df["tweet"][i]]
        else:
            tags_dict[tgs].append(df["tweet"][i])

# %%
tags = list(tags_dict.keys())
#crea una lista costituita da coppie di tags
couple_tags = []
for i in range(len(tags)):
    for j in tags[i+1:]:
        couple_tags.append((tags[i], j))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-f18780e0c4ec> in <module>
#       4 for i in range(len(tags)):
#       5     for j in tags[i+1:]:
# ----> 6         couple_tags.append((tags[i], j))
#
# KeyboardInterrupt:

# %%
source = []
target = []
count = []
nodes = []
month = []
for i in couple_tags:
    ll = list(set(tags_dict[i[0]]) & set(tags_dict[i[1]]))
    if len(ll)>0:
        source.append(i[0])
        target.append(i[1])
        count.append(len(ll))
        nodes.append(i[0])
        nodes.append(i[1])
        month.append(months)

# %%
mesi = list(set(str(month)))

# %%
len(mesi)

# %%
new_df

# %%
source = []
target = []
count = []
nodes = []
for i in couple_tags:
    ll = list(set(tags_dict[i[0]]) & set(tags_dict[i[1]]))
    if len(ll)>0:
        source.append(i[0])
        target.append(i[1])
        count.append(len(ll))
        nodes.append(i[0])
        nodes.append(i[1])

# %%
len(count)

# %%
len(month)

# %%
len(year)

# %%
len(nodes)

# %%
new_df = pd.DataFrame({"Title": df["Title"], "Timeval": new_date, "Month": month})
new_df.to_csv("../Dataset FFF/tweet_with_time.csv", index=False)

# %%
source = []
target = []
for i in couple_tags:
    source.append(i[0])
    target.append(i[1])

# %%
month = []
for i in time_tags:
    month.append(i[5:7])

# %%
new_df = pd.DataFrame({"Id": tags, "Timeval": time_tags, "Month": month})
new_df.to_csv("../Dataset FFF/hashtags_with_time.csv", index=False)

# %%
month = []
for i in time_couple:
    month.append(i[5:7])

# %%
new_df = pd.DataFrame({"Source": source,
                       "Target": target,
                      "Timeval": time_couple, "Month": month})
new_df.to_csv("../Dataset FFF/hashtags_edges_with_time.csv", index=False)
