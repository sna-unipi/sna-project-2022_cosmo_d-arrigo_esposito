# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
path_tags= "../Dataset FFF/tags_with_time.csv"

# %%
path_couple= "../Dataset FFF/edges_date.csv"

# %%
path_tweet = "../Dataset FFF/tweet_with_time.csv"

# %%
df_tags = pd.read_csv(path_tags)

# %%
df_couple = pd.read_csv(path_couple)

# %%
df_tweet = pd.read_csv(path_tweet)

# %%
df_tweet["Id"] = [1 for i in range(len(df_tweet))]

# %%
df_tweet
# Out:
#                                                   tweet     Timeval  Month  Id
# 0     #FridaysForFuture we wish u a happy new year 2...  2021-01-01      1   1
# 1     #ClimateStrike week 100!   Happy #NewYear! Tod...  2021-01-01      1   1
# 2     Frohes neues Jahr und danke an das Internet da...  2021-01-01      1   1
# 3     Das kommt dafon, wenn man das #Deutschunterric...  2021-01-01      1   1
# 4     #ClimateStrikeOnline #DigitalStrike for #Frida...  2021-01-01      1   1
# ...                                                 ...         ...    ...  ..
# 5905  We wish everyone a safe, happy and healthy new...  2021-12-31     12   1
# 5906  Week 1 #ClimateStrike in #Philippines  We Dema...  2021-12-31     12   1
# 5907  Global warming could lead to an increase in pe...  2021-12-31     12   1
# 5908  Week 159 Final climate strike of 2021. Happy H...  2021-12-31     12   1
# 5909  No time left for blah blah What I stand for is...  2021-12-31     12   1
#
# [5910 rows x 4 columns]

# %%
plt.plot([i for i in range(1, 13)], list(df_tweet.groupby(['Month']).sum()["Id"]) , color='blue', marker='o')
plt.title('Tweet per Month', fontsize=14)
plt.xlabel('Month', fontsize=14)
plt.xticks(np.arange(13),["", "January", "February", "March", "April", "May", "June", "July", "August", "September", "October", "November", "December"], rotation=50)
plt.ylabel('Number of tweet', fontsize=14)
plt.grid(True)
plt.show()

# %%
list(df_tweet.groupby(['Month']).sum()["Id"])
# Out:
# [406, 393, 553, 448, 486, 414, 508, 408, 988, 582, 424, 300]

# %%
df_tags["Val"] = [1 for i in range(len(df_tags))]
df_tags
# Out:
#                       tags  Month  Val
# 0         fridaysforfuture      1    1
# 1            climatestrike      1    1
# 2         climateemergency      1    1
# 3      climatestrikeonline      1    1
# 4            climatestrike      1    1
# ...                    ...    ...  ...
# 20909     climateactionnow     12    1
# 20910         schoolstrike     12    1
# 20911     fridaysforfuture     12    1
# 20912      uprootthesystem     12    1
# 20913     fridaysforfuture     12    1
#
# [20914 rows x 3 columns]

# %%
plt.figure(figsize=(15,7))
plt.plot(list(df_tags[df_tags["tags"]=="fridaysforfuture"].groupby(['Month']).sum()["Val"]) , color='blue')
plt.plot(list(df_tags[df_tags["tags"]=="climatecrisis"].groupby(['Month']).sum()["Val"]) , color='orange')
plt.plot(list(df_tags[df_tags["tags"]=="climatechange"].groupby(['Month']).sum()["Val"]) , color='green')
plt.plot(list(df_tags[df_tags["tags"]=="uprootthesystem"].groupby(['Month']).sum()["Val"]) , color='yellow')
plt.plot(list(df_tags[df_tags["tags"]=="globalwarming"].groupby(['Month']).sum()["Val"]) , color='red')
plt.plot(list(df_tags[df_tags["tags"]=="youngpeopleforclimateaction"].groupby(['Month']).sum()["Val"]) , color='violet')
plt.plot(list(df_tags[df_tags["tags"]=="fridays4futureonline"].groupby(['Month']).sum()["Val"]) , color='black')
plt.plot(list(df_tags[df_tags["tags"]=="facetheclimateemergency"].groupby(['Month']).sum()["Val"]) , color='gray')
plt.legend(["fridaysforfuture", "climatecrisis", "climatechange","uprootthesystem", "globalwarming", "youngpeopleforclimateaction", "fridays4futureonline", "facetheclimateemergency"])
plt.title('FridaysForFuture', fontsize=14)
plt.xlabel('Month', fontsize=14)
plt.xticks(np.arange(12),["January", "February", "March", "April", "May", "June", "July", "August", "September", "October", "November", "December"], rotation=50)
plt.ylabel('Val', fontsize=14)
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(15,7))
plt.plot(list(df_tags[df_tags["tags"]=="klimastreik"].groupby(['Month']).sum()["Val"]) , color='blue')
plt.plot(list(df_tags[df_tags["tags"]=="klimaschutz"].groupby(['Month']).sum()["Val"]) , color='orange')
plt.plot(list(df_tags[df_tags["tags"]=="berlin"].groupby(['Month']).sum()["Val"]) , color='green')
plt.plot(list(df_tags[df_tags["tags"]=="verkehrswende"].groupby(['Month']).sum()["Val"]) , color='red')
plt.plot(list(df_tags[df_tags["tags"]=="klimakrise"].groupby(['Month']).sum()["Val"]) , color='yellow')
plt.plot(list(df_tags[df_tags["tags"]=="windkraft"].groupby(['Month']).sum()["Val"]) , color='pink')
plt.plot(list(df_tags[df_tags["tags"]=="datteln4"].groupby(['Month']).sum()["Val"]) , color='violet')
plt.plot(list(df_tags[df_tags["tags"]=="allefürsklima"].groupby(['Month']).sum()["Val"]) , color='black')
plt.plot(list(df_tags[df_tags["tags"]=="neustartklima"].groupby(['Month']).sum()["Val"]) , color='gray')
plt.legend(["klimastreik", "klimaschutz", "berlin","verkehrswende","klimakrise", "windkraft", "datteln4", "allefürsklima", "neustartklima"])
plt.title('FFF Tedesco', fontsize=14)
plt.xlabel('Month', fontsize=14)
plt.xticks(np.arange(12),["January", "February", "March", "April", "May", "June", "July", "August", "September", "October", "November", "December"], rotation=50)
plt.ylabel('Val', fontsize=14)
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(15,7))
plt.plot(list(df_tags[df_tags["tags"]=="spd"].groupby(['Month']).sum()["Val"]) , color='blue')
plt.plot(list(df_tags[df_tags["tags"]=="merkel"].groupby(['Month']).sum()["Val"]) , color='orange')
plt.plot(list(df_tags[df_tags["tags"]=="groko"].groupby(['Month']).sum()["Val"]) , color='green')
plt.plot(list(df_tags[df_tags["tags"]=="grünen"].groupby(['Month']).sum()["Val"]) , color='red')
plt.plot(list(df_tags[df_tags["tags"]=="klimapolitik"].groupby(['Month']).sum()["Val"]) , color='yellow')
plt.plot(list(df_tags[df_tags["tags"]=="energiepolitik"].groupby(['Month']).sum()["Val"]) , color='pink')
plt.plot(list(df_tags[df_tags["tags"]=="afd"].groupby(['Month']).sum()["Val"]) , color='violet')
plt.plot(list(df_tags[df_tags["tags"]=="cdu"].groupby(['Month']).sum()["Val"]) , color='black')
plt.plot(list(df_tags[df_tags["tags"]=="rwe"].groupby(['Month']).sum()["Val"]) , color='brown')
plt.plot(list(df_tags[df_tags["tags"]=="bundestag"].groupby(['Month']).sum()["Val"]) , color='gray')
plt.plot(list(df_tags[df_tags["tags"]=="klimaschutzpolitik"].groupby(['Month']).sum()["Val"]) , color='teal')
plt.legend(["spd", "merkel", "groko","klimapolitik","energiepolitik", "afd", "cdu", "rwe", "bundestag","klimaschutzpolitik"])
plt.title('Politica Tedesca', fontsize=14)
plt.xlabel('Month', fontsize=14)
plt.xticks(np.arange(12),["January", "February", "March", "April", "May", "June", "July", "August", "September", "October", "November", "December"], rotation=50)
plt.ylabel('Val', fontsize=14)
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(15,7))
plt.plot(list(df_tags[df_tags["tags"]=="gas"].groupby(['Month']).sum()["Val"]) , color='blue')
plt.plot(list(df_tags[df_tags["tags"]=="fossilfuels"].groupby(['Month']).sum()["Val"]) , color='orange')
plt.plot(list(df_tags[df_tags["tags"]=="co2"].groupby(['Month']).sum()["Val"]) , color='red')
plt.plot(list(df_tags[df_tags["tags"]=="windkraft"].groupby(['Month']).sum()["Val"]) , color='yellow')

plt.legend(["gas", "fossilfuels", "co2","windkraft"])
plt.title('Fonti rinnovabili e non rinnovabili', fontsize=14)
plt.xlabel('Month', fontsize=14)
plt.xticks(np.arange(12),["January", "February", "March", "April", "May", "June", "July", "August", "September", "October", "November", "December"], rotation=50)
plt.ylabel('Val', fontsize=14)
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(15,7))
plt.plot(list(df_tags[df_tags["tags"]=="parisagreement"].groupby(['Month']).sum()["Val"]) , color='blue')
plt.plot(list(df_tags[df_tags["tags"]=="cop26"].groupby(['Month']).sum()["Val"]) , color='orange')
plt.plot(list(df_tags[df_tags["tags"]=="cop25"].groupby(['Month']).sum()["Val"]) , color='green')
plt.plot(list(df_tags[df_tags["tags"]=="ipcc"].groupby(['Month']).sum()["Val"]) , color='red')
plt.plot(list(df_tags[df_tags["tags"]=="greennewdeal"].groupby(['Month']).sum()["Val"]) , color='yellow')
plt.plot(list(df_tags[df_tags["tags"]=="greendeal"].groupby(['Month']).sum()["Val"]) , color='pink')
plt.legend(["parisagreement", "cop26", "cop25","ipcc","greennewdeal", "greendeal"])
plt.title('Convenzioni', fontsize=14)
plt.xlabel('Month', fontsize=14)
plt.xticks(np.arange(12),["January", "February", "March", "April", "May", "June", "July", "August", "September", "October", "November", "December"], rotation=50)
plt.ylabel('Val', fontsize=14)
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(15,7))
#plt.plot(list(df_tags[df_tags["tags"]=="dannibleibt"].groupby(['Month']).sum()["Val"]) , color='blue')
plt.plot(list(df_tags[df_tags["tags"]=="noafd"].groupby(['Month']).sum()["Val"]) , color='orange')
plt.plot(list(df_tags[df_tags["tags"]=="ampel"].groupby(['Month']).sum()["Val"]) , color='green')
plt.plot(list(df_tags[df_tags["tags"]=="endegelände"].groupby(['Month']).sum()["Val"]) , color='red')
plt.plot(list(df_tags[df_tags["tags"]=="lützerath"].groupby(['Month']).sum()["Val"]) , color='yellow')
#plt.plot(list(df_tags[df_tags["tags"]=="endegelaende"].groupby(['Month']).sum()["Val"]) , color='pink')
plt.legend(["dannibleibt", "noafd", "ampel","endegelände","lützerath", "endegelaende"])
plt.title('Convenzioni', fontsize=14)
plt.xlabel('Month', fontsize=14)
plt.xticks(np.arange(12),["January", "February", "March", "April", "May", "June", "July", "August", "September", "October", "November", "December"], rotation=50)
plt.ylabel('Val', fontsize=14)
plt.grid(True)
plt.show()
