# %%
import networkx as nx
import pandas as pd
import numpy as np
import json
import cdlib
from cdlib import evaluation
from cdlib import algorithms
from cdlib import viz
from cdlib import ensemble
from cdlib import readwrite
import pickle
import pquality
import matplotlib.pyplot as plt
# %matplotlib inline
from nf1 import NF1
# Out:
# Note: to be able to use all crisp methods, you need to install some additional packages:  {'graph_tool', 'wurlitzer'}
# 			<script type="text/javascript">
# 			<!--
#
# 			{
# 				var element = document.getElementById('NetworKit_script');
# 				if (element) {
# 					element.parentNode.removeChild(element);
# 				}
# 				element = document.createElement('script');
# 				element.type = 'text/javascript';
# 				element.innerHTML = 'function NetworKit_pageEmbed(id) { var i, j; var elements; elements = document.getElementById(id).getElementsByClassName("Plot"); for (i=0; i<elements.length; i++) { elements[i].id = id + "_Plot_" + i; var data = elements[i].getAttribute("data-image").split("|"); elements[i].removeAttribute("data-image"); var content = "<div class=\\"Image\\" id=\\"" + elements[i].id + "_Image\\" />"; elements[i].innerHTML = content; elements[i].setAttribute("data-image-index", 0); elements[i].setAttribute("data-image-length", data.length); for (j=0; j<data.length; j++) { elements[i].setAttribute("data-image-" + j, data[j]); } NetworKit_plotUpdate(elements[i]); elements[i].onclick = function (e) { NetworKit_overlayShow((e.target) ? e.target : e.srcElement); } } elements = document.getElementById(id).getElementsByClassName("HeatCell"); for (i=0; i<elements.length; i++) { var data = parseFloat(elements[i].getAttribute("data-heat")); var color = "#00FF00"; if (data <= 1 && data > 0) { color = "hsla(0, 100%, 75%, " + (data) + ")"; } else if (data <= 0 && data >= -1) { color = "hsla(240, 100%, 75%, " + (-data) + ")"; } elements[i].style.backgroundColor = color; } elements = document.getElementById(id).getElementsByClassName("Details"); for (i=0; i<elements.length; i++) { elements[i].setAttribute("data-title", "-"); NetworKit_toggleDetails(elements[i]); elements[i].onclick = function (e) { NetworKit_toggleDetails((e.target) ? e.target : e.srcElement); } } elements = document.getElementById(id).getElementsByClassName("MathValue"); for (i=elements.length-1; i>=0; i--) { value = elements[i].innerHTML.trim(); if (value === "nan") { elements[i].parentNode.innerHTML = "" } } elements = document.getElementById(id).getElementsByClassName("SubCategory"); for (i=elements.length-1; i>=0; i--) { value = elements[i].innerHTML.trim(); if (value === "") { elements[i].parentNode.removeChild(elements[i]) } } elements = document.getElementById(id).getElementsByClassName("Category"); for (i=elements.length-1; i>=0; i--) { value = elements[i].innerHTML.trim(); if (value === "") { elements[i].parentNode.removeChild(elements[i]) } } var isFirefox = false; try { isFirefox = typeof InstallTrigger !== "undefined"; } catch (e) {} if (!isFirefox) { alert("Currently the function\'s output is only fully supported by Firefox."); } } function NetworKit_plotUpdate(source) { var index = source.getAttribute("data-image-index"); var data = source.getAttribute("data-image-" + index); var image = document.getElementById(source.id + "_Image"); image.style.backgroundImage = "url(" + data + ")"; } function NetworKit_showElement(id, show) { var element = document.getElementById(id); element.style.display = (show) ? "block" : "none"; } function NetworKit_overlayShow(source) { NetworKit_overlayUpdate(source); NetworKit_showElement("NetworKit_Overlay", true); } function NetworKit_overlayUpdate(source) { document.getElementById("NetworKit_Overlay_Title").innerHTML = source.title; var index = source.getAttribute("data-image-index"); var data = source.getAttribute("data-image-" + index); var image = document.getElementById("NetworKit_Overlay_Image"); image.setAttribute("data-id", source.id); image.style.backgroundImage = "url(" + data + ")"; var link = document.getElementById("NetworKit_Overlay_Toolbar_Bottom_Save"); link.href = data; link.download = source.title + ".svg"; } function NetworKit_overlayImageShift(delta) { var image = document.getElementById("NetworKit_Overlay_Image"); var source = document.getElementById(image.getAttribute("data-id")); var index = parseInt(source.getAttribute("data-image-index")); var length = parseInt(source.getAttribute("data-image-length")); var index = (index+delta) % length; if (index < 0) { index = length + index; } source.setAttribute("data-image-index", index); NetworKit_overlayUpdate(source); } function NetworKit_toggleDetails(source) { var childs = source.children; var show = false; if (source.getAttribute("data-title") == "-") { ...
# 				element.setAttribute('id', 'NetworKit_script');
# 				document.head.appendChild(element);
# 			}
#
#
# 			{
# 				var element = document.getElementById('NetworKit_style');
# 				if (element) {
# 					element.parentNode.removeChild(element);
# 				}
# 				element = document.createElement('style');
# 				element.type = 'text/css';
# 				element.innerHTML = '.NetworKit_Page { font-family: Arial, Helvetica, sans-serif; font-size: 14px; } .NetworKit_Page .Value:before { font-family: Arial, Helvetica, sans-serif; font-size: 1.05em; content: attr(data-title) ":"; margin-left: -2.5em; padding-right: 0.5em; } .NetworKit_Page .Details .Value:before { display: block; } .NetworKit_Page .Value { font-family: monospace; white-space: pre; padding-left: 2.5em; white-space: -moz-pre-wrap !important; white-space: -pre-wrap; white-space: -o-pre-wrap; white-space: pre-wrap; word-wrap: break-word; tab-size: 4; -moz-tab-size: 4; } .NetworKit_Page .Category { clear: both; padding-left: 1em; margin-bottom: 1.5em; } .NetworKit_Page .Category:before { content: attr(data-title); font-size: 1.75em; display: block; margin-left: -0.8em; margin-bottom: 0.5em; } .NetworKit_Page .SubCategory { margin-bottom: 1.5em; padding-left: 1em; } .NetworKit_Page .SubCategory:before { font-size: 1.6em; display: block; margin-left: -0.8em; margin-bottom: 0.5em; } .NetworKit_Page .SubCategory[data-title]:before { content: attr(data-title); } .NetworKit_Page .Block { display: block; } .NetworKit_Page .Block:after { content: "."; visibility: hidden; display: block; height: 0; clear: both; } .NetworKit_Page .Block .Thumbnail_Overview, .NetworKit_Page .Block .Thumbnail_ScatterPlot { width: 260px; float: left; } .NetworKit_Page .Block .Thumbnail_Overview img, .NetworKit_Page .Block .Thumbnail_ScatterPlot img { width: 260px; } .NetworKit_Page .Block .Thumbnail_Overview:before, .NetworKit_Page .Block .Thumbnail_ScatterPlot:before { display: block; text-align: center; font-weight: bold; } .NetworKit_Page .Block .Thumbnail_Overview:before { content: attr(data-title); } .NetworKit_Page .HeatCell { font-family: "Courier New", Courier, monospace; cursor: pointer; } .NetworKit_Page .HeatCell, .NetworKit_Page .HeatCellName { display: inline; padding: 0.1em; margin-right: 2px; background-color: #FFFFFF } .NetworKit_Page .HeatCellName { margin-left: 0.25em; } .NetworKit_Page .HeatCell:before { content: attr(data-heat); display: inline-block; color: #000000; width: 4em; text-align: center; } .NetworKit_Page .Measure { clear: both; } .NetworKit_Page .Measure .Details { cursor: pointer; } .NetworKit_Page .Measure .Details:before { content: "[" attr(data-title) "]"; display: block; } .NetworKit_Page .Measure .Details .Value { border-left: 1px dotted black; margin-left: 0.4em; padding-left: 3.5em; pointer-events: none; } .NetworKit_Page .Measure .Details .Spacer:before { content: "."; opacity: 0.0; pointer-events: none; } .NetworKit_Page .Measure .Plot { width: 440px; height: 440px; cursor: pointer; float: left; margin-left: -0.9em; margin-right: 20px; } .NetworKit_Page .Measure .Plot .Image { background-repeat: no-repeat; background-position: center center; background-size: contain; height: 100%; pointer-events: none; } .NetworKit_Page .Measure .Stat { width: 500px; float: left; } .NetworKit_Page .Measure .Stat .Group { padding-left: 1.25em; margin-bottom: 0.75em; } .NetworKit_Page .Measure .Stat .Group .Title { font-size: 1.1em; display: block; margin-bottom: 0.3em; margin-left: -0.75em;
# Note: to be able to use all bipartite methods, you need to install some additional packages:  {'wurlitzer'}

# %%
path_graph = "../DataSet FFF/Graph_data/"

# %%
G = nx.read_graphml(path_graph+"Real_Network.graphml")

# %%
community_path = "../DataSet FFF/Community_task/"

# %%
with open(community_path+'louvain.pickle', 'rb') as f:
    louvain_coms = pickle.load(f)

# %%
len(louvain_coms.communities)
# Out:
# 185

# %%
louvain_coms.communities[:13]
# Out:
# [['fossilfuels',
#   'climateaction',
#   'climatecrisis',
#   'fridaysforfuture',
#   'peoplenotprofit',
#   'climatestrike',
#   'actnow',
#   'climateemergency',
#   'climateactionnow',
#   'uprootthesystem',
#   'climatejustice',
#   'planet',
#   'stopeacop',
#   'climatestrikeonline',
#   'schoolstrike4climate',
#   'savesoil',
#   'climatechange',
#   'facetheclimateemergency',
#   'conservation',
#   'digitalstrike',
#   'boomersforclimatejustice',
#   'systemchange',
#   'twiff',
#   'gretathunberg',
#   'stopcambo',
#   'india',
#   'justtransition',
#   'stockholm50',
#   'ilmastolakko',
#   'eusolidaritycorps',
#   'environmentaljustice',
#   'markcarney',
#   'sweden',
#   'ecocide',
#   'earthday2022',
#   'earthday',
#   'nomoreemptypromises',
#   'earthkeepersunite',
#   'cop26',
#   'oilprices',
#   'covid19',
#   'putinswar',
#   'oligarchs',
#   'peace4climate',
#   'cop26glasgow',
#   'policymakers',
#   'wtpearth',
#   'sustainablesolutions',
#   'nytonpakko',
#   'fairshare',
#   'justtransitionmossmorran',
#   'planetb',
#   'factoryfarming',
#   'climagechange',
#   'irtiturpeesta',
#   'vote',
#   'supplychains',
#   'washingtondc',
#   'frontline',
#   'actonclimate',
#   'emissions',
#   'heatwave',
#   'cambioclimático',
#   'globalwarming',
#   'fridays4future',
#   'worldenvironmentday',
#   'plasticfree',
#   'airpollution',
#   'climatechangeisreal',
#   'savetheplanet',
#   'consciousplanet',
#   'globalclimatestrike',
#   'climatepromise',
#   'biodiversityday',
#   'klimaatstaking',
#   'emergenciaclimatica',
#   'climatestrikecanada',
#   'chile',
#   'yomarcho',
#   'yellowknife',
#   'chilemarcha',
#   'savesoilbengaluru',
#   'climasv',
#   'peoplepower',
#   'mapa',
#   'fasting',
#   'striking',
#   'climatejusticenow',
#   'mindthegap',
#   'globalwarmingisreal',
#   'bangladesh',
#   'nomoreemptypromise',
#   'humanity',
#   'recycled',
#   'plasticwaste',
#   'endfossilfuels',
#   'earthdayis365days',
#   'climatecatastrophe',
#   'parisagreement',
#   'nowar',
#   'sharon',
#   'resisters',
#   'rjo',
#   'climatebrawl',
#   'schoolstrikeforclimate',
#   'schoolstrike',
#   'sadhguru',
#   'biodiversity',
#   'lossanddamage',
#   'riseupmovement',
#   'stopglobalwarming',
#   'world',
#   'thereisnoplanetb',
#   'followbackfriday',
#   'globalgoals',
#   'noplanetb',
#   'klimaat',
#   'fightfor1point5',
#   'restoreourearth',
#   'justiceclimatique',
#   'climateactivist',
#   'worldclimateactivist',
#   'africanclimatealliance',
#   'trees',
#   '気候危機見て見ぬふりはもうできない',
#   'peopleoverprofit',
#   'youthstrike4climate',
#   'heatwaves',
#   'foodsystems',
#   'savecongorainforest',
#   'climatecantwait',
#   'climatefinance',
#   'thinkgreenactgreen',
#   'kippraconference2022',
#   'climateenergysummit',
#   'onlyoneearth',
#   'aws22',
#   'educategirlsforclimatejustice',
#   'letafghangirlslearn',
#   'fffportlandmetro',
#   'unitebehindthescience',
#   'fridaysforfuturehamburg',
#   'hamburg',
#   'extinction',
#   'endplasticpollution',
#   'finland',
#   'worldoceansday',
#   'cycling',
#   'floods',
#   'brazil',
#   'onpoli',
#   'elxn43',
#   'helsinki',
#   'ilmasto',
#   'ilmastokriisi',
#   'ilmastonmuutos',
#   'cop27',
#   'makeparisreal',
#   'activists',
#   'droughts',
#   'wildfires',
#   'climatecriminals',
#   'climatereparations',
#   'savefuturebangladesh',
#   'strike4climate',
#   'keepitintheground',
#   'lifesbetterwithtrees',
#   'kokumsforclimate',
#   'eacop',
#   'bankingonabetterfuture',
#   'nocgl',
#   'wetsuwetenstrong',
#   'forpeopleforplanet',
#   'biodiversitycrisis',
#   'climatemarch',
#   'climatedisaster',
#   'edinburghclimatestrike',
#   'standforplanet',
#   'lettheearthbreath',
#   'scientistrebellion',
#   'saveearth',
#   'letearthbreathe',
#   'savethetrees',
#   'waterpollution',
#   'toronto',
#   'sdg13',
#   'covid',
#   'climatebreakdown',
#   'climatehopeful',
#   'youth',
#   'goodfriday',
#   'goodfriday2022',
#   'afrikavuka',
#   'climatereport',
#   'saveplanetearth',
#   'universitystrikeforclimate',
#   'buildbackbetter',
#   'week',
#   'cleannfts',
#   'ipccreport',
#   'children',
#   'crisisclimática',
#   'guwahati',
#   'assam',
#   'youthforclimate',
#   'gta',
#   'topoli',
#   'brighters',
#   'bsb',
#   'fridaysforfuturebangladesh',
#   'actionaidbangladesh',
#   'fffbd',
#   'youthclimatestrike',
#   'globalstrike',
#   'globalclimateaction',
#   'antarctica',
#   'lucknow',
#   'elokapina',
#   'dochooserenewables',
#   'ilmastotekoja',
#   'planttrees',
#   'save_tree',
#   'action4impact',
#   'plants',
#   'phaseoutgas2030',
#   'crisisoninfiniteearths',
#   'racialjustice',
#   'blackhistorymonth',
#   'environmentalism',
#   'climatelive2022',
#   'savegreen',
#   'savenature',
#   'fff_bangladesh',
#   'skolstrejkförklimatet',
#   'suomi',
#   'plasticpollution',
#   'vulnerabilities',
#   'visualimpairments',
#   'disasters',
#   '11febbraio',
#   'ireland',
#   'emptypromises',
#   'wecandothis',
#   'covid_19',
#   'theworldiswatching',
#   'fridaysforfutureindia',
#   'mumbai',
#   'womensclimatestrike',
#   'kids',
#   'environmentalprotection',
#   'greencolonialism',
#   'fornature',
#   'blacklivesmatter',
#   'defendthedefenders',
#   'blahblahblah',
#   'fightfor15',
#   'vancouver',
#   'bcpoli',
#   'cdnpoli',
#   'stoptmx',
#   'stopcgl',
#   'happynewyear2022',
#   'christmas',
#   'climatestrikes',
#   'happyholidays',
#   'wetsuweten',
#   'vanpoli',
#   'stockholm',
#   'crisis',
#   'fastingfridaysforfuture',
#   'victoriabc',
#   'страйкзаклімат',
#   'blackfriday',
#   'nomoreemptywords',
#   'kretslopp',
#   'klimatkris',
#   'climate360sa',
#   'femanism',
#   'climategirl',
#   'copout26',
#   'glasgow',
#   'climatescience',
#   'glasgowcop26',
#   'klimaatmars',
#   'sustainablegoodlife',
#   'ndcs',
#   'learningsociety',
#   'nuclearpower',
#   'exitcoalnow',
#   'netzeroneedsnuclear',
#   'nucléaire',
#   'forabolsonaro',
#   'cen',
#   'g20',
#   'pressphotography',
#   'news',
#   'divest',
#   'fffmapcount',
#   'climatestriking',
#   'whatthecop',
#   'copon4net',
#   'envirocoresubject',
#   'cleanupstandardchartered',
#   'treemendous',
#   'treesarmy',
#   'phoenix',
#   'urbanforests',
#   'gender',
#   'worldleaders',
#   'peopleb4profit',
#   'cop26plastics',
#   'dhaka',
#   'climatecompensation',
#   'tellthetruth',
#   'lakedistrict',
#   'windermere',
#   'river',
#   'lake',
#   'mondaymotivaton',
#   'gippsnews',
#   'forests',
#   'climatechangedme',
#   'timetoact',
#   'savefairycreek',
#   '11thhourforclimate',
#   'tiredearth',
#   'marchaporelclima',
#   '24s',
#   'justiciaporelclima',
#   '24septiembre',
#   'rebelforlife',
#   'unga',
#   'ecologia',
#   'planeta',
#   'climateweek',
#   'luxembourg',
#   '世界気候アクション0924',
#   '住友商事の森林破壊を許さない',
#   'stayhome',
#   'kenya',
#   'tourism',
#   'sttaconsulting',
#   'sustainabletourism',
#   'nutrition',
#   'elxn44',
#   'greenhouse',
#   'savetheearth',
#   'nomoreemptysummits',
#   'treatacrisislikeacrisis',
#   'climatecrisisis',
#   'climatestike',
#   'agriculture',
#   'victim',
#   'solution',
#   'foodsystemshas',
#   'socialjustice',
#   'denialmachine',
#   'betterfuture',
#   'canada',
#   'globalclimatejustice',
#   'withdrawthecap',
#   'extremeweather',
#   'fires',
#   'climateactionplan',
#   'stopdeforestation',
#   'decarbonizing',
#   'netzstreikfuersklima',
#   'greece',
#   'globalstrikeforfuture',
#   'iyd2021',
#   'notblownwithcyclone',
#   'cliamtestrike',
#   'socialjusticeisclimatejustice',
#   'savebuxwahaforest',
#   'flattenthecurve',
#   'borneo',
#   'saveborneorainforest',
#   'savebaritoriver',
#   'flooding',
#   'extreme',
#   'thinkglobal',
#   'actlocal',
#   'pollutersout',
#   'girlpower',
#   'listentoexperts',
#   'climatebrainy',
#   'climatecrisisbangladesh',
#   'bangladeshalreadysuffering',
#   'transpride',
#   'digitalprotest',
#   'fridaystrikeforclimate',
#   'geethikavenkatesan',
#   'globalheating',
#   'unitedkingdom',
#   'पेड़_लगाओ_पृथ्वी_बचाओ',
#   'planttreesaveearth',
#   'planttree',
#   'youthtakeover',
#   'saveaareyforest',
#   'plantalife',
#   'choices',
#   'lockdown',
#   'digitalclimatestrike',
#   'marcodecanaveses',
#   'ilmastovaalit',
#   '11thhourforclimat',
#   'snösätra',
#   'worldenvironmentday2021',
#   'youth2030',
#   'caminodesantiago',
#   'beyondcoal',
#   'raiseyourstandards',
#   'climatetwitter',
#   '未来のための金曜日',
#   'cycloneamphan',
#   'ravensburg',
#   'nomowmay',
#   'ethicalandinformedcitizens',
#   'ocsbsep',
#   'youngpeopleforclimateaction',
#   'standwithworkers',
#   'bicycle',
#   'canpoli',
#   'klimaurteil',
#   'coronavirus',
#   '温室効果ガス削減目標の大幅引き上げを求めます',
#   'peat',
#   'savetheoceans',
#   'stopeumercosur',
#   '気候危機止めるために学校休みます',
#   'banplastic',
#   'plasticfreeocean',
#   'childrenareourfuture',
#   'euclimatelaw',
#   'endplastic',
#   'climatepledge',
#   'peaceuponyemen',
#   'yemencantwait',
#   'amankumar',
#   'marcheclimat',
#   'vraieloiclimat',
#   '16avril',
#   'nantes',
#   'marchepourleclimat',
#   'climatresilience',
#   'iamgreta',
#   'intergenerational',
#   'climatecrises',
#   'climatealliance',
#   'climaterisk',
#   'savebugomaforest',
#   'kabila4sdgs',
#   'ethoslifestyle',
#   'generationclimat',
#   'climatepoli',
#   'fffmar19',
#   '私たちの未来を手放さない',
#   'protecttheoceans',
#   'womensday',
#   'fightforyourhumanright',
#   'climateart',
#   'stayathome',
#   'nzpol',
#   'cumbriacoalmine',
#   'ukgov',
#   'throwback',
#   'askgerald',
#   '気候危機に特効薬なし',
#   '気候も危機',
#   'greenspaces',
#   'parisclimateagreement',
#   'digitalstrikesapporo',
#   'teamcows',
#   'laniña',
#   'indiagate',
#   'newdelhi',
#   'nomoreemptypomises',
#   'actnowforfuture',
#   'saveourselves',
#   'savehumanity',
#   'madrid',
#   'socialdistancing',
#   'eu2020de',
#   'indigenousrights',
#   'fightclimateinjustice',
#   'wethepeople',
#   'gambia',
#   'christmas2020',
#   'greenchristmas',
#   'bushfires',
#   'hoax',
#   'firedrillfriday',
#   'shoestrike',
#   'endcapitalism',
#   'endfactoryfarming',
#   'saveamazonia',
#   '世界気候アクション0925',
#   'internationalhumanrightsday',
#   'euco',
#   'watchlive',
#   'wewanttolive',
#   'covidー19',
#   'endperiodplastic',
#   'papua',
#   'cop25',
#   'unitednations',
#   'fundfarmersnotcoal',
#   '地球温暖化',
#   'saveourcoast',
#   'noforestnofuture',
#   '仙台',
#   '女川原発の再稼働に反対します',
#   'priorities',
#   'online',
#   '2ndlockdown',
#   '気候非常事態宣言',
#   'withdraweia2020',
#   'filthyrich',
#   '金曜日アクション',
#   'erneuerbar',
#   'fffdigital',
#   'savewesternghats',
#   'davidattenborough',
#   'alifeonourplanet',
#   'ecoschool',
#   'cleavageforclimate',
#   'ilmastotwitter',
#   'greenrecovery',
#   'greeningtheasals',
#   'dkpol',
#   'シューズアクション',
#   'climatestrikers',
#   'climateshoesaction',
#   'andrapradesh',
#   'globalclimateaction2020',
#   'pune',
#   'escazuahora',
#   'globaldayofclimateaction',
#   'shoes4climateavtion',
#   'skostrejk',
#   'enviro',
#   'sportecology',
#   'sdgactionday2020',
#   'climateweeknyc',
#   'letterstotheearth',
#   'letterstopower',
#   'fridaysforfuturemumbai',
#   'globalclimatestrike2020',
#   'hudsonbay',
#   'redflags',
#   'carbonfootprint',
#   'esgmark',
#   'fffsenegal',
#   'africamatters',
#   '1day',
#   'thisiszerohour',
#   'fo',
#   'fff_egypt',
#   'symces',
#   'sudan',
#   'discobedience',
#   'danceforclimate',
#   'nvda',
#   'stayingalive',
#   'ceebill',
#   'actonscience',
#   'granada',
#   'satyagrahaagainsteia2020',
#   'scrapeiadraft2020',
#   'noeiadilution',
#   'saveeia',
#   'indianotforsale',
#   'モーリシャス重油流出事故',
#   'mauritiusoilspill',
#   'climateprotestonline',
#   'escazuya',
#   'bikelife',
#   'ebikes',
#   'walking',
#   'resetforbiking',
#   'thereisnovaccinefortheclimatecrisis',
#   'noexistevacunaparalacrisisclimatica',
#   'climatepals',
#   'stayathomesavelives',
#   'veganfortheplanet',
#   'thefuturewewant',
#   'savennp',
#   'nãohávacinaparaacriseclimatica',
#   'changeclimate',
#   'climatecriminal',
#   'powertothepeople',
#   'parliament',
#   'ituc',
#   'cepow',
#   'noweci',
#   'desertificationanddroughtday',
#   'foodfeedfibre',
#   'strikewithus',
#   'mask',
#   'democracyday',
#   'diamundialdelosoceanos',
#   'earthcomesfirst',
#   'locustsattack',
#   'north',
#   'savedehingpatkai',
#   'everytreeisawin',
#   'by2020weriseup',
#   'cycloneapmhan',
#   'climatefriday',
#   'campforfuture',
#   'washington',
#   'citizenkid',
#   'kurz',
#   'savedibangvalley',
#   'keepoilinsoil',
#   'ckimatechange',
#   '17daystolearn',
#   'strikingfriday',
#   'labourdaymay2020',
#   'labourday',
#   'unccdlandheroes',
#   'youthtopower',
#   'twitterdci',
#   'earthstrike',
#   'thegreenambassadors',
#   'everyhomealoevera',
#   'steindesanstosses',
#   'novosibirsk',
#   'stoneofreflection',
#   '3april',
#   'teachersforclimate',
#   'climatecricis',
#   'climateneutrality',
#   'stailcdigiteach',
#   'stailcaeráide',
#   'teamtrees',
#   'climatestrikr',
#   'istandwithgreta',
#   'brussels',
#   'day65',
#   'challenge2020',
#   '80milliontrees',
#   'drcongo',
#   'carbonsink',
#   'groningen',
#   'coronarvirusitalia',
#   'belfast',
#   'valentinesday',
#   'valentineday2020',
#   'wijstakenmee',
#   'ecoanxiety',
#   'climatehope',
#   'australianbushfires',
#   'bushfiresaustralia',
#   'mbpoli',
#   'retweeetplease',
#   'help',
#   'deadlineday',
#   'antarctica2020',
#   'generalelection2020',
#   'contaminación',
#   'salud',
#   'climateemegency',
#   'goinggreen',
#   'climatevote2020',
#   'australiaonfire',
#   'climatstreik',
#   'ableg',
#   'abpoli',
#   'yeg',
#   'australiafires',
#   'climateprotest',
#   'australianbushfiredisaster',
#   'belfastclimatecommission',
#   'australiaburns',
#   'prayforaustralia',
#   'confused',
#   'ecologicalcollapse',
#   'resilience',
#   'savethefuture',
#   'savecongofauna_flora',
#   'mondaythoughts',
#   'fbf',
#   'cop25madrid',
#   'timeforaction',
#   'timepoy',
#   'personoftheyear',
#   'genderday',
#   'actonthegap',
#   'brookline',
#   'weareunstoppable',
#   'rightlivelihoodaward',
#   'regina',
#   'saskatchewan',
#   '29november',
#   'climatica',
#   'strajkklimatyczny',
#   'ridhimapandey',
#   '29novembre',
#   'thanksgiving',
#   'tunisia',
#   'sustainabledevelopment',
#   'glamourwoty',
#   'mydayinla',
#   'maynooth',
#   'climatestrikevancouver',
#   'cop24',
#   'gretainalberta',
#   'edmonton',
#   'alberta',
#   'unitedweroll',
#   'filthparade',
#   'poisonisreal',
#   'pollutionisreal',
#   'tailingsponds',
#   'internationaldayofthegirl',
#   'worldchangersarenoisy',
#   'twitteranniversary',
#   '10milliontreesug',
#   'cse',
#   'srhr',
#   'tuesdaymorning',
#   'cybermonday2019',
#   'el7odesobedecemos',
#   'lacafeterappsoe',
#   'metroforward',
#   'biomassa',
#   'madeinecuador',
#   'montreal',
#   'globalclimatestrikes',
#   'weekforfuture',
#   'yycclimatestrike',
#   'kolkata',
#   'climaterebellion',
#   'westbengal',
#   'vpd',
#   'climatestriketo',
#   'torontoclimatestrike',
#   'teachsdgs',
#   'climatestrikeottawa',
#   'boston',
#   'bostonclimatestrike',
#   'climatestrikeott',
#   'kinima_mathiton',
#   'ottawa',
#   'climatestriketoronto',
#   'gipuzkoa',
#   'accionclimática',
#   'cuba',
#   'suffragettes',
#   'rallyfortheimagination',
#   'artsstrike4climate',
#   'climatestrikeindia',
#   'tweetstorm',
#   'halifax',
#   'united4climatejustice',
#   'teamestinzione',
#   'youngpeoplemarching',
#   'edchat',
#   'polmtl',
#   'kotloyals',
#   'southpole',
#   'fridaysforfutureantarctica',
#   'bhubaneswar',
#   'climatestrikekorea',
#   'mtlpoli',
#   'foreverychild',
#   'saturdaysforfuture',
#   'emergenza',
#   'weday',
#   'climateactionsummit',
#   'bced',
#   'commitment',
#   'commitment2action',
#   'shero',
#   '2030now',
#   'inspiredyouth',
#   'climatestrikepakistan',
#   'climatestrikeaz',
#   'climatestrikephx',
#   'climatestrikephoenix',
#   'العمل_لأجل_المناخ',
#   'climatestrikenyc',
#   'climatestrikedc',
#   'climateactionp',
#   'climatestrikesf',
#   'onealbuquerque',
#   'greenaf',
#   'climatetruth',
#   'girlsgetequal',
#   'puertooctaysinagua',
#   'keepitwild',
#   'faithsforfuture',
#   'greenunison',
#   'nuevayork',
#   'youthstrike4climatehuddersfield',
#   'teach4climate',
#   'oilcompanies',
#   'oilbusiness',
#   'eugreendeal',
#   '再生可能エネルギー',
#   '気候正義',
#   'pcilist',
#   'resistanceunited',
#   'fresh',
#   'onev1',
#   'borisjohnson',
#   'standwithukraine',
#   'australiabushfires',
#   'climatefires',
#   'peopleandplanet',
#   'activistabd',
#   'bagladesh',
#   'angola',
#   '1point5',
#   'action',
#   'g7',
#   'climaterightsnow',
#   'climatepeace',
#   'rainy',
#   'belgium',
#   'generationrestoration',
#   'fathersday2022',
#   'beingadad',
#   'dontlookup',
#   'environmentalracism',
#   'flashflood',
#   'sylhet',
#   'dayoftheafricanchild',
#   'freemint',
#   'röstförrättvisa',
#   'savegoldensands',
#   'listentothescience',
#   'voteclimate',
#   'ipcc',
#   'codered',
#   'madarakaday',
#   'climateactionclub',
#   'saveourburningforests',
#   'sdg',
#   'canyouhearusyet',
#   'ecosystems',
#   'fffnigeria',
#   'auspol',
#   'ausvotes',
#   'globalwarmingmatters',
#   'mothersday',
#   'moreofus',
#   'niunamenos',
#   'savesoilamman',
#   'riseupmovt',
#   'globalextinction',
#   'fridayswithrakkidol',
#   'earthovershootday',
#   'investinourplanet',
#   'earthday22',
#   'togetherforourplanet',
#   'climatesign',
#   'natureconnection',
#   'tbthursday',
#   'savesoilatun',
#   'census',
#   'timecapsule',
#   'emergenzaclimatica',
#   'planetoverprofit',
#   'freeukraine',
#   'peacenotwar',
#   'crisiclimatica',
#   'fffke',
#   'up',
#   'fridaysforforests',
#   'votethemout',
#   'clmateactionnow',
#   'nomoreblahblahblah',
#   'swedish',
#   'seriousness',
#   'urgency',
#   'stormeunice',
#   'stormdudley',
#   'stormfff',
#   'youth4climate',
#   'litteraction',
#   'ottawaoccupied',
#   'freedomconvoy2022',
#   'greenhousegases',
#   'strikeforclimate',
#   'justlookup',
#   'lnpfail',
#   'actonclimatevic',
#   'faiths4climate',
#   'turnthetide',
#   'wedonthavetime',
#   'stopblaming',
#   'climatemarchkarachi',
#   'calamity',
#   'amazon',
#   'politicians',
#   'industrialists',
#   'cambo',
#   'knittingnannas',
#   'deforestation',
#   'eternals',
#   'dinnaedawdle',
#   'viernesporelfuturo',
#   '5300climate',
#   'cl',
#   'climatelive2021',
#   'theyoutharerising',
#   'endclimatesilence',
#   'ilmastoisovanhemmat',
#   'gdp',
#   'scottmorrison',
#   'nowornever',
#   'wtpblue',
#   'scotland',
#   'climatedisasters',
#   'bristol',
#   'grevepourleclimat',
#   'crisisclimatica',
#   'scioperoperilclima',
#   'ipccreport2021',
#   'savebuxwaha',
#   'hurricane',
#   'newprofilepic',
#   'thereisnoplaneb',
#   'stopthesame',
#   'polluters',
#   'nofutureinfossilfuels',
#   'pollutersoutpeoplein',
#   'justtransitionnow',
#   'gurgaon',
#   'haryana',
#   'fossilfules',
#   'weekthisone',
#   'injustice',
#   'countdowntocop',
#   'stopclearcuts',
#   'stopline3pipeline',
#   'forestfires',
#   'greeceisburning',
#   'napoli',
#   'algae',
#   'bari',
#   'climatelaw',
#   'heatwave2021',
#   'onlineclimatestrike',
#   'gurugram',
#   'savelakshadweep',
#   'generationonfire',
#   'sunrisemovement',
#   'dunfermline',
#   'fightfor1point',
#   'carbonsinks',
#   'stayhomestaysafe',
#   'fridaysforfutureitaly',
#   'fridaysforfutureitalia',
#   'libri',
#   'savetheworld',
#   'climategrandparents',
#   'cornwall',
#   'forthroadbridge',
#   'queensferrycrossing',
#   'stopthegreenwash',
#   'uganda',
#   'globaltemperaturerise',
#   'localelections',
#   'justrecovery',
#   'makeirelandgreenagain',
#   'savecongoforest_flora_fauna',
#   'northernireland',
#   'parisionayla',
#   'nonewcoal',
#   'staysafe',
#   'climateactnow',
#   'nocoalforourfuture',
#   'happynewyear2021',
#   'newyear',
#   'banplasticug',
#   'hope',
#   'hedef1bucuk',
#   'eu2030',
#   'repairdontthrow',
#   'repairdontgiveup',
#   'dontbuyswap',
#   'bidentransition',
#   'istandwithgreata',
#   'yyj',
#   'delhi',
#   'airquality',
#   'sosamazonia',
#   'klimaatverandering',
#   'southafrica',
#   'greenrecoveryni',
#   'naturecrisis',
#   'peoplecrisis',
#   'extinctionthefacts',
#   'wildfires2020',
#   'climatered',
#   'hatayyanıyor',
#   'californiafires',
#   ...],
#  ['kohleausstieg',
#   'energiewende',
#   'eu',
#   'erneuerbare',
#   'klimaneutralität',
#   'ee',
#   'eeg2021',
#   'klimaneutral2050',
#   'klimakrise',
#   'berlin',
#   'klimastreik',
#   'deutschland',
#   'kernenergie',
#   'atom',
#   'eeg',
#   'klimapaket',
#   'abfckpraemie',
#   'schweiz',
#   'solarwirtschaft',
#   'speicher',
#   'es2050',
#   '10vor10',
#   'wärme',
#   'waermeinitiative',
#   'co2gesetz',
#   'srfclub',
#   'scientists4future',
#   'energiekrise',
#   'klimawandel',
#   'blackout',
#   'neubauer',
#   'video',
#   'scientistsforfuture',
#   'stromausfall',
#   'mondaymotivation',
#   'globalisierung',
#   'fff',
#   'klimaschutz',
#   'klima',
#   'rassismus',
#   'mönchsberggarage',
#   'verkehrswende',
#   'neinzumloch',
#   'endegelaende',
#   'parentsforfuture',
#   'futureforfridays',
#   'nigeria',
#   'ourhouseisonfire',
#   'alledörferbleiben',
#   'corona',
#   'earthhour',
#   'luetzerath',
#   'greta',
#   'merkel',
#   'meintwitterjubiläum',
#   'salzburg',
#   'konzert',
#   'greenpeace',
#   'trump',
#   'zukunft',
#   'systemchangenotclimatechange',
#   'endegelände',
#   'fighteverycrisis',
#   'extinctionrebelion',
#   'afdverbot',
#   'groko',
#   'keingradweiter',
#   'ngo',
#   'datteln4',
#   'garzweiler',
#   'howdareyou',
#   'schellnhuber',
#   'kurzstreckenflüge',
#   'xr',
#   'fossilfree',
#   'energie',
#   'covid19de',
#   'kohlegesetz',
#   'heldinnen',
#   'criticalmass',
#   'nextlevel4future',
#   'datteln',
#   'waldsterben',
#   'coronaeltern',
#   'klimahandeln',
#   'climatesolutions',
#   'unitedbehindthescience',
#   'davos',
#   'notmyklimapaket',
#   'wef20',
#   'wef',
#   'davos20',
#   'davos2020',
#   'wef2020',
#   '2019in5words',
#   'un',
#   'linz',
#   'radlobby',
#   'unclimatesummit',
#   'suv',
#   'diesel',
#   'oneworld',
#   'putin',
#   'klimakonferenz',
#   'riseup',
#   'tempolimit',
#   'afd',
#   'publicclimateschool',
#   'klimagerechtigkeit',
#   'europa',
#   'dresden',
#   'kohle',
#   'streik',
#   'happybirthdaygreta',
#   'laschet',
#   'hambibleibt',
#   'neustartklima',
#   'fitfor55',
#   'streiken',
#   'stopadani',
#   'siemens',
#   'chinafloods',
#   'netzstreikfürsklima',
#   'wwf',
#   'unfitforoffice',
#   'uspolitics',
#   'saveaustralia',
#   'nomorecoal',
#   'brexit',
#   'ichsagendeglände',
#   'rebel4live',
#   'sailtonothing',
#   'masculinity',
#   'akw',
#   'lützerathbleibt',
#   'karlsruhe',
#   'scholz',
#   'bundeskanzler',
#   'hitze',
#   'kernkraft',
#   'öpnv',
#   'habeck',
#   'eutaxonomy',
#   'klimakatastrophe',
#   'klimarat',
#   'klimakriseistjetzt',
#   'kriegsverbrecher',
#   'polizei',
#   'zivilerungehorsam',
#   'letztegeneration',
#   'taxonomie',
#   'klimacamp',
#   'münchen',
#   'fdp',
#   'polizeigewalt',
#   'polizeiproblem',
#   'gruenermist',
#   'notstromaggregaten',
#   'notstromaggregate',
#   'notstromaggregat',
#   'gaskrise',
#   'gaslieferungen',
#   'gasnotstand',
#   'totalausfall',
#   'luisaneubauer',
#   'gruene',
#   'russland',
#   'öko',
#   'verbrenneraus',
#   'atomkraft',
#   'gruenen',
#   'ldk22nrw',
#   'cdu',
#   'pflegestreik',
#   'nrw',
#   'klimaschutzaktivisten',
#   'klimaidioten',
#   'klimawahn',
#   'klimahysterie',
#   'klimaanpassung',
#   'lindner',
#   'aldi',
#   'klimaneutral',
#   'kohlekraftwerke',
#   'grüne',
#   'spd',
#   'union',
#   'ampel',
#   'dwenteignen',
#   'stopdeportations',
#   'antifa',
#   'bombendrohungen',
#   'sek',
#   'atomkraftneindanke',
#   'haltdiefressebild',
#   'pipeline',
#   'stopfakegreen',
#   'klimaaktivisten',
#   'terrorismus',
#   'straftaten',
#   'ideologie',
#   'demokratie',
#   'dänemark',
#   'frauenhasser',
#   'hatespeech',
#   'pipelineindieluft',
#   'terror',
#   'goere',
#   'hannover',
#   'niedersachsen',
#   'radikalisierung',
#   'langstreckenluisa',
#   'anschlag',
#   'steinmeier',
#   'pflichtdienst',
#   'tankrabatt',
#   'gardasee',
#   'sichererhafen',
#   'diegrünen',
#   'lng',
#   'embargoforpeace',
#   'bohn',
#   'klimaproteste',
#   'protestforscher',
#   'schulen',
#   'parteimitglieder',
#   'schulleitung',
#   'meinungsmache',
#   'beeinflussung',
#   'kindern',
#   'auto',
#   'scholzisteineschande',
#   'demonstration',
#   'a20',
#   'leipzig',
#   'a20stoppen',
#   'elektromobilität',
#   'elektroautos',
#   'lützerath',
#   'dürre',
#   'montagsblockaden',
#   'bayern',
#   'normal',
#   'paderborn',
#   'tornado',
#   'ahrtal',
#   'rotgrüne',
#   'australien',
#   'klimawahl',
#   'klimakatastropheistjetzt',
#   'windhose',
#   'nrwandel',
#   'menschen',
#   'umweltzerstörung',
#   'krieg',
#   'astronaut',
#   'maurer',
#   'iss',
#   'grünen',
#   'gasstop',
#   'autowahnsinn',
#   'städtefürmenschen',
#   'homeoffice',
#   'ltwnrw22',
#   'hambacherforst',
#   'verfassungsschutz',
#   'bmwk',
#   'piraten',
#   'nrwgenugverwüstet',
#   'windkraft',
#   'wirsindantifa',
#   'antifaforfuture',
#   'klimabildung',
#   'wahlarena',
#   'nrwwahl2022',
#   'zukunftegal',
#   'dielinke',
#   'bge',
#   'volt',
#   'votevolt',
#   'wissenschaft',
#   'schwerin',
#   'klimastiftung',
#   'nordstream2',
#   'kriegstreiber',
#   'baerbock',
#   'grünermist',
#   'leipzigfürsklima',
#   'luetzerathbleibt',
#   'freivonöl',
#   'servicetweet',
#   'niemehrcdu',
#   'ukrainekrieg',
#   'ukraine️',
#   'energieembargo',
#   'a100',
#   'greenwash',
#   'bawü',
#   'energiesparen',
#   'allefürlützi',
#   'atomausstieg',
#   'erneuerbareenergien',
#   'julis',
#   'csu',
#   'landtagswahl',
#   'autokorrektur',
#   'frieden',
#   'fortheanimals',
#   'blöd_on_tour_presse',
#   'merz',
#   'armut',
#   'hartziv',
#   'hartzundherzlich',
#   'memes',
#   'freiheit',
#   'klimanotstand',
#   'disziplin',
#   'schulpflicht',
#   'maskenpflicht',
#   'wasserstoff',
#   'afrika',
#   'hunger',
#   'tod',
#   'guterres',
#   'arroganz',
#   'klimaluege',
#   'co2luege',
#   'nato',
#   'speakoutagainstww3',
#   'neuwahlen',
#   'spritpreise',
#   'maybritillner',
#   'illner',
#   'lanz',
#   'greatreset',
#   'btw21',
#   'peaceandjustice',
#   'maaßen',
#   'aachen',
#   'dithmarschen',
#   'aktivisten',
#   'studentsforfuture',
#   'münster',
#   'dreadlock',
#   'kapitalismus',
#   'dreadlockgate',
#   'extremismus',
#   'systemwechsel',
#   'kommunismus',
#   'linksfaschismus',
#   'düsseldorf',
#   'dus2503',
#   'dreads',
#   'kiel',
#   'mitweltschutz',
#   'le2503',
#   'bielefeld',
#   'reichthaltnicht',
#   'burncarsnotgas',
#   'feuerdemkapitalismus',
#   'kleinaberfein',
#   'muskelkraftstattfossileenergie',
#   'keincentfürputinskrieg',
#   'zeitgemäß',
#   'lastenfahrrad',
#   'polarstern',
#   'dd2503',
#   'subventionen',
#   'erneuerbaren',
#   'freiburg',
#   'bundestag',
#   'öl',
#   'witten',
#   'allefürsklima',
#   'bremen',
#   'gerechtigkeit',
#   'globalerklimastreik',
#   'degrowth',
#   'klimagerechtwerden',
#   's4f',
#   'haloac3',
#   'wissenschafftklimaschutz',
#   'brandenburg',
#   'neumayer',
#   'verkehr',
#   'identitätspolitik',
#   'postmodernismus',
#   'entlastungspaket',
#   'wehrpflicht',
#   'straßenkleber',
#   'bremerhaven',
#   'potsdam',
#   'arktis',
#   'antarktis',
#   'deadlocks',
#   'arbeit',
#   'nichtsnutze',
#   'maltzahn',
#   'impfnebenwirkungen',
#   'maltzan',
#   'klimaguerilla',
#   'klimaziele',
#   'klimabewegung',
#   'klimaaktionstag',
#   'faschisten',
#   'protest',
#   'klimarevolution',
#   'hartaberfair',
#   'selenskyj',
#   'lotharwieler',
#   'rki',
#   'ambientalismo',
#   'sostenibilità',
#   'verdi',
#   'minipv',
#   'grundbedarf',
#   'photovoltaik',
#   'guerillapv',
#   'balkonpv',
#   'blutgas',
#   'ard',
#   'sabotage',
#   'industrie',
#   'infrastrukur',
#   'pendlerpauschale',
#   'essenrettenlebenretten',
#   'ampelkoalition',
#   'sturm',
#   'zufall',
#   'klimaquerdenken',
#   'ylenia',
#   'zeynep',
#   'orkan',
#   'seltensovielschwachsinngehört',
#   'wirwerdenlaut',
#   'scientistforfuture',
#   'edeka',
#   'oberhausen',
#   'umweltschutz',
#   'reichsbürger',
#   'querdenker',
#   'klimaschützer',
#   'ölkatastrophe',
#   'schifffahrt',
#   'umwelt',
#   'prien',
#   'durchseuchungstoppen',
#   'pandemie',
#   'impfung',
#   'vollgasindiekrise',
#   'atomenergie',
#   'maischberger',
#   'fracking',
#   'mönchengladbach',
#   'lobau',
#   'ricardalang',
#   'dbdk22',
#   'rrr',
#   'holocaustremembranceday',
#   'osterholzbleibt',
#   'ernährungswende',
#   'vegansforfuture',
#   'osterholz',
#   'querdenken',
#   'bonn',
#   'schweinemast',
#   'xfürlützi',
#   'luetzibleibt',
#   'thread',
#   'stomunfall',
#   'klimapolitik',
#   'coronapandemie',
#   'covidioten',
#   'querlullies',
#   'aufdemrechtenaugeblind',
#   'neujahr',
#   'containern',
#   'dontnuketheclimate',
#   'diegruenen',
#   'ludwig',
#   'eiffelturmtag',
#   'pariserklimaabkommen',
#   'eiffelturm',
#   'paris',
#   'autofrei',
#   'klimaschutzgesetz',
#   'studiom',
#   'koalitionsvertrag',
#   'cartoon',
#   'grueneraf',
#   'koalitionsverhandlungen',
#   'leag',
#   'braunkohle',
#   'lausitz',
#   'schule',
#   'nachhaltigkeit',
#   'refugeeswelcome',
#   'braingaga',
#   'thunberg',
#   'nuhr',
#   'privatjet',
#   'klimaheuchler',
#   'campact',
#   'oxfam',
#   'duh',
#   'bund',
#   'climateanalytics',
#   'kuh',
#   'faktencheck',
#   'landwirtschaft',
#   'agrarwende',
#   'animalrebellion',
#   'vonderleyen',
#   'klimagipfel',
#   'weltklimagipfel',
#   'luetzerathlebt',
#   'reemtsma',
#   'strukturwandel',
#   'antisemitismus',
#   'schäuble',
#   'wirtschaft',
#   'gerechtigkeitjetzt',
#   'timetorebel',
#   'bz',
#   'markuslanz',
#   'faktenfinder',
#   'sozialdemokraten',
#   'bildlive',
#   'dierichtigenfragen',
#   'ihrlasstunskeinewahl',
#   'linksextremismus',
#   'wirtschaftswachstum',
#   'kommunisten',
#   'b2210',
#   'allefuersklima',
#   'stuttgart',
#   'bdi',
#   'klimakoalition',
#   'nichtverhandelbar',
#   'klimaprotest',
#   'nino_pandari',
#   'demo',
#   'grün',
#   'bundjugend',
#   'autoausstieg',
#   'insulatebritain',
#   'klimafaschos',
#   'energiearmut',
#   '100tage',
#   'dortmund',
#   'essen',
#   'e2210',
#   'e2310',
#   'ms2310',
#   'bi2310',
#   'k3010',
#   'fightantisemitism',
#   'gegen1000kreuze',
#   'noversgnrw',
#   'versgnrwstoppen',
#   'nika',
#   'dieinsider',
#   'mobilitätswende',
#   'klimastreiks',
#   'spahn',
#   'sondierungspapier',
#   'rostock',
#   'doch',
#   'wahlalter',
#   'kanzler',
#   'artenschutz',
#   'rassistin',
#   'grünejugend',
#   'altmaier',
#   'akk',
#   'bundestagswahl',
#   'bverfg',
#   'btw2021',
#   'viertelnachacht',
#   'physik',
#   'lsa',
#   'linke',
#   'bne',
#   'twlz',
#   'nobelpreis',
#   'hasselmann',
#   'jamaika',
#   'bundestagswahl21',
#   'talkimhangar7',
#   'servustv',
#   'transformation',
#   'göpel',
#   'deutschlandaberohneklimawahn',
#   'emissionen',
#   'angst',
#   'veränderung',
#   'ü60wählern',
#   'wahl2021',
#   'laschetruecktritt',
#   'nojamaika',
#   'rezo',
#   'gehtwählen',
#   'mehrplatzfürsrad',
#   'deutschlandabernormal',
#   'kampfdrohnen',
#   'b2409',
#   'allesfuersklima',
#   'schlussrunde',
#   'hungerstreik21',
#   'schüler',
#   'allesfürsklima',
#   'klimasekte',
#   'wohlstand',
#   'freiewähler',
#   'grünerwasserstoff',
#   'bautzen',
#   'fffsep24',
#   'wirecard',
#   'gemeinsamsindwirstark',
#   'meisterwerden',
#   'thüringen',
#   'heuchler',
#   'toleranznaklar',
#   'diemeuterer',
#   'keinbockaufnazis',
#   'cducsu',
#   'hofgarten',
#   'muenster',
#   'laschetlügt',
#   'fck2038',
#   'lehrermangel',
#   'fridaysforfutureberlin',
#   'geongineering',
#   'deepsciencepodcast',
#   'diesmalgruen',
#   'btw',
#   'dd2409',
#   'frauenmachengeschichte',
#   'abgeordnetenhaus',
#   'berlinomat',
#   'aghw21',
#   'bild',
#   'protestzug',
#   'churchesforfuture',
#   'alledoerferbleiben',
#   'annalenabaerbock',
#   'klimaaktivistin',
#   'cumex',
#   'erfurt',
#   'kirche',
#   'wohnungsnot',
#   'migration',
#   'dilemma',
#   'laschetdarfnichtkanzlerwerden',
#   'allefürdiezukunft',
#   'flutkatastophe',
#   'passau',
#   'ichwaehlelinks',
#   'germanelection2021',
#   'nomoreexcuses',
#   'greenparty',
#   'bundestagswahl2021',
#   'klimaschutzistfreiheitsschutz',
#   'kohlestopp',
#   'demonstranten',
#   'lüneburg',
#   'sachsen',
#   'hh2409',
#   'ozean',
#   'meeresforschung',
#   'frühstart',
#   'triell',
#   'piratenwählen',
#   'developers4future',
#   'devsforfuture',
#   'programminghumor',
#   'allefür1komma5',
#   'javascript',
#   'lehrer',
#   'konstanz',
#   'weidel',
#   'fulda',
#   'braunerlaschet',
#   'klimagebet',
#   'rtl',
#   'erderwärmung',
#   'wegenmorgen',
#   'caritas',
#   'hattingen',
#   'schwelm',
#   'softwaredeveloper',
#   'startup',
#   'annewill',
#   'lawyersforfuture',
#   'herbert',
#   'diellnke',
#   'niewiedercdu',
#   'fakenews',
#   'beidestimmengrün',
#   'vortrag',
#   'stadtstrasse',
#   'lobauautobahn',
#   'nolobau',
#   'ardwahlarena',
#   'aktivistin',
#   'wahlkandidat',
#   'wahl',
#   'enkelbriefen',
#   'btw21klima',
#   'sportfürsklima',
#   'energiecharta',
#   'noect',
#   'enkelbriefe',
#   'btwahl2021',
#   'unteilbar',
#   'laschetverliert',
#   'baerbockjetzterstrecht',
#   'amnestyinternational',
#   'solidarität',
#   'respekt',
#   'zukunftsteam',
#   'solarenergie',
#   'saarbrücken',
#   'schulstreik',
#   'falschinfirmationen',
#   'rotgrün',
#   'sondergenehmigung',
#   'kohlekraftwerk',
#   'nichtwienrw',
#   'duesseldorf',
#   'sicherebildung',
#   'kinderrechte',
#   'kinderdurchseuchung',
#   'longcovidkids',
#   'dus2708',
#   'allesistdrin',
#   'ddorfistbereit',
#   'cduunwaehlbar',
#   'zentralstreik',
#   'klimafrage',
#   'amtischmit',
#   'huether',
#   'gasausstieg',
#   'deutschlandausstieg',
#   'grueneverhindern',
#   'klimaliste',
#   'pulseofeurope',
#   'denkeuropamit',
#   'denkklimamit',
#   'europasalon',
#   'griechenland',
#   'waldbrände',
#   'frankfurt',
#   'ffm1308',
#   'streikmituns',
#   'lawyers4future',
#   'demonstrationen',
#   'bankenblockieren',
#   'ourclimatisnotforsale',
#   'thinkgreenitsfriday',
#   'blockupy',
#   'flut',
#   'weltklimarat',
#   'ökolobby',
#   'turkeyisonfire',
#   'athensfire',
#   'jungefrau',
#   'kipppunkt',
#   'turkeyisburning',
#   'uniper',
#   'brunsbuettel',
#   'laschomat',
#   'arminlaschet',
#   'autoindustrie',
#   'wald',
#   'niemehrcducsu',
#   'spree',
#   'robinwood',
#   'flutkatastrophe',
#   'telegram',
#   'wahlkampfmanipulation',
#   'hochwasserkatastrophe',
#   'hupdolen',
#   'ökomarxisten',
#   'linksgrünesubintelligenz',
#   'klimalobbyisten',
#   'hochwasser',
#   'klimakriseisthier',
#   'ödp',
#   'rosenheim',
#   'powersätzeamfreitag',
#   'stern',
#   'kesselbambule',
#   'co2steuer',
#   'luisahilftnicht',
#   'klimaschmutzlobby',
#   'stockolores',
#   'umweltkatastrophe',
#   'gruenejugend',
#   'welt',
#   'wetzel',
#   'bojanowski',
#   'hallein',
#   'zib2',
#   'flutwelle',
#   'klimaerwärmung',
#   'seehofer',
#   'laschetlacht',
#   'tourdödp',
#   'kemfert',
#   'quaschning',
#   'aufbruchsklima',
#   'mondaysforfuture',
#   'tierschutz',
#   'wiesenhof',
#   'tierrecht',
#   'tierbefreiung',
#   'rlp',
#   'erftstadt',
#   'rheinstraße',
#   'wahlprogramm',
#   'zdf',
#   'wiesbaden',
#   'nowater',
#   'rwe',
#   'cancellej',
#   'övp',
#   'koalitionspakt',
#   'klimacheck',
#   'autobahnprojekte',
#   'nervosität',
#   'sterki',
#   'ourenergy2030',
#   'heidelberg',
#   'baerbockwählen',
#   'klimaschutzmaßnahmen',
#   'jungeunion',
#   'cduwahlprogramm',
#   'europawahl',
#   'artclimatetaskforce',
#   'wirhabeneinewahl',
#   'alexanderplatz',
#   'klimawandelignoranten',
#   'nextglobalclimatestrike',
#   'kanada',
#   'zivilgesellschaft',
#   'disoursesofdelay',
#   'klimawende',
#   'klimagesetz',
#   'traiskirchen',
#   'sanktpölten',
#   'radl',
#   'menschlichkeit',
#   'holtdieleuteraus',
#   'wirhabenplatz',
#   'ncradelt',
#   'widerstand',
#   'fridaysforquokkas',
#   'niedriglöhne',
#   'klimademo',
#   'a49',
#   'gutso',
#   'klimajugend',
#   'blödsinn',
#   'dbdk21',
#   'emcke',
#   'bpt',
#   'greatawakening',
#   'qanon',
#   'plastik',
#   'müll',
#   'futuremobilitysummit',
#   'tatort',
#   'fossileimagination',
#   'verkehrswendejetzt',
#   'fahrräder',
#   'aufbruchfahrrad',
#   'radwege',
#   'rs1',
#   'radverkehr',
#   'brasilien',
#   'zwickau',
#   'nazis',
#   'bearbock',
#   'frontal21',
#   'sachsenanhalt',
#   'ltwlsa21',
#   'bachmann',
#   'eilmeldung',
#   'pflanzenmilch',
#   'changeiscoming',
#   'milch',
#   'univie',
#   'semesterfrage',
#   'erde',
#   'luissa',
#   'in15jahrenaufnull',
#   'palästina',
#   'uno',
#   'bds',
#   'settlercolonialism',
#   'apartheidisrael',
#   'vergangenheitsbewältigung',
#   'haustür',
#   'wehrmacht',
#   'stopmisinformation',
#   'marskeinealternative',
#   'sciencematters',
#   'kirchentag',
#   'angelamerkel',
#   'reemtsa',
#   'keinekohlefuerdiekohle',
#   'workshop',
#   'klimaarschlöcher',
#   'göttingen',
#   'bank',
#   'investitionen',
#   'energieträger',
#   'klimapledge',
#   'hanau',
#   'hass',
#   'hetze',
#   'göre',
#   'neubauerluegt',
#   'sozialismus',
#   'holocaust',
#   'geschichtsrevisionismus',
#   'lachet',
#   'generationsgerechtigkeit',
#   'versammlungsgesetz',
#   'scheuer',
#   'phoenixrunde',
#   'klimalockdown',
#   'dieanstalt',
#   'amthor',
#   'pfeiffer',
#   'superwahljahr',
#   'bundesregierung',
#   'doppelmoral',
#   'klimahüpfer',
#   'energiepolitik',
#   'verbrenner',
#   'elektroauto',
#   'enteignung',
#   'biontech',
#   '1mai',
#   'bundesverfassungsgericht',
#   'klimaklage',
#   'tazlab2021',
#   'windenergie',
#   'april',
#   'gebauer',
#   'testpflicht',
#   'seebrücke',
#   'frauenstreik',
#   'bn1004',
#   'klimacampsaar',
#   'saarland',
#   'mindestlohn',
#   'uweconradt',
#   'zittau',
#   'grünelunge',
#   'artensterben',
#   'klimaprämie',
#   'dannenröderforst',
#   'agrarindustrie',
#   'notaprilfools',
#   'genz',
#   'kolonialismus',
#   'ddr',
#   'autogipfel',
#   'ac1903',
#   'landtagswahlen',
#   'greifswald',
#   'oberbaumbrücke',
#   'allefuer1komma5',
#   'dashausbrennt',
#   'wildsau',
#   'ka1903',
#   'klimaschutzjetzt',
#   'klimastreikinberlin',
#   'allefür1komma5grad',
#   'köln1903',
#   'k1903',
#   'mainz',
#   'darmstadt',
#   'werder',
#   'objektperspektiven',
#   'experimentierfeld',
#   'kli',
#   'kassel',
#   'neuesprofilbild',
#   'eurodrohne',
#   'fcas',
#   'sengal',
#   'ethiopia',
#   'mobilität',
#   'rad',
#   'öffentlicherraum',
#   'augustinlesen',
#   ...],
#  ['fridaymotivation',
#   'fridayvibes',
#   'goodmorningeveryone',
#   'fridaythoughts',
#   'thoughts',
#   'atmosphere',
#   'beauty',
#   'morning',
#   'freshness',
#   'emotions',
#   'ideas',
#   'city',
#   'fridayfeeling',
#   'nature',
#   'vegan',
#   'weekend',
#   'worldveganday',
#   'veganday',
#   'meat',
#   'govegan',
#   'friday',
#   'fridaymorning',
#   'climat',
#   'ff',
#   'naturelovers',
#   'nft',
#   'justice',
#   'rewilding',
#   'animalliberation',
#   'nationaldolphinday',
#   'dolphinday',
#   'captivity',
#   'kills',
#   'stopthegrind',
#   'thursdayvibes',
#   'opwhales',
#   'opseaworld',
#   'defendthewild',
#   'seaspiracy',
#   'happyeaster',
#   'cowspiracy',
#   'thursday',
#   'dogs',
#   'food',
#   'photo',
#   'winter',
#   'blockchain',
#   'happiness',
#   'healthy',
#   'sea',
#   'snow',
#   'fridayfunday',
#   'mayday',
#   'ecologie',
#   'katyayan',
#   'naturephotography',
#   'wakeup',
#   'greenfriday',
#   'reforestation',
#   'peaceful',
#   'aacc',
#   'decarbonize',
#   'ocean',
#   'bird',
#   'mondaymorning',
#   'bagneux',
#   'parc',
#   'hautsdeseine',
#   'municipales',
#   'municipales2020',
#   'bagneux2020',
#   'grandparis',
#   'biodiversité',
#   'eelv',
#   'yyc',
#   'slowtravel',
#   'wednesdaythoughts',
#   'sunset',
#   'hamont',
#   'mekong',
#   'luangprabang',
#   'laos',
#   'nofly',
#   'fromsingapore2germany',
#   'quote',
#   'gardening',
#   'fruits',
#   'followfriday',
#   'italy',
#   'sadhguruquotes',
#   'community',
#   'happy',
#   'birthday',
#   'cher',
#   'love',
#   'animal',
#   'liberation',
#   'freedom',
#   'sentient',
#   'beings',
#   'allstars7',
#   'nationalrescuedogday',
#   'nationalendangeredspeciesday',
#   'worldbeeday',
#   'endspeciesism',
#   'peace',
#   'happyvalentinesday',
#   'veganuary',
#   'inspiration',
#   'change',
#   'chocolate',
#   'mentalhealth',
#   'wednesdaywisdom',
#   'resist',
#   'saturdaythoughts',
#   'lettertotheminister',
#   'saturdaymorning',
#   'flowersonfriday',
#   'écologie',
#   'business',
#   'siccità',
#   'animals',
#   'vegans',
#   'animalrights',
#   'museumweek2022',
#   'ambientemw',
#   'environmentmw',
#   'weather',
#   'vita',
#   'motivation',
#   'fridayfitness',
#   'photography',
#   'photos',
#   'photographyisart',
#   'ontario',
#   'btc',
#   'crypto',
#   'entrepreneurship',
#   'airdrops',
#   'success',
#   'goldenheart',
#   'quotes',
#   'shireenabuakleh',
#   'anchor',
#   'confidence',
#   'followerpower',
#   'veganism',
#   'veganlifestyle',
#   'noanimaluse',
#   'speciesism',
#   'lifestyle',
#   'cleaning',
#   'swachhatajaarihai',
#   'writingcommunity',
#   'nftcommunity',
#   'goodmorning',
#   'goodmorningtwitterworld',
#   'nftcollector',
#   'lifemantrabypriya',
#   'morningquotes',
#   'fridayquotes',
#   'waahmuz',
#   'mithileshbaria',
#   'urdu',
#   'urdupoetry',
#   'shair',
#   'rishta',
#   'thursdaymorning',
#   'voiceover',
#   'ligue_des_optimistes',
#   'photographer',
#   'flower',
#   'pflanzenbasierte',
#   'fleisch',
#   'milchkuhmittwoch',
#   'live',
#   'cuomocommunity',
#   'twitterfriends',
#   'haveagoodday',
#   'glitterglue',
#   'gutenmorgen',
#   'freitag',
#   'kaffee',
#   'wochenende',
#   'happyfriday',
#   'wtf',
#   'standingwithukraine',
#   'stopthewar',
#   'amessagetoputin',
#   'weekendvibes',
#   'truthunveiled',
#   'fridayvibe',
#   'fridayfun',
#   'fridayfeels',
#   'cardanowomen',
#   'cardano',
#   'womenintech',
#   'womeninnfts',
#   'womenincrypto',
#   'respectanimals',
#   '365dayswild',
#   'macro',
#   'macrophotography',
#   'gardeningtwitter',
#   'gardenersworld',
#   'flowerpower',
#   'flowerlover',
#   'flowerreport',
#   'thephotohour',
#   'naturalbeauty',
#   'naturephoto',
#   'botany',
#   'happyweekend',
#   'जय_श्री_राधे_कृष्ण',
#   'egld',
#   'team',
#   'positivevibes',
#   'infotweet',
#   'marketingtips',
#   'branding',
#   'inspirationalquote',
#   'flash',
#   'november',
#   'autumn',
#   'windy',
#   'rain',
#   'wet',
#   'cloudy',
#   'sunshine',
#   'weatherforecast',
#   'motivationalquotes',
#   'motivational',
#   'zeehindustanquotes',
#   'corgi',
#   'corgicrew',
#   'thecorporatelady',
#   'ethnic',
#   'worklifebalance',
#   'size',
#   'brain',
#   'dependent',
#   'vegispowerful',
#   'worldvegetarianday',
#   'happyday',
#   'goodnewstoday',
#   'geceyebirsözbırak',
#   'cuma',
#   'gamedev',
#   'indiedev',
#   'indiegame',
#   'indiegamedev',
#   'indie',
#   'indiegames',
#   'gamer',
#   'games',
#   'gaming',
#   'game',
#   'programmer',
#   'unity',
#   'thursdaythoughts',
#   'saturdayvibes',
#   'firenze',
#   'arnabgoswami',
#   'caccia',
#   'incendi',
#   'stopcaccia',
#   'cryptocurrency',
#   'cryptotrading',
#   'stockedge',
#   'elearnmarkets',
#   'stockmarketindia',
#   'trending',
#   'azione',
#   'savewildlife',
#   'godmorningfriday',
#   'contentmarketing',
#   'marketingstrategy',
#   'digitalmarketing',
#   'marketing',
#   'blogging',
#   'sociamedia',
#   'blog',
#   'growthhacking',
#   'writerslift',
#   'author',
#   'links',
#   'work',
#   'milestone',
#   'tacotuesday',
#   'saladdays',
#   'breakfast',
#   'breakfastclub',
#   'twittertrends',
#   'beans',
#   'pasta',
#   'foodies',
#   'perfect',
#   'weird',
#   'huhtikuu',
#   'toukokuun',
#   'lumi',
#   'kevät',
#   'europeday',
#   'शुक्र_श्रीशक्ति',
#   'positivemindset',
#   'vocal4local',
#   'swadeshi',
#   'प्रबुद्ध_मनन',
#   'स्वदेशी',
#   'देशभक्त',
#   'किसान_पुकार_सुने_सरकार',
#   'atmanirbharbharat',
#   'mentalhealthawareness',
#   'nomoreemptypromisis',
#   'smile',
#   'condition',
#   'intention',
#   'reason',
#   'care',
#   'exception',
#   'relation',
#   'goodmorningworld',
#   'tgif',
#   'act',
#   'believe',
#   'right',
#   'good',
#   'yourself',
#   'shootmode',
#   'morningglory',
#   'pakkanen',
#   'vinter',
#   'fridayfunny',
#   'fridaymood',
#   'twitterworld',
#   'iqrtg',
#   'livelife',
#   'makeyouhappy',
#   'enjoyingeverydaylife',
#   'fikafuntimes',
#   'twitteroftime',
#   'contest',
#   'rajajitigerreserve',
#   'rishikesh',
#   'indiaves',
#   'twitternaturecommunity',
#   'earthcapture',
#   'bbcwildlifepotd',
#   'earthpix',
#   'sundayshoutout',
#   'positivity',
#   'bepositive',
#   'सकारात्मक_संदेश',
#   'नव_वर्ष_अन्नदाता_के_संग',
#   'sundayfeels',
#   'हिंदी',
#   'लखनऊ_विश्वविद्यालय',
#   'pmblessinglu',
#   'lucentennialcelebrations',
#   'panna',
#   'eat',
#   'goodmorningamerica',
#   'fridaylivestream',
#   'travelcorridor',
#   'florence',
#   'flood',
#   'november1st',
#   'failure',
#   'enthusiasm',
#   'worldfoodday',
#   'nayisoch',
#   'icecream',
#   'carboninequality',
#   'crestedaily',
#   'crestemedia',
#   'letsgrowtogether',
#   'crestefamily',
#   'prayer',
#   'hitanshisharma',
#   'mrfaisu',
#   'foodie',
#   'fabulousfinn',
#   'finnslawpart2',
#   'thinbluepaw',
#   'running',
#   'mountains',
#   'try',
#   'something',
#   'positive',
#   'productive',
#   'wonderful',
#   'fridaylove',
#   'contestindia',
#   'contestalertindia',
#   'contesttime',
#   'contestalartindia',
#   'contestquestion',
#   'quiztime',
#   'quiz',
#   'quizzed',
#   'quiznight',
#   'quizbuzz',
#   'friyay',
#   'fortnite',
#   'gifgame',
#   'dotin',
#   'iamin',
#   'playtime',
#   'digitalindia',
#   'armeniastrong',
#   'americanpolish',
#   'tiktokdown',
#   'garden',
#   'gardenshour',
#   'flowers',
#   'roses_are_rosie',
#   'leadership',
#   'men',
#   'tukslaw',
#   'rescuedog',
#   'sign',
#   'petition',
#   'please',
#   'secretwalks',
#   'secret',
#   'place',
#   'reflection',
#   'stayconnectedtogether',
#   'lovewhereyoulive',
#   'wellbeing',
#   'connections',
#   'swansea',
#   'wales',
#   'youthworkwales',
#   'cat',
#   'cats',
#   'kitten',
#   'catsoftwitter',
#   'catsontwitter',
#   'catsofinstagram',
#   'cats_of_world',
#   'dadijanki',
#   'omshanti',
#   'rajayoga',
#   'meditation',
#   'spirituality',
#   'thetimeisnow',
#   'thefuturewechoose',
#   'gch',
#   'foodblog',
#   'yummy',
#   'dream',
#   'keepdreaming',
#   'ddquiz',
#   'contestofchampions',
#   'quarantineandchill',
#   'lockdownextension',
#   'lockdown2',
#   'movie',
#   'guessthemovie',
#   'answersnews',
#   'youtube',
#   'progress',
#   'focus',
#   'now',
#   'behappy',
#   'healthiswealth',
#   'karma',
#   '2020vision',
#   'friday13th',
#   'dinner',
#   'foodbanks',
#   'fridaythe13th',
#   'tasty',
#   '13marzo',
#   'lasagne',
#   'quarantena',
#   'iorestoacasa',
#   'iosuonodacasa',
#   'iomangiodacasa',
#   'venerdi13',
#   'dennisthemenace',
#   'distancelearning',
#   'funfactfriday',
#   'comedy',
#   'sooraraipottru',
#   'sudhakongara',
#   'gvprakash',
#   'suriya',
#   'workout',
#   'happybirthdayceo',
#   'ceoquotes',
#   'ceo',
#   'ees20',
#   'okenwachukwuma',
#   'sootysfuckitfriday',
#   'cheesecake',
#   'sweet',
#   'getwellsoon',
#   'buonaserata',
#   'buonanotte',
#   'marvelousnature',
#   'socialistanyday',
#   'biodiveristy',
#   'farming',
#   'tuesdaythoughts',
#   'coronavirusuk',
#   'poetry',
#   'zorasarahcreates',
#   'zorasarahblogs',
#   'onmusicvideo',
#   'asprinkleofsorcery',
#   'zorahosen',
#   'retweet',
#   'heroes',
#   'seo',
#   'b2bmarketing',
#   'socialmediamarketing',
#   'germanmediart',
#   'retweetplease',
#   'denkmaldrübernach',
#   'andieeigenenasefassen',
#   'isso',
#   'nichtakleubereinenkammscheren',
#   'auchmalneanderemeinungzulassen',
#   'nikon',
#   'nikonphotography',
#   'nikonnofilter',
#   'photooftheday',
#   'landscape',
#   'costabrava',
#   'potd',
#   'compassionateliving',
#   'maketheconnection',
#   'crueltyfree',
#   'stopanimalabuse',
#   'stopanimalcruelty',
#   'バレンタイン',
#   'ヴィーガン子育てバレンタイン',
#   'wise',
#   'motivacion',
#   'ambition',
#   'biodiversität',
#   'nojudgement',
#   'like4like',
#   'loveis',
#   'vya',
#   'vaylatoken',
#   'vaylaiens',
#   'tbtjuly2019',
#   'behindthescenes',
#   'catsforfuture',
#   'cats4climate',
#   'catswillsavetheworld',
#   'tbttemmuz2019',
#   'kameraarkası',
#   'gelecekiçinkediler',
#   'fridaylituations',
#   'fridayreads',
#   'buffaloeshustles',
#   'thoughtfortheday',
#   'friends',
#   'fridaymadness',
#   'झूठे_रेप_केस_में_बढ़ोतरी',
#   'klimachallenge',
#   'grèveclimat',
#   'dld',
#   'themorningflava',
#   'theweekendfavour',
#   'twitch',
#   'twitchde',
#   'germantwitchrt',
#   'stream',
#   'streamer',
#   'streamacademyrt',
#   'primenightrt',
#   'twitchtv',
#   'rubiesallies',
#   'januar',
#   'thankyousafer',
#   'saferlift',
#   'follome',
#   'ffxiv',
#   'writingcommmunity',
#   'writerlift',
#   'tweetme',
#   'ff14',
#   'fridayheadlines',
#   'cardi',
#   'saturday',
#   'congress',
#   'danishkaneria',
#   'narendramodi',
#   'rahulgandhi',
#   'राष्ट्रवादिराठौर',
#   'indianarmy',
#   'boxingday2019',
#   'amwriting',
#   'artist',
#   'courage',
#   'anon',
#   'thoughtoftheday',
#   'decemberwish',
#   'december13th',
#   'december',
#   'planetearth',
#   'globe',
#   'flatearth',
#   'truth',
#   'generalelection2019',
#   'page48',
#   'blackfriday2019',
#   'thanksgivingwithblackfamilies',
#   'thanksgivingdinner',
#   'blackfridayfights',
#   'leftovers',
#   'leftovertunes',
#   'diaryoftips',
#   'macysblackfriday',
#   'funnyvines',
#   'byte',
#   'vine',
#   'funny',
#   'fail',
#   'howiwonblackfriday',
#   'kohlsblackfriday',
#   'target',
#   'walmartblackfriday',
#   'anime',
#   'buynothingday',
#   'adoptdontshop',
#   'jellybellyfriday',
#   'blackfridaysale',
#   'ecoshopping',
#   'morningmotivation',
#   'gooutside',
#   'neilyoung',
#   'neilyoungarchives',
#   'teachers',
#   'bigschoolsbirdwatch',
#   'outdoorlearning',
#   'schools',
#   'dog',
#   'dogsoftwittter',
#   'enjoynature',
#   'brekfast',
#   'fridaykiss',
#   'millefoglie',
#   'mozzarella',
#   'surprise',
#   'gratitude',
#   'innerpower',
#   'sewaactivitiesbyashram',
#   'संत',
#   'आशाराम',
#   'बापूजी',
#   'गाजियाबाद',
#   'talkfriday',
#   'thenationnews',
#   'विश्वविख्यातकवयित्रीडॉकविताकिरण',
#   'mrsindiarajasthan2019',
#   'ब्रांडएम्बेसडर',
#   'brandambassador',
#   'againstpollution',
#   'indiaagainstpollution',
#   'पॉलीथिनहटाओपर्यावरणबचाओ',
#   'tuesdaymotivation',
#   'zerohunger',
#   'cupofuji',
#   'togetherwefindtheway',
#   'neverwalkalone',
#   'saturdaymotivation',
#   'loveearth',
#   'loveall',
#   'happynewmonth',
#   'getoutside',
#   '100actions4nature',
#   'janshakti4jalshakti',
#   'waterfall',
#   'abstorm',
#   'caturday',
#   'clothing',
#   'धनतेरस',
#   'boycott4future',
#   'yum',
#   'endgunviolence',
#   'riseinfakerapecases',
#   'section144',
#   'skincare',
#   'skincareroutine',
#   'beautytips',
#   'skincaretips',
#   'clearskin',
#   'naturalskincare',
#   'pizza',
#   'review',
#   'comingoutday',
#   'kaalateeka',
#   'selfiequeen',
#   'selfietime',
#   'pkyek',
#   'pyarkiiyeekkahani',
#   'abhiya',
#   'sukirti',
#   'sukirtikandpal',
#   'vivian',
#   'viviandsena',
#   'visu',
#   'suku',
#   'renu',
#   'renucreations',
#   'drones',
#   'nationallottery',
#   'bame',
#   'nextgenerationleaders',
#   'octobrerose2019',
#   'goodvibes',
#   '2019mademerealize',
#   'fancyfriday',
#   'windingdown2019',
#   'weekendwithbae',
#   'chillvibes',
#   'thatfridayfeeling',
#   'futurefridays',
#   'octobervibes',
#   'positivethinking',
#   'ऋषि_प्रसाद',
#   'healthtipsbybapuji',
#   'nuhrimersten',
#   'ukrainegate',
#   'felizviernesatodos',
#   'planetaazul',
#   'ejecafetero',
#   'superm_jopping',
#   'jokermovie',
#   'joker',
#   'günaydın',
#   'ymornings',
#   'lakelandclimatewarriors',
#   'sundayforfuture',
#   'myyoutubechannelwouldbe',
#   'foodblogger',
#   'bestfridaynightplans',
#   'foodpics',
#   'cooking',
#   'recipe',
#   'cake',
#   'desserts',
#   'pie',
#   'fridaynight',
#   'parnellthechef',
#   'felizfindesemana',
#   'abandonedplaces',
#   'abandoned',
#   'urbex',
#   'fursuitfriday',
#   'horrorfamily',
#   'horrorcommunity',
#   'mutantfam',
#   'jasonvoorhees',
#   'thenun',
#   'flashbackfriday',
#   'freakyfriday',
#   'afterwecollidedmovie',
#   'animalcruelty',
#   'switzerland',
#   'zurich',
#   'nutorla',
#   'nutorlite',
#   'nutorite',
#   'proudlyyou',
#   'supremeplaypromo',
#   'supremeplay',
#   'supremeplaymarket',
#   'bhadrakali',
#   'amman',
#   'temple',
#   'visitwarangal',
# ...
#   'latinamerica',
#   'coronacrisis',
#   'bushfirerebellion',
#   'stem',
#   'girlsinstem',
#   'ai',
#   'designthinking',
#   'tokyo',
#   'no石炭',
#   'no石油',
#   'nocoaljapan',
#   'tokyo2020',
#   'youmatter',
#   'global',
#   'dumpfossilfuels',
#   'environmentally',
#   'extinctionrebellionlondon',
#   'marinelife',
#   'followbackrenewables',
#   'fbrparty',
#   'fbr',
#   'oksolar',
#   'car',
#   'biomass',
#   'electricvehicle',
#   'windenergy',
#   'van',
#   'truck',
#   'boat',
#   'tesla',
#   'trucks',
#   'everydayforfuture',
#   'leuven',
#   'tree',
#   'windwatersolar',
#   'solarpanels',
#   'wsdf2020',
#   'youthquake',
#   'webelieveinaction',
#   'education',
#   'technologyupdates',
#   'gardens',
#   'dutch',
#   'tamil',
#   'climatcrisis',
#   'gretafornobel',
#   'unga2019',
#   'nothingaboutuswithoutus',
#   'crpd',
#   'inclusion',
#   'disabilities',
#   'conversation',
#   'disinformation',
#   'happyholi2022',
#   'savewater',
#   'plantatree',
#   'happynewyear',
#   'bcstorm',
#   'bcflood',
#   'heatdome',
#   'rcaf',
#   'misinformation',
#   'electricvehicles',
#   'beaware',
#   'pge',
#   '2020ends',
#   'wastefree',
#   'sanfrancisco',
#   'follow',
#   'sf',
#   'styrofoam',
#   'composting',
#   'circulareconony',
#   'tibet',
#   'awareness',
#   'worldpeace',
#   'fridaysforfutureusa',
#   'renewableenegy',
#   'californians',
#   'landscapes',
#   'rural',
#   'rebellionweek',
#   '仏',
#   '佛',
#   'buddha',
#   'himalayas',
#   'laufzeitverlängerung',
#   'lastgeneration',
#   'blackouts',
#   'gasversorgung',
#   'habeckruecktritt',
#   'goodbyedeutschland',
#   'glastonbury',
#   'plantyourage',
#   'savesoildelhi',
#   'noise',
#   'sähköauto',
#   'emobile',
#   'pace',
#   'bluecarbon',
#   'windpower',
#   'sauna',
#   'räumung',
#   'lobaubleibt',
#   'lobaucamp',
#   'jugendrat',
#   'raeumung',
#   'oscarstembridge',
#   'carlareemtsma',
#   'gashahnzu',
#   'russischesgas',
#   'gasausrussland',
#   'tacoma',
#   'frackedgas',
#   'toxins',
#   'carbone',
#   'valentinstag',
#   'okainkitui',
#   'foremanameomoka',
#   'bildetbanden',
#   'youngpeople',
#   'bhavreenkandhari',
#   'switch',
#   'ökoterrorismus',
#   'austria',
#   'goodnighttwitterworld',
#   'stadtstraße',
#   'noiaa',
#   'worldwaterweek',
#   'fota4climate',
#   'ps126',
#   'climatestrike4future',
#   'saveourplanet',
#   'hamas',
#   'israelunderfire',
#   'israelunderattack',
#   'heidelbergcement',
#   'nonhumanrights',
#   'palmoil',
#   'consumers',
#   'dumpsters',
#   'indonesien',
#   'africavote',
#   'africansrising',
#   'aractivismawards',
#   'land4life',
#   'b117',
#   'joinin',
#   'klimadebatte',
#   'autoindustry',
#   'tedxstockholmcountdown',
#   'takeaction',
#   'klimaapokalypse',
#   'capreform',
#   'gertur',
#   'canlab',
#   '5g',
#   'iot',
#   'smartliving',
#   'ar',
#   'apocalypse2020',
#   'maga2020',
#   'joebiden',
#   'kalifornien',
#   'eiadraft2020',
#   'eltville',
#   'ycff',
#   'waste',
#   'savetheenvironment',
#   'greenliving',
#   'treeplanting',
#   'fish',
#   'gogretago',
#   'rustbelt',
#   'justhanks',
#   'environmental',
#   'climatecardinals',
#   'day42oflockdown',
#   'co2ppm',
#   'all4earth',
#   'fffdigitalstrike',
#   'earthhour2020',
#   'stayathomeandstaysafe',
#   'connect2earth',
#   'earthhourwales',
#   'earthhouruk',
#   'lightsoff',
#   'nolympia',
#   'ökorassismus',
#   'heathrow',
#   'kenyan',
#   'parenting',
#   'utopie',
#   'kohlausstieg',
#   'endracism',
#   'left',
#   'immigration',
#   'greens',
#   'think',
#   'leaveitintheground',
#   'pff',
#   'drawdown',
#   'nonewfossilfuels',
#   'energytwitter',
#   'poll',
#   'palmsteadslw',
#   'talklandscape',
#   'landscapeforfuture',
#   'lush',
#   'nolympiaf4f',
#   'flightshame',
#   'flygskam',
#   'wildliferescue',
#   'freshair',
#   'frischeluft',
#   'cgl',
#   'tmx',
#   'unhchr',
#   'zerocarbon',
#   'thirdindustrialrevolution',
#   'sharingeconomy',
#   'klimasozialismus',
#   'sendinglovefrompatagonia',
#   'democracy',
#   'elections',
#   'manovra2020',
#   'pickelhaube',
#   'soldaten',
#   'climatesummit',
#   'lisalein',
#   'antifaklima',
#   'laueslüftchen',
#   'generalelection',
#   'racist',
#   'islamaphobic',
#   'sexist',
#   'homophobic',
#   'frackboris',
#   'unstoppable',
#   'hallam',
#   'phheidelberg',
#   'bildungbitte',
#   'getoutthevote',
#   'jetzthandeln',
#   'fuß',
#   'pkw',
#   'schulbesuch',
#   'personenbeförderung',
#   'fahrrädern',
#   'doppeldenk',
#   'gretagonuclear',
#   'sevenworldsoneplanet',
#   'everydropcounts',
#   'savewatersavelife',
#   'jalshaktiabhiyan',
#   'bbcqt',
#   'wiseup',
#   'talkingclimate',
#   'tippingpoint',
#   'nodapl',
#   'standingrock',
#   'juttaditfurth',
#   'cduagainstfuture',
#   'inequalities',
#   'empowered',
#   'threatened',
#   'jugendhackt',
#   'reactor',
#   'control',
#   'skill',
#   'turbine',
#   'steam',
#   'elexn43',
#   'makethempay',
#   'verursacherprinzip',
#   'klimawahl2019',
#   'wahlench19',
#   'no3rdrunway',
#   'illustrator',
#   'gengnd',
#   'climatesongs',
#   'saturdayforsolutions',
#   'trumpresign',
#   'shapeyourfuture',
#   'helmholtzklima',
#   'beachcleanup',
#   'mobileapp',
#   'mixedreality',
#   '4ir',
#   'sdg14',
#   'saveger6',
#   'climatelitigation',
#   'heartland',
#   'systemschange',
#   'peking',
#   'leerflüge',
#   'milliarden',
#   'klimaproblem',
#   'atmosphäre',
#   'stopinthenameoflove',
#   'gutfaschisten',
#   'endanimalag',
#   'geoengineering',
#   'farmtofork',
#   'zeitfragen',
#   'nuketheclimate',
#   'nuklearia',
#   'mothersfornuclear',
#   'atoms4future',
#   'neckarwestheim'],
#  ['greenenergy',
#   'gogreen',
#   'government',
#   'greed',
#   'globalcrisis',
#   'leaveoilintheground',
#   'gocarfree',
#   'bikedontdrive',
#   'fightforonepointfive',
#   'midcoastnannas',
#   'stopecocide',
#   'bethechange',
#   'comics',
#   'comicsforclimate',
#   'biripi',
#   'koalas',
#   'nannassay',
#   'fundourfuturenotgas',
#   'saveourkoalas',
#   'ecosystem',
#   'wildlife',
#   'endangered',
#   'death',
#   'halloween',
#   'costumeshopping',
#   'happyspookyseason',
#   'peoplearedying',
#   'animalsaredying',
#   'thefutureneedsus',
#   'trickortreat',
#   'onetwoclimatescomingforyou',
#   'scary',
#   'cutthebullshit',
#   'wehavethedata',
#   'wehavethetechnology',
#   'humanchangenotclimatechange',
#   'species',
#   'collapse',
#   'losinglife',
#   'corporationsarekillingus',
#   'holdthemaccountable',
#   'rumors',
#   'alltherumorsaretrue',
#   'listentoscience',
#   'extinctionisforever',
#   'globalchange',
#   'overshoot',
#   'basketball',
#   'notevengonnatry',
#   'lazygovernment',
#   'americanpolitics',
#   'politicsarekillingpeople',
#   'globalcitizen',
#   'globalsolutions',
#   'worsethanthanos',
#   'humansaretheproblem',
#   'wecandobetter',
#   'tiktok',
#   'tiktokdance',
#   'iliketomoveitmoveit',
#   'strikeapose',
#   'vogue',
#   'planethumor',
#   'reducereuserecycle',
#   'wecanbetter',
#   'earthneedsyou',
#   'itsgettinghotinhere',
#   'coolestsummeryoulleverhave',
#   'marvel',
#   'marvelaudition',
#   'itstheendoftheworldasweknowit',
#   'keepoilintheground',
#   'fossilfuelsarekillingus',
#   'beforeitstoolate',
#   'wrongpayroll',
#   'police',
#   'dontgiveup',
#   'adifferenceofopinion',
#   'killingourselves',
#   'money',
#   'peoplelovemoneymore',
#   'leadershipmatters',
#   'entrepsawards',
#   '5gcitizens',
#   'thextraordinarionly',
#   'lyne',
#   'fridays4forest',
#   'dutyofcare',
#   'inktober',
#   'inktober2021',
#   'drawing',
#   'sour',
#   'draught',
#   'inktober2020',
#   'sleep',
#   'oldgrowth',
#   'ancientforest',
#   'protectourforests',
#   'nannas',
#   'fridays4forests',
#   'microplastics',
#   'actintime',
#   'climateclock',
#   'stopcoalplant',
#   'banallcars',
#   'banprivatecars',
#   'time4truth',
#   'glasgowclimatepact',
#   'transiciónenergética',
#   'betd22',
#   'greensofa',
#   'jointhedialogue',
#   'nswpol',
#   'thankyou',
#   'missedyou',
#   'imbackbaby',
#   'comic',
#   'coderedforhumanity',
#   'connect',
#   'fuzzy',
#   'endangeredspecies',
#   'quail',
#   'watch',
#   'raven',
#   'crystal',
#   'lakes',
#   'streams',
#   'endpollution',
#   'covidsafe',
#   'nswstategov',
#   'fridaysforforest',
#   'fixated',
#   'alarmed',
#   'nannasstrike4climate',
#   'worimi',
#   'forster',
#   'nsw',
#   'climatestrikeforster',
#   'koala',
#   'tigerquoll',
#   'sootyowl',
#   'tuncurry',
#   'activismisnotacrime',
#   'powerfulowl',
#   'greaterglider',
#   'myalllakes',
#   'koalakiller',
#   'gastransitiontoextinction',
#   'stopsantospillagingthepilliga',
#   'vivalanannalution',
#   'fridaysforfutureclimatecriminalwatch',
#   'kiddies',
#   'renewablesnow',
#   'fancy',
#   'wilderness',
#   'rodent',
#   'studentsstrike4climate',
#   'healthyrecovery',
#   'parachutefortheplanet',
#   'australiawildfires',
#   'saudi_arabia',
#   'tragedy',
#   'accentureatdavos',
#   'animalrescue',
#   'huh',
#   'solarbeam',
#   'pokemongotoronto',
#   'saveeverything',
#   'bulbasaur',
#   'pokélife',
#   'dougford',
#   'sero',
#   'climaticchange',
#   'ecologist',
#   'sustentable',
#   'sustentavel',
#   'sustentabilidad',
#   'thermalprint',
#   'smallchange',
#   'greatergood',
#   'ants',
#   'bansingleuseplastic',
#   'saveenvironment',
#   'singleuseplasticfreeindia'],
#  ['faschismus',
#   'fckafd',
#   'fcknzs',
#   'nazisraus',
#   'okboomer',
#   'neonazi',
#   'keinenmillimeternachrechts',
#   'afdm8dumm',
#   'neonazikalbitz',
#   'rechtsterror',
#   'keinmillimeternachrechts',
#   'pilgerunterwegs',
#   'magdeburg',
#   'rweenteignen',
#   'nazi',
#   'halle',
#   'koeln',
#   'satire',
#   'fightdreadlockracism',
#   'omas_gegen_dreadlocks',
#   'parents_for_undercut',
#   'keinvergessen',
#   'kulturrevolution',
#   'niewieder',
#   'böhmermann',
#   'md2201',
#   'nonazis',
#   'boellerverbot',
#   'umweltsau',
#   'köln',
#   'ganzmannheimhasstdieafd',
#   'afdverbotjetzt',
#   'klimastreikma',
#   'k2409',
#   'snobs',
#   'wdr',
#   'pro',
#   'antifas',
#   'antifamagazin',
#   'kilmagerechtigkeit',
#   'augsburg',
#   'weremember',
#   'silvester',
#   'vekehrswende',
#   'stadtrathalle',
#   'neuerwe',
#   'ypg',
#   'ypj',
#   'riseup4rojava',
#   'hungerstreik',
#   'protestmarsch',
#   'unitebehindscience',
#   'antifafamily',
#   'jugendantifa',
#   'jusos',
#   'nopegida',
#   'noh8',
#   'huber',
#   'fffhalle',
#   'klimafüralle',
#   'rojava',
#   'coops',
#   'pressefreiheit',
#   'meuthen',
#   'fffgegenrechts',
#   'kemmerich',
#   'lindnerruecktritt',
#   'höckeisteinfaschist',
#   'linder',
#   'lindnerrücktritt',
#   'ramelow',
#   'nofdp',
#   'mohring',
#   'nocdu',
#   'keinenmilimeternachrechts',
#   'md1701',
#   'omagate',
#   'koeln0401',
#   'k0401',
#   'umweltsauoma',
#   'pilgerstatthetze',
#   'feierabend',
#   'presseausweiss',
#   'bundespolizei',
#   'omaumweltsau',
#   'granniesforfuture',
#   'k0301',
#   'generationenkonflikt',
#   'connewitz',
#   'le3112',
#   'le0101',
#   'müllsammelaktion',
#   'nazisau',
#   'umweltsaugate',
#   'silvester2019',
#   'brotstattboeller',
#   'feuerwerk',
#   'feuerwerksverbot',
#   'nopegidadd',
#   'staatsfunk',
#   'restle',
#   'funk',
#   'wdr2',
#   'kindersoldaten',
#   'wdrkinderlieder',
#   'grünesneues',
#   'neuesjahr',
#   'kinderchor',
#   'moralpolizei',
#   'oma',
#   'weihnachtenundklimakrise',
#   'georgrestle',
#   'großeltern',
#   'böller',
#   'lindemann',
#   'rheinspange',
#   'wagner',
#   'danke',
#   'forgreta',
#   'triggerleftists',
#   'enteignungsparty',
#   'nikolaus',
#   'k0612',
#   'greenrojava',
#   'hallesaale',
#   'tvhalle',
#   'tanzdemo',
#   'wunderblokk',
#   'ggultras',
#   'su2911',
#   'siegburg',
#   'einschrittweiter',
#   'bonnerjugendbewegung',
#   'gauland',
#   'naziwatchgoe',
#   'clique',
#   'woistgreta',
#   'mitmenschenwürde',
#   'pegidaistscheisse',
#   'dresdenfüralle',
#   'dd2210',
#   'lichtstatthetze',
#   'bahnhof',
#   'dresdenneustadt',
#   'hate',
#   'yorkshirepatriots',
#   'nopasaran',
#   'chlodwigplatz',
#   'koeln1910',
#   'k1910',
#   'fridaysforpeace',
#   'rojavaresistance',
#   'hopefight',
#   'tolerave',
#   'herzstatthetze',
#   'solidaritätmitrojava',
#   'rojovakazanacak',
#   'stopturkeydefendrojava',
#   'do1110',
#   'antireport',
#   'ltw19',
#   'handicap',
#   'follower',
#   'herzstatthass',
#   'fairerumgangmiteinander',
#   'ggutras',
#   'abendland',
#   'fridaysforco2',
#   'lecktmich',
#   'maassen',
#   'klimajahr',
#   'b0802',
#   'hirte',
#   'enteignenstattkrise',
#   'friedlichesabotage',
#   'generationenbashing',
#   'b3112',
#   'froheweihnachten',
#   'hallohallo'],
#  ['気候変動',
#   '環境問題',
#   'プラントベース',
#   'おうちごはん',
#   '気候危機',
#   'plantbased',
#   '気候危機対策に菜食を',
#   'キッコーマン',
#   'twitter家庭料理部',
#   '大豆ミート',
#   '未来のためにお肉を減らそう',
#   'ヴィーガン',
#   'すき焼き',
#   '仙台麩',
#   '油麩',
#   'お腹ペコリン部',
#   'ココイチ',
#   'switchtoplantbased',
#   'エシカル消費',
#   '買い物は投票',
#   'アースデー',
#   'アースデイ',
#   '大戸屋',
#   '動物性不使用',
#   '代替肉',
#   '山口県',
#   '山口',
#   '牛肉',
#   'ソミート',
#   '牛丼',
#   'ビーガン',
#   'クリスマスディナー',
#   'メリークリスマス',
#   '読書の秋',
#   '東北大学',
#   '大学生協',
#   'fridaysforfutureiwate',
#   'fridaysforfuturesapporo',
#   '拡散希望',
#   'worldmeatfreeweek',
#   'おうちtftプロジェクト',
#   'vegetablefortwo',
#   'うちベジkitchen',
#   '昼ごはん',
#   'グリーンバーガー',
#   'モスバーガー',
#   '未来のために肉食減らそう',
#   'someat',
#   'おうちごはんを楽しもう',
#   '高野豆腐',
#   '唐揚げ',
#   'おうちご飯',
#   'greenfridays',
#   'eco',
#   'エコ',
#   'おうちランチ',
#   'ベジタリアン',
#   'いいにくいことを言う日',
#   'いい肉の日',
#   'fffsantiago',
#   'vegano',
#   'veganismo',
#   '気候ストライキ'],
#  ['usa',
#   'stopshell',
#   'actonsahel',
#   'ss4c',
#   'week17',
#   'hongkong',
#   'globalstrikeonline',
#   'cancelwhitedreadlocks',
#   'whitedreadlocks',
#   'cancelculture',
#   'gendern',
#   'blm',
#   'fff_digital',
#   'feminism',
#   'antifascist',
#   'swedishconstitution',
#   'rebellionextension',
#   'antifaterrorist',
#   'politcalcorrectness',
#   'gendergaga',
#   'oekoterror',
#   'noliestal',
#   'instagram',
#   'climateanxiety',
#   'northsea',
#   'nocarsundays',
#   'belarus',
#   'shoeprotest',
#   'stophell',
#   'northsearevolution',
#   '11thhfc',
#   'levelup',
#   'toxictories',
#   'stopthano',
#   'живебеларусь',
#   'deepclimatestrike',
#   'buildourfuture',
#   'nipaluna',
#   'stoppapreem',
#   'week11',
#   'savecalifornia',
#   'forestsofhope',
#   'oneearthonemovement',
#   'stoppapreemraff',
#   'equalrights',
#   'wohlstandsverwahrlosung',
#   'thinktank',
#   'alternativefürdeutschland',
#   'silverhair',
#   'hkpolicebrutality',
#   'hongkongers',
#   'soshk',
#   'hongkongprotests',
#   'fossilfreerevolution',
#   'week18',
#   'dd2010'],
#  ['standwithukraine️',
#   'stopwar',
#   'ichbinarmutsbetroffen',
#   'ohnemeinenphysiotherapeuten',
#   'therapeutenamlimit',
#   'einesorgeweniger',
#   'heimatstern',
#   'noafd',
#   'legalizeit',
#   'entkriminalisierungsofort',
#   'stopputinnow',
#   'gesundheitkämpft',
#   'unten',
#   'legalisierung',
#   'armutabschaffen',
#   'russianwarcrimes',
#   'legalisierungjetzt',
#   'stopwarinukraine',
#   'friedenjetzt',
#   'nazisrausausmünchen',
#   '200milligramm',
#   'spaziergangnurimwald',
#   'blienertfreude',
#   'münchenbleibtbunt',
#   'richtermüller',
#   'cannabisverfolgungstop',
#   'allesindenarm',
#   'legalisierenjetzt',
#   'wirwollencannabis',
#   'rheinlandtrump',
#   'laschetverhindern',
#   'laschetluegt',
#   'cdurausausderregierung',
#   'laschetrücktritt',
#   'merzauch',
#   'merzluegt',
#   'lebenretten',
#   'nolaschet',
#   'uefafail',
#   'sorgeweniger',
#   'legalzeit',
#   'patientenamlimit',
#   'aufstehen',
#   'wirsindmehr',
#   'pflegebonus',
#   'renten',
#   'grundrente',
#   'hartz4',
#   'thuehringen',
#   'cduthueringen',
#   'eskabolation',
#   'sogafd',
#   'putinskrieg',
#   'luebcke'],
#  ['giornatamondialedellambiente',
#   'consigli',
#   'viaggio',
#   'viaggiare',
#   'travel',
#   'viajes',
#   'birdlovers',
#   'owl',
#   'photograph',
#   'photographylovers',
#   'womensart',
#   'newhampshire',
#   'fridaynightfunkin',
#   'birdphotography',
#   'birding',
#   'birdwatching',
#   'viernes',
#   'suecia',
#   'acciónclimática',
#   'acciónxods',
#   'huelgaporlatierra',
#   'derechosdeniñosyniñas',
#   'saludparatodos',
#   'times',
#   'pacificocean',
#   'atacamadesert',
#   'sky',
#   'wanderlustxl',
#   'lluvia',
#   'puestadesol',
#   'buenviernes',
#   'findesemana',
#   'rest',
#   'vicentelopez',
#   'transito',
#   'bda',
#   'trensarmiento',
#   'queremosunpaisnormal',
#   'mifotobang'],
#  ['humanrights',
#   'padredalloglio',
#   'ahmedsamirsantawy',
#   'patrickzaki',
#   'veritapergiulioregeni',
#   'mariopaciolla',
#   'freepalestine',
#   'freeassange',
#   '18marzo',
#   'buongiorno',
#   'farmersprotest',
#   'firstnations',
#   'lostchildren',
#   'residentialschools',
#   'yemen',
#   'toolkitcase',
#   'disharavi',
#   'delhipolice',
#   'vertical',
#   'newsmo',
#   're',
#   'farmersprostests',
#   'freedisharavi',
#   'humanrightsviolations',
#   'toolkitexposed',
#   'farmersprotesthijacked',
#   'indiaagaistpropoganda',
#   'freenavalny',
#   'justiceformyanmar',
#   'oceansarerising',
#   'kiribati'],
#  ['win',
#   'socialmedia',
#   'gesellschaft',
#   'zigaretten',
#   'mothersday2022',
#   'climateconscious',
#   'giveaway',
#   'climatepositive',
#   'contestalert',
#   'winning',
#   'freemoney',
#   'giveaways',
#   'winner',
#   'gift',
#   'freebies',
#   'sweepstakes',
#   'forcefriday',
#   'graben',
#   'egoismus',
#   'rechts',
#   'empathie',
#   'funfriday',
#   'funday',
#   'fundayfriday',
#   'medibuddy',
#   'aapkahealthbuddy',
#   'funactivity',
#   'funkyfriday']]

# %%
nodes = []
comm = []

# %%
for idx, k in enumerate(louvain_coms.communities[:13]):
    for i in k:
        nodes.append(i)
        comm.append(idx)

# %%
df = pd.DataFrame({"Id": nodes,
                   "Community": comm})
df.to_csv("nodes.csv", index=False)
