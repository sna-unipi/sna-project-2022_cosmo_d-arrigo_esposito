# %%
import networkx as nx
import pandas as pd
import numpy as np
import json
import cdlib
from cdlib import evaluation
from cdlib import algorithms
from cdlib import viz
from cdlib import ensemble
from cdlib import readwrite
import pickle
import pquality
import matplotlib.pyplot as plt
# %matplotlib inline
from nf1 import NF1
# Out:
# Note: to be able to use all crisp methods, you need to install some additional packages:  {'leidenalg', 'karateclub', 'infomap', 'wurlitzer', 'graph_tool'}
# Note: to be able to use all overlapping methods, you need to install some additional packages:  {'karateclub', 'ASLPAw'}
# Note: to be able to use all bipartite methods, you need to install some additional packages:  {'leidenalg', 'infomap', 'wurlitzer'}

# %%
path_graph = "../DataSet FFF/Graph_data/"

# %%
G = nx.read_graphml(path_graph+"Real_Network.graphml")

# %%
community_path = "../DataSet FFF/Community_task/"

# %%
with open(community_path+'louvain.pickle', 'rb') as f:
    louvain_coms = pickle.load(f)

# %%
len(louvain_coms.communities)
# Out:
# 156

# %%
louvain_coms.communities[:13]
# Out:
# [[' renewableenergy',
#   ' climatecrisis',
#   'fridaysforfuture',
#   ' fridaysforfuture',
#   'climatecrisis',
#   ' climatestrike',
#   ' climate',
#   ' actnow',
#   ' climateemergency',
#   ' climateactionnow',
#   ' uprootthesystem',
#   ' mindthegap',
#   ' globalwarming',
#   ' sustainability',
#   ' renewables',
#   ' climatejustice',
#   ' peoplenotprofit',
#   'climatestrike',
#   ' humanity',
#   ' planet',
#   ' earth',
#   ' co2',
#   ' endfossilfuels',
#   ' climatestrikeonline',
#   ' fossilfuel',
#   ' digitalstrike',
#   ' climatebreakdown',
#   'climatejustice',
#   ' systemchange',
#   ' fridayforfuture',
#   'climateaction',
#   ' fff',
#   ' savesoil',
#   ' biodiversity',
#   'climatechange',
#   ' fightfor1point5',
#   ' ilmastolakko',
#   ' nytonpakko',
#   'climateactionnow',
#   ' climatebrawl',
#   'fridayforfuture',
#   ' ireland',
#   ' standwithukraine️',
#   ' conservation',
#   ' fossilfuels',
#   'peoplenotprofit',
#   'stopeacop',
#   ' floods',
#   ' twiff',
#   ' schoolstrike4climate',
#   ' facetheclimateemergency',
#   '1point5',
#   ' netzero',
#   ' climatechange',
#   ' climatechangeisreal',
#   'climateemergency',
#   ' environment',
#   ' world',
#   ' gretathunberg',
#   ' g7',
#   ' noemptypromises',
#   ' stopfundingfossilfuel',
#   ' thereisnoplanetb',
#   ' actonclimate',
#   ' belgium',
#   ' stopeacop',
#   'restoreourearth',
#   ' consciousplanet',
#   ' helsinki',
#   ' climatefinance',
#   ' india',
#   ' heatwaves',
#   ' parisagreement',
#   ' humanrights',
#   ' ecocide',
#   'savecongorainforest',
#   ' fridayfeeling',
#   ' savecongorainforest',
#   ' extinction',
#   'climate',
#   ' extinctionrebellion',
#   ' stockholm50',
#   ' arctic',
#   'stockholm50',
#   'worldbicycleday',
#   ' ilmastokriisi',
#   ' plasticfree',
#   'globalclimatestrike',
#   ' climatepromise',
#   ' biodiversityday',
#   ' saveourburningforests',
#   'schoolstrike',
#   'uprootthesystem',
#   ' showusthemoneynow',
#   ' makeparisreal',
#   ' racialjustice',
#   ' socialjustice',
#   'conservation',
#   ' droughts',
#   ' auspol',
#   ' environmentaljustice',
#   ' amawithsadhguru',
#   'savesoil',
#   ' endallfossilfuels',
#   ' youth',
#   'earthday',
#   ' earthday',
#   ' investinourplanet',
#   'parisagreement',
#   ' ipccreport',
#   ' nomoreemptypromises',
#   ' earthkeepersunite',
#   ' cop26',
#   ' human',
#   'nomoreemptypromises',
#   ' uganda',
#   'climatestrikes',
#   ' globalstrike',
#   ' fffke',
#   ' dochooserenewables',
#   ' gender',
#   'cop26',
#   ' covid_19',
#   'eusolidaritycorps',
#   ' renewableeuropeby2040',
#   ' solidaarisuuttasuomessa',
#   ' happynewyear2022',
#   ' ilmastotekoja',
#   ' togetherfor100re',
#   ' calamity',
#   'nature',
#   ' togethefor100re',
#   ' justsolarandwind',
#   ' policymakers',
#   ' famine',
#   ' humankind',
#   'gdp',
#   ' eusew2021',
#   'policymakers',
#   'facetheclimateemergency',
#   ' famines',
#   ' withdrawthecap',
#   ' forestfires',
#   ' draughts',
#   'climagechange',
#   ' algae',
#   ' rains',
#   ' naturalcalamities',
#   ' enviroenment',
#   'covid19',
#   'parents',
#   ' cllimatechange',
#   ' coronavirus',
#   ' defendthedefenders',
#   ' ilmastoteko',
#   'climatedecade',
#   'ecanu',
#   ' irtiturpeesta',
#   ' greenrecovery',
#   ' stayathome',
#   ' sosamazonia',
#   ' togetherathome',
#   ' treateverycrisis',
#   'aotearoa',
#   ' climateprotest',
#   ' fridaymorning',
#   ' klimaschutz',
#   ' trees',
#   ' divest',
#   ' climataction',
#   ' klimawandel',
#   ' savetheplanet',
#   ' nature',
#   ' fridays4future',
#   'giornatamondialedellambiente',
#   ' consigli',
#   ' viaggio',
#   ' viaggiare',
#   ' ambiente',
#   ' photography',
#   ' gogreen',
#   ' wwf',
#   ' repost',
#   ' gaskrise',
#   ' food',
#   ' wildlife',
#   ' russia',
#   ' government',
#   ' stoptmx',
#   ' bcpoli',
#   ' vancouver',
#   ' cdnpoli',
#   'bcpoli',
#   ' wef20',
#   ' abpoli',
#   ' climatstreik',
#   ' climatestrikecanada',
#   ' climatestrikevancouver',
#   'climatestrikevancouver',
#   ' indigenous',
#   ' govegan',
#   ' riseupmovement',
#   ' istayontheground',
#   ' savesoilbengaluru',
#   ' grünen',
#   'peoplepower',
#   ' mapa',
#   'climatestrikeonline',
#   'fasting',
#   ' fridays',
#   ' striking',
#   ' climatejusticenow',
#   ' globalwarmingisreal',
#   ' plastic',
#   ' recycled',
#   ' plasticwaste',
#   ' notmytaxonomy',
#   'digitalstrike',
#   ' coalcompanies',
#   ' oilcompanies',
#   ' gascompanies',
#   ' earthdayis365days',
#   ' climatecatastrophe',
#   ' coalminers',
#   ' activistabd',
#   ' motherearth',
#   ' lifesbetterwithtrees',
#   ' dublin',
#   ' spanishpoint',
#   ' laudatosi',
#   ' careforourcommonhome',
#   ' willieclancy',
#   'schoolstrike4climate',
#   'savesoilsavelife',
#   ' fffmapa',
#   'strikeforfriday',
#   ' nomoreemptypromise',
#   ' uproot',
#   ' globle',
#   ' savesoilsavelife',
#   ' climateschool',
#   ' f4fyouthstriker',
#   ' youthforclimatechange',
#   'العدالة_المناخية',
#   ' youth4tpnw',
#   ' itshappening',
#   ' plasticban',
#   ' schoolstrikeforclimate',
#   ' plogrun',
#   ' schoolstrike',
#   ' noafd',
#   '拡散希望',
#   ' plantbased',
#   ' plantbasedfood',
#   ' vegan',
#   ' scholz',
#   ' climasv',
#   ' frankfurt',
#   ' sadhguru',
#   ' spd',
#   'wearehey',
#   ' trump',
#   ' standwithukraine',
#   ' ghgemissions',
#   ' lossanddamage',
#   ' fridayforfutureyouthstrikers',
#   ' greenhousegas',
#   'movement',
#   ' agra',
#   ' stopglobalwarming',
#   ' greed',
#   ' g7showusthemoney',
#   ' endegelaende',
#   'climatejusticenow',
#   ' climaterightsnow',
#   ' climatepeace',
#   ' followbackfriday',
#   ' globalgoals',
#   'cop27',
#   ' gaia',
#   ' savenature',
#   ' ff',
#   'savehasdeo_savetribal',
#   ' savebuxbaha',
#   ' riseupmovment',
#   ' klimaat',
#   'thenameofthismachineistree',
#   ' planttree',
#   ' nuclearbanweek',
#   ' cleanup',
#   ' ukraine',
#   'actnow',
#   ' justiceclimatique',
#   ' climateactivist',
#   ' worldclimateactivist',
#   ' africanclimatealliance',
#   ' naturelovers',
#   ' 気候危機見て見ぬふりはもうできない',
#   ' finland',
#   ' ilmasto',
#   'stopfinancingfossilfuels',
#   ' educategirlsforclimatejustice',
#   ' noweymouthcompressor',
#   ' don',
#   ' honey',
#   ' stopjackdaw',
#   ' stopcambo',
#   'schoolstrikeforclimate',
#   ' letafghangirlslearn',
#   ' animalrights',
#   ' environmentalracism',
#   ' climatecantwait',
#   'thinkgreenactgreen',
#   ' kippraconference2022',
#   ' climateenergysummit',
#   'educategirlsforclimatejustice',
#   ' onlyoneearth',
#   ' fffportlandmetro',
#   ' freemint',
#   ' community',
#   ' reduce',
#   ' reuse',
#   ' fridaysforfuturehamburg',
#   ' hamburg',
#   ' parentsforfuture',
#   ' endplasticpollution',
#   'stopfunding',
#   ' ban',
#   ' phasingout',
#   ' fridaysforfuturejhansi',
#   'riseuptogetherfromdrought',
#   ' ddday',
#   'week87',
#   'justtransition',
#   ' chafrica',
#   'worldenvironmentday',
#   ' cimatejustice',
#   ' wien',
#   ' listentothescience',
#   ' peoplenotprofits',
#   ' lyne',
#   'healthyplanetsklm50',
#   ' stopfossilfuel',
#   ' smrjs',
#   ' swapnafoundation',
#   ' worldbicycleday',
#   ' cycling',
#   ' ipcc',
#   ' codered',
#   ' stopfuellingwar',
#   ' onpoli',
#   ' voteclimate',
#   ' f4fystrikers',
#   ' climate_strike',
#   'climateactionclub',
#   ' punjab',
#   'week86',
#   ' riseup',
#   ' ilmastonmuutos',
#   ' greenpeace',
#   ' birthday',
#   ' justice',
#   ' scientistrebellion',
#   ' blackfriday',
#   ' gazprom',
#   ' pace',
#   ' nationalbikeweek',
#   ' worldbeeday2022',
#   ' savethenature',
#   'canyouhearusyet',
#   ' endfossilfinance',
#   ' lossanddamagefinance',
#   'blacklivesmatter',
#   ' bepartofthesolution_notthepollution',
#   ' greatgambia',
#   ' webinar',
#   ' marinescience',
#   ' spreadawareness',
#   ' marineeducation',
#   ' fastingfridaysforfuture',
#   ' generationrestoration',
#   ' globalclimatestrike',
#   ' 気候変動',
#   ' climatereparations',
#   ' savefuturebangladesh',
#   'lifesbetterwithtrees',
#   'week85',
#   ' wirsindantifa',
#   ' boomersforclimatejustice',
#   ' embargoforpeace',
#   'climatechangeisreal',
#   ' keepitintheground',
#   ' planetnotprofit',
#   'lossanddamage',
#   'schoolstrikeforclimatestrike',
#   ' globalextinction',
#   ' noplanetb',
#   ' weatherupdate',
#   'followbackfriday',
#   ' carbondioxide',
#   'standwithukraine',
#   ' rewilding',
#   ' bankingonabetterfuture',
#   ' nocgl',
#   ' fridays4forest',
#   ' dutyofcare',
#   ' forpeopleforplanet',
#   'keepitintheground',
#   ' tempolimitjetzt',
#   ' biodiversitycrisis',
#   ' earthday2022',
#   ' climatemarch',
#   ' climatedisaster',
#   ' earthday22',
#   ' earthdayeveryday',
#   ' アースデイ2022',
#   ' treestreestrees',
#   'earthdayriseupmovement',
#   ' standforplanet',
#   'lettheearthbreath',
#   ' saveearth',
#   ' letearthbreathe',
#   ' lettheearthbreath',
#   ' freivonöl',
#   ' energiesparen',
#   'savetheplanet',
#   ' savethetrees',
#   ' waterpollution',
#   ' togetherforourplanet',
#   ' fbf',
#   ' fbfriday',
#   ' juststopoil',
#   ' sdg13',
#   'asap',
#   ' actintime',
#   ' peopleoverprofit',
#   ' foodsecurity',
#   ' hunger',
#   ' goodfriday',
#   'isrealiapartheidweek',
#   ' freepalaestine',
#   ' edinburghclimatestrike',
#   ' climatereparationsnow',
#   'week',
#   ' greenwashing',
#   ' cop27',
#   ' politicians',
#   'universitystrikeforclimate',
#   'climatereport',
#   ' climatehopeful',
#   ' fffsolidaritywithsudan',
#   'sealevels',
#   ' ourplanetourhealth',
#   'noplanetb',
#   ' nft',
#   ' cleannfts',
#   'nuclear',
#   ' children',
#   ' crisisclimática',
#   'rinnovabili',
#   ' 2aprile',
#   ' clima',
#   ' fridaysagainstfuture',
#   ' sfb',
#   ' web3',
#   ' universitystrikeforclimate',
#   ' journeyforsoil',
#   ' batman',
#   ' photo',
#   ' cute',
#   ' france',
#   ' europe',
#   ' europeanunion',
#   ' forest',
#   ' solvingit',
#   'peoplenotprofits',
#   ' hongkong',
#   ' guwahati',
#   ' planetoverprofit',
#   ' globalstrikeforclimate',
#   ' toronto',
#   ' gta',
#   ' topoli',
#   ' brighters',
#   ' bsb',
#   ' fridaysforfuturebangladesh',
#   ' actionaidbangladesh',
#   ' nowar',
#   ' guerra',
#   'globalstrikeforclimate',
#   ' dontfuelwar',
#   'matarbari',
#   ' reparations',
#   'onpoli',
#   ' proplenotprofit',
#   ' climatebarbage',
#   ' lucknow',
#   ' up',
#   'reparations',
#   'nooilinvirunga',
#   ' youthforclimate',
#   ' sciopero',
#   ' elokapina',
#   ' climatestrikenow',
#   ' globalrecyclingday',
#   'happyholi2022',
#   ' savewater',
#   ' fridaysforforests',
#   ' freepalestine',
#   ' clmateactionnow',
#   ' bigoil',
#   ' blacklivesmatter',
#   ' nomorewars',
#   ' stopsumitomo',
#   'newclimatewar',
#   'standforukraine',
#   ' stopthewar',
#   ' climatereport',
#   'stopsumitomo',
#   ' save_tree',
#   ' action4impact',
#   ' peace',
#   ' siochain',
#   ' shanti',
#   ' seriousness',
#   ' urgency',
#   'ff',
#   'peace',
#   ' ucraine',
#   '58th',
#   ' crisisoninfiniteearths',
#   ' blackhistorymonth',
#   ' climatelive2022',
#   ' savegreen',
#   ' fff_bangladesh',
#   ' climateeducation',
#   ' stormeunice',
#   ' stormdudley',
#   ' stormfff',
#   ' taxtherich',
#   'africaisnotadumpster',
#   ' unea5',
#   ' plasticstreaty',
#   'forpeople',
#   ' forclimate',
#   '57th',
#   ' naturalproducts',
#   ' recycle',
#   'youth4climate',
#   ' ottawaoccupied',
#   ' freedomconvoy2022',
#   ' savethedate',
#   ' 11febbraio',
#   ' youthstrike4climate',
#   'edinburghclimatestrike',
#   ' edinburgh',
#   ' humanitarian',
#   'school',
#   'stopglobalwarming',
#   'lucknow',
#   ' recruitment',
#   ' actsoneducation',
#   'vancouver',
#   ' stopcgl',
#   ' vanpoli',
#   ' youth4climate',
#   ' greenhousegases',
#   'ireland',
#   ' emptypromises',
#   ' stopfakerenewables',
#   'savethedate',
#   ' nyc',
#   ' 気候危機',
#   'justlookup',
#   'savetrees',
#   'planetoverprofit',
#   'wetlands',
#   ' theworldiswatching',
#   ' webelieveactions',
#   ' accionclimatica',
#   ' fridaysforfutureindia',
#   'mumbai',
#   ' kids',
#   ' wedonthavetime',
#   ' ecosocialism',
#   'dublin',
#   ' protectmangroves',
#   ' environmentalprotection',
#   'beatplasticpollution',
#   ' fornature',
#   ' pancec',
#   ' greenspaces',
#   ' travel',
#   'mindthegap',
#   ' christmas',
#   ' climatestrikes',
#   ' saveyourplanet',
#   'fightfor1point5',
#   ' odetteph',
#   ' thwaites',
#   ' gearceimaeraide',
#   'canyouhereusyet',
#   ' wetsuweten',
#   ' mpa',
#   ' digitalclimatestrike',
#   'stopblaming',
#   ' climateactnow',
#   'stopcambo',
#   ' ourcommonhome',
#   ' switch',
#   ' industrialists',
#   '52nd',
#   'tomorrowistoolate',
#   'страйкзаклімат',
#   ' strikeforclimate',
#   ' saveplanetearth',
#   'farmersprotest',
#   ' votethiscapdown',
#   ' withdrawthiscap',
#   'somalia',
#   ' somalia',
#   ' copon',
#   ' koalitionsverhandlungen',
#   'kretslopp',
#   ' torino',
#   ' climatepoli',
#   'stopfailingus',
#   ' cop26bbc',
#   'climatechangestrike',
#   ' childrenoftherevolution',
#   '51th',
#   ' satkhira',
#   'gilgitbaltistan',
#   ' justtransition',
#   'savebugomaforest',
#   ' environmentartist',
#   ' ecology',
#   ' cop26glasow',
#   ' sustainablegoodlife',
#   ' ndcs',
#   ' learningsociety',
#   ' eternals',
#   ' scottishindependence',
#   ' fightclimateinjustice',
#   ' glasgowcop26',
#   ' savehasdeoforest',
#   ' actionforclimate',
#   ' climatefighters',
#   ' climatecompensation',
#   ' movement',
#   'influencers',
#   ' neet2021',
#   ' faiths4cop26',
#   ' faith4climate',
#   ' riseandrebel',
#   ' g20',
#   'scottishindependence13',
#   ' climatejusticeaction',
#   'climatestriking',
#   ' wecandothis',
#   ' whatthecop',
#   ' copon4net',
#   ' cleanupstandardchartered',
#   ' smr',
#   ' go100re',
#   ' buildbackbetter',
#   ' extinctionrebelion',
#   ' cop26plastics',
#   ' cl',
#   ' climatelive2021',
#   '50th',
#   ' dhaka',
#   'lakedistrict',
#   ' windermere',
#   ' river',
#   ' lake',
#   ' envirocoresubject',
#   ' cop15',
#   ' peoplevsfossilfuels',
#   ' buildbackfossilfree',
#   'ilmastokriisi',
#   ' unitebehindthescience',
#   'peoplevsfossilfuels',
#   ' activism',
#   'defundclimatechaos',
#   'defendthedefenders',
#   ' scottmorrison',
#   ' gdp',
#   ' solidarity',
#   ' alternativeenergy',
#   ' heatpumps',
#   '49th',
#   ' savehasdeo',
#   ' हसदेव_बचेगा_देश_बचेगा',
#   ' climatechnage',
#   ' austria',
#   'goodnighttwitterworld',
#   'mega',
#   '48th',
#   ' crisiclimatica',
#   'fromparistocop26',
#   ' laschetruecktritt',
#   ' timetoact',
#   'wenaturalists',
#   ' worldpeopleofnatureday',
#   ' sustainabiity',
#   'tiredearth',
#   ' 24s',
#   'justiciaporelclima',
#   ' 24septiembre',
#   'cambioclimatico',
#   'hashtags',
#   ' allforclimate',
#   ' climatestrike2021',
#   ' pupsfortheplanet',
#   ' respectyourmother',
#   'globalclimatechangestrike',
#   ' uprootsystem',
#   'buonaserata',
#   ' buonanotte',
#   ' fffsep24',
#   ' sistemiköktendeğiştir',
#   ' i̇klimgrevi2021',
#   ' ecologia',
#   ' climateweek',
#   'allefürdiezukunft',
#   ' vienna',
#   ' germanelection2021',
#   ' greenparty',
#   ' marte',
#   '世界気候アクション0924',
#   ' 住友商事の森林破壊を許さない',
#   ' climateinjustice',
#   ' tourism',
#   ' sttaconsulting',
#   ' lacroisade',
#   ' ecologicalbreakdown',
#   'standforplanet',
#   ' anotherworldisnecessary',
#   'insulatebritain',
#   ' elxn44',
#   ' nomoreemptysummits',
#   ' treatacrisislikeacrisis',
#   ' restoreourearth',
#   ' endclimatesilence',
#   ' ipccreport2021',
#   ' animalagriculture',
#   ' methane',
#   ' globalclimatejustice',
#   ' marchepourleclimat',
#   'electricvehicle',
#   ' healthy',
#   ' tiredearth',
#   ' actionforbiodiversity',
#   ' hurricanes',
#   ' climateactionplan',
#   ' polluters',
#   ' stopdeforestation',
#   ' worldwaterweek',
#   'savebuxwaha',
#   ' farmersprotest',
#   ' canada',
#   'bikelanes',
#   ' bicycles',
#   ' cargobikes',
#   ' ebikes',
#   ' fitness',
#   '46th',
#   ' stopbeingfossilfools',
#   '45th',
#   ' africaisnotadumpster',
#   ' siberia',
#   ' greece',
#   ' algeria',
#   ' fire',
#   'bushfiresurvivorsvsepa',
#   ' climatesolution',
#   'pride',
#   ' gulfstreamcollapse',
#   ' savebugomaforest',
#   ' turkeyisburning',
#   ' climatecrisisishere',
#   '44th',
#   ' stopclearcuts',
#   ' notblownwithcyclone',
#   ' cliamtestrike',
#   ' socialjusticeisclimatejustice',
#   'savebuxwahaforest',
#   'notblownwithcyclone',
#   ' edo',
#   ' rapidreduction2030',
#   ' climatenow',
#   ' bushfire',
#   ' factoryfarming',
#   ' strike4climate',
#   ' takeabreathwecansolvethis',
#   ' earthovershotday',
#   ' flattenthecurve',
#   ' earthovershootday',
#   ' borneo',
#   ' saveborneorainforest',
#   '43th',
#   ' savebuxwahasavelife',
#   ' fairycreek',
#   ' bc',
#   ' climat',
#   ' intermittentfasting',
#   ' nogenerationscanexistonadeadplanet',
#   '42th',
#   ' savebuxwahaforest',
#   'withdrawthecap',
#   '41th',
#   'klimatkris',
#   ' rehabilitatekhori',
#   ' nomorelies',
#   ' heatwave2021',
#   ' onlineclimatestrike',
#   ' savewildlife',
#   ' safewater4all',
#   '40th',
#   ' genderequality',
#   ' pollutersout',
#   ' africaisnotàdumpster',
#   ' netzstreikfuesklima',
#   ' nosustainabilityonadeadplanet',
#   ' girlpower',
#   ' iammadagascar',
#   '39th',
#   ' wetlands',
#   'protect',
#   ' preserve',
#   ' climatecrisisbangladesh',
#   ' bangladeshalreadysuffering',
#   'transpride',
#   ' 11thhourforclimate',
#   ' digitalprotest',
#   'environmentaljustice',
#   ' fridaystrikeforclimate',
#   ' withdrawthecapnow',
#   '38th',
#   ' unitedkingdom',
#   'पेड़_लगाओ_पृथ्वी_बचाओ',
#   ' planttreesaveearth',
#   ' evironmentalism',
#   ' art',
#   ' 17sdgs',
#   ' goodhealth',
#   ' qualityeducation',
#   ' cleanwater',
#   ' lifeonland',
#   ' youngpeopleshopeinmotion',
#   ' desertificationanddroughtday',
#   'saveaareyforest',
#   ' digitalstrikepune',
#   ' plantalife',
#   ' choices',
#   ' michaelmann',
#   ' vocalmedia',
#   ' mondaymotivation',
#   ' mondaythoughts',
#   'nomoreemptysummits',
#   'g7summit2021',
#   ' nokxl',
#   ' kxlisdead',
#   ' nopipelines',
#   'marcodecanaveses',
#   ' ilmastovaalit',
#   'savebuxwahasavelife',
#   ' cancelbunderminingproject',
#   ' worldenvironmentday',
#   ' wedemandimmediateaction',
#   '35th',
#   ' stopreconafrica',
#   ' savetheokavangodelta',
#   ' ilmastohätätila',
#   ' youth2030',
#   ' caminodesantiago',
#   ' forabolsonaro',
#   '34th',
#   ' pge',
#   ' canviclimàtic',
#   ' yositecreomartayolga',
#   'fornature',
#   ' raiseyourstandards',
#   ' climatetwitter',
#   ' schoolstrikeforclimateaction',
#   ' बकस्वाहा_जंगल_बचाओ_अभियान',
#   ' nodexl',
#   ' soscolombia',
#   'strike4climate',
#   ' cycloneamphan',
#   'euyouthweek',
#   ' resilience',
#   ' erasmusplus',
#   ' savetheoceans',
#   'wetlaland',
#   ' powerofwetlands',
#   ' fffmay14',
#   ' canpoli',
#   ' climateactionbill',
#   'thenewclimatewar',
#   '33rd',
#   'forabetterworld',
#   ' forabettertomorrow',
#   ' ocsbsep',
#   'soscolombiaddhh',
#   ' digitalstrikeforclimate',
#   ' kanvango',
#   'welovescience',
#   ' welovetheearth',
#   ' rebelforlife',
#   ' strongertogether',
#   ' standwithworkers',
#   '32nd',
#   ' mindthecap',
#   'plant',
#   ' bicycle',
#   ' nomowmay',
#   ' fridaysforfuturepakistan',
#   ' pakistan',
#   ' 温室効果ガス削減目標の大幅引き上げを求めます',
#   ' i̇kizderetaşocağıolmasın',
#   ' makeecocideacrime',
#   ' localelections',
#   ' vacunaparalacrisisclimatica',
#   ' mayday',
#   ' peat',
#   '31st',
#   ' oxygen',
#   ' indianeedsoxygen',
#   'strike',
#   ' justrecovery',
#   ' ocsb',
#   ' localelections2021',
#   ' leadersclimatesummit',
#   'savetheoceans',
#   ' banplastic',
#   ' plasticfreeocean',
#   ' childrenareourfuture',
#   'noweymouthcompressor',
#   ' elfonsite',
#   ' mapoli',
#   ' receipts',
#   ' stopline3',
#   ' haltmarinernow',
#   ' nodapl',
#   ' notyoursacrificezone',
#   ' nosacrificezones',
#   ' earthweek',
#   ' endplastic',
#   ' climatepledge',
#   'cleanupstandardchartered',
#   ' peaceuponyemen',
#   ' yemencantwait',
#   ' fossilfreerevolution',
#   'marcheclimat',
#   ' vraieloiclimat',
#   ' 16avril',
#   ' nantes',
#   ' iamgreta',
#   'intergenerational',
#   'ndc',
#   ' climatecrises',
#   'fukushima',
#   ' tepco',
#   ' japan',
#   ' tritium',
#   'savenatureforfuture',
#   ' 420ppm',
#   'ocsbsep',
#   ' kanalistanbul',
#   ' yakanalyaistanbul',
#   'climatesrikeonline',
#   ' climatealliance',
#   ' climaterisk',
#   ' ratifyparis',
#   '気候危機止めるために学校休みます',
#   ' cilimatestrike',
#   ' saveourforests',
#   ' climatebill',
#   ' takeaction',
#   ' mentalhealth',
#   ' プラスチック',
#   ' stopeumercosur',
#   ' suezcanal',
#   'nomoreemptypromise',
#   ' cleanair',
#   ' beyondrecovery',
#   ' toxicplastics',
#   'outaouais',
#   ' makeirelandgreenagain',
#   ' fffengland',
#   ' 私たちの未来を手放さない',
#   'sinistra',
#   ' giustiziasociale',
#   ' bosvaatleri̇stemiyoruz',
#   ' i̇klimiçinhareketegeç',
#   'mumbsi',
#   'raceformars',
#   ' nowayout',
#   ...],
#  ['gretathunberg',
#   'extinctionrebellion',
#   'gas',
#   'co2',
#   ' klima',
#   ' energiewende',
#   ' thunberg',
#   'elektromobilität',
#   ' elektroautos',
#   'klimaschutz',
#   'erneuerbare',
#   ' kohle',
#   'leerflüge',
#   'greta',
#   'autoindustrie',
#   'ausgleichseffekt',
#   ' akkus',
#   ' disruption',
#   ' ee',
#   ' eeg2021',
#   'klimaneutralität',
#   ' tagesthemen',
#   'mehrwertsteuer',
#   ' konjunkturpaketes',
#   ' elektromobilität',
#   'solarstrom',
#   ' klimakrise',
#   ' atom',
#   ' klimastreik',
#   ' corona',
#   'deutschland',
#   ' kernenergie',
#   ' solarenergie',
#   ' klimapaket',
#   'energiestrategie',
#   ' solarwirtschaft',
#   ' speicher',
#   ' es2050',
#   ' 10vor10',
#   ' wärme',
#   ' co2gesetz',
#   ' nfp70',
#   ' srfarena',
#   ' schweiz',
#   'solarwirtschaft',
#   ' waermeinitiative',
#   ' srfclub',
#   'transformation',
#   ' storytelling',
#   ' klimakatastropheistjetzt',
#   'greenpeace',
#   ' klimakatastrophe',
#   ' blackout',
#   'energiewende',
#   'blackouts',
#   ' gasversorgung',
#   ' laufzeitverlängerung',
#   ' atomkraft',
#   ' nuclear',
#   ' habeck',
#   ' habeckruecktritt',
#   ' uranium',
#   'klimawandel',
#   ' neubauer',
#   'klimastreik',
#   'ukrainekrieg',
#   'uranium',
#   ' nuclear4future',
#   'german',
#   ' america',
#   ' roberthabeck',
#   ' olafscholz',
#   'neubauer',
#   ' laschet',
#   ' energiekrise',
#   ' klimabewegung',
#   ' bundestag',
#   ' selenskyj',
#   ' lotharwieler',
#   ' rki',
#   ' allefuersklima',
#   ' btw21',
#   ' degrowth',
#   'mondaymotivation',
#   'blasel',
#   'klimakrise',
#   ' grüne',
#   'klimakatastrophe',
#   'klima',
#   ' putin',
#   'berlin',
#   'mönchsberggarage',
#   ' verkehrswende',
#   ' neinzumloch',
#   ' cdu',
#   'antifa',
#   'kohle',
#   'klimagerechtigkeit',
#   ' eu',
#   'fff',
#   'tankrabatt',
#   'tempolimit',
#   ' klimawahl',
#   'autowahnsinn',
#   'städtefürmenschen',
#   'equity',
#   ' tempolimit',
#   ' hambacherforst',
#   'alledörferbleiben',
#   'feuerdenwissing',
#   'klimawahl',
#   'klimapolitik',
#   ' lützerathbleibt',
#   ' lützerath',
#   'lützerath',
#   'freivonöl',
#   ' mobilitaetswende',
#   ' lützibleibt',
#   'a100',
#   ' berlin',
#   'bawü',
#   'atomkraft',
#   ' atomkraftneindanke',
#   ' atomausstieg',
#   ' csu',
#   'windkraftbremse',
#   ' zukunftsrisikocsu',
#   'ipcc',
#   'spritpreise',
#   'gebauer',
#   'earthhour',
#   'btw21',
#   'autokorrektur',
#   'cdu',
#   ' aachen',
#   ' studentsforfuture',
#   ' klimagerechtigkeit',
#   ' peaceandjustice',
#   ' alledörferbleiben',
#   ' allefürsklima',
#   ' antarctica',
#   ' reichthaltnicht',
#   ' verkehr',
#   'klimaziele',
#   'meintwitterjubiläum',
#   ' salzburg',
#   ' konzert',
#   ' scientists4future',
#   ' stopputinswar',
#   ' windkraft',
#   'stadtpanzerraus',
#   'wirsindantifa',
#   'pressefreiheit',
#   ' hambibleibt',
#   ' osterholzbleibt',
#   ' kapitalismus',
#   'corona',
#   ' heute',
#   'eutaxonomie',
#   ' autokorrektur',
#   ' gronau',
#   ' lingen',
#   'makeparisreal',
#   ' systemchangenotclimatechange',
#   'verkehrswende',
#   'eiffelturmtag',
#   ' pariserklimaabkommen',
#   'autofrei',
#   ' städtefürmenschen',
#   ' klimaschutzgesetz',
#   ' eiffelturmtag',
#   ' climatejusticewithoutborders',
#   ' kohleausstieg',
#   'ampelaufkrise',
#   'herrenwald',
#   'glasgow',
#   ' greta',
#   ' bund',
#   ' agrarwende',
#   ' umweltsau',
#   'vonderleyen',
#   'kohleausstieg',
#   'g20',
#   ' nomoreblahblahblah',
#   ' thismachinefightsclimatechange',
#   'lanz',
#   ' autoausstieg',
#   ' köln',
#   'groko',
#   'bundestagswahl',
#   ' alledoerferbleiben',
#   ' fcknzs',
#   ' fckafd',
#   ' lützerathlebt',
#   'laschetverhindern',
#   'umweltschutz',
#   'parentsforfuture',
#   'allefürsklima',
#   ' laschetlügt',
#   ' kirche',
#   'laschetdarfnichtkanzlerwerden',
#   ' allefür1komma5',
#   'laschet',
#   'düsseldorf',
#   'konstanz',
#   ' ngo',
#   ' beidestimmengrün',
#   ' laschetrücktritt',
#   ' laschetverhindern',
#   ' klimaliste',
#   'windkraft',
#   'zivilerungehorsam',
#   ' datteln4',
#   'nichtwienrw',
#   ' klimafrage',
#   ' neustartklima',
#   ' netzstreikfuersklima',
#   'perscheid',
#   'brunsbuettel',
#   'endegelände',
#   'earthovershotday',
#   ' hochwasser',
#   ' klimanotstand',
#   'aufbruchsklima',
#   ' endegelände',
#   ' keingradweiter',
#   ' roteklimakarte',
#   'vanessanakate',
#   'globalstrike',
#   ' wdr',
#   ' a49',
#   'fighteverycrisis',
#   'klimaerhitzung',
#   ' aufbruchsklima',
#   'klimawende',
#   'greatawakening',
#   ' g7summit',
#   'mahnwache',
#   'benzinpreis',
#   ' kurzstreckenflüge',
#   'keinekohlefürdiekohle',
#   'ravensburg',
#   ' klimakonsens',
#   ' merkel',
#   ' fighteverycrisis',
#   'in15jahrenaufnull',
#   'beuys',
#   'maaßen',
#   ' keinea49',
#   'klimalockdown',
#   'dieanstalt',
#   ' amthor',
#   ' pfeiffer',
#   'howdareyou',
#   'fcknzs',
#   'wien',
#   ' xr',
#   ' allefuer1komma5',
#   ' altmaier',
#   ' anotherworldispossible',
#   'petition',
#   ' klimaprämie',
#   'allefür1komma5',
#   'klimaprämie',
#   'raiseyourstandards',
#   'keingradweiter',
#   ' coronakrise',
#   ' notbremsejetzt',
#   'subventionen',
#   'mercosur',
#   ' dannibleibt',
#   ' nonazis',
#   'dannibleibt',
#   ' waldstattasphalt',
#   'djimavic2zoom',
#   ' dannenröderwald',
#   'menschenrechte',
#   ' solidaritaet',
#   ' ravensburg',
#   'baumhausdorf',
#   ' fckrwe',
#   'fridaysforfuturekassel',
#   ' a44',
#   ' actnowforfuture',
#   'l277',
#   ' bauwendejetzt',
#   'eu2020de',
#   'baumbesetzung',
#   'baumhaus',
#   ' klimaziel',
#   'weihnachten',
#   ' parisgoesrathaus',
#   'waldstattasphalt',
#   ' rodungsstoppjetzt',
#   'danni2211',
#   'polizeiproblem',
#   ' tempo30',
#   ' visionzero',
#   ' autofrei',
#   'futureofcap',
#   ' konstanz',
#   ' autogipfel',
#   ' groko',
#   ' berlindirekt',
#   ' herrenlosbleibt',
#   'xr',
#   ' bahnoffensive',
#   ' duisburg',
#   ' streik',
#   ' leavenoonebehind',
#   'coronakrise',
#   ' kretschmann',
#   ' 1komma5',
#   'migrantifa',
#   'verbrennerminister',
#   ' unfried',
#   ' garzweiler',
#   ' stopadani',
#   'fckmlpd',
#   'datteln4',
#   ' stopdatteln4',
#   'youtube',
#   'augsburg',
#   'wahlrecht',
#   'criticalmass',
#   ' nextlevel4future',
#   'kohleeinstiegsgesetz',
#   ' kohleausstiegsgesetz',
#   ' howdareyou',
#   ' großekohlekoalition',
#   ' kohlegesetz',
#   'siemens',
#   'csu',
#   ' wuppertal',
#   ' rotelinie',
#   ' klimazerstörung',
#   ' kohlekonzerne',
#   ' dorfspaziergang',
#   'köln',
#   ' porz',
#   ' haltestelle',
#   'essen',
#   ' datteln',
#   ' allegegenrwe',
#   ' halleschestor',
#   ' blockiererblockieren',
#   ' hambacherwald',
#   ' wahlrechtsreform',
#   'pressekonferenz',
#   ' datteln4stoppen',
#   ' 4dattelnessen',
#   ' rwestoppen',
#   ' mönchengladbach',
#   ' krefeld',
#   ' weitersowargestern',
#   'rebellionwave',
#   ' solaroffensive',
#   'wirundjetzt',
#   'migrantifaforfuture',
#   ' whiteprivilege',
#   ' ffm2404',
#   ' wo0606',
#   'abfckpraemie',
#   'abfckprämie',
#   ' abwrackprämie',
#   ' abfckprämie',
#   ' nolng',
#   'dat3005',
#   ' klimanetzdatteln',
#   ' schildermeerfürsklima',
#   ' netzstreikfürsklima',
#   'trump',
#   ' by2020weriseup',
#   'wirbildenzukunft',
#   ' fortumirtifossiilisista',
#   ' nowiwu',
#   ' afrika',
#   ' industriestaaten',
#   'neueswirtschaftswunder',
#   ' greeneconomy',
#   ' windenergie',
#   ' wirbildenzukunft',
#   'klatschenfürdielobby',
#   ' kaufprämie',
#   'profilbild',
#   ' abgasautos',
#   'klassenklimakampf',
#   ' 1mai',
#   ' indymedia',
#   ' gretaultras',
#   ' 1mai2020',
#   ' tagderarbeit',
#   ' r1mb',
#   'herauszumerstenmai',
#   ' klassenklimakampf',
#   ' fffbleibtaktiv',
#   'klimahandeln',
#   ' climatesolutions',
#   ' mainkai',
#   ' alteoper',
#   ' hauptwache',
#   ' weactnow',
#   ' appforfuture',
#   ' alankurdî',
#   'fffbleibtaktiv',
#   ' covid2019',
#   ' youthstrikeforclimate',
#   ' solaranlagen',
#   ' radfahrprämie',
#   ' mehrgeldfürsrad',
#   ' hamburgwähltklima',
#   'hamburgwaehltklima',
#   ' hamburgwahl',
#   ' hhwahl',
#   ' pilgerunterwegs',
#   ' hamburgklimawahl',
#   'geisterzug',
#   'siemensfuelsfires',
#   'stopfracking',
#   'by2020weriseup',
#   ' adani',
#   ' eike',
#   'klimainterviews',
#   'manheim',
#   ' waldspaziergang',
#   'visionsforclimate',
#   ' davos',
#   'wef',
#   'wef2020',
#   'wecker',
#   ' australiaburning',
#   ' australiafires',
#   ' koeln0401',
#   ' k0401',
#   ' omagate',
#   ' umweltsauoma',
#   'feierabend',
#   'nazi',
#   ' presseausweiss',
#   ' bundespolizei',
#   ' twitter',
#   ' rweenteignen',
#   ' stoprwe',
#   ' stopcoalmining',
#   'weihnachtenundklimakrise',
#   ' queenelizabeth',
#   'cop25madrid',
#   ' suvs',
#   ' scheuerruecktritt',
#   'billigflüge',
#   ' flynice',
#   ' mimikana',
#   ' cop25madrid',
#   ' zeitzuhandeln',
#   ' climatedebate',
#   'ourocean',
#   ' endoverfishing',
#   ' oceanaction',
#   ' agrifish',
#   ' cfpreality',
#   ' pendlerpauschale',
#   ' wenigerautos',
#   'neustartklima',
#   ' film',
#   'campino',
#   ' publicclimateschool',
#   ' ichsagendeglände',
#   ' rebel4live',
#   'klimastreikwoche',
#   ' weiterso',
#   ' niederlande',
#   ' 5jahreskandal',
#   'containern',
#   ' baumoffensive',
#   'hexafluorid',
#   ' hauptbahnhof',
#   ' sofamünster',
#   ' nicht_mein_endlager',
#   ' atommüll',
#   ' atomkraftwerk',
#   ' kernschmelze',
#   'fossilfree',
#   'otd',
#   ' wef2020',
#   'speeddating',
#   ' klimawandelspeeddating',
#   'notmytaxonomy',
#   'degrowth',
#   ' deutschland',
#   'muenchen',
#   'merkel',
#   ' dresden',
#   'bonn',
#   ' niemehrcducsu',
#   'frankfurt',
#   'ampel',
#   'jederbaumzählt',
#   ' antifa',
#   ' klimakonferenz',
#   'wettendass',
#   'klimakriseistjetzt',
#   'ihrlasstunskeinewahl',
#   ' wahlalter',
#   ' kanzler',
#   'bverfg',
#   'allefuersklima',
#   ' schüler',
#   'keinea49',
#   'lehrer',
#   'unteilbar',
#   ' solidarität',
#   'klimanotstand',
#   'fitfor55',
#   ' lasstunshandeln',
#   ' garkeinplan',
#   ' wirhabenplatz',
#   'sprüchevor8',
#   ' klimavor8',
#   'kohlecommerzbank',
#   ' klimaklage',
#   'stopeumercosur',
#   ' unteilbar',
#   'eeg',
#   'bundesregierung',
#   ' kinder',
#   'sogeht1komma5',
#   'niemehrcdu',
#   ' verdi',
#   'endegelaende',
#   ' endcolonialism',
#   'globaldayofclimateaction',
#   ' erneuerbarenenergien',
#   'systemchangenotclimatechange',
#   'bne',
#   ' endpatriarchy',
#   'nrwähltklima',
#   'klimavor8',
#   ' bureg',
#   'kommunalwahlen',
#   ' berlin4future',
#   ' kohleeinstiegsgesetz',
#   'kohleausstiegsgesetz',
#   ' fightforclimatejustice',
#   ' kommunalwahlen',
#   ' grossekohlekoalition',
#   'kohlegesetz',
#   'grossekohlekoalition',
#   ' generationenrettungsschirm',
#   'konjunkturpaket',
#   ' generationengerechtigkeit',
#   ' sogehtsolidarisch',
#   'klimazielstattlobbydeal',
#   ' konjunkturmitzukunft',
#   ' konjunkturpaket',
#   ' abwrackpraemie',
#   'kohlekraftwerk',
#   'kretschmann',
#   'stopdatteln4',
#   'netzstreikfürsklima',
#   'coronavirusde',
#   ' coronacrisis',
#   'klimapaket',
#   ' luft',
#   ' bailouttheplanet',
#   ' klimarettungsschirm',
#   'stopadani',
#   ' left',
#   ' sabine',
#   ' siemens',
#   'thueringen',
#   ' olympiahalle',
#   ' menschenrechte',
#   'davos',
#   ' davos2020',
#   ' kaeserfuelsfires',
#   ' smashcapitalism',
#   ' nomorecoal',
#   'australianbushfire',
#   ' australianbushfire',
#   'australiaburning',
#   '2020werdenwir',
#   '1jahrnurblockiert',
#   ' notmyklimapaket',
#   ' versammlungsfreiheit',
#   'stellungnahme',
#   ' 1jahrnurblockiert',
#   ' marburg',
#   'klimaneutral',
#   'wahrheit',
#   'tagdermenschenrechte',
#   'hungersnot',
#   ' spdbpt19',
#   ' spdbt19',
#   ' verantwortung',
#   ' nichtmeinklimapaket',
#   'schenktunszukunft',
#   ' eltern',
#   ' lehrer',
#   ' twitterlehrerzimmer',
#   ' lausitz',
#   ' streikenstattfeiern',
#   ' wirstreikenbisihrhandelt',
#   ' wennnichtjetztwanndann',
#   ' jetztodernie',
#   ' schule',
#   ' bringafriendfriday',
#   'venedig',
#   ' einvenedigreicht',
#   ' autofreieinnenstadt',
#   ' filmforfuture',
#   ' würzburg',
#   ' weshutdown',
#   'chile',
#   ' un',
#   ' streiken',
#   ' landtag4climate',
#   ' ltwth19',
#   'karlsruhe',
#   'hitze',
#   'union',
#   ' fdp',
#   ' afd',
#   ' ampel',
#   'öpnv',
#   'akw',
#   'letztegeneration',
#   'klimacamp',
#   'fdp',
#   ' rassismus',
#   ' luisaneubauer',
#   'russland',
#   'klimadebatte',
#   ' klimahysterie',
#   'habeck',
#   ' krieg',
#   'scholz',
#   ' klimaneutral',
#   'xtausend',
#   'klimahysterie',
#   ' gaskraftwerke',
#   ' kohlekraftwerke',
#   'dwenteignen',
#   'taxonomie',
#   'klimaaktivisten',
#   ' demokratie',
#   ' nazi',
#   'hannover',
#   ' langstreckenluisa',
#   'wortzumsonntag',
#   ' sozialekipppunkte',
#   'payup4lossanddamage',
#   'lützerathbleibt',
#   'crappybirthday',
#   'sylt',
#   'münchen',
#   ' gruene',
#   ' klimaziele',
#   ' leipzig',
#   'keinea20',
#   'a20stoppen',
#   'dürre',
#   'halle',
#   ' australien',
#   ' gasstop',
#   ' tankrabatt',
#   'idahobit2022',
#   'yestoqueer',
#   'antarktis',
#   'nrw',
#   'nrwandel',
#   'verfassungsschutz',
#   ' nrw',
#   ' nrwgenugverwüstet',
#   'publicclimateschool',
#   ' 9euroticket',
#   'polizeigewalt',
#   'spd',
#   ' dielinke',
#   ' nordstream2',
#   ' öpnv',
#   ' luetzerathbleibt',
#   'servicetweet',
#   ' niemehrcdu',
#   ' elektroauto',
#   'afd',
#   ' erneuerbareenergien',
#   ' rwe',
#   ' hauptversammlung',
#   ' fortheanimals',
#   ' merz',
#   ' satire',
#   ' hysterie',
#   ' sekte',
#   '1komma5',
#   'osterpaket',
#   ' nato',
#   'grünen',
#   ' illner',
#   ' russland',
#   'luetzerath',
#   'ard',
#   'kapitalismus',
#   ' verfassungsschutz',
#   'kiel',
#   ' mitweltschutz',
#   ' klimagerechtwerden',
#   'bielefeld',
#   'frieden',
#   ' öl',
#   'globalerklimastreik',
#   ' taxonomie',
#   'scientists4future',
#   ' diskriminierung',
#   'entlastungspaket',
#   ' antarktis',
#   'klimasteik',
#   'fckafd',
#   'klimaaktionstag',
#   ' demo',
#   'rassismus',
#   ' gigafucktory',
#   'bundestag',
#   ' lindner',
#   'livestream',
#   ' lessionsforpeace',
#   ' photovoltaik',
#   ' f4f',
#   'hamburg',
#   'photovoltaik',
#   'saytheirnames',
#   ' hanau1902',
#   'reichthaltnicht',
#   ' wissenschaft',
#   'naturstattautobahnstruktur',
#   'sterkibleibt',
#   'klimaschützer',
#   ' umwelt',
#   ' pandemie',
#   ' atomenergie',
#   ' dannilebt',
#   ' osterholz',
#   'osterholzbleibt',
#   ' ernährungswende',
#   'kohlekraftwerke',
#   'vollgasindiekrise',
#   ' magdeburg',
#   'temperaturrekord',
#   ' kodiak',
#   ' alaska',
#   ' klimapolitik',
#   ' coronapandemie',
#   ' containern',
#   'schule',
#   ' rezo',
#   'demokratie',
#   'nichteuerernst',
#   'impfen',
#   'k53',
#   ' grübe',
#   'koalitionsvertrag',
#   'leag',
#   ' braunkohle',
#   ' copout26',
#   'copout26',
#   'thunberg',
#   'nuhr',
#   ' landwirtschaft',
#   'hartaberfair',
#   'reemtsma',
#   ' klimagipfel',
#   'strukturwandel',
#   'g20gipfel',
#   ' klimawandelleugner',
#   'klimabewegung',
#   ' terror',
#   ' terroristen',
#   'faktenfinder',
#   ' klimaneutralität',
#   ' ihrlasstunskeinewahl',
#   ' klimakoalition',
#   'windenergie',
#   ' efficiencyfirst',
#   ' klimaproteste',
#   'klimakoalition',
#   ' nichtverhandelbar',
#   ' flugverbot',
#   'fffordert',
#   ' klimastreiks',
#   'koalitionsverhandlungen',
#   ' klimaregierung',
#   'merz',
#   ' sondierungspapier',
#   'naturkrise',
#   ' sondierungsgespraeche',
#   'sondierungsgespräche',
#   'schluchsee',
#   'altmaier',
#   'linke',
#   'nobelprize',
#   'facebookdown',
#   ' antisemitismus',
#   ' transformation',
#   ' mobilitätswende',
#   ' ökozial',
#   ' bundestagswahl',
#   ' linke',
#   ' allesfuersklima',
#   'thread',
#   ' thüringen',
#   'cducsu',
#   'allesfuersklima',
#   ' diesmalgruen',
#   'allesfürsklima',
#   'schlussrunde',
#   ' churchesforfuture',
#   'klimaaktivistin',
#   ' zusammenveraendern',
#   ' laschetdarfnichtkanzlerwerden',
#   ' ichwaehlelinks',
#   ' klimaschutzpolitik',
#   ' demonstranten',
#   'wahlkampf',
#   ' grillfest',
#   'weidel',
#   ' btw',
#   ' fffleaks',
#   ' zusammenverändern',
#   ' klimagebet',
#   ' bouffier',
#   ' erderwärmung',
#   ' zukunftwählen',
#   'weltkindertag',
#   'annewill',
#   'diesmalgruen',
#   'enkelkinderbriefe',
#   'igmetall',
#   ' energiecharta',
#   ' noect',
#   'triell',
#   'hambacherforst',
#   'blockiaa',
#   ' btwahl2021',
#   ' wählbar2021',
#   ' duesseldorf',
#   ' gruenen',
#   ' oknb',
#   ' kino',
#   ' trailer',
#   'briefwahl',
#   ' griechenland',
#   ' streikmituns',
#   ' 1komma5grad',
#   ' finanzsektor',
#   'bankenblockieren',
#   'streikmituns',
#   ' blockupy',
#   ' dürre',
#   ' waldbrände',
#   ' kalifornien',
#   'oknb',
#   'wald',
#   ' hass',
#   ' hetze',
#   ' klimaschmutzlobby',
#   ' flutkatastrophe',
#   'seehofer',
#   ' laschetlacht',
#   'hochwasserkatastrophe',
#   'zdf',
#   'wählbar2021',
#   'umwelt',
#   'wissenschaft',
#   ' fitfor55',
#   ' starkregen',
#   'sterki',
#   ' fahrrad',
#   'kohleausstieg2030',
#   ' zukunft',
#   ' klimaschutzmaßnahmen',
#   'cduwahlprogramm',
#   ' artclimatetaskforce',
#   ' saarbrücken',
#   'gutesklimagesetz',
#   ' nextglobalclimatestrike',
#   'kanada',
#   ' zivilgesellschaft',
#   ' treibhausgasneutralität',
#   ' dannenröderforst',
#   'garkeinplan',
#   ' cduwahlprogramm',
#   'worldrefugeeday',
#   'linkebpt',
#   ' sozialklimagerecht',
#   ' linkebpt',
#   'insm',
#   'alledoerferbleiben',
#   ' müll',
#   'pendler',
#   ' heimarbeit',
#   ' homeoffice',
#   'verkehrswendejetzt',
#   ' dortmund',
#   'a20',
#   ' nazis',
#   ' luissa',
#   'oberhausen',
#   'sterkraderwald',
#   'fridays',
#   ' vergangenheitsbewältigung',
#   ' haustür',
#   'p7spezial',
#   ' sciencematters',
#   ' angelamerkel',
#   'eg2021',
#   'v2g',
#   ' bpt',
#   ' carsharing',
#   ' miv',
#   ' klimaarschlöcher',
#   'lieferkettengesetz',
#   ' nachhaltigkeit',
#   ' klimapledge',
#   'klimaschutzgesetz',
#   'klimaunion',
#   'spdbpt21',
#   'podcast',
#   'greendeal',
#   'heidelbergcement',
#   ' gutearbeit',
#   'welt',
#   ' bverfg',
#   ' bundesregierung',
#   'energiepolitik',
#   ' verbrenner',
#   ' e',
#   '1mai',
#   'bundesverfassungsgericht',
#   ' freiheit',
#   'petersbergerklimadialog',
#   'emissionsbudget',
#   'klimaklage',
#   ' bundesverfassungsgericht',
#   'climatelawsuit',
#   'rwehv',
#   ' kohlestopp',
#   ' tazlab2021',
#   'latif',
#   ' tschernobyl',
#   'plurv',
#   'omv',
#   ' euclimatelaw',
#   ' co2restbudget',
#   'drosten',
#   'grüner',
#   'söder',
#   'euclimatelaw',
#   'neinzurlobbygap',
#   'dd0004',
#   ' saarland',
#   ' tierschutz',
#   ' hambi',
#   ' klimacampsaar',
#   'weltgesundheitstag',
#   ' doppelmoral',
#   'transrightsarehumanrights',
#   ' co2steuer',
#   'suezblocked',
#   'klimaklagen',
#   ' grundrechte',
#   'autogipfel',
#   ' wegenmorgen',
#   'whatsappdown',
#   'allefuer1komma5',
#   'magdeburg',
#   ' mainz',
#   ' darmstadt',
#   ' objektperspektiven',
#   ' experimentierfeld',
#   'agrarwende',
#   'superwahljahr',
#   ' kli',
#   ' erneuerbare',
#   ' ökolandbau',
#   'klimabilanz',
#   'landwirtschaft',
#   'breonnataylor',
#   'wirmüssenreden',
#   'dannilebt',
#   'hanau',
#   ' saytheirnames',
#   'hanauistkeineinzefall',
#   ' höffner',
#   ' hanauistüberall',
#   'klimaschmutzlobby',
#   ' niemehrcsu',
#   'moria',
#   ' unterdrückung',
#   'klimaprotest',
#   'bureg',
#   'schulterschluss',
#   ...],
#  [' fridaymotivation',
#   'volunteer',
#   'fridaythoughts',
#   'friday',
#   ' fridayvibes',
#   ' goodmorning',
#   ' goodmorningtwitterworld',
#   ' goodmorningeveryone',
#   ' fridaythoughts',
#   ' beautiful',
#   'goodmorningtwitterworld',
#   'success',
#   ' size',
#   ' brain',
#   ' dependent',
#   ' thoughts',
#   ' atmosphere',
#   ' perfect',
#   ' weird',
#   'beauty',
#   ' morning',
#   ' freshness',
#   ' emotions',
#   ' ideas',
#   'smile',
#   ' condition',
#   ' intention',
#   ' reason',
#   ' care',
#   ' exception',
#   ' beauty',
#   ' relation',
#   ' goodmorningworld',
#   ' weekendvibes',
#   ' believe',
#   ' right',
#   ' wakeup',
#   ' good',
#   ' yourself',
#   ' shootmode',
#   ' failure',
#   ' enthusiasm',
#   ' try',
#   ' something',
#   ' positive',
#   ' productive',
#   ' peaceful',
#   ' wonderful',
#   ' fridaylove',
#   ' weekend',
#   ' heroes',
#   'fridayfeeling',
#   'fridaymorning',
#   ' friday',
#   'vegan',
#   ' love',
#   ' letloverule',
#   ' lennykravitz',
#   ' endgunviolence',
#   ' topgun',
#   ' anxiety',
#   ' texas',
#   ' survivor',
#   ' parkland',
#   ' memorialday',
#   ' emergency',
#   'happy',
#   ' worldbeeday',
#   ' bee',
#   ' bees',
#   ' agave',
#   ' dates',
#   ' maple',
#   ' syrup',
#   ' beeday',
#   ' sugardaddys',
#   ' savethebees',
#   ' cowspiracy',
#   ' pollinators',
#   ' queen',
#   ' cher',
#   ' animal',
#   ' liberation',
#   ' freedom',
#   ' sentient',
#   ' beings',
#   ' allstars7',
#   ' nationalrescuedogday',
#   ' nationalendangeredspeciesday',
#   ' endspeciesism',
#   ' animalliberation',
#   'switchtoplantbased',
#   ' エシカル消費',
#   ' 買い物は投票',
#   ' プラントベース',
#   ' おうちごはん',
#   ' アースデー',
#   ' アースデイ',
#   ' naturephotography',
#   ' happyeaster',
#   'nationaldolphinday',
#   ' dolphinday',
#   ' captivity',
#   ' kills',
#   ' stopthegrind',
#   ' thursdayvibes',
#   ' opwhales',
#   ' opseaworld',
#   ' defendthewild',
#   ' seaspiracy',
#   ' fridayfitness',
#   ' fridayfun',
#   '大戸屋',
#   ' 動物性不使用',
#   'キッコーマン',
#   ' 気候危機対策に菜食を',
#   '気候危機対策に菜食を',
#   ' 大豆ミート',
#   ' 代替肉',
#   ' sunshine',
#   ' retweeetplease',
#   ' thursdaythoughts',
#   'ヴィーガン',
#   ' 日テレnews24',
#   ' 日テレ',
#   ' ntv',
#   ' 気候変動に具体的な対策を',
#   'beautiful',
#   ' blog',
#   'proverbe',
#   ' cataluñaisspain',
#   ' vivaespaña',
#   ' giro',
#   ' maaneskin',
#   ' yoveosalvame',
#   ' telecincomanipuladores',
#   ' fabricadelateleacosadores',
#   ' italy',
#   ' carlotapradojusticiaya',
#   ' hundimosmediaset',
#   ' rocio2021',
#   ' eusolidaritycorps',
#   ' 再生可能エネルギー',
#   ' 未来のための金曜日',
#   'katyayan',
#   ' katyayan',
#   '未来のための金曜日',
#   ' 未来のためにお肉を減らそう',
#   ' ヴィーガン',
#   ' fridayfunny',
#   ' fridaymood',
#   ' スイーツ',
#   ' おうち時間',
#   ' 伊勢丹',
#   ' 牛肉',
#   ' ソミート',
#   ' 牛丼',
#   'news',
#   'クリスマスディナー',
#   ' メリークリスマス',
#   'ナウシカ',
#   'すき焼き',
#   ' 仙台麩',
#   ' 油麩',
#   ' twitter家庭料理部',
#   '大豆ミート',
#   'ココイチ',
#   '気候も危機',
#   'worldmeatfreeweek',
#   ' おうちtftプロジェクト',
#   ' vegetablefortwo',
#   ' うちベジkitchen',
#   ' 温暖化',
#   ' 異常気象',
#   ' 石炭火力',
#   ' 脱炭素',
#   ' 三菱ufj',
#   ' みずほ',
#   '昼ごはん',
#   ' グリーンバーガー',
#   'ファミマ',
#   '未来のために肉食減らそう',
#   ' someat',
#   ' 高野豆腐',
#   ' おうちごはんを楽しもう',
#   '小泉大臣聞こえますか',
#   'earthhour2020',
#   ' now',
#   ' 唐揚げ',
#   ' おからこんにゃく',
#   'バレンタイン',
#   'おうちランチ',
#   ' ベジタリアン',
#   '福山和人氏',
#   ' 未来に投票',
#   ' 京都市長選',
#   ' fridaysforfuturekyoto',
#   'エコシア',
#   ' ecosia',
#   ' 化石賞',
#   ' 小泉大臣聞こえますか',
#   ' ベジタブルスープカレー',
#   ' グローバル気候マーチ',
#   ' 沖縄',
#   'いいにくいことを言う日',
#   ' いい肉の日',
#   ' quote',
#   'fridaymotivation',
#   ' work',
#   'saveenvironment',
#   'ambientemw',
#   ' museum4climate',
#   ' museiperilclima',
#   'museumweek2022',
#   ' ambientemw',
#   ' siccità',
#   ' weather',
#   'animalrights',
#   ' dogs',
#   'plantatree',
#   'foodie',
#   ' recipes',
#   ' 環境問題',
#   'himalaya',
#   ' youtube',
#   ' tuesdaymotivation',
#   ' greenjobs',
#   'autumn',
#   'beforeifallasleep',
#   ' cupofuji',
#   ' zerohunger',
#   'tmx',
#   ' keystone',
#   ' alberta',
#   ' rainforest',
#   'change',
#   'animals',
#   ' vegans',
#   'vegans',
#   ' veganism',
#   ' veganmessage',
#   ' veganadvocacy',
#   ' vegancommunity',
#   ' veganlife',
#   ' veganlifestyle',
#   ' noanimaluse',
#   ' speciesism',
#   ' respectanimals',
#   'fridayvibes',
#   ' success',
#   ' goldenheart',
#   ' quotes',
#   ' fridaythe13th',
#   ' writingcommunity',
#   ' fridayvibe',
#   ' team',
#   ' inspirationalquote',
#   ' motivationalquotes',
#   ' quotesoftheday',
#   ' quotesdaily',
#   ' quotesaboutlife',
#   ' friendswithbenefits',
#   ' animaloftheday',
#   ' like',
#   ' blogging',
#   ' 山口県',
#   ' foodie',
#   ' thefuturewechoose',
#   ' foodblog',
#   ' yummy',
#   ' friday13th',
#   ' dinner',
#   ' foodies',
#   ' foodbanks',
#   'fridaythe13th',
#   ' tasty',
#   'lasagne',
#   ' quarantena',
#   ' iorestoacasa',
#   ' iosuonodacasa',
#   ' iomangiodacasa',
#   ' venerdi13',
#   ' 13marzo',
#   ' funfactfriday',
#   '東日本大震災から9年',
#   ' パワーシフト',
#   'cheesecake',
#   ' sweet',
#   '気候非常事態宣言',
#   'godmorningfriday',
#   '気候ストライキ',
#   'hanshinawaji',
#   ' werefusecoalmine',
#   ' werefusecoalplant',
#   '気候危機',
#   ' yyc',
#   ' 神戸大学',
#   ' プラごみ',
#   ' 気候ストライキ',
#   'environmentmw',
#   ' planetearth',
#   'motivation',
#   ' photos',
#   ' crypto',
#   ' anchor',
#   ' lifestyle',
#   ' cleaning',
#   ' photographylovers',
#   'nftcommunity',
#   ' nfts',
#   ' nftfamily',
#   ' nftfam',
#   ' fridayquotes',
#   'ligue_des_optimistes',
#   ' photographer',
#   'cuomocommunity',
#   ' twitterfriends',
#   ' haveagoodday',
#   'i̇mamzamana',
#   ' جمعه_مباركه',
#   ' whoismahdi',
#   'flowersonfriday',
#   ' 365dayswild',
#   ' macro',
#   ' macrophotography',
#   ' gardeningtwitter',
#   ' gardenersworld',
#   ' flowerpower',
#   ' flowerlover',
#   ' flowerreport',
#   ' thephotohour',
#   ' naturalbeauty',
#   ' naturephoto',
#   'happyweekend',
#   ' positivevibes',
#   'birdlovers',
#   ' owl',
#   ' photograph',
#   ' womensart',
#   ' newhampshire',
#   ' fridaynightfunkin',
#   ' birdphotography',
#   ' birding',
#   'photography',
#   ' marketingtips',
#   ' learn',
#   ' elephants',
#   ' saveallelephants',
#   ' jumatberkah',
#   ' jummamubarak',
#   ' jummahmubarak',
#   ' cumalar',
#   ' cumamızmubarekolsun',
#   ' makkah',
#   'weather',
#   ' november',
#   ' autumn',
#   ' windy',
#   ' rain',
#   ' wet',
#   ' cloudy',
#   ' weatherforecast',
#   ' motivational',
#   'hungerstrikeforclimate',
#   'thecorporatelady',
#   ' ethnic',
#   ' worklifebalance',
#   'happyday',
#   ' goodnewstoday',
#   'gamedev',
#   ' indiedev',
#   ' indiegame',
#   ' indiegamedev',
#   ' indie',
#   ' indiegames',
#   ' gamer',
#   ' games',
#   ' gaming',
#   ' game',
#   ' programmer',
#   ' unity',
#   ' saturdayvibes',
#   'presidentielles2022',
#   ' jeunesse',
#   ' égalité',
#   ' feminisme',
#   ' avenir',
#   ' jadot2022',
#   'cryptocurrency',
#   ' cryptotrading',
#   'stockedge',
#   ' elearnmarkets',
#   ' motivation',
#   ' stockmarketindia',
#   'cleanwater',
#   'fridayfitness',
#   'contentmarketing',
#   ' marketingstrategy',
#   ' digitalmarketing',
#   ' marketing',
#   ' sociamedia',
#   ' growthhacking',
#   'शुभ_शुक्रवार',
#   ' positivemindset',
#   ' बोधिसत्व',
#   ' vocal4local',
#   ' स्वदेशी',
#   ' वैक्सीन_पेटैंट',
#   ' atmanirbharbharat',
#   ' author',
#   ' links',
#   ' tacotuesday',
#   'saladdays',
#   ' breakfast',
#   ' breakfastclub',
#   ' twittertrends',
#   ' beans',
#   ' pasta',
#   ' europeday',
#   ' fridayfunday',
#   'शुक्र_श्रीशक्ति',
#   ' swadeshi',
#   ' प्रबुद्ध_मनन',
#   ' देशभक्त',
#   ' किसान_पुकार_सुने_सरकार',
#   'शुभ_शुक्र',
#   ' देश_को_जवाब_दो',
#   ' किसान_भगत_सिंह_बनेगा',
#   ' nonhumanrights',
#   ' palmoil',
#   ' consumers',
#   'happyfriday',
#   ' twitterworld',
#   ' iqrtg',
#   ' livelife',
#   ' makeyouhappy',
#   ' enjoyingeverydaylife',
#   ' fikafuntimes',
#   ' contest',
#   'sundayshoutout',
#   ' positivity',
#   ' bepositive',
#   ' सकारात्मक_संदेश',
#   'saturdayvibes',
#   ' joinin',
#   'fuckit',
#   'sundayfeels',
#   ' हिंदी',
#   ' लखनऊ_विश्वविद्यालय',
#   ' pmblessinglu',
#   'saturdaymotivation',
#   'panna',
#   ' eat',
#   ' goodmorningamerica',
#   ' fridaylivestream',
#   'florence',
#   ' flood',
#   ' november1st',
#   ' florence',
#   ' quoteoftheday',
#   ' godmorningfriday',
#   'worldfoodday',
#   ' nayisoch',
#   'treesforthefuture',
#   ' worldsmileday',
#   '気候変動',
#   ' believeinyourself',
#   ' uplifting',
#   'crestedaily',
#   ' crestemedia',
#   ' letsgrowtogether',
#   ' crestefamily',
#   ' prayer',
#   'hitanshisharma',
#   'mrfaisu',
#   'running',
#   'jwave',
#   ' sky813',
#   'contestindia',
#   ' contestalertindia',
#   ' contesttime',
#   ' contestalartindia',
#   ' contestquestion',
#   ' contestindia',
#   ' quiztime',
#   ' quiz',
#   ' quizzed',
#   ' quiznight',
#   ' quizbuzz',
#   ' tgif',
#   'vivaldi',
#   ' violin',
#   ' violinist',
#   ' classicalmusic',
#   ' electronicmusic',
#   'litterpicking',
#   ' volunteer',
#   ' lovewhereyoulive',
#   ' wales',
#   ' horror',
#   ' movies',
#   'femqualities',
#   ' relationship',
#   ' savetheenvironment',
#   ' greenliving',
#   ' plantatree',
#   ' treeplanting',
#   'garden',
#   ' gardenshour',
#   ' flowers',
#   ' roses_are_rosie',
#   'videogames',
#   ' gamedev',
#   ' pixelart',
#   ' photooftheday',
#   ' italiy',
#   ' colors',
#   ' photographyisart',
#   ' natura',
#   'blog',
#   'anarosaquintana',
#   ' yoapoyoalgobierno',
#   ' uniontrabajoyproduccion',
#   ' anarosacorrupta',
#   'secretwalks',
#   ' secret',
#   ' place',
#   ' reflection',
#   ' stayconnectedtogether',
#   ' wellbeing',
#   ' connections',
#   ' swansea',
#   'cat',
#   ' cats',
#   ' kitten',
#   ' catsontwitter',
#   ' catsofinstagram',
#   ' cats_of_world',
#   'palmoil',
#   ' dadijanki',
#   ' omshanti',
#   ' rajayoga',
#   ' meditation',
#   ' spirituality',
#   ' thetimeisnow',
#   'dream',
#   'love',
#   ' goodvibes',
#   ' thinkpositive',
#   ' imagine',
#   'ddquiz',
#   ' contestofchampions',
#   ' quarantineandchill',
#   ' lockdownextension',
#   ' lockdown2',
#   ' movie',
#   ' guessthemovie',
#   ' answersnews',
#   'anipals',
#   ' gainesville',
#   ' florida',
#   ' nonprofit',
#   ' progress',
#   ' focus',
#   ' youngpeople',
#   ' connect2earth',
#   ' earthhourwales',
#   ' earthhouruk',
#   ' behappy',
#   ' healthiswealth',
#   ' karma',
#   ' 2020vision',
#   'dennisthemenace',
#   'sooraraipottru',
#   ' sudhakongara',
#   ' gvprakash',
#   ' suriya',
#   ' workout',
#   'happybirthdayceo',
#   ' ceoquotes',
#   ' ceo',
#   ' ees20',
#   'sootysfuckitfriday',
#   ' coachella',
#   ' foodbloggers',
#   ' recipe',
#   ' cooking',
#   ' easyrecipes',
#   ' dessert',
#   ' desserts',
#   'helau',
#   'digitalmarketing',
#   ' seo',
#   ' b2bmarketing',
#   ' socialmediamarketing',
#   'germanmediart',
#   ' retweetplease',
#   ' denkmaldrübernach',
#   ' andieeigenenasefassen',
#   ' isso',
#   ' nichtakleubereinenkammscheren',
#   'povertycrowdfund',
#   ' povertywishlists',
#   ' emergencycrowdfund',
#   ' emergencywishlists',
#   ' joinin247',
#   ' joininfeelgood',
#   ' fridaynight',
#   'nikon',
#   ' nikonphotography',
#   ' nikonnofilter',
#   ' landscape',
#   ' costabrava',
#   'tuesdaythoughts',
#   'rosenmontagsumzug',
#   ' helau',
#   ' teens',
#   ' northernireland',
#   ' wise',
#   ' motivacion',
#   ' happiness',
#   ' happy',
#   ' ambition',
#   ' friyay',
#   ' nojudgement',
#   ' joy',
#   ' loveis',
#   'endanimalag',
#   ' fridaylituations',
#   ' friends',
#   'seo',
#   'davos20',
#   'felizviernes',
#   ' mainz1701',
#   ' themorningflava',
#   'wochenende',
#   ' twitchde',
#   ' germantwitchrt',
#   ' stream',
#   ' streamer',
#   ' streamacademyrt',
#   ' germanmediart',
#   ' primenightrt',
#   ' twitchtv',
#   'rubiesallies',
#   ' cgl',
#   ' thankyousafer',
#   ' saferlift',
#   ' fridayheadlines',
#   ' saturday',
#   ' bird',
#   ' rahulgandhi',
#   ' राष्ट्रवादिराठौर',
#   'boxingday2019',
#   ' treesforthefuture',
#   ' courage',
#   ' fridayreads',
#   'thoughtoftheday',
#   ' thoughtfortheday',
#   ' decemberwish',
#   ' december13th',
#   ' december',
#   ' onelove',
#   ' reggae',
#   ' reggaemusic',
#   ' rastafari',
#   ' reggaevibes',
# ...
#   'archaeologists',
#   ' museums',
#   ' archaeology',
#   ' openairmuseum',
#   ' ecofascism',
#   ' polcan',
#   'buynothingday',
#   'artstrike4climate',
#   ' lastjudgement',
#   ' lucasvanleyden',
#   'museums',
#   ' museumsforfutureaustria',
#   'sijoitanuoriin',
#   ' äläostamitään',
#   ' whitemonday',
#   ' dog',
#   ' dogsoftwittter',
#   ' enjoynature',
#   'mbpoli',
#   ' climateactionmb',
#   'thisiszerohour',
#   'londonbridge',
#   ' terrorismo',
#   ' attentato',
#   ' londra',
#   ' conte',
#   ' mes',
#   ' dimaio',
#   ' ikea',
#   'gazprom',
#   'jokuraja',
#   'heatwaves',
#   'pipeline',
#   'ratm',
#   ' notmeus',
#   ' bernie2020',
#   ' bernieorbust',
#   ' feelthebern',
#   ' berniesanders',
#   ' bernieblackout',
#   ' berniesanders2020',
#   ' berniesbackinmn',
#   ' democrats',
#   ' berniesback',
#   ' berniebeatstrump',
#   ' bernie',
#   ' bernieisback',
#   ' bernieyellsforus',
#   'emobile',
#   'ilmastonmuutos',
#   'cartoon',
#   ' walliserbote',
#   'ecoshopping',
#   'luontokato',
#   'luonto',
#   'tuulivoima',
#   'ympäristö',
#   'chokedup',
#   'droughts',
#   'tiede',
#   'korruptio',
#   'politiikka',
#   'konzernstrategie',
#   ' rwetoterplanet',
#   'nichtmitmeinemgeld',
#   ' weltspartag',
#   'rwetoterplanet',
#   'räumung',
#   'lobaubleibt',
#   ' stadtstraße',
#   'lobaucamp',
#   'disinformation',
#   'msm',
#   'socialmedia',
#   ' rc3',
#   'informationscience',
#   'foodforfuture',
#   'disasters',
#   'winter',
#   ' nobau',
#   'ecosocialism',
#   'deniers',
#   'christmas',
#   ' boycott4future',
#   ' shoplocal',
#   ' repamera',
#   'monitor',
#   ' dieanstait',
#   'arktinen',
#   'kestäväkehitys',
#   'pohjoinenulottuvuus',
#   'arktinenstrategia',
#   'doubt',
#   'division',
#   'dismissive',
#   'trolltactics',
#   'peopleb4profit',
#   'nowruz',
#   ' iran',
#   ' ایران',
#   ' نوروز',
#   'misinformation',
#   'electricvehicles',
#   'beaware',
#   'perfection',
#   'umsganze',
#   'iaa',
#   'sandimgetriebe',
#   'carpitalism',
#   'decarbonizing',
#   'extreme',
#   'thinkglobal',
#   'actlocal',
#   'evergiven',
#   'evergreen',
#   'leadership',
#   'girlpower',
#   'climatebrainy',
#   'libera1m2',
#   'wastewatchenaccion',
#   'hèroeslibera',
#   '1m2xpersona',
#   'toukokuun',
#   'lumi',
#   'talvi',
#   'klimaurteil',
#   'lawsuit',
#   'ecthr',
#   'april12th',
#   'teamlaura',
#   'votelaura',
#   'aberdeen',
#   'sp21',
#   'se21',
#   'fightforyourhumanright',
#   'askgerald',
#   'chocolate',
#   'africavote',
#   'teamcows',
#   '2020ends',
#   'economyforfuture',
#   ' profitunabhängig',
#   'profitideologie',
#   ' mensch',
#   'profitunabhängig',
#   'internationalmigrantsday',
#   'marktführer',
#   'blackfridayamazon',
#   'buyingstuff',
#   'lessismore',
#   'worldchildrensday',
#   'online',
#   'election2020',
#   'euparliament',
#   'istandwithgreata',
#   'decarbonize',
#   'solvingtheclimatecrisis',
#   'bolsonaro',
#   'audi',
#   'nestle',
#   'forfuture',
#   'betterfuture',
#   'besserezukunft',
#   'unterricht',
#   'matura2020',
#   'kurz',
#   'womenshistorymonth',
#   'iran',
#   'ایران',
#   'fröhlicherevolution',
#   'carbonneutral',
#   'zerstörung',
#   'wachstum',
#   'sotu',
#   'showyourstripes',
#   'archaeology',
#   'holidayseason',
#   'timeforaction',
#   'terrorismo',
#   'attentato',
#   'londra',
#   'conte',
#   'mes',
#   'dimaio',
#   'lastjudgement',
#   'äläostamitään',
#   'whitemonday',
#   'dog',
#   'dogsoftwittter',
#   'shoplocal',
#   'notmeus',
#   'bernie2020',
#   'bernieorbust',
#   'feelthebern',
#   'berniesanders',
#   'bernieblackout',
#   'berniesanders2020',
#   'berniesbackinmn',
#   'democrats',
#   'berniesback',
#   'berniebeatstrump',
#   'bernie',
#   'bernieisback',
#   'nb6thgrade',
#   'sundevils'],
#  ['maizittiebuoni',
#   'insorgiamo',
#   'clima',
#   'roma',
#   'torino',
#   'thetimeforgamesisover',
#   'milano',
#   ' climateactionow',
#   ' uproothesystem',
#   '24settembre',
#   ' scioperoperilclima',
#   ' momentostorico',
#   ' 24settembre',
#   ' mercalli',
#   'fiamme',
#   'bari',
#   ' emergenzaclimatica',
#   ' weareunstoppable',
#   'no',
#   ' eumercosur',
#   ' saynoeumercosur',
#   ' faceclimateemergeny',
#   '9ottobre',
#   ' 9ottobre',
#   '25settembre',
#   ' politica',
#   'overshootday2020',
#   'terra',
#   ' 5giugno',
#   '5giugno',
#   'breaking',
#   ' digitalizzato',
#   ' casa',
#   'wallstreet',
#   ' fossile',
#   ' cnbc',
#   'futuro',
#   ' turin',
#   'personoftheyear',
#   'persone',
#   ' cambiamento',
#   'marchforclimate',
#   ' cumbredelclima',
#   'napoli',
#   ' conferenza',
#   ' politiche',
#   'november30th',
#   'blockfriday',
#   ' climatica',
#   '29novembre',
#   ' 29novembre',
#   'scioperoglobale',
#   'crisi',
#   ' collinsdictionaries',
#   'italy',
#   ' lettertotheminister',
#   'leader',
#   'uproothesystem',
#   'cambiamentoclimatico',
#   ' napoli',
#   'riscaldamentoglobale',
#   'fossilgas',
#   ' total',
#   'incendi',
#   ' azione',
#   'scioperoperilclima',
#   'antartide',
#   ' mare',
#   '19marzo',
#   ' agricoltura',
#   'cdp',
#   'sardine',
#   ' santori',
#   ' sardine',
#   ' italia',
#   'ambiente',
#   'renzi',
#   ' italiaviva',
#   ' trivelle',
#   ' tantacazz',
#   ' roma',
#   'posillipo',
#   ' vento',
#   ' uragano',
#   'eni',
#   ' basilicata',
#   ' nimby',
#   ' rie',
#   ' nomisma',
#   ' prodi',
#   ' pd',
#   'total',
#   ' cambiamenticlimatici',
#   ' decretoclima',
#   'bellanova',
#   ' salute',
#   ' prodottitipici',
#   ' eni',
#   ' cessodestra',
#   ' autostrade',
#   ' concessioni',
#   'prescrizione',
#   ' futuro',
#   'plastica',
#   'dissestoidrogeologico',
#   'italiaviva',
#   ' gioventùbruciata',
#   ' vecchiaia',
#   ' via',
#   ' gela',
#   ' salvini',
#   ' ong',
#   'weareunstoppable',
#   ' sardinefritte',
#   ' salvinimerda',
#   ' notriv',
#   'speranza',
#   ' verde',
#   ' europaverde',
#   ' venezia',
#   'basilicata',
#   ' concessione',
#   ' black',
#   'armi',
#   ' arabiasaudita',
#   ' egitto',
#   ' squali',
#   ' leader',
#   'movimento',
#   ' m5s',
#   'italiashock',
#   ' matera',
#   ' renzeni',
#   ' bolloré',
#   ' criminelsécologistes',
#   ' esclavagistes',
#   ' lrem',
#   ' modem',
#   ' lr',
#   ' huiledepalme',
#   ' 1for25',
#   ' 1pour25',
#   ' carbonrationtickets',
#   'bologna',
#   ' zaia',
#   'italiavivadi',
#   ' forzamafia',
#   ' berlusconi',
#   ' dellutri',
#   ' renzi',
#   ' carfagna',
#   'cretino',
#   ' treccani',
#   ' plastica',
#   ' inceneritori',
#   ' immunità',
#   ' ilva',
#   ' mondialidisci',
#   ' lega',
#   ' cemento',
#   ' ndrangheta',
#   'pd',
#   'marattin',
#   'emergenzaclimatica',
#   'sciopero',
#   'fckatomausstieg',
#   'transizioneecologica',
#   'cingolani',
#   ' radicalchic',
#   ' fridaysforfutureitalia',
#   ' libri',
#   'taranto',
#   ' speranza',
#   ' 1ºmaggiotaranto',
#   ' cingolani',
#   ' fffmar19',
#   ' alimentazione',
#   'recoveryfund',
#   'pianeta',
#   'dirittiincomune',
#   '24aprile',
#   'ritapavone',
#   'manovra2020',
#   ' 13dicembre',
#   ' 13dic',
#   '13dicembre',
#   ' facciamorete',
#   ' rome',
#   ' treviso',
#   'ilva',
#   ' usb',
#   ' liberiepensanti',
#   ' educazionecivica',
#   'gretagonuclear',
#   ' nograndinavi',
#   ' mose',
#   ' salviamovenezia',
#   'venezia',
#   'music',
#   ' verona',
#   ' mantova',
#   ' design',
#   ' sport',
#   ' streatweare',
#   ' calcio',
#   ' fashionweek',
#   ' governo',
#   ' valpolicella',
#   'stories',
#   ' imaginative',
#   ' relevant',
#   'casepopolari',
#   ' aler',
#   ' 29n',
#   'papafrancesco',
#   ' fratellitutti',
#   ' migranti',
#   ' islam',
#   ' fckatomausstieg',
#   ' atoms4future',
#   'neckarwestheim',
#   'acquaaltaavenezia',
#   ' feltri',
#   ' libero',
#   ' veneto',
#   ' 14novembre',
#   ' acquaalta',
#   ' acquagranda',
#   ' altamarea',
#   'studio24',
#   ' recoveryfund',
#   'globawarming',
#   'notav',
#   'ricerca',
#   'biani',
#   ' migrantiambientali',
#   'guerra',
#   'biciinprotesta',
#   'shell',
#   ' colosseo',
#   'crisiclimatica',
#   'climateactionow',
#   'momentostorico',
#   'mercalli',
#   'azione',
#   'amazonie',
#   ' uemercosur',
#   'fridaysforfutureitaly',
#   'fridaysforfutureitalia',
#   'fashion',
#   'mare',
#   'eumercosur',
#   'saynoeumercosur',
#   'faceclimateemergeny',
#   'atoms4future',
#   'agricoltura',
#   'alimentazione',
#   'carboninequality',
#   'politica',
#   'santori',
#   ' giornatamondialedellambiente',
#   'colosseo',
#   'italia',
#   'digitalizzato',
#   'casa',
#   'trivelle',
#   'tantacazz',
#   'stopttip',
#   'vento',
#   'uragano',
#   ' eniecocida',
#   'nimby',
#   'rie',
#   'nomisma',
#   'prodi',
#   'fossile',
#   'cnbc',
#   'cambiamenticlimatici',
#   'decretoclima',
#   'salute',
#   'prodottitipici',
#   'prayersforaustralia',
#   'cessodestra',
#   'autostrade',
#   'concessioni',
#   'geologica',
#   'turin',
#   'migranti',
#   'gioventùbruciata',
#   'vecchiaia',
#   'aritmodelcuore',
#   ' christmasiscoming',
#   'cambiamento',
#   'via',
#   'gela',
#   'cumbredelclima',
#   'salvini',
#   'conferenza',
#   'politiche',
#   'ong',
#   'sardinefritte',
#   'salvinimerda',
#   'notriv',
#   'verde',
#   'europaverde',
#   'climatica',
#   'treviso',
#   'concessione',
#   'black',
#   'aler',
#   'usb',
#   'liberiepensanti',
#   'nograndinavi',
#   'mose',
#   'arabiasaudita',
#   'egitto',
#   'squali',
#   'm5s',
#   'matera',
#   'renzeni',
#   '15novembre',
#   'bolloré',
#   'criminelsécologistes',
#   'esclavagistes',
#   'lrem',
#   'modem',
#   'lr',
#   'huiledepalme',
#   '1for25',
#   '1pour25',
#   'feltri',
#   'libero',
#   'zaia',
#   'veneto',
#   '14novembre',
#   'acquaalta',
#   'acquagranda',
#   'verona',
#   'mantova',
#   'design',
#   'sport',
#   'streatweare',
#   'calcio',
#   'fashionweek',
#   'governo',
#   'valpolicella',
#   'collinsdictionaries',
#   'forzamafia',
#   'berlusconi',
#   'dellutri',
#   'carfagna',
#   'treccani',
#   'inceneritori',
#   'immunità',
#   'mondialidisci',
#   'lega',
#   'cemento',
#   'ndrangheta',
#   'imaginative'],
#  [' wirsindmehr',
#   ' vonderleyen',
#   'ichbinarmutsbetroffen',
#   ' ohnemeinenphysiotherapeuten',
#   ' therapeutenamlimit',
#   ' einesorgeweniger',
#   ' heimatstern',
#   ' legalizeit',
#   ' entkriminalisierungsofort',
#   ' gesundheitkämpft',
#   ' unten',
#   ' legalisierung',
#   'boomer',
#   ' frauenhasser',
#   ' pipelineindieluft',
#   'ohnemeinenphysiotherapeuten',
#   ' stopputinnow',
#   ' armut',
#   ' legalisierungjetzt',
#   ' stopwarinukraine',
#   ' münchenbleibtbunt',
#   ' richtermüller',
#   'legalisierenjetzt',
#   ' rheinlandtrump',
#   ' laschetluegt',
#   ' cdurausausderregierung',
#   ' cducsu',
#   'chemnitz',
#   ' systemfrage',
#   ' unrechtsstaat',
#   ' sorgeweniger',
#   ' rente',
#   'covid19de',
#   ' patientenamlimit',
#   ' aufstehen',
#   'pflegebonus',
#   ' renten',
#   ' grundrente',
#   ' hartz4',
#   'alle',
#   ' cannabisliebhaber',
#   ' cannabiskonsumenten',
#   ' legalisierungsbefürworter',
#   ' jugend',
#   ' senioren',
#   ' cannabisverbot',
#   ' erwerbsminderungsrente',
#   'golfstrom',
#   ' cduverhindern',
#   ' narrative',
#   ' aktivismus',
#   'steuern',
#   ' covididioten',
#   'klimawandeln',
#   ' klimawandeln',
#   'coronavirusdeutschland',
#   ' faktenstatteinlullen',
#   ' pff',
#   ' p4f',
#   ' ieselparador',
#   ' almería',
#   'therapeutenamlimit',
#   'einesorgeweniger',
#   'heimatstern',
#   'legalizeit',
#   'entkriminalisierungsofort',
#   'gesundheitkämpft',
#   'unten',
#   'legalisierung',
#   'frauenhasser',
#   'stopputinnow',
#   'putinskrieg',
#   ' pension',
#   ' besteuert',
#   ' generation',
#   'hartziv',
#   'blöd_on_tour_presse',
#   ' hartzundherzlich',
#   ' memes',
#   's4f',
#   'armut',
#   'hartzundherzlich',
#   'legalisierungjetzt',
#   'stopwarinukraine',
#   'f4f',
#   'münchenbleibtbunt',
#   'richtermüller',
#   'rheinlandtrump',
#   'cdurausausderregierung',
#   'cduunwaehlbar',
#   'cduverhindern',
#   'europawahl',
#   'systemfrage',
#   'cannabis',
#   'narrative',
#   'sorgeweniger',
#   'rente',
#   'pension',
#   'besteuert',
#   'patientenamlimit',
#   'aufstehen',
#   'renten',
#   'grundrente',
#   'cannabisliebhaber',
#   'cannabiskonsumenten',
#   'legalisierungsbefürworter',
#   'jugend',
#   'senioren',
#   'faktenstatteinlullen',
#   'cannabisverbot',
#   'climatehope',
#   'ieselparador'],
#  ['nahverkehr',
#   'schulen',
#   ' schulen',
#   ' energie',
#   ' bußgeldbescheide',
#   ' schulschwänzer',
#   ' kitas',
#   ' pressekonferenz',
#   ' markus',
#   ' gemeine',
#   ' bahnhof',
#   ' ernten',
#   'br',
#   ' ryanair',
#   ' basis',
#   ' nürnberger',
#   ' eka',
#   '600meter',
#   'billige',
#   ' saubere',
#   ' standortfaktor',
#   'schulschwänzer',
#   ' nichtsnutze',
#   'virtualreality',
#   ' augmentedreality',
#   ' realestate',
#   ' realestatemarket',
#   ' 360vrtour',
#   ' virtualtours',
#   ' 3dtours',
#   ' vrtour',
#   ' vr',
#   ' realtor',
#   ' marketingdigital',
#   'zukunft',
#   'childrenslivesmatter',
#   'taz',
#   ' mietenwahnsinn',
#   'arbeit',
#   ' pflege',
#   ' frauen',
#   ' streikbornheim',
#   ' lgbti',
#   ' wellfarenotwarfare',
#   'microabenteuer',
#   ' wiwableibt',
#   ' völlibleibt',
#   ' pappelheimer',
#   'homeoffice',
#   'nachhaltig',
#   ' bauen',
#   ' leerstand',
#   ' torstr225_227',
#   ' verdrängung',
#   ' 200häuser',
#   ' wirbleibenalle',
#   ' jetzterstrecht',
#   'urwald',
#   'profit',
#   ' parteimitglieder',
#   ' schulleitung',
#   ' meinungsmache',
#   ' beeinflussung',
#   ' kindern',
#   'parteimitglieder',
#   'schulleitung',
#   'meinungsmache',
#   'beeinflussung',
#   'augmentedreality',
#   'realestate',
#   'realestatemarket',
#   '360vrtour',
#   'virtualtours',
#   '3dtours',
#   'vrtour',
#   'vr',
#   'realtor',
#   'verbünden',
#   ' politischerwandel',
#   'mindestabstand',
#   'stadt',
#   'erneuerbarer',
#   'energie',
#   'bauen',
#   'leerstand',
#   'torstr225_227',
#   'verdrängung',
#   '200häuser',
#   'mietenwahnsinn',
#   'wirbleibenalle',
#   'flughafen',
#   'pflege',
#   'frauen',
#   'streikbornheim',
#   'lgbti',
#   'wiwableibt',
#   'völlibleibt',
#   'bußgeldbescheide',
#   'kitas',
#   'markus',
#   'gemeine',
#   'bahnhof',
#   'ernten',
#   'ryanair',
#   'basis',
#   'nürnberger',
#   'eka',
#   'saubere'],
#  ['oldenburg',
#   'polarstern',
#   'bremen',
#   ' wissenschafftklimaschutz',
#   ' potsdam',
#   ' polarstern',
#   ' ps126',
#   ' scientistforfuture',
#   ' stern',
#   ' hitzewelle',
#   ' antifaschismus',
#   ' unitebehindscience',
#   ' awis4future',
#   'antarctic',
#   'potsdam',
#   'negativeemissionen',
#   ' cdr',
#   ' haloac3',
#   'neumayer',
#   ' bremerhaven',
#   ' arktis',
#   'geoengineering',
#   ' enhancedweathering',
#   'klimamahnwache',
#   'awipev',
#   ' nyalesund',
#   'wissenschafftklimaschutz',
#   'werder',
#   'pillepalle',
#   ' angrypenguin',
#   ' feminismus',
#   ' siemenslügt',
#   ' boykottsiemens',
#   'wissenschaftskommunikation',
#   ' scienceslam',
#   'scienceslam',
#   ' wisskomm',
#   ' keepcalmandcutemissions',
#   ' globalwarmingsucks',
#   ' palice',
#   ' werder',
#   'olivin',
#   'cdr',
#   'haloac3',
#   'bremerhaven',
#   'enhancedweathering',
#   'planetb',
#   'ps126',
#   'angrypenguin',
#   'feminismus',
#   'antifaschismus',
#   'siemenslügt',
#   'unitebehindscience',
#   'awis4future',
#   'wisskomm',
#   'keepcalmandcutemissions',
#   'globalwarmingsucks'],
#  [' sudan',
#   'klimawahlhelfer',
#   ' staytuned',
#   'week33',
#   ' ldc',
#   ' day2',
#   ' educationforgirls',
#   'week32',
#   ' day17',
#   'people',
#   ' freedomstruggle',
#   'week31',
#   ' day16',
#   'week30',
#   ' day15',
#   'week29',
#   ' day14',
#   ' day13',
#   'day1',
#   'weehawken',
#   ' selday',
#   ' fuelingfutures',
#   'writing',
#   ' nevertooearly',
#   ' preparation',
#   ' hydroponics',
#   ' tomato',
#   ' weehawken',
#   ' weegrow',
#   ' spring2020',
#   ' getexcited',
#   ' startsmall',
#   'day18',
#   'ldc',
#   'day2',
#   'educationforgirls',
#   ' distance',
#   'day17',
#   'sudan',
#   'freedomstruggle',
#   'day16',
#   'day15',
#   'day14',
#   'day13',
#   'selday',
#   'fuelingfutures',
#   'nevertooearly',
#   'preparation',
#   'masks',
#   'staytuned',
#   'hydroponics',
#   'tomato',
#   'weegrow',
#   'spring2020',
#   'getexcited'],
#  ['scamdemic',
#   ' racewar',
#   ' newworldorder',
#   ' fridaysforfreedom',
#   ' byobb',
#   ' coronaviruscanada',
#   ' policestate',
#   ' policebrutality',
#   ' martiallaw',
#   ' agenda21',
#   ' contacttracing',
#   'fridaysforfreedom',
#   '3k',
#   'atomausstiegs',
#   ' luisaschweigt',
#   'stopp',
#   'grohnde',
#   'theweleit',
#   'kernkraftwerke',
#   ' reinhardswald',
#   ' keingradmehr',
#   'maßen',
#   'bildungsstattpraesenzpflicht',
#   ' teamsicherebildung',
#   ' teamdrosten',
#   ' lauterbach',
#   ' elternstehenauf',
#   'luisaschweigt',
#   'teamsicherebildung',
#   'teamdrosten',
#   'lauterbach',
#   'reinhardswald',
#   'plandemic',
#   'racewar',
#   'newworldorder',
#   'byobb',
#   'coronaviruscanada',
#   'policestate',
#   'policebrutality',
#   'martiallaw',
#   'agenda21'],
#  ['einigung',
#   ' nationalstaaten',
#   'forscher',
#   ' förderung',
#   ' präsidenten',
#   ' pariser',
#   ' jülicher',
#   ' forscher',
#   ' treibhausgasausstoß',
#   ' volkswirtschaftlich',
#   'preisverleihungen',
#   ' ehrungen',
#   ' alibi',
#   ' umweltpreis',
#   'überwärmung',
#   ' klimawandels',
#   'kohleindustrie',
#   'wohlstand',
#   'dokumente',
#   'nationalstaaten',
#   'förderung',
#   'präsidenten',
#   'pariser',
#   'jülicher',
#   'treibhausgasausstoß',
#   'volkswirtschaftlich',
#   'ehrungen',
#   'alibi',
#   'umweltpreis']]

# %%
nodes = []
comm = []

# %%
for idx, k in enumerate(louvain_coms.communities[:13]):
    for i in k:
        nodes.append(i)
        comm.append(idx)

# %%
df = pd.DataFrame({"Id": nodes,
                   "Community": comm})
df.to_csv("nodes.csv", index=False)
