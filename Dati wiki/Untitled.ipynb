# %%
import pandas as pd

# %%
path = "../Dati wiki/nodes_meaning_Ex.xlsx"

# %%
df = pd.read_excel(path, index_col=None)

# %%
df
# Out:
#                  Tag                                        Significati  \
# 0   fridaysforfuture  School Strike for Climate Swedish, also known ...
# 1      climatestrike  School Strike for Climate Swedish, also known ...
# 2      climateaction  Climate action (or climate change action) refe...
# 3      climatecrisis  Climate crisis is a term describing global war...
# 4      climatechange   Contemporary climate change includes both glo...
# ..               ...                                                ...
# 94           animals  Animals are multicellular, eukaryotic organism...
# 95           governo  Governo is a winemaking technique reportedly i...
# 96         emobility  EVs first came into existence in the mid-19th ...
# 97             chile  Chile, officially the Republic of Chile, is a ...
# 98               onu  United Nations in other languages, e.g. French...
#
#    Unnamed: 2
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# ...

# %%
df.to_csv('no_me.csv', index = False)

# %%
new = pd.read_csv("no_me.csv")

# %%
new
# Out:
#                  Tag                                        Significati  \
# 0   fridaysforfuture  School Strike for Climate Swedish, also known ...
# 1      climatestrike  School Strike for Climate Swedish, also known ...
# 2      climateaction  Climate action (or climate change action) refe...
# 3      climatecrisis  Climate crisis is a term describing global war...
# 4      climatechange   Contemporary climate change includes both glo...
# ..               ...                                                ...
# 94           animals  Animals are multicellular, eukaryotic organism...
# 95           governo  Governo is a winemaking technique reportedly i...
# 96         emobility  EVs first came into existence in the mid-19th ...
# 97             chile  Chile, officially the Republic of Chile, is a ...
# 98               onu  United Nations in other languages, e.g. French...
#
#    Unnamed: 2
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# ...

# %%
new.columns
# Out:
# Index(['Tag', 'Significati', 'Unnamed: 2'], dtype='object')

# %%
new.drop(['Unnamed: 2'], axis=1, inplace=True)

# %%
new
# Out:
#                  Tag                                        Significati
# 0   fridaysforfuture  School Strike for Climate Swedish, also known ...
# 1      climatestrike  School Strike for Climate Swedish, also known ...
# 2      climateaction  Climate action (or climate change action) refe...
# 3      climatecrisis  Climate crisis is a term describing global war...
# 4      climatechange   Contemporary climate change includes both glo...
# ..               ...                                                ...
# 94           animals  Animals are multicellular, eukaryotic organism...
# 95           governo  Governo is a winemaking technique reportedly i...
# 96         emobility  EVs first came into existence in the mid-19th ...
# 97             chile  Chile, officially the Republic of Chile, is a ...
# 98               onu  United Nations in other languages, e.g. French...
#
# [99 rows x 2 columns]

# %%
pd = new.to_csv('pulito_nodes.csv', index = False)
pd

# %%
pd

# %%
pip install tensorflow
# Out:
# ...
#   Using cached tensorflow-2.9.1-cp38-cp38-win_amd64.whl (444.1 MB)
# ...
#   Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# ...
#   Using cached keras-2.9.0-py2.py3-none-any.whl (1.6 MB)
# ...
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# ...
#   Using cached absl_py-1.2.0-py3-none-any.whl (123 kB)
# ...
#   Using cached libclang-14.0.1-py2.py3-none-win_amd64.whl (14.2 MB)
# ...
#   Using cached Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
# ...
#   Using cached tensorflow_io_gcs_filesystem-0.26.0-cp38-cp38-win_amd64.whl (1.5 MB)
# ...
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# ...
#   Using cached termcolor-1.1.0.tar.gz (3.9 kB)
# ...
#   ERROR: Can't roll back numpy; was not uninstalled
# ERROR: Could not install packages due to an OSError: [WinError 5] Accesso negato: 'C:\\Users\\naomi\\anaconda3\\Lib\\site-packages\\numpy\\core\\_multiarray_tests.cp38-win_amd64.pyd'
# Consider using the `--user` option or check the permissions.
# ...
