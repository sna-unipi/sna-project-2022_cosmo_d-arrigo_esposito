# %%
import json
import csv

f = open('data_travel_tags.json')
data = json.load(f)
f.close()

# %%
data
# Out:
# {'backoff': 0,
#  'has_more': False,
#  'page': 1,
#  'quota_max': 10000,
#  'quota_remaining': 9999,
#  'total': 0,
#  'items': [{'has_synonyms': False,
#    'is_moderator_only': False,
#    'is_required': False,
#    'count': 1,
#    'name': 'hebrew'},
#   {'has_synonyms': False,
#    'is_moderator_only': False,
#    'is_required': False,
#    'count': 5,
#    'name': 'expired'},
#   {'has_synonyms': False,
#    'is_moderator_only': False,
#    'is_required': False,
#    'count': 1,
#    'name': 'concurrent-h1b'},
#   {'has_synonyms': False,
#    'is_moderator_only': False,
#    'is_required': False,
#    'count': 1,
#    'name': 'housekeeping'},
#   {'has_synonyms': False,
#    'is_moderator_only': False,
#    'is_required': False,
#    'count': 5,
#    'name': 'canadian-permanent-residents'},
#   {'has_synonyms': False,
#    'is_moderator_only': False,
#    'is_required': False,
#    'count': 3,
#    'name': 'tijuana'},
#   {'has_synonyms': False,
# ...

# %%
import pandas as pd

df = pd.DataFrame.from_records(data)

df.to_csv('data22maggio_travel.csv')

# %%
df.tail(5)
# Out:
#     backoff  has_more                                              items  \
# 26        0     False  {'has_synonyms': False, 'is_moderator_only': F...
# 27        0     False  {'has_synonyms': False, 'is_moderator_only': F...
# 28        0     False  {'has_synonyms': False, 'is_moderator_only': F...
# 29        0     False  {'has_synonyms': False, 'is_moderator_only': F...
# 30        0     False  {'has_synonyms': False, 'is_moderator_only': F...
#
#     page  quota_max  quota_remaining  total
# 26     1      10000             9999      0
# 27     1      10000             9999      0
# 28     1      10000             9999      0
# 29     1      10000             9999      0
# 30     1      10000             9999      0
