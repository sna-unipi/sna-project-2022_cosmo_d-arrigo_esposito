# %%
import json
import csv

f = open('data_travel_tags.json')
data = json.load(f)
f.close()

# %%
data
# Out:
# {'backoff': 0,
#  'has_more': False,
#  'page': 1,
#  'quota_max': 10000,
#  'quota_remaining': 9999,
#  'total': 0,
#  'items': [{'has_synonyms': False,
#    'is_moderator_only': False,
#    'is_required': False,
#    'count': 1,
#    'name': 'hebrew'},
#   {'has_synonyms': False,
#    'is_moderator_only': False,
#    'is_required': False,
#    'count': 5,
#    'name': 'expired'},
#   {'has_synonyms': False,
#    'is_moderator_only': False,
#    'is_required': False,
#    'count': 1,
#    'name': 'concurrent-h1b'},
#   {'has_synonyms': False,
#    'is_moderator_only': False,
#    'is_required': False,
#    'count': 1,
#    'name': 'housekeeping'},
#   {'has_synonyms': False,
#    'is_moderator_only': False,
#    'is_required': False,
#    'count': 5,
#    'name': 'canadian-permanent-residents'},
#   {'has_synonyms': False,
#    'is_moderator_only': False,
#    'is_required': False,
#    'count': 3,
#    'name': 'tijuana'},
#   {'has_synonyms': False,
# ...

# %%
import pandas as pd

df = pd.DataFrame.from_records(data)

df.to_csv('data22maggio_travel.csv')

# %%
df
# Out:
#     backoff  has_more                                              items  \
# 0         0     False  {'has_synonyms': False, 'is_moderator_only': F...
# 1         0     False  {'has_synonyms': False, 'is_moderator_only': F...
# 2         0     False  {'has_synonyms': False, 'is_moderator_only': F...
# 3         0     False  {'has_synonyms': False, 'is_moderator_only': F...
# 4         0     False  {'has_synonyms': False, 'is_moderator_only': F...
# 5         0     False  {'has_synonyms': False, 'is_moderator_only': F...
# 6         0     False  {'has_synonyms': False, 'is_moderator_only': F...
# 7         0     False  {'has_synonyms': False, 'is_moderator_only': F...
# 8         0     False  {'has_synonyms': False, 'is_moderator_only': F...
# 9         0     False  {'has_synonyms': False, 'is_moderator_only': F...
# 10        0     False  {'has_synonyms': False, 'is_moderator_only': F...
# 11        0     False  {'has_synonyms': False, 'is_moderator_only': F...
# ...
